# %%
import pandas as pd

# Load the saved CSV file
data = pd.read_csv('processed_data.csv')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import torch
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# Define target and input variables
target_cols = ['meanLineIntensity', 'meanNumPixels15']
input_cols = ['Z', 'Y_Start', 'Wall', 'Overhang', 'Power', 'd_edge', 'd_over', 'd_col', 'd_over_z']
# remove z, lines per layer instead of Y

# Extract features and targets
X = data[input_cols].values
y = data[target_cols].values

# Create a custom Dataset class
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.FloatTensor(X)
        self.y = torch.FloatTensor(y)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# Function to prepare data loaders for a specific fold
def prepare_fold_data(X, y, train_idx, val_idx, batch_size=32):
    # Scale the features
    scaler = MinMaxScaler()
    scaler_y = MinMaxScaler()
    
    if scaler:
        X_train = scaler.fit_transform(X[train_idx])
        X_val = scaler.transform(X[val_idx])
    else:
        X_train = X[train_idx]
        X_val = X[val_idx]
    y_train = scaler_y.fit_transform(y[train_idx])
    y_eval = scaler_y.transform(y[val_idx])
    
    # Create datasets
    train_dataset = CustomDataset(X_train, y_train)
    val_dataset = CustomDataset(X_val, y_eval)
    
    # Create data loaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False
    )
    
    return train_loader, val_loader, scaler, scaler_y

# Set up K-Fold cross-validation
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Store fold indices for later use
fold_indices = []
for train_idx, val_idx in kf.split(X):
    fold_indices.append((train_idx, val_idx))

# %%
import torch.nn as nn
import torch.optim as optim
import tqdm
from tqdm import tqdm
import copy
import matplotlib.pyplot as plt

class ResidualBlock(nn.Module):
    def __init__(self, dim, dropout_rate=0.2):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Linear(dim, dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate),
            nn.Linear(dim, dim),
        )
        self.relu = nn.ReLU()
        
    def forward(self, x):
        residual = x
        out = self.block(x)
        out += residual  # Skip connection
        return self.relu(out)

class MLPRegressor(nn.Module):
    def __init__(self, input_dim=5, hidden_dim=128, num_layers=3, output_dim=2, dropout_rate=0.2):
        super(MLPRegressor, self).__init__()
        
        self.input_layer = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate)
        )
        
        self.residual_layers = nn.ModuleList([
            ResidualBlock(hidden_dim, dropout_rate) 
            for _ in range(num_layers - 1)
        ])
        
        self.output_layer = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        x = self.input_layer(x)
        for layer in self.residual_layers:
            x = layer(x)
        return self.output_layer(x)

def print_model_params(model):
    total_params = 0
    input_params = sum(p.numel() for p in model.input_layer.parameters())
    total_params += input_params
    
    for i, block in enumerate(model.residual_layers):
        block_params = sum(p.numel() for p in block.parameters())
        total_params += block_params
    
    output_params = sum(p.numel() for p in model.output_layer.parameters())
    total_params += output_params
    
    print("-" * 50)
    print(f"Total Parameters: {total_params:,}")

def train_model(model, train_loader, val_loader, num_epochs=1000, patience=50):
    model = model.to(device)
    criterion = nn.L1Loss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

    best_val_loss = float('inf')
    best_model = None
    patience_counter = 0
    
    # Lists to store losses for plotting
    train_losses = []
    val_losses = []
    epochs = []

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * X_batch.size(0)

        train_loss /= len(train_loader.dataset)

        # Validation phase
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)

        val_loss /= len(val_loader.dataset)

        # Store losses for plotting
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        epochs.append(epoch + 1)

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = copy.deepcopy(model)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f'Early stopping triggered at epoch {epoch+1}')
            break

        if (epoch + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.6f}, Val Loss: {val_loss:.6f}')

    return best_model, train_losses, val_losses, epochs

def train_k_fold(X, y, fold_indices, hidden_dim=128, num_layers=3, batch_size=32):
    models = []
    scalers = []
    scalers_y = []
    val_scores = []
    r2_scores_all = []

    for fold, (train_idx, val_idx) in enumerate(fold_indices):
        print(f'\nTraining Fold {fold+1}')

        # Prepare data for this fold
        train_loader, val_loader, scaler, scaler_y = prepare_fold_data(
            X, y, train_idx, val_idx, batch_size
        )

        # Initialize model
        model = MLPRegressor(
            input_dim=X.shape[1],
            hidden_dim=hidden_dim,
            num_layers=num_layers,
            output_dim=y.shape[1]
        )
        
        print_model_params(model)

        # Train model and get loss history
        best_model, train_losses, val_losses, epochs = train_model(
            model,
            train_loader,
            val_loader,
            num_epochs=10000,
            patience=500
        )

        # Plot loss evolution for this fold
        plt.figure(figsize=(10, 6))
        plt.plot(epochs[1:], train_losses[1:], label='Training Loss')
        plt.plot(epochs[1:], val_losses[1:], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title(f'Loss Evolution - Fold {fold+1}')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Store the trained model and scalers
        models.append(best_model)
        scalers.append(scaler)
        scalers_y.append(scaler_y)

        # Calculate validation scores
        mse, r2_scores, predictions, actuals = evaluate_model(best_model, val_loader, scaler_y)
        val_scores.append(mse)
        r2_scores_all.append(r2_scores)
        print(f'Fold {fold+1} Validation MSE: {mse:.4f}')
        print(f'Fold {fold+1} R² scores: {[f"{r2:.4f}" for r2 in r2_scores]}')

    # Calculate and print average metrics
    print("\nCross-validation Results:")
    print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
    r2_scores_all = np.array(r2_scores_all)
    for i, target in enumerate(['meanLineIntensity', 'meanNumPixels15']):
        mean_r2 = np.mean(r2_scores_all[:, i])
        std_r2 = np.std(r2_scores_all[:, i])
        print(f"Average R² ({target}): {mean_r2:.4f} ± {std_r2:.4f}")
    
    return models, scalers, scalers_y, val_scores, r2_scores_all

def evaluate_model(model, data_loader, scaler_y):
    model = model.to(device)
    model.eval()
    criterion = nn.MSELoss()
    total_loss = 0.0

    # Lists to store predictions and actual values
    all_predictions = []
    all_actuals = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            outputs = model(X_batch)

            # Move to CPU and convert to numpy
            outputs_np = outputs.cpu().numpy()
            y_batch_np = y_batch.cpu().numpy()

            # Inverse transform
            outputs_inv = scaler_y.inverse_transform(outputs_np)
            y_batch_inv = scaler_y.inverse_transform(y_batch_np)

            # Compute loss in original scale
            loss = criterion(torch.tensor(outputs_inv), torch.tensor(y_batch_inv))
            total_loss += loss.item() * X_batch.size(0)

            all_predictions.append(outputs_inv)
            all_actuals.append(y_batch_inv)

    # Convert lists to numpy arrays
    predictions = np.vstack(all_predictions)
    actuals = np.vstack(all_actuals)

    # Calculate MSE
    mse = total_loss / len(data_loader.dataset)

    # Calculate R2 for each target
    r2_scores = []
    for i in range(actuals.shape[1]):
        ss_res = np.sum((actuals[:, i] - predictions[:, i]) ** 2)
        ss_tot = np.sum((actuals[:, i] - np.mean(actuals[:, i])) ** 2)
        r2 = 1 - (ss_res / ss_tot)
        r2_scores.append(r2)

    # Create plots
    import matplotlib.pyplot as plt

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    target_names = ['meanLineIntensity', 'meanNumPixels15']

    for i, (ax, target) in enumerate(zip(axes, target_names)):
        # Plot predicted vs actual
        ax.scatter(actuals[:, i], predictions[:, i], alpha=0.5)

        # Plot perfect prediction line
        min_val = min(actuals[:, i].min(), predictions[:, i].min())
        max_val = max(actuals[:, i].max(), predictions[:, i].max())
        ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Prediction')

        # Add labels and title
        ax.set_xlabel('Actual Values')
        ax.set_ylabel('Predicted Values')
        ax.set_title(f'{target}\nR² = {r2_scores[i]:.4f}')
        ax.grid(True)
        ax.legend()

    plt.tight_layout()
    plt.show()

    # Print detailed metrics
    print("\nEvaluation Metrics:")
    print(f"MSE: {mse:.4f}")
    for i, target in enumerate(target_names):
        print(f"R² ({target}): {r2_scores[i]:.4f}")

    return mse, r2_scores, predictions, actuals


# Train the models
models, scalers, scalers_y, val_scores, r2_scores_all = train_k_fold(X, y, fold_indices, 
                                                                     hidden_dim=1024, 
                                                                     num_layers=96,
                                                                     batch_size=128)

print('---'*10)
# Print overall results
print("\nCross-validation Results:")
print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
# Out:
# Training Fold 1
# --------------------------------------------------
# Total Parameters: 199,436,290
# Epoch [10/10000], Train Loss: 0.084761, Val Loss: 0.084256
# Epoch [20/10000], Train Loss: 0.082442, Val Loss: 0.077642
# Epoch [30/10000], Train Loss: 0.081410, Val Loss: 0.078958
# Epoch [40/10000], Train Loss: 0.082446, Val Loss: 0.076800
# Epoch [50/10000], Train Loss: 0.086919, Val Loss: 0.078865
# Epoch [60/10000], Train Loss: 0.078767, Val Loss: 0.076938
# Epoch [70/10000], Train Loss: 0.076659, Val Loss: 0.071939
# Epoch [80/10000], Train Loss: 0.074940, Val Loss: 0.074312
# Epoch [90/10000], Train Loss: 0.073684, Val Loss: 0.073499
# Epoch [100/10000], Train Loss: 0.075226, Val Loss: 0.075825
# Epoch [110/10000], Train Loss: 0.072446, Val Loss: 0.069895
# Epoch [120/10000], Train Loss: 0.073964, Val Loss: 0.074411
# Epoch [130/10000], Train Loss: 0.071990, Val Loss: 0.068679
# Epoch [140/10000], Train Loss: 0.071090, Val Loss: 0.068146
# Epoch [150/10000], Train Loss: 0.072164, Val Loss: 0.072045
# Epoch [160/10000], Train Loss: 0.070011, Val Loss: 0.071287
# Epoch [170/10000], Train Loss: 0.070672, Val Loss: 0.066106
# Epoch [180/10000], Train Loss: 0.071778, Val Loss: 0.071117
# Epoch [190/10000], Train Loss: 0.069805, Val Loss: 0.068121
# Epoch [200/10000], Train Loss: 0.070803, Val Loss: 0.071132
# Epoch [210/10000], Train Loss: 0.070415, Val Loss: 0.067029
# Epoch [220/10000], Train Loss: 0.068334, Val Loss: 0.064595
# Epoch [230/10000], Train Loss: 0.067151, Val Loss: 0.069170
# Epoch [240/10000], Train Loss: 0.066358, Val Loss: 0.065271
# Epoch [250/10000], Train Loss: 0.067080, Val Loss: 0.064026
# Epoch [260/10000], Train Loss: 0.069195, Val Loss: 0.069212
# Epoch [270/10000], Train Loss: 0.065276, Val Loss: 0.065890
# Epoch [280/10000], Train Loss: 0.067847, Val Loss: 0.067076
# Epoch [290/10000], Train Loss: 0.064600, Val Loss: 0.069179
# Epoch [300/10000], Train Loss: 0.065896, Val Loss: 0.064457
# Epoch [310/10000], Train Loss: 0.064008, Val Loss: 0.065810
# Epoch [320/10000], Train Loss: 0.063365, Val Loss: 0.067452
# Epoch [330/10000], Train Loss: 0.063692, Val Loss: 0.065638
# Epoch [340/10000], Train Loss: 0.059512, Val Loss: 0.065304
# Epoch [350/10000], Train Loss: 0.056840, Val Loss: 0.062862
# Epoch [360/10000], Train Loss: 0.056478, Val Loss: 0.063721
# Epoch [370/10000], Train Loss: 0.058285, Val Loss: 0.065024
# Epoch [380/10000], Train Loss: 0.059184, Val Loss: 0.065235
# Epoch [390/10000], Train Loss: 0.055234, Val Loss: 0.061800
# Epoch [400/10000], Train Loss: 0.057517, Val Loss: 0.062214
# Epoch [410/10000], Train Loss: 0.056549, Val Loss: 0.061780
# Epoch [420/10000], Train Loss: 0.055932, Val Loss: 0.062441
# Epoch [430/10000], Train Loss: 0.053771, Val Loss: 0.059957
# Epoch [440/10000], Train Loss: 0.053954, Val Loss: 0.060551
# Epoch [450/10000], Train Loss: 0.054012, Val Loss: 0.064081
# Epoch [460/10000], Train Loss: 0.052254, Val Loss: 0.059013
# Epoch [470/10000], Train Loss: 0.051365, Val Loss: 0.057553
# Epoch [480/10000], Train Loss: 0.052211, Val Loss: 0.066862
# Epoch [490/10000], Train Loss: 0.050891, Val Loss: 0.058394
# Epoch [500/10000], Train Loss: 0.049385, Val Loss: 0.057365
# Epoch [510/10000], Train Loss: 0.049723, Val Loss: 0.062379
# Epoch [520/10000], Train Loss: 0.047522, Val Loss: 0.057310
# Epoch [530/10000], Train Loss: 0.047495, Val Loss: 0.059999
# Epoch [540/10000], Train Loss: 0.048206, Val Loss: 0.058953
# Epoch [550/10000], Train Loss: 0.048576, Val Loss: 0.057992
# Epoch [560/10000], Train Loss: 0.049700, Val Loss: 0.059042
# Epoch [570/10000], Train Loss: 0.046147, Val Loss: 0.056074
# Epoch [580/10000], Train Loss: 0.046080, Val Loss: 0.057100
# Epoch [590/10000], Train Loss: 0.046844, Val Loss: 0.057845
# Epoch [600/10000], Train Loss: 0.044736, Val Loss: 0.055947
# Epoch [610/10000], Train Loss: 0.047593, Val Loss: 0.057109
# Epoch [620/10000], Train Loss: 0.045932, Val Loss: 0.055075
# Epoch [630/10000], Train Loss: 0.052383, Val Loss: 0.058297
# Epoch [640/10000], Train Loss: 0.047349, Val Loss: 0.056585
# Epoch [650/10000], Train Loss: 0.045730, Val Loss: 0.055817
# Epoch [660/10000], Train Loss: 0.045198, Val Loss: 0.057855
# Epoch [670/10000], Train Loss: 0.045334, Val Loss: 0.057444
# Epoch [680/10000], Train Loss: 0.044368, Val Loss: 0.057040
# Epoch [690/10000], Train Loss: 0.044991, Val Loss: 0.057379
# Epoch [700/10000], Train Loss: 0.044013, Val Loss: 0.057966
# Epoch [710/10000], Train Loss: 0.044332, Val Loss: 0.056426
# Epoch [720/10000], Train Loss: 0.044749, Val Loss: 0.058034
# Epoch [730/10000], Train Loss: 0.042799, Val Loss: 0.059396
# Epoch [740/10000], Train Loss: 0.042112, Val Loss: 0.058194
# Epoch [750/10000], Train Loss: 0.047015, Val Loss: 0.060115
# Epoch [760/10000], Train Loss: 0.041504, Val Loss: 0.056765
# Epoch [770/10000], Train Loss: 0.042637, Val Loss: 0.057421
# Epoch [780/10000], Train Loss: 0.040883, Val Loss: 0.055958
# Epoch [790/10000], Train Loss: 0.041866, Val Loss: 0.059162
# Epoch [800/10000], Train Loss: 0.044291, Val Loss: 0.058400
# Epoch [810/10000], Train Loss: 0.041029, Val Loss: 0.057501
# Epoch [820/10000], Train Loss: 0.039972, Val Loss: 0.056621
# Epoch [830/10000], Train Loss: 0.042983, Val Loss: 0.063053
# Epoch [840/10000], Train Loss: 0.051789, Val Loss: 0.061443
# Epoch [850/10000], Train Loss: 0.039989, Val Loss: 0.057226
# Epoch [860/10000], Train Loss: 0.040149, Val Loss: 0.060749
# Epoch [870/10000], Train Loss: 0.039799, Val Loss: 0.056608
# Epoch [880/10000], Train Loss: 0.039341, Val Loss: 0.058121
# Epoch [890/10000], Train Loss: 0.037920, Val Loss: 0.056721
# Epoch [900/10000], Train Loss: 0.039250, Val Loss: 0.058975
# Epoch [910/10000], Train Loss: 0.041101, Val Loss: 0.057299
# Epoch [920/10000], Train Loss: 0.038672, Val Loss: 0.054842
# Epoch [930/10000], Train Loss: 0.037344, Val Loss: 0.055508
# Epoch [940/10000], Train Loss: 0.037821, Val Loss: 0.056867
# Epoch [950/10000], Train Loss: 0.038535, Val Loss: 0.055752
# Epoch [960/10000], Train Loss: 0.037627, Val Loss: 0.058483
# Epoch [970/10000], Train Loss: 0.036744, Val Loss: 0.056397
# Epoch [980/10000], Train Loss: 0.038033, Val Loss: 0.057292
# Epoch [990/10000], Train Loss: 0.037728, Val Loss: 0.057155
# Epoch [1000/10000], Train Loss: 0.038932, Val Loss: 0.064091
# Epoch [1010/10000], Train Loss: 0.038511, Val Loss: 0.057824
# Epoch [1020/10000], Train Loss: 0.035909, Val Loss: 0.059348
# Epoch [1030/10000], Train Loss: 0.035293, Val Loss: 0.055929
# Epoch [1040/10000], Train Loss: 0.034894, Val Loss: 0.058897
# Epoch [1050/10000], Train Loss: 0.036171, Val Loss: 0.058180
# Epoch [1060/10000], Train Loss: 0.035145, Val Loss: 0.057980
# Epoch [1070/10000], Train Loss: 0.037852, Val Loss: 0.059762
# Epoch [1080/10000], Train Loss: 0.036034, Val Loss: 0.057940
# Epoch [1090/10000], Train Loss: 0.035986, Val Loss: 0.056746
# Epoch [1100/10000], Train Loss: 0.037663, Val Loss: 0.059599
# Epoch [1110/10000], Train Loss: 0.036760, Val Loss: 0.056945
# Epoch [1120/10000], Train Loss: 0.034573, Val Loss: 0.056235
# Epoch [1130/10000], Train Loss: 0.032543, Val Loss: 0.055950
# Epoch [1140/10000], Train Loss: 0.032700, Val Loss: 0.054547
# Epoch [1150/10000], Train Loss: 0.032139, Val Loss: 0.056275
# Epoch [1160/10000], Train Loss: 0.032921, Val Loss: 0.055768
# Epoch [1170/10000], Train Loss: 0.034342, Val Loss: 0.057218
# Epoch [1180/10000], Train Loss: 0.035597, Val Loss: 0.057055
# Epoch [1190/10000], Train Loss: 0.034040, Val Loss: 0.058303
# Epoch [1200/10000], Train Loss: 0.035232, Val Loss: 0.059686
# Epoch [1210/10000], Train Loss: 0.031245, Val Loss: 0.056575
# Epoch [1220/10000], Train Loss: 0.035046, Val Loss: 0.056415
# Epoch [1230/10000], Train Loss: 0.034131, Val Loss: 0.055177
# Epoch [1240/10000], Train Loss: 0.034139, Val Loss: 0.056864
# Epoch [1250/10000], Train Loss: 0.033765, Val Loss: 0.059306
# Epoch [1260/10000], Train Loss: 0.030777, Val Loss: 0.057543
# Epoch [1270/10000], Train Loss: 0.030555, Val Loss: 0.058145
# Epoch [1280/10000], Train Loss: 0.031918, Val Loss: 0.058225
# Epoch [1290/10000], Train Loss: 0.032695, Val Loss: 0.057679
# Epoch [1300/10000], Train Loss: 0.032702, Val Loss: 0.055577
# Epoch [1310/10000], Train Loss: 0.030374, Val Loss: 0.057421
# Epoch [1320/10000], Train Loss: 0.030399, Val Loss: 0.056979
# Epoch [1330/10000], Train Loss: 0.032334, Val Loss: 0.056902
# Early stopping triggered at epoch 1337
# Evaluation Metrics:
# MSE: 638999990.6556
# R² (Median_meltLength): 0.7915
# R² (meanNumPixels15): 0.7403
# Fold 1 Validation MSE: 638999990.6556
# Fold 1 R² scores: ['0.7915', '0.7403']
#
# Training Fold 2
# --------------------------------------------------
# Total Parameters: 199,436,290
# Epoch [10/10000], Train Loss: 0.086246, Val Loss: 0.086944
# Epoch [20/10000], Train Loss: 0.085668, Val Loss: 0.084146
# Epoch [30/10000], Train Loss: 0.086063, Val Loss: 0.083171
# Epoch [40/10000], Train Loss: 0.078680, Val Loss: 0.079298
# Epoch [50/10000], Train Loss: 0.079493, Val Loss: 0.077313
# Epoch [60/10000], Train Loss: 0.078139, Val Loss: 0.080162
# Epoch [70/10000], Train Loss: 0.077830, Val Loss: 0.073338
# Epoch [80/10000], Train Loss: 0.074789, Val Loss: 0.075830
# Epoch [90/10000], Train Loss: 0.076501, Val Loss: 0.072448
# Epoch [100/10000], Train Loss: 0.073954, Val Loss: 0.073108
# Epoch [110/10000], Train Loss: 0.071442, Val Loss: 0.071185
# Epoch [120/10000], Train Loss: 0.072783, Val Loss: 0.075817
# Epoch [130/10000], Train Loss: 0.071196, Val Loss: 0.068547
# Epoch [140/10000], Train Loss: 0.068151, Val Loss: 0.070859
# Epoch [150/10000], Train Loss: 0.066065, Val Loss: 0.067066
# Epoch [160/10000], Train Loss: 0.066728, Val Loss: 0.073952
# Epoch [170/10000], Train Loss: 0.061913, Val Loss: 0.064301
# Epoch [180/10000], Train Loss: 0.062970, Val Loss: 0.066798
# Epoch [190/10000], Train Loss: 0.064032, Val Loss: 0.062971
# Epoch [200/10000], Train Loss: 0.060496, Val Loss: 0.063357
# Epoch [210/10000], Train Loss: 0.062180, Val Loss: 0.070850
# Epoch [220/10000], Train Loss: 0.057176, Val Loss: 0.063058
# Epoch [230/10000], Train Loss: 0.056675, Val Loss: 0.062335
# Epoch [240/10000], Train Loss: 0.053468, Val Loss: 0.059309
# Epoch [250/10000], Train Loss: 0.056666, Val Loss: 0.061752
# Epoch [260/10000], Train Loss: 0.055561, Val Loss: 0.058873
# Epoch [270/10000], Train Loss: 0.051629, Val Loss: 0.058178
# Epoch [280/10000], Train Loss: 0.052839, Val Loss: 0.059573
# Epoch [290/10000], Train Loss: 0.050879, Val Loss: 0.060397
# Epoch [300/10000], Train Loss: 0.048987, Val Loss: 0.059874
# Epoch [310/10000], Train Loss: 0.049293, Val Loss: 0.058277
# Epoch [320/10000], Train Loss: 0.049144, Val Loss: 0.058042
# Epoch [330/10000], Train Loss: 0.048654, Val Loss: 0.060778
# Epoch [340/10000], Train Loss: 0.046251, Val Loss: 0.059911
# Epoch [350/10000], Train Loss: 0.047097, Val Loss: 0.058343
# Epoch [360/10000], Train Loss: 0.047962, Val Loss: 0.056194
# Epoch [370/10000], Train Loss: 0.044670, Val Loss: 0.056579
# Epoch [380/10000], Train Loss: 0.043165, Val Loss: 0.055267
# Epoch [390/10000], Train Loss: 0.041560, Val Loss: 0.057830
# Epoch [400/10000], Train Loss: 0.042944, Val Loss: 0.057223
# Epoch [410/10000], Train Loss: 0.041214, Val Loss: 0.057355
# Epoch [420/10000], Train Loss: 0.041492, Val Loss: 0.061384
# Epoch [430/10000], Train Loss: 0.038316, Val Loss: 0.055407
# Epoch [440/10000], Train Loss: 0.045674, Val Loss: 0.061170
# Epoch [450/10000], Train Loss: 0.041812, Val Loss: 0.059750
# Epoch [460/10000], Train Loss: 0.042548, Val Loss: 0.056071
# Epoch [470/10000], Train Loss: 0.043892, Val Loss: 0.057627
# Epoch [480/10000], Train Loss: 0.037354, Val Loss: 0.057373
# Epoch [490/10000], Train Loss: 0.034016, Val Loss: 0.055339
# Epoch [500/10000], Train Loss: 0.036861, Val Loss: 0.055788
# Epoch [510/10000], Train Loss: 0.035062, Val Loss: 0.055742
# Epoch [520/10000], Train Loss: 0.035888, Val Loss: 0.057437
# Epoch [530/10000], Train Loss: 0.034076, Val Loss: 0.056747
# Epoch [540/10000], Train Loss: 0.038689, Val Loss: 0.059174
# Epoch [550/10000], Train Loss: 0.035157, Val Loss: 0.058964
# Epoch [560/10000], Train Loss: 0.035764, Val Loss: 0.054891
# Epoch [570/10000], Train Loss: 0.034285, Val Loss: 0.057042
# Epoch [580/10000], Train Loss: 0.043175, Val Loss: 0.061176
# Epoch [590/10000], Train Loss: 0.037204, Val Loss: 0.055935
# Epoch [600/10000], Train Loss: 0.033318, Val Loss: 0.055251
# Epoch [610/10000], Train Loss: 0.034749, Val Loss: 0.055653
# Epoch [620/10000], Train Loss: 0.034207, Val Loss: 0.054902
# Epoch [630/10000], Train Loss: 0.031701, Val Loss: 0.056575
# Epoch [640/10000], Train Loss: 0.031517, Val Loss: 0.054500
# Epoch [650/10000], Train Loss: 0.032336, Val Loss: 0.056549
# Epoch [660/10000], Train Loss: 0.033118, Val Loss: 0.058413
# Epoch [670/10000], Train Loss: 0.031733, Val Loss: 0.054601
# Epoch [680/10000], Train Loss: 0.031891, Val Loss: 0.059261
# Epoch [690/10000], Train Loss: 0.031966, Val Loss: 0.053694
# Epoch [700/10000], Train Loss: 0.034879, Val Loss: 0.055307
# Epoch [710/10000], Train Loss: 0.032029, Val Loss: 0.057402
# Epoch [720/10000], Train Loss: 0.031141, Val Loss: 0.055723
# Epoch [730/10000], Train Loss: 0.033686, Val Loss: 0.055019
# Epoch [740/10000], Train Loss: 0.030304, Val Loss: 0.056322
# Epoch [750/10000], Train Loss: 0.031382, Val Loss: 0.058813
# Epoch [760/10000], Train Loss: 0.030889, Val Loss: 0.061100
# Epoch [770/10000], Train Loss: 0.033699, Val Loss: 0.054364
# Epoch [780/10000], Train Loss: 0.029299, Val Loss: 0.054429
# Epoch [790/10000], Train Loss: 0.029109, Val Loss: 0.053549
# Epoch [800/10000], Train Loss: 0.029440, Val Loss: 0.057104
# Epoch [810/10000], Train Loss: 0.028379, Val Loss: 0.055385
# Epoch [820/10000], Train Loss: 0.034615, Val Loss: 0.059770
# Epoch [830/10000], Train Loss: 0.029035, Val Loss: 0.058999
# Epoch [840/10000], Train Loss: 0.026558, Val Loss: 0.054315
# Epoch [850/10000], Train Loss: 0.027931, Val Loss: 0.055594
# Epoch [860/10000], Train Loss: 0.028647, Val Loss: 0.055471
# Epoch [870/10000], Train Loss: 0.029563, Val Loss: 0.056609
# Epoch [880/10000], Train Loss: 0.027117, Val Loss: 0.056334
# Epoch [890/10000], Train Loss: 0.029226, Val Loss: 0.055617
# Epoch [900/10000], Train Loss: 0.029052, Val Loss: 0.057483
# Epoch [910/10000], Train Loss: 0.026727, Val Loss: 0.055775
# Epoch [920/10000], Train Loss: 0.028190, Val Loss: 0.055966
# Epoch [930/10000], Train Loss: 0.028663, Val Loss: 0.055367
# Epoch [940/10000], Train Loss: 0.025234, Val Loss: 0.055132
# Epoch [950/10000], Train Loss: 0.025812, Val Loss: 0.058191
# Epoch [960/10000], Train Loss: 0.027239, Val Loss: 0.056797
# Epoch [970/10000], Train Loss: 0.030581, Val Loss: 0.054660
# Epoch [980/10000], Train Loss: 0.025514, Val Loss: 0.055085
# Epoch [990/10000], Train Loss: 0.026561, Val Loss: 0.056144
# Epoch [1000/10000], Train Loss: 0.027100, Val Loss: 0.054193
# Epoch [1010/10000], Train Loss: 0.026669, Val Loss: 0.054805
# Epoch [1020/10000], Train Loss: 0.028308, Val Loss: 0.057100
# Epoch [1030/10000], Train Loss: 0.027671, Val Loss: 0.056856
# Epoch [1040/10000], Train Loss: 0.027033, Val Loss: 0.059017
# Epoch [1050/10000], Train Loss: 0.026798, Val Loss: 0.056023
# Epoch [1060/10000], Train Loss: 0.024943, Val Loss: 0.054339
# Epoch [1070/10000], Train Loss: 0.024030, Val Loss: 0.054573
# Epoch [1080/10000], Train Loss: 0.029292, Val Loss: 0.054115
# Epoch [1090/10000], Train Loss: 0.027027, Val Loss: 0.053442
# Epoch [1100/10000], Train Loss: 0.028102, Val Loss: 0.054972
# Epoch [1110/10000], Train Loss: 0.026633, Val Loss: 0.055377
# Epoch [1120/10000], Train Loss: 0.025526, Val Loss: 0.053969
# Epoch [1130/10000], Train Loss: 0.026971, Val Loss: 0.057528
# Epoch [1140/10000], Train Loss: 0.022143, Val Loss: 0.053522
# Epoch [1150/10000], Train Loss: 0.027770, Val Loss: 0.055259
# Epoch [1160/10000], Train Loss: 0.028224, Val Loss: 0.054357
# Epoch [1170/10000], Train Loss: 0.026737, Val Loss: 0.054890
# Epoch [1180/10000], Train Loss: 0.025264, Val Loss: 0.052829
# Epoch [1190/10000], Train Loss: 0.025472, Val Loss: 0.054473
# Epoch [1200/10000], Train Loss: 0.024798, Val Loss: 0.054219
# Epoch [1210/10000], Train Loss: 0.025174, Val Loss: 0.054967
# Epoch [1220/10000], Train Loss: 0.023478, Val Loss: 0.053657
# Epoch [1230/10000], Train Loss: 0.025847, Val Loss: 0.053773
# Epoch [1240/10000], Train Loss: 0.022599, Val Loss: 0.054058
# Epoch [1250/10000], Train Loss: 0.025311, Val Loss: 0.054507
# Epoch [1260/10000], Train Loss: 0.026378, Val Loss: 0.054575
# Epoch [1270/10000], Train Loss: 0.025275, Val Loss: 0.055625
# Epoch [1280/10000], Train Loss: 0.023581, Val Loss: 0.056876
# Epoch [1290/10000], Train Loss: 0.023532, Val Loss: 0.053761
# Epoch [1300/10000], Train Loss: 0.024189, Val Loss: 0.054699
# Epoch [1310/10000], Train Loss: 0.027407, Val Loss: 0.053752
# Epoch [1320/10000], Train Loss: 0.023859, Val Loss: 0.054118
# Epoch [1330/10000], Train Loss: 0.029123, Val Loss: 0.053916
# Epoch [1340/10000], Train Loss: 0.022026, Val Loss: 0.054979
# Epoch [1350/10000], Train Loss: 0.023348, Val Loss: 0.055393
# Epoch [1360/10000], Train Loss: 0.021149, Val Loss: 0.056286
# Epoch [1370/10000], Train Loss: 0.022551, Val Loss: 0.053505
# Epoch [1380/10000], Train Loss: 0.024860, Val Loss: 0.054641
# Epoch [1390/10000], Train Loss: 0.025595, Val Loss: 0.056499
# Epoch [1400/10000], Train Loss: 0.021827, Val Loss: 0.056124
# Epoch [1410/10000], Train Loss: 0.023185, Val Loss: 0.054736
# Epoch [1420/10000], Train Loss: 0.023066, Val Loss: 0.053139
# Epoch [1430/10000], Train Loss: 0.037748, Val Loss: 0.059999
# Epoch [1440/10000], Train Loss: 0.025710, Val Loss: 0.056805
# Epoch [1450/10000], Train Loss: 0.024792, Val Loss: 0.054009
# Epoch [1460/10000], Train Loss: 0.023649, Val Loss: 0.055534
# Epoch [1470/10000], Train Loss: 0.023111, Val Loss: 0.055098
# Epoch [1480/10000], Train Loss: 0.021772, Val Loss: 0.056342
# Epoch [1490/10000], Train Loss: 0.022626, Val Loss: 0.054009
# Epoch [1500/10000], Train Loss: 0.022166, Val Loss: 0.056630
# Epoch [1510/10000], Train Loss: 0.025567, Val Loss: 0.055698
# Epoch [1520/10000], Train Loss: 0.026643, Val Loss: 0.057851
# Epoch [1530/10000], Train Loss: 0.033537, Val Loss: 0.060463
# Epoch [1540/10000], Train Loss: 0.024125, Val Loss: 0.054127
# Epoch [1550/10000], Train Loss: 0.081542, Val Loss: 0.073297
# Epoch [1560/10000], Train Loss: 0.064347, Val Loss: 0.065756
# Epoch [1570/10000], Train Loss: 0.056252, Val Loss: 0.060538
# Epoch [1580/10000], Train Loss: 0.053605, Val Loss: 0.062772
# Epoch [1590/10000], Train Loss: 0.050817, Val Loss: 0.064392
# Epoch [1600/10000], Train Loss: 0.049381, Val Loss: 0.056679
# Epoch [1610/10000], Train Loss: 0.046167, Val Loss: 0.055031
# Epoch [1620/10000], Train Loss: 0.046897, Val Loss: 0.060475
# Epoch [1630/10000], Train Loss: 0.049148, Val Loss: 0.061854
# Epoch [1640/10000], Train Loss: 0.039827, Val Loss: 0.054565
# Epoch [1650/10000], Train Loss: 0.041436, Val Loss: 0.057649
# Epoch [1660/10000], Train Loss: 0.041480, Val Loss: 0.055262
# Epoch [1670/10000], Train Loss: 0.043868, Val Loss: 0.057968
# Epoch [1680/10000], Train Loss: 0.039711, Val Loss: 0.055843
# Epoch [1690/10000], Train Loss: 0.036602, Val Loss: 0.059428
# Epoch [1700/10000], Train Loss: 0.037488, Val Loss: 0.064160
# Epoch [1710/10000], Train Loss: 0.037976, Val Loss: 0.056100
# Epoch [1720/10000], Train Loss: 0.037433, Val Loss: 0.057566
# Epoch [1730/10000], Train Loss: 0.036697, Val Loss: 0.056094
# Epoch [1740/10000], Train Loss: 0.035662, Val Loss: 0.053138
# Epoch [1750/10000], Train Loss: 0.037407, Val Loss: 0.056223
# Epoch [1760/10000], Train Loss: 0.042815, Val Loss: 0.055493
# Epoch [1770/10000], Train Loss: 0.035286, Val Loss: 0.056227
# Epoch [1780/10000], Train Loss: 0.034153, Val Loss: 0.057652
# Epoch [1790/10000], Train Loss: 0.036417, Val Loss: 0.055514
# Epoch [1800/10000], Train Loss: 0.032375, Val Loss: 0.054252
# Epoch [1810/10000], Train Loss: 0.037599, Val Loss: 0.054140
# Epoch [1820/10000], Train Loss: 0.031136, Val Loss: 0.054626
# Epoch [1830/10000], Train Loss: 0.037906, Val Loss: 0.055030
# Epoch [1840/10000], Train Loss: 0.036958, Val Loss: 0.058306
# Epoch [1850/10000], Train Loss: 0.032506, Val Loss: 0.052196
# Epoch [1860/10000], Train Loss: 0.037408, Val Loss: 0.053680
# Epoch [1870/10000], Train Loss: 0.033194, Val Loss: 0.058090
# Epoch [1880/10000], Train Loss: 0.034860, Val Loss: 0.054454
# Epoch [1890/10000], Train Loss: 0.031101, Val Loss: 0.056462
# Epoch [1900/10000], Train Loss: 0.030375, Val Loss: 0.057162
# Epoch [1910/10000], Train Loss: 0.033613, Val Loss: 0.055524
# Epoch [1920/10000], Train Loss: 0.034327, Val Loss: 0.059287
# Epoch [1930/10000], Train Loss: 0.038215, Val Loss: 0.059603
# Epoch [1940/10000], Train Loss: 0.030623, Val Loss: 0.055197
# Epoch [1950/10000], Train Loss: 0.028998, Val Loss: 0.056233
# Epoch [1960/10000], Train Loss: 0.030188, Val Loss: 0.054709
# Epoch [1970/10000], Train Loss: 0.028397, Val Loss: 0.057108
# Epoch [1980/10000], Train Loss: 0.028334, Val Loss: 0.055850
# Epoch [1990/10000], Train Loss: 0.027576, Val Loss: 0.056034
# Epoch [2000/10000], Train Loss: 0.032365, Val Loss: 0.056065
# Epoch [2010/10000], Train Loss: 0.031596, Val Loss: 0.055764
# Epoch [2020/10000], Train Loss: 0.030768, Val Loss: 0.053969
# Epoch [2030/10000], Train Loss: 0.035779, Val Loss: 0.057105
# Epoch [2040/10000], Train Loss: 0.028902, Val Loss: 0.055233
# Epoch [2050/10000], Train Loss: 0.031011, Val Loss: 0.054941
# Epoch [2060/10000], Train Loss: 0.033458, Val Loss: 0.055699
# Epoch [2070/10000], Train Loss: 0.028194, Val Loss: 0.053765
# Epoch [2080/10000], Train Loss: 0.040883, Val Loss: 0.060237
# Epoch [2090/10000], Train Loss: 0.026874, Val Loss: 0.055374
# Epoch [2100/10000], Train Loss: 0.027927, Val Loss: 0.054374
# Epoch [2110/10000], Train Loss: 0.037033, Val Loss: 0.067642
# Epoch [2120/10000], Train Loss: 0.029144, Val Loss: 0.056582
# Epoch [2130/10000], Train Loss: 0.028277, Val Loss: 0.057044
# Epoch [2140/10000], Train Loss: 0.029783, Val Loss: 0.054971
# Epoch [2150/10000], Train Loss: 0.024199, Val Loss: 0.055286
# Epoch [2160/10000], Train Loss: 0.031535, Val Loss: 0.056996
# Epoch [2170/10000], Train Loss: 0.027396, Val Loss: 0.056069
# Epoch [2180/10000], Train Loss: 0.026200, Val Loss: 0.058004
# Epoch [2190/10000], Train Loss: 0.031415, Val Loss: 0.061764
# Epoch [2200/10000], Train Loss: 0.028688, Val Loss: 0.053708
# Epoch [2210/10000], Train Loss: 0.025172, Val Loss: 0.057523
# Epoch [2220/10000], Train Loss: 0.026961, Val Loss: 0.057169
# Epoch [2230/10000], Train Loss: 0.040938, Val Loss: 0.055434
# Epoch [2240/10000], Train Loss: 0.032040, Val Loss: 0.053905
# Epoch [2250/10000], Train Loss: 0.029762, Val Loss: 0.054705
# Epoch [2260/10000], Train Loss: 0.030818, Val Loss: 0.053641
# Epoch [2270/10000], Train Loss: 0.029090, Val Loss: 0.053929
# Epoch [2280/10000], Train Loss: 0.033607, Val Loss: 0.056597
# Epoch [2290/10000], Train Loss: 0.028123, Val Loss: 0.055276
# Epoch [2300/10000], Train Loss: 0.028922, Val Loss: 0.054408
# Epoch [2310/10000], Train Loss: 0.031055, Val Loss: 0.053328
# Epoch [2320/10000], Train Loss: 0.027671, Val Loss: 0.055376
# Epoch [2330/10000], Train Loss: 0.027409, Val Loss: 0.053909
# Epoch [2340/10000], Train Loss: 0.026964, Val Loss: 0.056266
# Epoch [2350/10000], Train Loss: 0.031994, Val Loss: 0.056138
# Epoch [2360/10000], Train Loss: 0.035656, Val Loss: 0.057230
# Epoch [2370/10000], Train Loss: 0.029580, Val Loss: 0.055624
# Epoch [2380/10000], Train Loss: 0.024339, Val Loss: 0.053929
# Epoch [2390/10000], Train Loss: 0.029375, Val Loss: 0.058762
# Epoch [2400/10000], Train Loss: 0.024650, Val Loss: 0.055154
# Epoch [2410/10000], Train Loss: 0.022969, Val Loss: 0.053157
# Epoch [2420/10000], Train Loss: 0.023880, Val Loss: 0.057035
# Epoch [2430/10000], Train Loss: 0.027108, Val Loss: 0.056681
# Epoch [2440/10000], Train Loss: 0.021983, Val Loss: 0.054617
# Epoch [2450/10000], Train Loss: 0.030513, Val Loss: 0.053426
# Epoch [2460/10000], Train Loss: 0.023693, Val Loss: 0.053139
# Epoch [2470/10000], Train Loss: 0.052342, Val Loss: 0.064387
# Epoch [2480/10000], Train Loss: 0.025082, Val Loss: 0.055161
# Epoch [2490/10000], Train Loss: 0.022541, Val Loss: 0.054341
# Epoch [2500/10000], Train Loss: 0.024292, Val Loss: 0.055464
# Epoch [2510/10000], Train Loss: 0.021742, Val Loss: 0.054516
# Epoch [2520/10000], Train Loss: 0.021063, Val Loss: 0.057766
# Epoch [2530/10000], Train Loss: 0.027499, Val Loss: 0.056085
# Epoch [2540/10000], Train Loss: 0.024370, Val Loss: 0.054975
# Epoch [2550/10000], Train Loss: 0.031473, Val Loss: 0.071456
# Epoch [2560/10000], Train Loss: 0.024297, Val Loss: 0.054255
# Epoch [2570/10000], Train Loss: 0.025924, Val Loss: 0.056388
# Epoch [2580/10000], Train Loss: 0.021746, Val Loss: 0.055080
# Epoch [2590/10000], Train Loss: 0.029514, Val Loss: 0.058489
# Epoch [2600/10000], Train Loss: 0.028076, Val Loss: 0.056144
# Epoch [2610/10000], Train Loss: 0.022408, Val Loss: 0.055383
# Epoch [2620/10000], Train Loss: 0.021833, Val Loss: 0.054402
# Epoch [2630/10000], Train Loss: 0.022529, Val Loss: 0.055155
# Epoch [2640/10000], Train Loss: 0.024332, Val Loss: 0.055596
# Epoch [2650/10000], Train Loss: 0.024210, Val Loss: 0.057988
# Epoch [2660/10000], Train Loss: 0.023944, Val Loss: 0.056713
# Epoch [2670/10000], Train Loss: 0.023356, Val Loss: 0.054310
# Epoch [2680/10000], Train Loss: 0.023155, Val Loss: 0.057349
# Epoch [2690/10000], Train Loss: 0.030673, Val Loss: 0.057419
# Epoch [2700/10000], Train Loss: 0.022030, Val Loss: 0.054646
# Epoch [2710/10000], Train Loss: 0.029003, Val Loss: 0.054791
# Epoch [2720/10000], Train Loss: 0.021199, Val Loss: 0.055822
# Epoch [2730/10000], Train Loss: 0.021964, Val Loss: 0.054728
# Early stopping triggered at epoch 2737
# Evaluation Metrics:
# MSE: 590824452.2314
# R² (Median_meltLength): 0.8097
# R² (meanNumPixels15): 0.7494
# Fold 2 Validation MSE: 590824452.2314
# Fold 2 R² scores: ['0.8097', '0.7494']
#
# Training Fold 3
# --------------------------------------------------
# Total Parameters: 199,436,290
# Epoch [10/10000], Train Loss: 0.087572, Val Loss: 0.086760
# Epoch [20/10000], Train Loss: 0.084720, Val Loss: 0.090132
# Epoch [30/10000], Train Loss: 0.082532, Val Loss: 0.085075
# Epoch [40/10000], Train Loss: 0.079463, Val Loss: 0.079600
# Epoch [50/10000], Train Loss: 0.079902, Val Loss: 0.083547
# Epoch [60/10000], Train Loss: 0.076705, Val Loss: 0.077147
# Epoch [70/10000], Train Loss: 0.075120, Val Loss: 0.078145
# Epoch [80/10000], Train Loss: 0.072222, Val Loss: 0.076194
# Epoch [90/10000], Train Loss: 0.071467, Val Loss: 0.076215
# Epoch [100/10000], Train Loss: 0.072426, Val Loss: 0.077510
# Epoch [110/10000], Train Loss: 0.070128, Val Loss: 0.074313
# Epoch [120/10000], Train Loss: 0.072055, Val Loss: 0.079643
# Epoch [130/10000], Train Loss: 0.073170, Val Loss: 0.077078
# Epoch [140/10000], Train Loss: 0.071209, Val Loss: 0.074215
# Epoch [150/10000], Train Loss: 0.068099, Val Loss: 0.079567
# Epoch [160/10000], Train Loss: 0.069007, Val Loss: 0.074148
# Epoch [170/10000], Train Loss: 0.070036, Val Loss: 0.076534
# Epoch [180/10000], Train Loss: 0.067188, Val Loss: 0.078020
# Epoch [190/10000], Train Loss: 0.068152, Val Loss: 0.073743
# Epoch [200/10000], Train Loss: 0.070914, Val Loss: 0.071629
# Epoch [210/10000], Train Loss: 0.066826, Val Loss: 0.072600
# Epoch [220/10000], Train Loss: 0.061914, Val Loss: 0.071074
# Epoch [230/10000], Train Loss: 0.062533, Val Loss: 0.069410
# Epoch [240/10000], Train Loss: 0.060635, Val Loss: 0.070475
# Epoch [250/10000], Train Loss: 0.060423, Val Loss: 0.067412
# Epoch [260/10000], Train Loss: 0.061654, Val Loss: 0.072318
# Epoch [270/10000], Train Loss: 0.057942, Val Loss: 0.066282
# Epoch [280/10000], Train Loss: 0.058298, Val Loss: 0.069658
# Epoch [290/10000], Train Loss: 0.060927, Val Loss: 0.069965
# Epoch [300/10000], Train Loss: 0.057553, Val Loss: 0.075219
# Epoch [310/10000], Train Loss: 0.056969, Val Loss: 0.070707
# Epoch [320/10000], Train Loss: 0.051328, Val Loss: 0.065356
# Epoch [330/10000], Train Loss: 0.053886, Val Loss: 0.067995
# Epoch [340/10000], Train Loss: 0.051057, Val Loss: 0.063555
# Epoch [350/10000], Train Loss: 0.053604, Val Loss: 0.068954
# Epoch [360/10000], Train Loss: 0.049964, Val Loss: 0.067183
# Epoch [370/10000], Train Loss: 0.050297, Val Loss: 0.063722
# Epoch [380/10000], Train Loss: 0.050729, Val Loss: 0.064070
# Epoch [390/10000], Train Loss: 0.051216, Val Loss: 0.063818
# Epoch [400/10000], Train Loss: 0.049174, Val Loss: 0.065350
# Epoch [410/10000], Train Loss: 0.048538, Val Loss: 0.060235
# Epoch [420/10000], Train Loss: 0.051701, Val Loss: 0.066601
# Epoch [430/10000], Train Loss: 0.050554, Val Loss: 0.063507
# Epoch [440/10000], Train Loss: 0.048083, Val Loss: 0.062076
# Epoch [450/10000], Train Loss: 0.045762, Val Loss: 0.060215
# Epoch [460/10000], Train Loss: 0.048595, Val Loss: 0.062404
# Epoch [470/10000], Train Loss: 0.049063, Val Loss: 0.060591
# Epoch [480/10000], Train Loss: 0.047676, Val Loss: 0.058894
# Epoch [490/10000], Train Loss: 0.049100, Val Loss: 0.065380
# Epoch [500/10000], Train Loss: 0.045142, Val Loss: 0.062861
# Epoch [510/10000], Train Loss: 0.048629, Val Loss: 0.060836
# Epoch [520/10000], Train Loss: 0.045463, Val Loss: 0.063184
# Epoch [530/10000], Train Loss: 0.047301, Val Loss: 0.060433
# Epoch [540/10000], Train Loss: 0.044125, Val Loss: 0.059393
# Epoch [550/10000], Train Loss: 0.047434, Val Loss: 0.064711
# Epoch [560/10000], Train Loss: 0.044529, Val Loss: 0.062383
# Epoch [570/10000], Train Loss: 0.046914, Val Loss: 0.062688
# Epoch [580/10000], Train Loss: 0.048465, Val Loss: 0.060630
# Epoch [590/10000], Train Loss: 0.043211, Val Loss: 0.059549
# Epoch [600/10000], Train Loss: 0.045490, Val Loss: 0.064654
# Epoch [610/10000], Train Loss: 0.048439, Val Loss: 0.061397
# Epoch [620/10000], Train Loss: 0.043205, Val Loss: 0.060889
# Epoch [630/10000], Train Loss: 0.042989, Val Loss: 0.062173
# Epoch [640/10000], Train Loss: 0.044899, Val Loss: 0.063005
# Epoch [650/10000], Train Loss: 0.042140, Val Loss: 0.060676
# Epoch [660/10000], Train Loss: 0.046392, Val Loss: 0.065604
# Epoch [670/10000], Train Loss: 0.049479, Val Loss: 0.063082
# Epoch [680/10000], Train Loss: 0.043602, Val Loss: 0.059782
# Epoch [690/10000], Train Loss: 0.043217, Val Loss: 0.063330
# Epoch [700/10000], Train Loss: 0.044788, Val Loss: 0.063952
# Epoch [710/10000], Train Loss: 0.046255, Val Loss: 0.060651
# Epoch [720/10000], Train Loss: 0.042515, Val Loss: 0.060521
# Epoch [730/10000], Train Loss: 0.040052, Val Loss: 0.060905
# Epoch [740/10000], Train Loss: 0.043352, Val Loss: 0.063873
# Epoch [750/10000], Train Loss: 0.046075, Val Loss: 0.058893
# Epoch [760/10000], Train Loss: 0.042214, Val Loss: 0.063229
# Epoch [770/10000], Train Loss: 0.041475, Val Loss: 0.060840
# Epoch [780/10000], Train Loss: 0.041947, Val Loss: 0.061222
# Epoch [790/10000], Train Loss: 0.040592, Val Loss: 0.062511
# Epoch [800/10000], Train Loss: 0.037522, Val Loss: 0.060033
# Epoch [810/10000], Train Loss: 0.040677, Val Loss: 0.059808
# Epoch [820/10000], Train Loss: 0.038332, Val Loss: 0.058617
# Epoch [830/10000], Train Loss: 0.037745, Val Loss: 0.059947
# Epoch [840/10000], Train Loss: 0.044281, Val Loss: 0.064087
# Epoch [850/10000], Train Loss: 0.039650, Val Loss: 0.060157
# Epoch [860/10000], Train Loss: 0.040495, Val Loss: 0.059470
# Epoch [870/10000], Train Loss: 0.037727, Val Loss: 0.059156
# Epoch [880/10000], Train Loss: 0.037833, Val Loss: 0.058907
# Epoch [890/10000], Train Loss: 0.037543, Val Loss: 0.061073
# Epoch [900/10000], Train Loss: 0.041827, Val Loss: 0.057827
# Epoch [910/10000], Train Loss: 0.038726, Val Loss: 0.063642
# Epoch [920/10000], Train Loss: 0.040593, Val Loss: 0.064147
# Epoch [930/10000], Train Loss: 0.037964, Val Loss: 0.062370
# Epoch [940/10000], Train Loss: 0.036929, Val Loss: 0.060211
# Epoch [950/10000], Train Loss: 0.036636, Val Loss: 0.060178
# Epoch [960/10000], Train Loss: 0.037271, Val Loss: 0.061278
# Epoch [970/10000], Train Loss: 0.035711, Val Loss: 0.057446
# Epoch [980/10000], Train Loss: 0.034157, Val Loss: 0.063233
# Epoch [990/10000], Train Loss: 0.034504, Val Loss: 0.057218
# Epoch [1000/10000], Train Loss: 0.036003, Val Loss: 0.061974
# Epoch [1010/10000], Train Loss: 0.032830, Val Loss: 0.059615
# Epoch [1020/10000], Train Loss: 0.038640, Val Loss: 0.062967
# Epoch [1030/10000], Train Loss: 0.034098, Val Loss: 0.058241
# Epoch [1040/10000], Train Loss: 0.036749, Val Loss: 0.059167
# Epoch [1050/10000], Train Loss: 0.034679, Val Loss: 0.062272
# Epoch [1060/10000], Train Loss: 0.035349, Val Loss: 0.057360
# Epoch [1070/10000], Train Loss: 0.032429, Val Loss: 0.058341
# Epoch [1080/10000], Train Loss: 0.035713, Val Loss: 0.057824
# Epoch [1090/10000], Train Loss: 0.033132, Val Loss: 0.059318
# Epoch [1100/10000], Train Loss: 0.036949, Val Loss: 0.060235
# Epoch [1110/10000], Train Loss: 0.032591, Val Loss: 0.058461
# Epoch [1120/10000], Train Loss: 0.033547, Val Loss: 0.060049
# Epoch [1130/10000], Train Loss: 0.034268, Val Loss: 0.060244
# Epoch [1140/10000], Train Loss: 0.034747, Val Loss: 0.058895
# Epoch [1150/10000], Train Loss: 0.036838, Val Loss: 0.057250
# Epoch [1160/10000], Train Loss: 0.031697, Val Loss: 0.059702
# Epoch [1170/10000], Train Loss: 0.034673, Val Loss: 0.062023
# Epoch [1180/10000], Train Loss: 0.032808, Val Loss: 0.059118
# Epoch [1190/10000], Train Loss: 0.032803, Val Loss: 0.057568
# Epoch [1200/10000], Train Loss: 0.033336, Val Loss: 0.059651
# Epoch [1210/10000], Train Loss: 0.029866, Val Loss: 0.058214
# Epoch [1220/10000], Train Loss: 0.030945, Val Loss: 0.061180
# Epoch [1230/10000], Train Loss: 0.033947, Val Loss: 0.060207
# Epoch [1240/10000], Train Loss: 0.039423, Val Loss: 0.064142
# Epoch [1250/10000], Train Loss: 0.029561, Val Loss: 0.060775
# Epoch [1260/10000], Train Loss: 0.032904, Val Loss: 0.063579
# Epoch [1270/10000], Train Loss: 0.031727, Val Loss: 0.058603
# Epoch [1280/10000], Train Loss: 0.033016, Val Loss: 0.060589
# Epoch [1290/10000], Train Loss: 0.030851, Val Loss: 0.057767
# Epoch [1300/10000], Train Loss: 0.034597, Val Loss: 0.058683
# Epoch [1310/10000], Train Loss: 0.034938, Val Loss: 0.057470
# Epoch [1320/10000], Train Loss: 0.029243, Val Loss: 0.062310
# Epoch [1330/10000], Train Loss: 0.033402, Val Loss: 0.059682
# Epoch [1340/10000], Train Loss: 0.032427, Val Loss: 0.058616
# Epoch [1350/10000], Train Loss: 0.032611, Val Loss: 0.062781
# Epoch [1360/10000], Train Loss: 0.032442, Val Loss: 0.057142
# Epoch [1370/10000], Train Loss: 0.034611, Val Loss: 0.058372
# Epoch [1380/10000], Train Loss: 0.030366, Val Loss: 0.058947
# Epoch [1390/10000], Train Loss: 0.029710, Val Loss: 0.059187
# Epoch [1400/10000], Train Loss: 0.034089, Val Loss: 0.063636
# Epoch [1410/10000], Train Loss: 0.032049, Val Loss: 0.057575
# Epoch [1420/10000], Train Loss: 0.028888, Val Loss: 0.059297
# Epoch [1430/10000], Train Loss: 0.029000, Val Loss: 0.058754
# Epoch [1440/10000], Train Loss: 0.029369, Val Loss: 0.061589
# Epoch [1450/10000], Train Loss: 0.032386, Val Loss: 0.059829
# Epoch [1460/10000], Train Loss: 0.030860, Val Loss: 0.060630
# Early stopping triggered at epoch 1462
# Evaluation Metrics:
# MSE: 733526735.5580
# R² (Median_meltLength): 0.7981
# R² (meanNumPixels15): 0.7314
# Fold 3 Validation MSE: 733526735.5580
# Fold 3 R² scores: ['0.7981', '0.7314']
#
# Training Fold 4
# --------------------------------------------------
# Total Parameters: 199,436,290
# Epoch [10/10000], Train Loss: 0.086585, Val Loss: 0.087240
# Epoch [20/10000], Train Loss: 0.084776, Val Loss: 0.087253
# Epoch [30/10000], Train Loss: 0.080461, Val Loss: 0.084628
# Epoch [40/10000], Train Loss: 0.078804, Val Loss: 0.089069
# Epoch [50/10000], Train Loss: 0.076315, Val Loss: 0.082799
# Epoch [60/10000], Train Loss: 0.076286, Val Loss: 0.085334
# Epoch [70/10000], Train Loss: 0.072724, Val Loss: 0.086162
# Epoch [80/10000], Train Loss: 0.073009, Val Loss: 0.079526
# Epoch [90/10000], Train Loss: 0.069288, Val Loss: 0.074928
# Epoch [100/10000], Train Loss: 0.072997, Val Loss: 0.077972
# Epoch [110/10000], Train Loss: 0.068395, Val Loss: 0.074334
# Epoch [120/10000], Train Loss: 0.067607, Val Loss: 0.073699
# Epoch [130/10000], Train Loss: 0.068359, Val Loss: 0.074189
# Epoch [140/10000], Train Loss: 0.066759, Val Loss: 0.072757
# Epoch [150/10000], Train Loss: 0.064506, Val Loss: 0.069889
# Epoch [160/10000], Train Loss: 0.066220, Val Loss: 0.071219
# Epoch [170/10000], Train Loss: 0.065796, Val Loss: 0.071848
# Epoch [180/10000], Train Loss: 0.061038, Val Loss: 0.067577
# Epoch [190/10000], Train Loss: 0.059492, Val Loss: 0.068380
# Epoch [200/10000], Train Loss: 0.059253, Val Loss: 0.067386
# Epoch [210/10000], Train Loss: 0.059105, Val Loss: 0.068386
# Epoch [220/10000], Train Loss: 0.060106, Val Loss: 0.069184
# Epoch [230/10000], Train Loss: 0.061130, Val Loss: 0.067984
# Epoch [240/10000], Train Loss: 0.059922, Val Loss: 0.063756
# Epoch [250/10000], Train Loss: 0.053146, Val Loss: 0.061811
# Epoch [260/10000], Train Loss: 0.054801, Val Loss: 0.065117
# Epoch [270/10000], Train Loss: 0.054136, Val Loss: 0.063194
# Epoch [280/10000], Train Loss: 0.051583, Val Loss: 0.063609
# Epoch [290/10000], Train Loss: 0.052071, Val Loss: 0.062874
# Epoch [300/10000], Train Loss: 0.051046, Val Loss: 0.062015
# Epoch [310/10000], Train Loss: 0.050675, Val Loss: 0.057833
# Epoch [320/10000], Train Loss: 0.050313, Val Loss: 0.059839
# Epoch [330/10000], Train Loss: 0.049924, Val Loss: 0.064685
# Epoch [340/10000], Train Loss: 0.049816, Val Loss: 0.060596
# Epoch [350/10000], Train Loss: 0.051260, Val Loss: 0.060163
# Epoch [360/10000], Train Loss: 0.047922, Val Loss: 0.057534
# Epoch [370/10000], Train Loss: 0.045665, Val Loss: 0.059268
# Epoch [380/10000], Train Loss: 0.046054, Val Loss: 0.057109
# Epoch [390/10000], Train Loss: 0.044759, Val Loss: 0.055479
# Epoch [400/10000], Train Loss: 0.042894, Val Loss: 0.056455
# Epoch [410/10000], Train Loss: 0.042669, Val Loss: 0.054755
# Epoch [420/10000], Train Loss: 0.042387, Val Loss: 0.057405
# Epoch [430/10000], Train Loss: 0.042461, Val Loss: 0.055977
# Epoch [440/10000], Train Loss: 0.042706, Val Loss: 0.054373
# Epoch [450/10000], Train Loss: 0.043612, Val Loss: 0.056611
# Epoch [460/10000], Train Loss: 0.042015, Val Loss: 0.059419
# Epoch [470/10000], Train Loss: 0.040332, Val Loss: 0.055361
# Epoch [480/10000], Train Loss: 0.041396, Val Loss: 0.054781
# Epoch [490/10000], Train Loss: 0.039292, Val Loss: 0.053177
# Epoch [500/10000], Train Loss: 0.038084, Val Loss: 0.054638
# Epoch [510/10000], Train Loss: 0.038597, Val Loss: 0.055493
# Epoch [520/10000], Train Loss: 0.036934, Val Loss: 0.055617
# Epoch [530/10000], Train Loss: 0.046840, Val Loss: 0.059952
# Epoch [540/10000], Train Loss: 0.036392, Val Loss: 0.055083
# Epoch [550/10000], Train Loss: 0.039055, Val Loss: 0.056352
# Epoch [560/10000], Train Loss: 0.037067, Val Loss: 0.057056
# Epoch [570/10000], Train Loss: 0.036571, Val Loss: 0.055212
# Epoch [580/10000], Train Loss: 0.032741, Val Loss: 0.053348
# Epoch [590/10000], Train Loss: 0.035970, Val Loss: 0.055947
# Epoch [600/10000], Train Loss: 0.034309, Val Loss: 0.052147
# Epoch [610/10000], Train Loss: 0.033070, Val Loss: 0.053873
# Epoch [620/10000], Train Loss: 0.033793, Val Loss: 0.054827
# Epoch [630/10000], Train Loss: 0.031848, Val Loss: 0.052310
# Epoch [640/10000], Train Loss: 0.035204, Val Loss: 0.055030
# Epoch [650/10000], Train Loss: 0.033971, Val Loss: 0.060362
# Epoch [660/10000], Train Loss: 0.031349, Val Loss: 0.056059
# Epoch [670/10000], Train Loss: 0.033302, Val Loss: 0.055431
# Epoch [680/10000], Train Loss: 0.029668, Val Loss: 0.052809
# Epoch [690/10000], Train Loss: 0.034638, Val Loss: 0.054481
# Epoch [700/10000], Train Loss: 0.032596, Val Loss: 0.052546
# Epoch [710/10000], Train Loss: 0.032375, Val Loss: 0.055237
# Epoch [720/10000], Train Loss: 0.030249, Val Loss: 0.052364
# Epoch [730/10000], Train Loss: 0.033557, Val Loss: 0.054717
# Epoch [740/10000], Train Loss: 0.030932, Val Loss: 0.053138
# Epoch [750/10000], Train Loss: 0.028508, Val Loss: 0.053798
# Epoch [760/10000], Train Loss: 0.028187, Val Loss: 0.053506
# Epoch [770/10000], Train Loss: 0.029717, Val Loss: 0.053369
# Epoch [780/10000], Train Loss: 0.030375, Val Loss: 0.055790
# Epoch [790/10000], Train Loss: 0.028120, Val Loss: 0.052864
# Epoch [800/10000], Train Loss: 0.028162, Val Loss: 0.052143
# Epoch [810/10000], Train Loss: 0.027336, Val Loss: 0.053863
# Epoch [820/10000], Train Loss: 0.029006, Val Loss: 0.054744
# Epoch [830/10000], Train Loss: 0.028068, Val Loss: 0.054117
# Epoch [840/10000], Train Loss: 0.028206, Val Loss: 0.052635
# Epoch [850/10000], Train Loss: 0.030246, Val Loss: 0.058351
# Epoch [860/10000], Train Loss: 0.026087, Val Loss: 0.054663
# Epoch [870/10000], Train Loss: 0.026639, Val Loss: 0.052438
# Epoch [880/10000], Train Loss: 0.029384, Val Loss: 0.053338
# Epoch [890/10000], Train Loss: 0.028698, Val Loss: 0.053215
# Epoch [900/10000], Train Loss: 0.028715, Val Loss: 0.053999
# Epoch [910/10000], Train Loss: 0.026385, Val Loss: 0.054009
# Epoch [920/10000], Train Loss: 0.025129, Val Loss: 0.054773
# Epoch [930/10000], Train Loss: 0.026399, Val Loss: 0.054183
# Epoch [940/10000], Train Loss: 0.025176, Val Loss: 0.053881
# Epoch [950/10000], Train Loss: 0.026599, Val Loss: 0.053386
# Epoch [960/10000], Train Loss: 0.027475, Val Loss: 0.052380
# Epoch [970/10000], Train Loss: 0.023777, Val Loss: 0.053499
# Epoch [980/10000], Train Loss: 0.025016, Val Loss: 0.054607
# Epoch [990/10000], Train Loss: 0.026351, Val Loss: 0.055330
# Epoch [1000/10000], Train Loss: 0.024491, Val Loss: 0.053313
# Epoch [1010/10000], Train Loss: 0.023061, Val Loss: 0.051942
# Epoch [1020/10000], Train Loss: 0.025213, Val Loss: 0.054426
# Epoch [1030/10000], Train Loss: 0.034720, Val Loss: 0.057514
# Epoch [1040/10000], Train Loss: 0.024288, Val Loss: 0.053181
# Epoch [1050/10000], Train Loss: 0.022435, Val Loss: 0.053228
# Epoch [1060/10000], Train Loss: 0.027192, Val Loss: 0.061183
# Epoch [1070/10000], Train Loss: 0.023935, Val Loss: 0.054276
# Epoch [1080/10000], Train Loss: 0.023260, Val Loss: 0.054951
# Epoch [1090/10000], Train Loss: 0.022955, Val Loss: 0.055102
# Epoch [1100/10000], Train Loss: 0.028132, Val Loss: 0.056185
# Epoch [1110/10000], Train Loss: 0.023143, Val Loss: 0.055715
# Epoch [1120/10000], Train Loss: 0.023123, Val Loss: 0.054038
# Epoch [1130/10000], Train Loss: 0.024395, Val Loss: 0.056237
# Epoch [1140/10000], Train Loss: 0.024626, Val Loss: 0.054660
# Epoch [1150/10000], Train Loss: 0.024972, Val Loss: 0.053880
# Epoch [1160/10000], Train Loss: 0.022689, Val Loss: 0.053953
# Epoch [1170/10000], Train Loss: 0.022097, Val Loss: 0.054310
# Early stopping triggered at epoch 1174
# Evaluation Metrics:
# MSE: 662100332.1989
# R² (Median_meltLength): 0.8200
# R² (meanNumPixels15): 0.7717
# Fold 4 Validation MSE: 662100332.1989
# Fold 4 R² scores: ['0.8200', '0.7717']
#
# Training Fold 5
# --------------------------------------------------
# Total Parameters: 199,436,290
# Epoch [10/10000], Train Loss: 0.093265, Val Loss: 0.087979
# Epoch [20/10000], Train Loss: 0.085743, Val Loss: 0.089018
# Epoch [30/10000], Train Loss: 0.083417, Val Loss: 0.084357
# Epoch [40/10000], Train Loss: 0.080480, Val Loss: 0.085318
# Epoch [50/10000], Train Loss: 0.083050, Val Loss: 0.082685
# Epoch [60/10000], Train Loss: 0.081965, Val Loss: 0.086163
# Epoch [70/10000], Train Loss: 0.074512, Val Loss: 0.083512
# Epoch [80/10000], Train Loss: 0.076456, Val Loss: 0.076362
# Epoch [90/10000], Train Loss: 0.077414, Val Loss: 0.079429
# Epoch [100/10000], Train Loss: 0.069927, Val Loss: 0.076905
# Epoch [110/10000], Train Loss: 0.068972, Val Loss: 0.071217
# Epoch [120/10000], Train Loss: 0.067725, Val Loss: 0.068192
# Epoch [130/10000], Train Loss: 0.066062, Val Loss: 0.070614
# Epoch [140/10000], Train Loss: 0.063074, Val Loss: 0.066017
# Epoch [150/10000], Train Loss: 0.067159, Val Loss: 0.065773
# Epoch [160/10000], Train Loss: 0.060299, Val Loss: 0.067624
# Epoch [170/10000], Train Loss: 0.059289, Val Loss: 0.065132
# Epoch [180/10000], Train Loss: 0.062520, Val Loss: 0.069074
# Epoch [190/10000], Train Loss: 0.056461, Val Loss: 0.065807
# Epoch [200/10000], Train Loss: 0.058445, Val Loss: 0.063519
# Epoch [210/10000], Train Loss: 0.060745, Val Loss: 0.066548
# Epoch [220/10000], Train Loss: 0.054656, Val Loss: 0.072344
# Epoch [230/10000], Train Loss: 0.055669, Val Loss: 0.071308
# Epoch [240/10000], Train Loss: 0.054039, Val Loss: 0.063330
# Epoch [250/10000], Train Loss: 0.054739, Val Loss: 0.076490
# Epoch [260/10000], Train Loss: 0.048645, Val Loss: 0.060816
# Epoch [270/10000], Train Loss: 0.050712, Val Loss: 0.060155
# Epoch [280/10000], Train Loss: 0.046721, Val Loss: 0.059041
# Epoch [290/10000], Train Loss: 0.050821, Val Loss: 0.062516
# Epoch [300/10000], Train Loss: 0.048213, Val Loss: 0.059556
# Epoch [310/10000], Train Loss: 0.050346, Val Loss: 0.061001
# Epoch [320/10000], Train Loss: 0.045548, Val Loss: 0.060869
# Epoch [330/10000], Train Loss: 0.043929, Val Loss: 0.054845
# Epoch [340/10000], Train Loss: 0.045883, Val Loss: 0.059637
# Epoch [350/10000], Train Loss: 0.043864, Val Loss: 0.057948
# Epoch [360/10000], Train Loss: 0.042346, Val Loss: 0.061599
# Epoch [370/10000], Train Loss: 0.041441, Val Loss: 0.059353
# Epoch [380/10000], Train Loss: 0.045347, Val Loss: 0.057417
# Epoch [390/10000], Train Loss: 0.041586, Val Loss: 0.057657
# Epoch [400/10000], Train Loss: 0.042430, Val Loss: 0.061075
# Epoch [410/10000], Train Loss: 0.042076, Val Loss: 0.060145
# Epoch [420/10000], Train Loss: 0.042115, Val Loss: 0.059740
# Epoch [430/10000], Train Loss: 0.044739, Val Loss: 0.061846
# Epoch [440/10000], Train Loss: 0.039050, Val Loss: 0.056630
# Epoch [450/10000], Train Loss: 0.040227, Val Loss: 0.056145
# Epoch [460/10000], Train Loss: 0.036739, Val Loss: 0.062570
# Epoch [470/10000], Train Loss: 0.036632, Val Loss: 0.057271
# Epoch [480/10000], Train Loss: 0.036917, Val Loss: 0.060152
# Epoch [490/10000], Train Loss: 0.035790, Val Loss: 0.058403
# Epoch [500/10000], Train Loss: 0.035189, Val Loss: 0.057404
# Epoch [510/10000], Train Loss: 0.036595, Val Loss: 0.060966
# Epoch [520/10000], Train Loss: 0.038262, Val Loss: 0.059966
# Epoch [530/10000], Train Loss: 0.038395, Val Loss: 0.055627
# Epoch [540/10000], Train Loss: 0.034476, Val Loss: 0.059806
# Epoch [550/10000], Train Loss: 0.036024, Val Loss: 0.060559
# Epoch [560/10000], Train Loss: 0.036357, Val Loss: 0.055224
# Epoch [570/10000], Train Loss: 0.034878, Val Loss: 0.058774
# Epoch [580/10000], Train Loss: 0.032676, Val Loss: 0.057515
# Epoch [590/10000], Train Loss: 0.037343, Val Loss: 0.063340
# Epoch [600/10000], Train Loss: 0.036203, Val Loss: 0.060487
# Epoch [610/10000], Train Loss: 0.032469, Val Loss: 0.055929
# Epoch [620/10000], Train Loss: 0.035129, Val Loss: 0.058285
# Epoch [630/10000], Train Loss: 0.034155, Val Loss: 0.056274
# Epoch [640/10000], Train Loss: 0.030326, Val Loss: 0.056020
# Epoch [650/10000], Train Loss: 0.036868, Val Loss: 0.060883
# Epoch [660/10000], Train Loss: 0.031565, Val Loss: 0.058611
# Epoch [670/10000], Train Loss: 0.037641, Val Loss: 0.059384
# Epoch [680/10000], Train Loss: 0.033291, Val Loss: 0.055953
# Epoch [690/10000], Train Loss: 0.033967, Val Loss: 0.055352
# Epoch [700/10000], Train Loss: 0.031290, Val Loss: 0.058315
# Epoch [710/10000], Train Loss: 0.029210, Val Loss: 0.056304
# Epoch [720/10000], Train Loss: 0.032204, Val Loss: 0.056078
# Epoch [730/10000], Train Loss: 0.030417, Val Loss: 0.056122
# Epoch [740/10000], Train Loss: 0.028243, Val Loss: 0.056163
# Epoch [750/10000], Train Loss: 0.029596, Val Loss: 0.060202
# Epoch [760/10000], Train Loss: 0.034457, Val Loss: 0.063788
# Epoch [770/10000], Train Loss: 0.028714, Val Loss: 0.057293
# Epoch [780/10000], Train Loss: 0.030213, Val Loss: 0.057995
# Epoch [790/10000], Train Loss: 0.027770, Val Loss: 0.059952
# Epoch [800/10000], Train Loss: 0.029991, Val Loss: 0.060710
# Epoch [810/10000], Train Loss: 0.028597, Val Loss: 0.061159
# Epoch [820/10000], Train Loss: 0.029302, Val Loss: 0.059188
# Epoch [830/10000], Train Loss: 0.028359, Val Loss: 0.058556
# Epoch [840/10000], Train Loss: 0.029285, Val Loss: 0.059023
# Epoch [850/10000], Train Loss: 0.025881, Val Loss: 0.058151
# Epoch [860/10000], Train Loss: 0.025933, Val Loss: 0.057500
# Epoch [870/10000], Train Loss: 0.027041, Val Loss: 0.059516
# Epoch [880/10000], Train Loss: 0.026359, Val Loss: 0.057366
# Epoch [890/10000], Train Loss: 0.031052, Val Loss: 0.058929
# Epoch [900/10000], Train Loss: 0.027387, Val Loss: 0.057318
# Epoch [910/10000], Train Loss: 0.025297, Val Loss: 0.057182
# Epoch [920/10000], Train Loss: 0.028841, Val Loss: 0.056312
# Epoch [930/10000], Train Loss: 0.028062, Val Loss: 0.058847
# Epoch [940/10000], Train Loss: 0.024139, Val Loss: 0.057496
# Epoch [950/10000], Train Loss: 0.029582, Val Loss: 0.061258
# Epoch [960/10000], Train Loss: 0.026284, Val Loss: 0.059295
# Epoch [970/10000], Train Loss: 0.026902, Val Loss: 0.055530
# Epoch [980/10000], Train Loss: 0.027298, Val Loss: 0.059378
# Early stopping triggered at epoch 986
# Evaluation Metrics:
# MSE: 632958014.2320
# R² (Median_meltLength): 0.8345
# R² (meanNumPixels15): 0.7875
# Fold 5 Validation MSE: 632958014.2320
# Fold 5 R² scores: ['0.8345', '0.7875']
#
# Cross-validation Results:
# Average MSE: 651681904.9752 ± 46951388.7096
# Average R² (Median_meltLength): 0.8107 ± 0.0154
# Average R² (meanNumPixels15): 0.7561 ± 0.0207
# ------------------------------
#
# Cross-validation Results:
# Average MSE: 651681904.9752 ± 46951388.7096

# %%
import os
import json
import pickle
import torch
from datetime import datetime

def save_training_results(models, scalers, scalers_y, val_scores, r2_scores_all, input_cols, target_cols):
    # Create Results directory if it doesn't exist
    results_dir = "Results"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
    
    # Create timestamped subdirectory for this training run
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = os.path.join(results_dir, f"run_{timestamp}")
    os.makedirs(run_dir)
    
    # Save models
    models_dir = os.path.join(run_dir, "models")
    os.makedirs(models_dir)
    for i, model in enumerate(models):
        model_path = os.path.join(models_dir, f"model_fold_{i+1}.pt")
        torch.save(model.state_dict(), model_path)
    
    # Save scalers
    scalers_dir = os.path.join(run_dir, "scalers")
    os.makedirs(scalers_dir)
    for i, (scaler, scaler_y) in enumerate(zip(scalers, scalers_y)):
        # Save feature scaler
        scaler_path = os.path.join(scalers_dir, f"feature_scaler_fold_{i+1}.pkl")
        with open(scaler_path, 'wb') as f:
            pickle.dump(scaler, f)
        
        # Save target scaler
        scaler_y_path = os.path.join(scalers_dir, f"target_scaler_fold_{i+1}.pkl")
        with open(scaler_y_path, 'wb') as f:
            pickle.dump(scaler_y, f)
    
    # Save metrics and configuration
    metrics = {
        'input_features': input_cols,
        'target_variables': target_cols,
        'val_scores': val_scores.tolist() if isinstance(val_scores, np.ndarray) else val_scores,
        'r2_scores_all': r2_scores_all.tolist() if isinstance(r2_scores_all, np.ndarray) else r2_scores_all,
        'average_mse': float(np.mean(val_scores)),
        'mse_std': float(np.std(val_scores)),
        'average_r2_by_target': {
            target: {
                'mean': float(np.mean(r2_scores_all[:, i])),
                'std': float(np.std(r2_scores_all[:, i]))
            }
            for i, target in enumerate(target_cols)
        }
    }
    
    metrics_path = os.path.join(run_dir, "metrics.json")
    with open(metrics_path, 'w') as f:
        json.dump(metrics, f, indent=4)
    
    print(f"\nResults saved in: {run_dir}")
    print("Saved contents:")
    print(f"- {len(models)} models")
    print(f"- {len(scalers)} feature scalers and target scalers")
    print("- Evaluation metrics and configuration")

# Call the function to save the results
save_training_results(
    models=models,
    scalers=scalers,
    scalers_y=scalers_y,  
    val_scores=val_scores,
    r2_scores_all=r2_scores_all,
    input_cols=input_cols,
    target_cols=target_cols
)
# Out:
# Results saved in: Results/run_20241115_125532
# Saved contents:
# - 5 models
# - 5 feature scalers and target scalers
# - Evaluation metrics and configuration

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms for each feature
for col in input_cols + target_cols:
    sns.histplot(data[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
import seaborn as sns

sns.pairplot(data[input_cols + target_cols])
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

r2s = []
for fold_no, indices in enumerate(fold_indices):
    
    X_train, X_val = X[indices[0]], X[indices[1]]
    y_train, y_val = y[indices[0]], y[indices[1]]

    lr_model = LinearRegression()
    lr_model.fit(X_train, y_train)
    y_pred = lr_model.predict(X_val)

    mse = mean_squared_error(y_val, y_pred)
    r2 = r2_score(y_val, y_pred, multioutput='raw_values')
    print(f'Fold:  {fold_no}')
    print(f'Linear Regression MSE: {mse:.4f}')
    print(f'Linear Regression R² scores: {r2}')
    r2s.append(r2)

r2s = np.array(r2s)
mean_score = r2s.mean(axis=0)
print(f'Cross-validation mean score {mean_score}')
# Out:
# Fold:  0
# Linear Regression MSE: 1613249441.3207
# Linear Regression R² scores: [0.47361174 0.28443274]
# Fold:  1
# Linear Regression MSE: 1740251513.6222
# Linear Regression R² scores: [0.43941274 0.23107319]
# Fold:  2
# Linear Regression MSE: 1929862082.6366
# Linear Regression R² scores: [0.46881006 0.27604734]
# Fold:  3
# Linear Regression MSE: 1826342403.9509
# Linear Regression R² scores: [0.50338192 0.27136192]
# Fold:  4
# Linear Regression MSE: 1917418069.7276
# Linear Regression R² scores: [0.49851518 0.29590548]
# Cross-validation mean score [0.47674633 0.27176413]

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X[train_idx])
X_val = scaler.transform(X[val_idx])

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(X_val[:, 1])
plt.plot(X_val[:, 2])
plt.plot(X_val[:, 3])
plt.plot(X_val[:, 4])

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_val)

mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred, multioutput='raw_values')
print(f'Random Forest MSE: {mse:.4f}')
print(f'Random Forest R² scores: {r2}')
