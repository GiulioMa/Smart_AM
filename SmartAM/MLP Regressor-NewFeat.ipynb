# %%
import pandas as pd

# Load the saved CSV file
data = pd.read_csv('processed_data.csv')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import torch
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# Define target and input variables
target_cols = ['meanLineIntensity', 'meanNumPixels15']
input_cols = ['Z', 'Wall', 'Overhang', 'NoLines', 'Power', 
                'd_edge_right', 'd_edge_left', 'd_over_left', 
                'd_over_right', 'd_col', 'd_over_z']

# Extract features and targets
X = data[input_cols].values
y = data[target_cols].values

# Create a custom Dataset class
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.FloatTensor(X)
        self.y = torch.FloatTensor(y)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# Function to prepare data loaders for a specific fold
def prepare_fold_data(X, y, train_idx, val_idx, batch_size=32):
    # Always use StandardScaler for features
    scaler = StandardScaler()
    scaler_y = StandardScaler()  
    
    # Scale features
    X_train = scaler.fit_transform(X[train_idx])
    X_val = scaler.transform(X[val_idx])
    
    # Scale targets
    y_train = scaler_y.fit_transform(y[train_idx])
    y_val = scaler_y.transform(y[val_idx])
    
    # Create datasets
    train_dataset = CustomDataset(X_train, y_train)
    val_dataset = CustomDataset(X_val, y_val)
    
    # Create data loaders with larger batch size
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False
    )
    
    return train_loader, val_loader, scaler, scaler_y

# Set up K-Fold cross-validation
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Store fold indices for later use
fold_indices = []
for train_idx, val_idx in kf.split(X):
    fold_indices.append((train_idx, val_idx))

# %%
import torch.nn as nn
import torch.optim as optim
import tqdm
from tqdm import tqdm
import copy
import matplotlib.pyplot as plt

class ResidualBlock(nn.Module):
    def __init__(self, dim, dropout_rate=0.2):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Linear(dim, dim),
            #nn.BatchNorm1d(dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate),
            nn.Linear(dim, dim),
            #nn.BatchNorm1d(dim)
        )
        self.relu = nn.ReLU()
        
    def forward(self, x):
        residual = x
        out = self.block(x)
        out += residual  # Skip connection
        return self.relu(out)

class MLPRegressor(nn.Module):
    def __init__(self, input_dim=5, hidden_dim=128, num_layers=3, output_dim=2, dropout_rate=0.2):
        super(MLPRegressor, self).__init__()
        
        self.input_layer = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            #nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate)
        )
        
        self.residual_layers = nn.ModuleList([
            ResidualBlock(hidden_dim, dropout_rate) 
            for _ in range(num_layers - 1)
        ])
        
        self.output_layer = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        x = self.input_layer(x)
        for layer in self.residual_layers:
            x = layer(x)
        return self.output_layer(x)

def print_model_params(model):
    total_params = 0
    input_params = sum(p.numel() for p in model.input_layer.parameters())
    total_params += input_params
    
    for i, block in enumerate(model.residual_layers):
        block_params = sum(p.numel() for p in block.parameters())
        total_params += block_params
    
    output_params = sum(p.numel() for p in model.output_layer.parameters())
    total_params += output_params
    
    print("-" * 50)
    print(f"Total Parameters: {total_params:,}")

def train_model(model, train_loader, val_loader, num_epochs=1000, patience=50):
    model = model.to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.00001)

    best_val_loss = float('inf')
    best_model = None
    patience_counter = 0
    
    # Lists to store losses for plotting
    train_losses = []
    val_losses = []
    epochs = []

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * X_batch.size(0)

        train_loss /= len(train_loader.dataset)

        # Validation phase
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)

        val_loss /= len(val_loader.dataset)

        # Store losses for plotting
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        epochs.append(epoch + 1)

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = copy.deepcopy(model)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f'Early stopping triggered at epoch {epoch+1}')
            break

        if (epoch + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.6f}, Val Loss: {val_loss:.6f}')

    return best_model, train_losses, val_losses, epochs

def train_k_fold(X, y, fold_indices, hidden_dim=128, num_layers=3, batch_size=32):
    models = []
    scalers = []
    scalers_y = []
    val_scores = []
    r2_scores_all = []

    for fold, (train_idx, val_idx) in enumerate(fold_indices):
        print(f'\nTraining Fold {fold+1}')

        # Prepare data for this fold
        train_loader, val_loader, scaler, scaler_y = prepare_fold_data(
            X, y, train_idx, val_idx, batch_size
        )

        # Initialize model
        model = MLPRegressor(
            input_dim=X.shape[1],
            hidden_dim=hidden_dim,
            num_layers=num_layers,
            output_dim=y.shape[1]
        )
        
        print_model_params(model)

        # Train model and get loss history
        best_model, train_losses, val_losses, epochs = train_model(
            model,
            train_loader,
            val_loader,
            num_epochs=10000,
            patience=500
        )

        # Plot loss evolution for this fold
        plt.figure(figsize=(10, 6))
        plt.plot(epochs[1:], train_losses[1:], label='Training Loss')
        plt.plot(epochs[1:], val_losses[1:], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title(f'Loss Evolution - Fold {fold+1}')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Store the trained model and scalers
        models.append(best_model)
        scalers.append(scaler)
        scalers_y.append(scaler_y)

        # Calculate validation scores
        mse, r2_scores, predictions, actuals = evaluate_model(best_model, val_loader, scaler_y)
        val_scores.append(mse)
        r2_scores_all.append(r2_scores)
        print(f'Fold {fold+1} Validation MSE: {mse:.4f}')
        print(f'Fold {fold+1} R² scores: {[f"{r2:.4f}" for r2 in r2_scores]}')

    # Calculate and print average metrics
    print("\nCross-validation Results:")
    print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
    r2_scores_all = np.array(r2_scores_all)
    for i, target in enumerate(['meanLineIntensity', 'meanNumPixels15']):
        mean_r2 = np.mean(r2_scores_all[:, i])
        std_r2 = np.std(r2_scores_all[:, i])
        print(f"Average R² ({target}): {mean_r2:.4f} ± {std_r2:.4f}")
    
    return models, scalers, scalers_y, val_scores, r2_scores_all

def evaluate_model(model, data_loader, scaler_y):
    model = model.to(device)
    model.eval()
    criterion = nn.MSELoss()
    total_loss = 0.0

    # Lists to store predictions and actual values
    all_predictions = []
    all_actuals = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            outputs = model(X_batch)

            # Move to CPU and convert to numpy
            outputs_np = outputs.cpu().numpy()
            y_batch_np = y_batch.cpu().numpy()

            # Inverse transform
            outputs_inv = scaler_y.inverse_transform(outputs_np)
            y_batch_inv = scaler_y.inverse_transform(y_batch_np)

            # Compute loss in original scale
            loss = criterion(torch.tensor(outputs_inv), torch.tensor(y_batch_inv))
            total_loss += loss.item() * X_batch.size(0)

            all_predictions.append(outputs_inv)
            all_actuals.append(y_batch_inv)

    # Convert lists to numpy arrays
    predictions = np.vstack(all_predictions)
    actuals = np.vstack(all_actuals)

    # Calculate MSE
    mse = total_loss / len(data_loader.dataset)

    # Calculate R2 for each target
    r2_scores = []
    for i in range(actuals.shape[1]):
        ss_res = np.sum((actuals[:, i] - predictions[:, i]) ** 2)
        ss_tot = np.sum((actuals[:, i] - np.mean(actuals[:, i])) ** 2)
        r2 = 1 - (ss_res / ss_tot)
        r2_scores.append(r2)

    # Create plots
    import matplotlib.pyplot as plt

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    target_names = ['meanLineIntensity', 'meanNumPixels15']

    for i, (ax, target) in enumerate(zip(axes, target_names)):
        # Plot predicted vs actual
        ax.scatter(actuals[:, i], predictions[:, i], alpha=0.5)

        # Plot perfect prediction line
        min_val = min(actuals[:, i].min(), predictions[:, i].min())
        max_val = max(actuals[:, i].max(), predictions[:, i].max())
        ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Prediction')

        # Add labels and title
        ax.set_xlabel('Actual Values')
        ax.set_ylabel('Predicted Values')
        ax.set_title(f'{target}\nR² = {r2_scores[i]:.4f}')
        ax.grid(True)
        ax.legend()

    plt.tight_layout()
    plt.show()

    # Print detailed metrics
    print("\nEvaluation Metrics:")
    print(f"MSE: {mse:.4f}")
    for i, target in enumerate(target_names):
        print(f"R² ({target}): {r2_scores[i]:.4f}")

    return mse, r2_scores, predictions, actuals


# Train the models
models, scalers, scalers_y, val_scores, r2_scores_all = train_k_fold(X, y, fold_indices, 
                                                                     hidden_dim=1024, 
                                                                     num_layers=128,
                                                                     batch_size=128)

print('---'*10)
# Print overall results
print("\nCross-validation Results:")
print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
# Out:
# Training Fold 1
# --------------------------------------------------
# Total Parameters: 266,612,738
# Epoch [10/10000], Train Loss: 0.345654, Val Loss: 0.353373
# Epoch [20/10000], Train Loss: 0.320283, Val Loss: 0.326181
# Epoch [30/10000], Train Loss: 0.250027, Val Loss: 0.283309
# Epoch [40/10000], Train Loss: 0.234947, Val Loss: 0.264784
# Epoch [50/10000], Train Loss: 0.240818, Val Loss: 0.263505
# Epoch [60/10000], Train Loss: 0.240067, Val Loss: 0.239562
# Epoch [70/10000], Train Loss: 0.178114, Val Loss: 0.238535
# Epoch [80/10000], Train Loss: 0.184326, Val Loss: 0.222074
# Epoch [90/10000], Train Loss: 0.191460, Val Loss: 0.263846
# Epoch [100/10000], Train Loss: 0.165222, Val Loss: 0.291771
# Epoch [110/10000], Train Loss: 0.177227, Val Loss: 0.236202
# Epoch [120/10000], Train Loss: 0.147194, Val Loss: 0.210566
# Epoch [130/10000], Train Loss: 0.126995, Val Loss: 0.205221
# Epoch [140/10000], Train Loss: 0.138641, Val Loss: 0.191835
# Epoch [150/10000], Train Loss: 0.128094, Val Loss: 0.250197
# Epoch [160/10000], Train Loss: 0.125545, Val Loss: 0.296688
# Epoch [170/10000], Train Loss: 0.132474, Val Loss: 0.232923
# Epoch [180/10000], Train Loss: 0.132570, Val Loss: 0.221849
# Epoch [190/10000], Train Loss: 0.114428, Val Loss: 0.235376
# Epoch [200/10000], Train Loss: 0.120140, Val Loss: 0.209771
# Epoch [210/10000], Train Loss: 0.112910, Val Loss: 0.216375
# Epoch [220/10000], Train Loss: 0.128705, Val Loss: 0.214561
# Epoch [230/10000], Train Loss: 0.106830, Val Loss: 0.224235
# Epoch [240/10000], Train Loss: 0.099596, Val Loss: 0.202236
# Epoch [250/10000], Train Loss: 0.128096, Val Loss: 0.214800
# Epoch [260/10000], Train Loss: 0.104109, Val Loss: 0.204668
# Epoch [270/10000], Train Loss: 0.150582, Val Loss: 0.234697
# Epoch [280/10000], Train Loss: 0.112310, Val Loss: 0.253175
# Epoch [290/10000], Train Loss: 0.107112, Val Loss: 0.220418
# Epoch [300/10000], Train Loss: 0.104570, Val Loss: 0.192375
# Epoch [310/10000], Train Loss: 0.092581, Val Loss: 0.204206
# Epoch [320/10000], Train Loss: 0.130925, Val Loss: 0.231178
# Epoch [330/10000], Train Loss: 0.094491, Val Loss: 0.222234
# Epoch [340/10000], Train Loss: 0.124406, Val Loss: 0.229214
# Epoch [350/10000], Train Loss: 0.089795, Val Loss: 0.222340
# Epoch [360/10000], Train Loss: 0.113974, Val Loss: 0.231172
# Epoch [370/10000], Train Loss: 0.078319, Val Loss: 0.210510
# Epoch [380/10000], Train Loss: 0.063144, Val Loss: 0.260705
# Epoch [390/10000], Train Loss: 0.078739, Val Loss: 0.262730
# Epoch [400/10000], Train Loss: 0.071497, Val Loss: 0.217504
# Epoch [410/10000], Train Loss: 0.090219, Val Loss: 0.210433
# Epoch [420/10000], Train Loss: 0.072887, Val Loss: 0.211131
# Epoch [430/10000], Train Loss: 0.076141, Val Loss: 0.221404
# Epoch [440/10000], Train Loss: 0.064362, Val Loss: 0.216314
# Epoch [450/10000], Train Loss: 0.070014, Val Loss: 0.216564
# Epoch [460/10000], Train Loss: 0.063354, Val Loss: 0.228217
# Epoch [470/10000], Train Loss: 0.090855, Val Loss: 0.208637
# Epoch [480/10000], Train Loss: 0.064286, Val Loss: 0.219030
# Epoch [490/10000], Train Loss: 0.083762, Val Loss: 0.259819
# Epoch [500/10000], Train Loss: 0.055697, Val Loss: 0.222661
# Epoch [510/10000], Train Loss: 0.079107, Val Loss: 0.200074
# Epoch [520/10000], Train Loss: 0.043726, Val Loss: 0.227339
# Epoch [530/10000], Train Loss: 0.071731, Val Loss: 0.219797
# Epoch [540/10000], Train Loss: 0.055257, Val Loss: 0.244764
# Epoch [550/10000], Train Loss: 0.092712, Val Loss: 0.193421
# Epoch [560/10000], Train Loss: 0.067069, Val Loss: 0.201325
# Epoch [570/10000], Train Loss: 0.104538, Val Loss: 0.216255
# Epoch [580/10000], Train Loss: 0.056090, Val Loss: 0.199998
# Epoch [590/10000], Train Loss: 0.100327, Val Loss: 0.225848
# Epoch [600/10000], Train Loss: 0.071492, Val Loss: 0.232414
# Epoch [610/10000], Train Loss: 0.060471, Val Loss: 0.216226
# Epoch [620/10000], Train Loss: 0.081726, Val Loss: 0.192517
# Epoch [630/10000], Train Loss: 0.065153, Val Loss: 0.231973
# Epoch [640/10000], Train Loss: 0.039535, Val Loss: 0.222250
# Epoch [650/10000], Train Loss: 0.029601, Val Loss: 0.213481
# Epoch [660/10000], Train Loss: 0.050245, Val Loss: 0.279712
# Epoch [670/10000], Train Loss: 0.039167, Val Loss: 0.240431
# Epoch [680/10000], Train Loss: 0.038611, Val Loss: 0.238030
# Epoch [690/10000], Train Loss: 0.074687, Val Loss: 0.225846
# Epoch [700/10000], Train Loss: 0.097200, Val Loss: 0.238486
# Epoch [710/10000], Train Loss: 0.047479, Val Loss: 0.219316
# Epoch [720/10000], Train Loss: 0.034510, Val Loss: 0.230240
# Epoch [730/10000], Train Loss: 0.070611, Val Loss: 0.208965
# Epoch [740/10000], Train Loss: 0.040159, Val Loss: 0.214592
# Epoch [750/10000], Train Loss: 0.082055, Val Loss: 0.240832
# Epoch [760/10000], Train Loss: 0.045682, Val Loss: 0.277803
# Epoch [770/10000], Train Loss: 0.033334, Val Loss: 0.267598
# Epoch [780/10000], Train Loss: 0.063440, Val Loss: 0.245869
# Early stopping triggered at epoch 785
# Evaluation Metrics:
# MSE: 535070588.3857
# R² (meanLineIntensity): 0.8254
# R² (meanNumPixels15): 0.7687
# Fold 1 Validation MSE: 535070588.3857
# Fold 1 R² scores: ['0.8254', '0.7687']
#
# Training Fold 2
# --------------------------------------------------
# Total Parameters: 266,612,738
# Epoch [10/10000], Train Loss: 0.371344, Val Loss: 0.368387
# Epoch [20/10000], Train Loss: 0.296085, Val Loss: 0.344509
# Epoch [30/10000], Train Loss: 0.264033, Val Loss: 0.346155
# Epoch [40/10000], Train Loss: 0.273872, Val Loss: 0.298580
# Epoch [50/10000], Train Loss: 0.224111, Val Loss: 0.286693
# Epoch [60/10000], Train Loss: 0.231786, Val Loss: 0.292970
# Epoch [70/10000], Train Loss: 0.206631, Val Loss: 0.276472
# Epoch [80/10000], Train Loss: 0.200960, Val Loss: 0.252251
# Epoch [90/10000], Train Loss: 0.200432, Val Loss: 0.305112
# Epoch [100/10000], Train Loss: 0.195017, Val Loss: 0.244451
# Epoch [110/10000], Train Loss: 0.186293, Val Loss: 0.271368
# Epoch [120/10000], Train Loss: 0.170384, Val Loss: 0.255362
# Epoch [130/10000], Train Loss: 0.166017, Val Loss: 0.252600
# Epoch [140/10000], Train Loss: 0.162463, Val Loss: 0.236700
# Epoch [150/10000], Train Loss: 0.151926, Val Loss: 0.236135
# Epoch [160/10000], Train Loss: 0.162277, Val Loss: 0.268517
# Epoch [170/10000], Train Loss: 0.134232, Val Loss: 0.252918
# Epoch [180/10000], Train Loss: 0.166290, Val Loss: 0.271147
# Epoch [190/10000], Train Loss: 0.183891, Val Loss: 0.256987
# Epoch [200/10000], Train Loss: 0.146971, Val Loss: 0.232424
# Epoch [210/10000], Train Loss: 0.140857, Val Loss: 0.229761
# Epoch [220/10000], Train Loss: 0.109497, Val Loss: 0.220763
# Epoch [230/10000], Train Loss: 0.123745, Val Loss: 0.220257
# Epoch [240/10000], Train Loss: 0.097871, Val Loss: 0.222879
# Epoch [250/10000], Train Loss: 0.127951, Val Loss: 0.208045
# Epoch [260/10000], Train Loss: 0.095145, Val Loss: 0.230279
# Epoch [270/10000], Train Loss: 0.120736, Val Loss: 0.197962
# Epoch [280/10000], Train Loss: 0.126072, Val Loss: 0.248595
# Epoch [290/10000], Train Loss: 0.129849, Val Loss: 0.234371
# Epoch [300/10000], Train Loss: 0.093697, Val Loss: 0.239646
# Epoch [310/10000], Train Loss: 0.075928, Val Loss: 0.220543
# Epoch [320/10000], Train Loss: 0.082114, Val Loss: 0.224829
# Epoch [330/10000], Train Loss: 0.074119, Val Loss: 0.228015
# Epoch [340/10000], Train Loss: 0.097911, Val Loss: 0.228157
# Epoch [350/10000], Train Loss: 0.119337, Val Loss: 0.249179
# Epoch [360/10000], Train Loss: 0.122969, Val Loss: 0.252227
# Epoch [370/10000], Train Loss: 0.108925, Val Loss: 0.216400
# Epoch [380/10000], Train Loss: 0.066728, Val Loss: 0.226404
# Epoch [390/10000], Train Loss: 0.115114, Val Loss: 0.221505
# Epoch [400/10000], Train Loss: 0.078325, Val Loss: 0.221477
# Epoch [410/10000], Train Loss: 0.073428, Val Loss: 0.230023
# Epoch [420/10000], Train Loss: 0.073019, Val Loss: 0.214024
# Epoch [430/10000], Train Loss: 0.073370, Val Loss: 0.235027
# Epoch [440/10000], Train Loss: 0.087582, Val Loss: 0.239308
# Epoch [450/10000], Train Loss: 0.062565, Val Loss: 0.219505
# Epoch [460/10000], Train Loss: 0.058541, Val Loss: 0.219171
# Epoch [470/10000], Train Loss: 0.082578, Val Loss: 0.208464
# Epoch [480/10000], Train Loss: 0.162875, Val Loss: 0.257996
# Epoch [490/10000], Train Loss: 0.088131, Val Loss: 0.253266
# Epoch [500/10000], Train Loss: 0.076485, Val Loss: 0.218279
# Epoch [510/10000], Train Loss: 0.073205, Val Loss: 0.207940
# Epoch [520/10000], Train Loss: 0.063948, Val Loss: 0.227119
# Epoch [530/10000], Train Loss: 0.043458, Val Loss: 0.217092
# Epoch [540/10000], Train Loss: 0.067521, Val Loss: 0.247971
# Epoch [550/10000], Train Loss: 0.091769, Val Loss: 0.201352
# Epoch [560/10000], Train Loss: 0.164604, Val Loss: 0.293324
# Epoch [570/10000], Train Loss: 0.072100, Val Loss: 0.214026
# Epoch [580/10000], Train Loss: 0.068797, Val Loss: 0.222539
# Epoch [590/10000], Train Loss: 0.074170, Val Loss: 0.215048
# Epoch [600/10000], Train Loss: 0.084945, Val Loss: 0.231712
# Epoch [610/10000], Train Loss: 0.051046, Val Loss: 0.208410
# Epoch [620/10000], Train Loss: 0.063685, Val Loss: 0.211659
# Epoch [630/10000], Train Loss: 0.090622, Val Loss: 0.222948
# Epoch [640/10000], Train Loss: 0.086141, Val Loss: 0.218171
# Epoch [650/10000], Train Loss: 0.057976, Val Loss: 0.216049
# Epoch [660/10000], Train Loss: 0.072849, Val Loss: 0.229906
# Epoch [670/10000], Train Loss: 0.065694, Val Loss: 0.222310
# Epoch [680/10000], Train Loss: 0.037950, Val Loss: 0.208752
# Epoch [690/10000], Train Loss: 0.086156, Val Loss: 0.214560
# Epoch [700/10000], Train Loss: 0.069481, Val Loss: 0.212547
# Epoch [710/10000], Train Loss: 0.043905, Val Loss: 0.213758
# Epoch [720/10000], Train Loss: 0.043510, Val Loss: 0.215266
# Epoch [730/10000], Train Loss: 0.052307, Val Loss: 0.226404
# Epoch [740/10000], Train Loss: 0.034440, Val Loss: 0.224289
# Epoch [750/10000], Train Loss: 0.056940, Val Loss: 0.222974
# Epoch [760/10000], Train Loss: 0.105819, Val Loss: 0.201193
# Epoch [770/10000], Train Loss: 0.073451, Val Loss: 0.202534
# Epoch [780/10000], Train Loss: 0.066299, Val Loss: 0.228897
# Epoch [790/10000], Train Loss: 0.072143, Val Loss: 0.222709
# Epoch [800/10000], Train Loss: 0.045624, Val Loss: 0.226972
# Epoch [810/10000], Train Loss: 0.047126, Val Loss: 0.198852
# Epoch [820/10000], Train Loss: 0.035247, Val Loss: 0.203857
# Epoch [830/10000], Train Loss: 0.056581, Val Loss: 0.236924
# Epoch [840/10000], Train Loss: 0.060712, Val Loss: 0.216786
# Epoch [850/10000], Train Loss: 0.052717, Val Loss: 0.206266
# Epoch [860/10000], Train Loss: 0.074527, Val Loss: 0.242600
# Epoch [870/10000], Train Loss: 0.036193, Val Loss: 0.209317
# Epoch [880/10000], Train Loss: 0.039204, Val Loss: 0.208293
# Epoch [890/10000], Train Loss: 0.024925, Val Loss: 0.203457
# Epoch [900/10000], Train Loss: 0.051013, Val Loss: 0.223498
# Epoch [910/10000], Train Loss: 0.061299, Val Loss: 0.206963
# Epoch [920/10000], Train Loss: 0.055700, Val Loss: 0.204407
# Epoch [930/10000], Train Loss: 0.077634, Val Loss: 0.207818
# Epoch [940/10000], Train Loss: 0.050131, Val Loss: 0.223411
# Epoch [950/10000], Train Loss: 0.045673, Val Loss: 0.197406
# Epoch [960/10000], Train Loss: 0.022050, Val Loss: 0.206642
# Epoch [970/10000], Train Loss: 0.031711, Val Loss: 0.225213
# Epoch [980/10000], Train Loss: 0.017786, Val Loss: 0.207905
# Epoch [990/10000], Train Loss: 0.118704, Val Loss: 0.266739
# Epoch [1000/10000], Train Loss: 0.056551, Val Loss: 0.204282
# Epoch [1010/10000], Train Loss: 0.052905, Val Loss: 0.240745
# Epoch [1020/10000], Train Loss: 0.084304, Val Loss: 0.203977
# Epoch [1030/10000], Train Loss: 0.037778, Val Loss: 0.204487
# Epoch [1040/10000], Train Loss: 0.051035, Val Loss: 0.194845
# Epoch [1050/10000], Train Loss: 0.041399, Val Loss: 0.213842
# Epoch [1060/10000], Train Loss: 0.022004, Val Loss: 0.203981
# Epoch [1070/10000], Train Loss: 0.014593, Val Loss: 0.205770
# Epoch [1080/10000], Train Loss: 0.040690, Val Loss: 0.212543
# Epoch [1090/10000], Train Loss: 0.020511, Val Loss: 0.201016
# Epoch [1100/10000], Train Loss: 0.015574, Val Loss: 0.198976
# Epoch [1110/10000], Train Loss: 0.012529, Val Loss: 0.203106
# Epoch [1120/10000], Train Loss: 0.069166, Val Loss: 0.238310
# Epoch [1130/10000], Train Loss: 0.080446, Val Loss: 0.233349
# Epoch [1140/10000], Train Loss: 0.059036, Val Loss: 0.224354
# Epoch [1150/10000], Train Loss: 0.037621, Val Loss: 0.218393
# Epoch [1160/10000], Train Loss: 0.044886, Val Loss: 0.201401
# Epoch [1170/10000], Train Loss: 0.036054, Val Loss: 0.207212
# Epoch [1180/10000], Train Loss: 0.039043, Val Loss: 0.216722
# Epoch [1190/10000], Train Loss: 0.049216, Val Loss: 0.259163
# Epoch [1200/10000], Train Loss: 0.046592, Val Loss: 0.212732
# Epoch [1210/10000], Train Loss: 0.024123, Val Loss: 0.226876
# Epoch [1220/10000], Train Loss: 0.053293, Val Loss: 0.215910
# Epoch [1230/10000], Train Loss: 0.016951, Val Loss: 0.198760
# Epoch [1240/10000], Train Loss: 0.074108, Val Loss: 0.221773
# Epoch [1250/10000], Train Loss: 0.076784, Val Loss: 0.229623
# Epoch [1260/10000], Train Loss: 0.039079, Val Loss: 0.216753
# Epoch [1270/10000], Train Loss: 0.016101, Val Loss: 0.199265
# Epoch [1280/10000], Train Loss: 0.015348, Val Loss: 0.208803
# Epoch [1290/10000], Train Loss: 0.008218, Val Loss: 0.201009
# Epoch [1300/10000], Train Loss: 0.009104, Val Loss: 0.207996
# Epoch [1310/10000], Train Loss: 0.017926, Val Loss: 0.211441
# Epoch [1320/10000], Train Loss: 0.022133, Val Loss: 0.203262
# Epoch [1330/10000], Train Loss: 0.018007, Val Loss: 0.202370
# Epoch [1340/10000], Train Loss: 0.019068, Val Loss: 0.203765
# Epoch [1350/10000], Train Loss: 0.016753, Val Loss: 0.203639
# Epoch [1360/10000], Train Loss: 0.012911, Val Loss: 0.205757
# Epoch [1370/10000], Train Loss: 0.015472, Val Loss: 0.207270
# Epoch [1380/10000], Train Loss: 0.016275, Val Loss: 0.205153
# Epoch [1390/10000], Train Loss: 0.056349, Val Loss: 0.248828
# Epoch [1400/10000], Train Loss: 0.146100, Val Loss: 0.271134
# Epoch [1410/10000], Train Loss: 0.048833, Val Loss: 0.207180
# Epoch [1420/10000], Train Loss: 0.056258, Val Loss: 0.227795
# Epoch [1430/10000], Train Loss: 0.067570, Val Loss: 0.197919
# Epoch [1440/10000], Train Loss: 0.089814, Val Loss: 0.291841
# Epoch [1450/10000], Train Loss: 0.035174, Val Loss: 0.210422
# Epoch [1460/10000], Train Loss: 0.029532, Val Loss: 0.216497
# Epoch [1470/10000], Train Loss: 0.064599, Val Loss: 0.229029
# Epoch [1480/10000], Train Loss: 0.037367, Val Loss: 0.206204
# Epoch [1490/10000], Train Loss: 0.033817, Val Loss: 0.225522
# Epoch [1500/10000], Train Loss: 0.025116, Val Loss: 0.202530
# Epoch [1510/10000], Train Loss: 0.011562, Val Loss: 0.202591
# Epoch [1520/10000], Train Loss: 0.015422, Val Loss: 0.217947
# Epoch [1530/10000], Train Loss: 0.030464, Val Loss: 0.208022
# Epoch [1540/10000], Train Loss: 0.021882, Val Loss: 0.206206
# Epoch [1550/10000], Train Loss: 0.012177, Val Loss: 0.199734
# Epoch [1560/10000], Train Loss: 0.015963, Val Loss: 0.200461
# Epoch [1570/10000], Train Loss: 0.016353, Val Loss: 0.213820
# Epoch [1580/10000], Train Loss: 0.058437, Val Loss: 0.198148
# Epoch [1590/10000], Train Loss: 0.064031, Val Loss: 0.242659
# Epoch [1600/10000], Train Loss: 0.030080, Val Loss: 0.209315
# Epoch [1610/10000], Train Loss: 0.035925, Val Loss: 0.209802
# Epoch [1620/10000], Train Loss: 0.061186, Val Loss: 0.215784
# Epoch [1630/10000], Train Loss: 0.069379, Val Loss: 0.231332
# Epoch [1640/10000], Train Loss: 0.053014, Val Loss: 0.273175
# Epoch [1650/10000], Train Loss: 0.024153, Val Loss: 0.223528
# Epoch [1660/10000], Train Loss: 0.028893, Val Loss: 0.234663
# Epoch [1670/10000], Train Loss: 0.052962, Val Loss: 0.226953
# Epoch [1680/10000], Train Loss: 0.016847, Val Loss: 0.222367
# Epoch [1690/10000], Train Loss: 0.021835, Val Loss: 0.228895
# Epoch [1700/10000], Train Loss: 0.009681, Val Loss: 0.212685
# Epoch [1710/10000], Train Loss: 0.025239, Val Loss: 0.202693
# Epoch [1720/10000], Train Loss: 0.035060, Val Loss: 0.213669
# Epoch [1730/10000], Train Loss: 0.062188, Val Loss: 0.229169
# Epoch [1740/10000], Train Loss: 0.045922, Val Loss: 0.196795
# Epoch [1750/10000], Train Loss: 0.019689, Val Loss: 0.205347
# Epoch [1760/10000], Train Loss: 0.026829, Val Loss: 0.206318
# Epoch [1770/10000], Train Loss: 0.008014, Val Loss: 0.203158
# Epoch [1780/10000], Train Loss: 0.014777, Val Loss: 0.211183
# Epoch [1790/10000], Train Loss: 0.008405, Val Loss: 0.210485
# Epoch [1800/10000], Train Loss: 0.016893, Val Loss: 0.224290
# Epoch [1810/10000], Train Loss: 0.015090, Val Loss: 0.214770
# Epoch [1820/10000], Train Loss: 0.013421, Val Loss: 0.209291
# Epoch [1830/10000], Train Loss: 0.015682, Val Loss: 0.215515
# Epoch [1840/10000], Train Loss: 0.017125, Val Loss: 0.213014
# Epoch [1850/10000], Train Loss: 0.019928, Val Loss: 0.225313
# Epoch [1860/10000], Train Loss: 0.024619, Val Loss: 0.214664
# Epoch [1870/10000], Train Loss: 0.012215, Val Loss: 0.211771
# Epoch [1880/10000], Train Loss: 0.026162, Val Loss: 0.205935
# Epoch [1890/10000], Train Loss: 0.017593, Val Loss: 0.201683
# Epoch [1900/10000], Train Loss: 0.024324, Val Loss: 0.236798
# Epoch [1910/10000], Train Loss: 0.106995, Val Loss: 0.249655
# Epoch [1920/10000], Train Loss: 0.025917, Val Loss: 0.222261
# Epoch [1930/10000], Train Loss: 0.012789, Val Loss: 0.229240
# Epoch [1940/10000], Train Loss: 0.009799, Val Loss: 0.221402
# Epoch [1950/10000], Train Loss: 0.010343, Val Loss: 0.238107
# Epoch [1960/10000], Train Loss: 0.008886, Val Loss: 0.233288
# Epoch [1970/10000], Train Loss: 0.016967, Val Loss: 0.225846
# Epoch [1980/10000], Train Loss: 0.009475, Val Loss: 0.230008
# Epoch [1990/10000], Train Loss: 0.012337, Val Loss: 0.227795
# Epoch [2000/10000], Train Loss: 0.036683, Val Loss: 0.239482
# Epoch [2010/10000], Train Loss: 0.042937, Val Loss: 0.225156
# Epoch [2020/10000], Train Loss: 0.022076, Val Loss: 0.217945
# Epoch [2030/10000], Train Loss: 0.044243, Val Loss: 0.216584
# Epoch [2040/10000], Train Loss: 0.024442, Val Loss: 0.213777
# Epoch [2050/10000], Train Loss: 0.008295, Val Loss: 0.215596
# Epoch [2060/10000], Train Loss: 0.009490, Val Loss: 0.214313
# Epoch [2070/10000], Train Loss: 0.011815, Val Loss: 0.211025
# Epoch [2080/10000], Train Loss: 0.007868, Val Loss: 0.206470
# Epoch [2090/10000], Train Loss: 0.006221, Val Loss: 0.209642
# Epoch [2100/10000], Train Loss: 0.030086, Val Loss: 0.216078
# Epoch [2110/10000], Train Loss: 0.029740, Val Loss: 0.224603
# Epoch [2120/10000], Train Loss: 0.004792, Val Loss: 0.208951
# Epoch [2130/10000], Train Loss: 0.005359, Val Loss: 0.211580
# Epoch [2140/10000], Train Loss: 0.006116, Val Loss: 0.211175
# Epoch [2150/10000], Train Loss: 0.015052, Val Loss: 0.215209
# Epoch [2160/10000], Train Loss: 0.028428, Val Loss: 0.212999
# Epoch [2170/10000], Train Loss: 0.058485, Val Loss: 0.234662
# Epoch [2180/10000], Train Loss: 0.020087, Val Loss: 0.214567
# Epoch [2190/10000], Train Loss: 0.053501, Val Loss: 0.221300
# Epoch [2200/10000], Train Loss: 0.016634, Val Loss: 0.218786
# Epoch [2210/10000], Train Loss: 0.010075, Val Loss: 0.211646
# Epoch [2220/10000], Train Loss: 0.030468, Val Loss: 0.209583
# Epoch [2230/10000], Train Loss: 0.042434, Val Loss: 0.220907
# Epoch [2240/10000], Train Loss: 0.073250, Val Loss: 0.219845
# Epoch [2250/10000], Train Loss: 0.061506, Val Loss: 0.220912
# Epoch [2260/10000], Train Loss: 0.008976, Val Loss: 0.210778
# Epoch [2270/10000], Train Loss: 0.009282, Val Loss: 0.216258
# Epoch [2280/10000], Train Loss: 0.007038, Val Loss: 0.214509
# Epoch [2290/10000], Train Loss: 0.003881, Val Loss: 0.210075
# Epoch [2300/10000], Train Loss: 0.005213, Val Loss: 0.207019
# Epoch [2310/10000], Train Loss: 0.005938, Val Loss: 0.214555
# Epoch [2320/10000], Train Loss: 0.007330, Val Loss: 0.205902
# Epoch [2330/10000], Train Loss: 0.009305, Val Loss: 0.210382
# Epoch [2340/10000], Train Loss: 0.003628, Val Loss: 0.207125
# Epoch [2350/10000], Train Loss: 0.006413, Val Loss: 0.204560
# Epoch [2360/10000], Train Loss: 0.011510, Val Loss: 0.212105
# Epoch [2370/10000], Train Loss: 0.009757, Val Loss: 0.210157
# Epoch [2380/10000], Train Loss: 0.010250, Val Loss: 0.211039
# Early stopping triggered at epoch 2388
# Evaluation Metrics:
# MSE: 551634941.9725
# R² (meanLineIntensity): 0.8223
# R² (meanNumPixels15): 0.7537
# Fold 2 Validation MSE: 551634941.9725
# Fold 2 R² scores: ['0.8223', '0.7537']
#
# Training Fold 3
# --------------------------------------------------
# Total Parameters: 266,612,738
# Epoch [10/10000], Train Loss: 0.394955, Val Loss: 0.432169
# Epoch [20/10000], Train Loss: 0.346340, Val Loss: 0.435698
# Epoch [30/10000], Train Loss: 0.280619, Val Loss: 0.396501
# Epoch [40/10000], Train Loss: 0.232943, Val Loss: 0.351149
# Epoch [50/10000], Train Loss: 0.273540, Val Loss: 0.404564
# Epoch [60/10000], Train Loss: 0.222981, Val Loss: 0.428483
# Epoch [70/10000], Train Loss: 0.193632, Val Loss: 0.332680
# Epoch [80/10000], Train Loss: 0.196977, Val Loss: 0.325875
# Epoch [90/10000], Train Loss: 0.179429, Val Loss: 0.321180
# Epoch [100/10000], Train Loss: 0.203017, Val Loss: 0.318933
# Epoch [110/10000], Train Loss: 0.152601, Val Loss: 0.286078
# Epoch [120/10000], Train Loss: 0.153253, Val Loss: 0.279023
# Epoch [130/10000], Train Loss: 0.144747, Val Loss: 0.279107
# Epoch [140/10000], Train Loss: 0.135789, Val Loss: 0.260498
# Epoch [150/10000], Train Loss: 0.156650, Val Loss: 0.303557
# Epoch [160/10000], Train Loss: 0.187866, Val Loss: 0.316629
# Epoch [170/10000], Train Loss: 0.141508, Val Loss: 0.275864
# Epoch [180/10000], Train Loss: 0.141202, Val Loss: 0.309143
# Epoch [190/10000], Train Loss: 0.132512, Val Loss: 0.295691
# Epoch [200/10000], Train Loss: 0.144532, Val Loss: 0.273499
# Epoch [210/10000], Train Loss: 0.115885, Val Loss: 0.268088
# Epoch [220/10000], Train Loss: 0.120895, Val Loss: 0.282387
# Epoch [230/10000], Train Loss: 0.131328, Val Loss: 0.340287
# Epoch [240/10000], Train Loss: 0.112437, Val Loss: 0.265521
# Epoch [250/10000], Train Loss: 0.117267, Val Loss: 0.255673
# Epoch [260/10000], Train Loss: 0.148085, Val Loss: 0.292417
# Epoch [270/10000], Train Loss: 0.129832, Val Loss: 0.257438
# Epoch [280/10000], Train Loss: 0.111178, Val Loss: 0.264090
# Epoch [290/10000], Train Loss: 0.110281, Val Loss: 0.263870
# Epoch [300/10000], Train Loss: 0.097121, Val Loss: 0.264902
# Epoch [310/10000], Train Loss: 0.088690, Val Loss: 0.276143
# Epoch [320/10000], Train Loss: 0.085026, Val Loss: 0.286933
# Epoch [330/10000], Train Loss: 0.097020, Val Loss: 0.266062
# Epoch [340/10000], Train Loss: 0.103507, Val Loss: 0.263221
# Epoch [350/10000], Train Loss: 0.091230, Val Loss: 0.293872
# Epoch [360/10000], Train Loss: 0.114518, Val Loss: 0.270956
# Epoch [370/10000], Train Loss: 0.105718, Val Loss: 0.335703
# Epoch [380/10000], Train Loss: 0.085933, Val Loss: 0.277186
# Epoch [390/10000], Train Loss: 0.121055, Val Loss: 0.339706
# Epoch [400/10000], Train Loss: 0.075693, Val Loss: 0.234093
# Epoch [410/10000], Train Loss: 0.078708, Val Loss: 0.264627
# Epoch [420/10000], Train Loss: 0.063631, Val Loss: 0.272167
# Epoch [430/10000], Train Loss: 0.068340, Val Loss: 0.265573
# Epoch [440/10000], Train Loss: 0.089606, Val Loss: 0.251833
# Epoch [450/10000], Train Loss: 0.074186, Val Loss: 0.264043
# Epoch [460/10000], Train Loss: 0.067826, Val Loss: 0.281944
# Epoch [470/10000], Train Loss: 0.070017, Val Loss: 0.297050
# Epoch [480/10000], Train Loss: 0.091159, Val Loss: 0.289203
# Epoch [490/10000], Train Loss: 0.111452, Val Loss: 0.249881
# Epoch [500/10000], Train Loss: 0.128058, Val Loss: 0.296305
# Epoch [510/10000], Train Loss: 0.108642, Val Loss: 0.254062
# Epoch [520/10000], Train Loss: 0.112533, Val Loss: 0.278822
# Epoch [530/10000], Train Loss: 0.064086, Val Loss: 0.282711
# Epoch [540/10000], Train Loss: 0.079503, Val Loss: 0.260992
# Epoch [550/10000], Train Loss: 0.079652, Val Loss: 0.267853
# Epoch [560/10000], Train Loss: 0.089079, Val Loss: 0.289716
# Epoch [570/10000], Train Loss: 0.176446, Val Loss: 0.305414
# Epoch [580/10000], Train Loss: 0.069992, Val Loss: 0.297296
# Epoch [590/10000], Train Loss: 0.077306, Val Loss: 0.263448
# Epoch [600/10000], Train Loss: 0.044594, Val Loss: 0.271405
# Epoch [610/10000], Train Loss: 0.043656, Val Loss: 0.261439
# Epoch [620/10000], Train Loss: 0.058358, Val Loss: 0.275943
# Epoch [630/10000], Train Loss: 0.049811, Val Loss: 0.275768
# Epoch [640/10000], Train Loss: 0.032053, Val Loss: 0.268346
# Epoch [650/10000], Train Loss: 0.066660, Val Loss: 0.286750
# Epoch [660/10000], Train Loss: 0.050919, Val Loss: 0.299179
# Epoch [670/10000], Train Loss: 0.041437, Val Loss: 0.281155
# Epoch [680/10000], Train Loss: 0.073957, Val Loss: 0.259533
# Epoch [690/10000], Train Loss: 0.115966, Val Loss: 0.338934
# Epoch [700/10000], Train Loss: 0.078131, Val Loss: 0.257774
# Epoch [710/10000], Train Loss: 0.052993, Val Loss: 0.278713
# Epoch [720/10000], Train Loss: 0.088261, Val Loss: 0.295223
# Epoch [730/10000], Train Loss: 0.067861, Val Loss: 0.247479
# Epoch [740/10000], Train Loss: 0.037619, Val Loss: 0.275881
# Epoch [750/10000], Train Loss: 0.058495, Val Loss: 0.259498
# Epoch [760/10000], Train Loss: 0.074315, Val Loss: 0.249484
# Epoch [770/10000], Train Loss: 0.102639, Val Loss: 0.281422
# Epoch [780/10000], Train Loss: 0.034347, Val Loss: 0.273482
# Epoch [790/10000], Train Loss: 0.057365, Val Loss: 0.267083
# Epoch [800/10000], Train Loss: 0.037690, Val Loss: 0.280977
# Epoch [810/10000], Train Loss: 0.041422, Val Loss: 0.258022
# Epoch [820/10000], Train Loss: 0.027985, Val Loss: 0.257051
# Epoch [830/10000], Train Loss: 0.017881, Val Loss: 0.264831
# Epoch [840/10000], Train Loss: 0.029787, Val Loss: 0.261588
# Epoch [850/10000], Train Loss: 0.036919, Val Loss: 0.260885
# Epoch [860/10000], Train Loss: 0.082380, Val Loss: 0.276864
# Epoch [870/10000], Train Loss: 0.082202, Val Loss: 0.268453
# Epoch [880/10000], Train Loss: 0.073213, Val Loss: 0.322527
# Epoch [890/10000], Train Loss: 0.050464, Val Loss: 0.263073
# Epoch [900/10000], Train Loss: 0.160859, Val Loss: 0.277944
# Epoch [910/10000], Train Loss: 0.053043, Val Loss: 0.261074
# Epoch [920/10000], Train Loss: 0.047698, Val Loss: 0.288369
# Epoch [930/10000], Train Loss: 0.051931, Val Loss: 0.254590
# Early stopping triggered at epoch 938
# Evaluation Metrics:
# MSE: 672590617.9890
# R² (meanLineIntensity): 0.8149
# R² (meanNumPixels15): 0.7527
# Fold 3 Validation MSE: 672590617.9890
# Fold 3 R² scores: ['0.8149', '0.7527']
#
# Training Fold 4
# --------------------------------------------------
# Total Parameters: 266,612,738
# Epoch [10/10000], Train Loss: 0.332470, Val Loss: 0.478068
# Epoch [20/10000], Train Loss: 0.313542, Val Loss: 0.416725
# Epoch [30/10000], Train Loss: 0.255647, Val Loss: 0.393837
# Epoch [40/10000], Train Loss: 0.253209, Val Loss: 0.351808
# Epoch [50/10000], Train Loss: 0.244216, Val Loss: 0.347889
# Epoch [60/10000], Train Loss: 0.227289, Val Loss: 0.320591
# Epoch [70/10000], Train Loss: 0.191075, Val Loss: 0.381016
# Epoch [80/10000], Train Loss: 0.184505, Val Loss: 0.284973
# Epoch [90/10000], Train Loss: 0.217218, Val Loss: 0.295920
# Epoch [100/10000], Train Loss: 0.235171, Val Loss: 0.304291
# Epoch [110/10000], Train Loss: 0.180348, Val Loss: 0.283824
# Epoch [120/10000], Train Loss: 0.160040, Val Loss: 0.284512
# Epoch [130/10000], Train Loss: 0.160687, Val Loss: 0.261901
# Epoch [140/10000], Train Loss: 0.141657, Val Loss: 0.238849
# Epoch [150/10000], Train Loss: 0.151319, Val Loss: 0.248901
# Epoch [160/10000], Train Loss: 0.127868, Val Loss: 0.258225
# Epoch [170/10000], Train Loss: 0.145982, Val Loss: 0.282030
# Epoch [180/10000], Train Loss: 0.140172, Val Loss: 0.254188
# Epoch [190/10000], Train Loss: 0.134157, Val Loss: 0.264985
# Epoch [200/10000], Train Loss: 0.156872, Val Loss: 0.274917
# Epoch [210/10000], Train Loss: 0.109158, Val Loss: 0.247751
# Epoch [220/10000], Train Loss: 0.144090, Val Loss: 0.235744
# Epoch [230/10000], Train Loss: 0.119074, Val Loss: 0.255404
# Epoch [240/10000], Train Loss: 0.100381, Val Loss: 0.263162
# Epoch [250/10000], Train Loss: 0.107447, Val Loss: 0.275995
# Epoch [260/10000], Train Loss: 0.168473, Val Loss: 0.335304
# Epoch [270/10000], Train Loss: 0.105277, Val Loss: 0.238439
# Epoch [280/10000], Train Loss: 0.096250, Val Loss: 0.252146
# Epoch [290/10000], Train Loss: 0.113525, Val Loss: 0.290970
# Epoch [300/10000], Train Loss: 0.114359, Val Loss: 0.276035
# Epoch [310/10000], Train Loss: 0.114812, Val Loss: 0.271944
# Epoch [320/10000], Train Loss: 0.119706, Val Loss: 0.237024
# Epoch [330/10000], Train Loss: 0.107667, Val Loss: 0.290800
# Epoch [340/10000], Train Loss: 0.127840, Val Loss: 0.275252
# Epoch [350/10000], Train Loss: 0.098873, Val Loss: 0.239476
# Epoch [360/10000], Train Loss: 0.152687, Val Loss: 0.266367
# Epoch [370/10000], Train Loss: 0.084946, Val Loss: 0.235199
# Epoch [380/10000], Train Loss: 0.084212, Val Loss: 0.227682
# Epoch [390/10000], Train Loss: 0.085144, Val Loss: 0.237022
# Epoch [400/10000], Train Loss: 0.066508, Val Loss: 0.240678
# Epoch [410/10000], Train Loss: 0.098878, Val Loss: 0.230394
# Epoch [420/10000], Train Loss: 0.125209, Val Loss: 0.284352
# Epoch [430/10000], Train Loss: 0.069353, Val Loss: 0.237670
# Epoch [440/10000], Train Loss: 0.058399, Val Loss: 0.245099
# Epoch [450/10000], Train Loss: 0.068427, Val Loss: 0.246764
# Epoch [460/10000], Train Loss: 0.081172, Val Loss: 0.251643
# Epoch [470/10000], Train Loss: 0.078363, Val Loss: 0.236429
# Epoch [480/10000], Train Loss: 0.074124, Val Loss: 0.246076
# Epoch [490/10000], Train Loss: 0.080468, Val Loss: 0.248582
# Epoch [500/10000], Train Loss: 0.077483, Val Loss: 0.275617
# Epoch [510/10000], Train Loss: 0.090793, Val Loss: 0.226813
# Epoch [520/10000], Train Loss: 0.088814, Val Loss: 0.270829
# Epoch [530/10000], Train Loss: 0.072498, Val Loss: 0.235555
# Epoch [540/10000], Train Loss: 0.089871, Val Loss: 0.260444
# Epoch [550/10000], Train Loss: 0.059570, Val Loss: 0.242791
# Epoch [560/10000], Train Loss: 0.060793, Val Loss: 0.244761
# Epoch [570/10000], Train Loss: 0.060312, Val Loss: 0.252569
# Epoch [580/10000], Train Loss: 0.059867, Val Loss: 0.242371
# Epoch [590/10000], Train Loss: 0.085039, Val Loss: 0.258956
# Epoch [600/10000], Train Loss: 0.048308, Val Loss: 0.232074
# Epoch [610/10000], Train Loss: 0.082721, Val Loss: 0.269089
# Epoch [620/10000], Train Loss: 0.046043, Val Loss: 0.236312
# Epoch [630/10000], Train Loss: 0.099313, Val Loss: 0.240709
# Epoch [640/10000], Train Loss: 0.086664, Val Loss: 0.230814
# Epoch [650/10000], Train Loss: 0.055457, Val Loss: 0.244898
# Epoch [660/10000], Train Loss: 0.073841, Val Loss: 0.238003
# Epoch [670/10000], Train Loss: 0.075687, Val Loss: 0.240462
# Epoch [680/10000], Train Loss: 0.054971, Val Loss: 0.240374
# Epoch [690/10000], Train Loss: 0.058506, Val Loss: 0.246876
# Epoch [700/10000], Train Loss: 0.050742, Val Loss: 0.252302
# Epoch [710/10000], Train Loss: 0.038529, Val Loss: 0.243405
# Epoch [720/10000], Train Loss: 0.084807, Val Loss: 0.289035
# Epoch [730/10000], Train Loss: 0.065840, Val Loss: 0.242114
# Epoch [740/10000], Train Loss: 0.035277, Val Loss: 0.242839
# Epoch [750/10000], Train Loss: 0.052765, Val Loss: 0.240981
# Epoch [760/10000], Train Loss: 0.116037, Val Loss: 0.267427
# Epoch [770/10000], Train Loss: 0.062085, Val Loss: 0.231825
# Epoch [780/10000], Train Loss: 0.043309, Val Loss: 0.239918
# Epoch [790/10000], Train Loss: 0.051276, Val Loss: 0.243408
# Epoch [800/10000], Train Loss: 0.101740, Val Loss: 0.248144
# Epoch [810/10000], Train Loss: 0.086881, Val Loss: 0.301364
# Epoch [820/10000], Train Loss: 0.065173, Val Loss: 0.244406
# Epoch [830/10000], Train Loss: 0.126933, Val Loss: 0.280715
# Epoch [840/10000], Train Loss: 0.115190, Val Loss: 0.277196
# Epoch [850/10000], Train Loss: 0.073869, Val Loss: 0.254358
# Epoch [860/10000], Train Loss: 0.038739, Val Loss: 0.247995
# Epoch [870/10000], Train Loss: 0.038188, Val Loss: 0.247916
# Epoch [880/10000], Train Loss: 0.031612, Val Loss: 0.244525
# Epoch [890/10000], Train Loss: 0.133634, Val Loss: 0.255829
# Epoch [900/10000], Train Loss: 0.075177, Val Loss: 0.272033
# Epoch [910/10000], Train Loss: 0.060179, Val Loss: 0.248116
# Epoch [920/10000], Train Loss: 0.034029, Val Loss: 0.255895
# Epoch [930/10000], Train Loss: 0.050602, Val Loss: 0.265864
# Epoch [940/10000], Train Loss: 0.029775, Val Loss: 0.243514
# Epoch [950/10000], Train Loss: 0.046742, Val Loss: 0.278069
# Epoch [960/10000], Train Loss: 0.030399, Val Loss: 0.254584
# Epoch [970/10000], Train Loss: 0.040307, Val Loss: 0.248547
# Epoch [980/10000], Train Loss: 0.022197, Val Loss: 0.261194
# Epoch [990/10000], Train Loss: 0.022138, Val Loss: 0.245840
# Epoch [1000/10000], Train Loss: 0.055351, Val Loss: 0.262515
# Epoch [1010/10000], Train Loss: 0.027947, Val Loss: 0.245348
# Epoch [1020/10000], Train Loss: 0.028089, Val Loss: 0.253451
# Epoch [1030/10000], Train Loss: 0.083339, Val Loss: 0.257730
# Epoch [1040/10000], Train Loss: 0.060073, Val Loss: 0.233240
# Epoch [1050/10000], Train Loss: 0.078060, Val Loss: 0.269539
# Epoch [1060/10000], Train Loss: 0.040534, Val Loss: 0.239449
# Epoch [1070/10000], Train Loss: 0.035197, Val Loss: 0.227795
# Epoch [1080/10000], Train Loss: 0.051552, Val Loss: 0.235026
# Epoch [1090/10000], Train Loss: 0.053298, Val Loss: 0.241620
# Epoch [1100/10000], Train Loss: 0.042372, Val Loss: 0.236091
# Epoch [1110/10000], Train Loss: 0.056958, Val Loss: 0.253092
# Epoch [1120/10000], Train Loss: 0.045929, Val Loss: 0.233156
# Epoch [1130/10000], Train Loss: 0.040283, Val Loss: 0.231552
# Epoch [1140/10000], Train Loss: 0.018325, Val Loss: 0.234048
# Epoch [1150/10000], Train Loss: 0.024932, Val Loss: 0.241966
# Epoch [1160/10000], Train Loss: 0.017757, Val Loss: 0.235330
# Epoch [1170/10000], Train Loss: 0.100193, Val Loss: 0.249554
# Epoch [1180/10000], Train Loss: 0.035891, Val Loss: 0.252919
# Epoch [1190/10000], Train Loss: 0.047380, Val Loss: 0.256909
# Epoch [1200/10000], Train Loss: 0.032831, Val Loss: 0.242032
# Epoch [1210/10000], Train Loss: 0.026162, Val Loss: 0.255880
# Epoch [1220/10000], Train Loss: 0.070676, Val Loss: 0.272246
# Epoch [1230/10000], Train Loss: 0.051289, Val Loss: 0.265946
# Epoch [1240/10000], Train Loss: 0.039774, Val Loss: 0.250481
# Epoch [1250/10000], Train Loss: 0.047009, Val Loss: 0.246374
# Epoch [1260/10000], Train Loss: 0.016382, Val Loss: 0.241720
# Epoch [1270/10000], Train Loss: 0.012001, Val Loss: 0.241877
# Early stopping triggered at epoch 1272
# Evaluation Metrics:
# MSE: 620993986.2983
# R² (meanLineIntensity): 0.8311
# R² (meanNumPixels15): 0.7561
# Fold 4 Validation MSE: 620993986.2983
# Fold 4 R² scores: ['0.8311', '0.7561']
#
# Training Fold 5
# --------------------------------------------------
# Total Parameters: 266,612,738
# Epoch [10/10000], Train Loss: 0.350911, Val Loss: 0.381389
# Epoch [20/10000], Train Loss: 0.304172, Val Loss: 0.371813
# Epoch [30/10000], Train Loss: 0.319705, Val Loss: 0.437037
# Epoch [40/10000], Train Loss: 0.273180, Val Loss: 0.323052
# Epoch [50/10000], Train Loss: 0.222381, Val Loss: 0.309748
# Epoch [60/10000], Train Loss: 0.216707, Val Loss: 0.267911
# Epoch [70/10000], Train Loss: 0.211838, Val Loss: 0.298986
# Epoch [80/10000], Train Loss: 0.211906, Val Loss: 0.315812
# Epoch [90/10000], Train Loss: 0.208704, Val Loss: 0.274670
# Epoch [100/10000], Train Loss: 0.217762, Val Loss: 0.274022
# Epoch [110/10000], Train Loss: 0.179645, Val Loss: 0.300682
# Epoch [120/10000], Train Loss: 0.176135, Val Loss: 0.266899
# Epoch [130/10000], Train Loss: 0.160728, Val Loss: 0.275847
# Epoch [140/10000], Train Loss: 0.188133, Val Loss: 0.289701
# Epoch [150/10000], Train Loss: 0.190079, Val Loss: 0.248036
# Epoch [160/10000], Train Loss: 0.141918, Val Loss: 0.278899
# Epoch [170/10000], Train Loss: 0.163229, Val Loss: 0.315911
# Epoch [180/10000], Train Loss: 0.146449, Val Loss: 0.255367
# Epoch [190/10000], Train Loss: 0.166677, Val Loss: 0.233510
# Epoch [200/10000], Train Loss: 0.128276, Val Loss: 0.227829
# Epoch [210/10000], Train Loss: 0.108505, Val Loss: 0.290518
# Epoch [220/10000], Train Loss: 0.128434, Val Loss: 0.251830
# Epoch [230/10000], Train Loss: 0.115249, Val Loss: 0.246120
# Epoch [240/10000], Train Loss: 0.118482, Val Loss: 0.263899
# Epoch [250/10000], Train Loss: 0.125183, Val Loss: 0.292384
# Epoch [260/10000], Train Loss: 0.136139, Val Loss: 0.258395
# Epoch [270/10000], Train Loss: 0.115796, Val Loss: 0.247324
# Epoch [280/10000], Train Loss: 0.098119, Val Loss: 0.248819
# Epoch [290/10000], Train Loss: 0.111096, Val Loss: 0.225130
# Epoch [300/10000], Train Loss: 0.128857, Val Loss: 0.251076
# Epoch [310/10000], Train Loss: 0.078961, Val Loss: 0.216407
# Epoch [320/10000], Train Loss: 0.106537, Val Loss: 0.288260
# Epoch [330/10000], Train Loss: 0.116969, Val Loss: 0.241238
# Epoch [340/10000], Train Loss: 0.089263, Val Loss: 0.214746
# Epoch [350/10000], Train Loss: 0.066400, Val Loss: 0.235381
# Epoch [360/10000], Train Loss: 0.117056, Val Loss: 0.234408
# Epoch [370/10000], Train Loss: 0.083399, Val Loss: 0.236029
# Epoch [380/10000], Train Loss: 0.087891, Val Loss: 0.237029
# Epoch [390/10000], Train Loss: 0.072815, Val Loss: 0.222943
# Epoch [400/10000], Train Loss: 0.110580, Val Loss: 0.226203
# Epoch [410/10000], Train Loss: 0.113567, Val Loss: 0.228106
# Epoch [420/10000], Train Loss: 0.105322, Val Loss: 0.228419
# Epoch [430/10000], Train Loss: 0.079022, Val Loss: 0.235690
# Epoch [440/10000], Train Loss: 0.076770, Val Loss: 0.248361
# Epoch [450/10000], Train Loss: 0.065449, Val Loss: 0.221387
# Epoch [460/10000], Train Loss: 0.119760, Val Loss: 0.268424
# Epoch [470/10000], Train Loss: 0.074335, Val Loss: 0.219004
# Epoch [480/10000], Train Loss: 0.058267, Val Loss: 0.225240
# Epoch [490/10000], Train Loss: 0.094636, Val Loss: 0.231105
# Epoch [500/10000], Train Loss: 0.097432, Val Loss: 0.272098
# Epoch [510/10000], Train Loss: 0.081036, Val Loss: 0.231622
# Epoch [520/10000], Train Loss: 0.068065, Val Loss: 0.264139
# Epoch [530/10000], Train Loss: 0.068963, Val Loss: 0.224499
# Epoch [540/10000], Train Loss: 0.052405, Val Loss: 0.253089
# Epoch [550/10000], Train Loss: 0.097272, Val Loss: 0.264479
# Epoch [560/10000], Train Loss: 0.067439, Val Loss: 0.256778
# Epoch [570/10000], Train Loss: 0.051879, Val Loss: 0.231025
# Epoch [580/10000], Train Loss: 0.038034, Val Loss: 0.226229
# Epoch [590/10000], Train Loss: 0.083394, Val Loss: 0.242010
# Epoch [600/10000], Train Loss: 0.090026, Val Loss: 0.248249
# Epoch [610/10000], Train Loss: 0.087813, Val Loss: 0.240570
# Epoch [620/10000], Train Loss: 0.044651, Val Loss: 0.213814
# Epoch [630/10000], Train Loss: 0.061487, Val Loss: 0.242525
# Epoch [640/10000], Train Loss: 0.050763, Val Loss: 0.244924
# Epoch [650/10000], Train Loss: 0.063859, Val Loss: 0.260865
# Epoch [660/10000], Train Loss: 0.053814, Val Loss: 0.245626
# Epoch [670/10000], Train Loss: 0.053185, Val Loss: 0.229320
# Epoch [680/10000], Train Loss: 0.128251, Val Loss: 0.237710
# Epoch [690/10000], Train Loss: 0.092321, Val Loss: 0.243315
# Epoch [700/10000], Train Loss: 0.064049, Val Loss: 0.231301
# Epoch [710/10000], Train Loss: 0.029288, Val Loss: 0.221308
# Epoch [720/10000], Train Loss: 0.083373, Val Loss: 0.257486
# Epoch [730/10000], Train Loss: 0.043448, Val Loss: 0.222919
# Epoch [740/10000], Train Loss: 0.057310, Val Loss: 0.221846
# Epoch [750/10000], Train Loss: 0.040498, Val Loss: 0.211913
# Epoch [760/10000], Train Loss: 0.032830, Val Loss: 0.228297
# Epoch [770/10000], Train Loss: 0.044733, Val Loss: 0.223442
# Epoch [780/10000], Train Loss: 0.054846, Val Loss: 0.243288
# Epoch [790/10000], Train Loss: 0.080479, Val Loss: 0.236742
# Epoch [800/10000], Train Loss: 0.056744, Val Loss: 0.241276
# Epoch [810/10000], Train Loss: 0.039614, Val Loss: 0.247737
# Epoch [820/10000], Train Loss: 0.032051, Val Loss: 0.228663
# Epoch [830/10000], Train Loss: 0.021442, Val Loss: 0.235377
# Epoch [840/10000], Train Loss: 0.042357, Val Loss: 0.232023
# Epoch [850/10000], Train Loss: 0.030472, Val Loss: 0.233217
# Epoch [860/10000], Train Loss: 0.023769, Val Loss: 0.235961
# Epoch [870/10000], Train Loss: 0.049296, Val Loss: 0.248466
# Epoch [880/10000], Train Loss: 0.072152, Val Loss: 0.245145
# Epoch [890/10000], Train Loss: 0.054151, Val Loss: 0.238243
# Epoch [900/10000], Train Loss: 0.037049, Val Loss: 0.218355
# Epoch [910/10000], Train Loss: 0.033585, Val Loss: 0.214401
# Epoch [920/10000], Train Loss: 0.054937, Val Loss: 0.243924
# Epoch [930/10000], Train Loss: 0.123847, Val Loss: 0.248477
# Epoch [940/10000], Train Loss: 0.064162, Val Loss: 0.243185
# Epoch [950/10000], Train Loss: 0.025030, Val Loss: 0.213943
# Epoch [960/10000], Train Loss: 0.040008, Val Loss: 0.265058
# Epoch [970/10000], Train Loss: 0.028822, Val Loss: 0.209376
# Epoch [980/10000], Train Loss: 0.016503, Val Loss: 0.206980
# Epoch [990/10000], Train Loss: 0.060298, Val Loss: 0.233468
# Epoch [1000/10000], Train Loss: 0.066198, Val Loss: 0.229427
# Epoch [1010/10000], Train Loss: 0.071229, Val Loss: 0.289487
# Epoch [1020/10000], Train Loss: 0.052924, Val Loss: 0.218519
# Epoch [1030/10000], Train Loss: 0.070841, Val Loss: 0.217732
# Epoch [1040/10000], Train Loss: 0.029552, Val Loss: 0.235732
# Epoch [1050/10000], Train Loss: 0.051650, Val Loss: 0.237866
# Epoch [1060/10000], Train Loss: 0.017751, Val Loss: 0.214657
# Epoch [1070/10000], Train Loss: 0.015432, Val Loss: 0.217014
# Epoch [1080/10000], Train Loss: 0.036135, Val Loss: 0.225509
# Epoch [1090/10000], Train Loss: 0.020494, Val Loss: 0.227108
# Epoch [1100/10000], Train Loss: 0.034407, Val Loss: 0.226143
# Epoch [1110/10000], Train Loss: 0.032539, Val Loss: 0.213543
# Epoch [1120/10000], Train Loss: 0.043588, Val Loss: 0.224333
# Epoch [1130/10000], Train Loss: 0.028063, Val Loss: 0.224401
# Epoch [1140/10000], Train Loss: 0.030820, Val Loss: 0.210446
# Epoch [1150/10000], Train Loss: 0.020753, Val Loss: 0.215118
# Epoch [1160/10000], Train Loss: 0.043186, Val Loss: 0.234728
# Epoch [1170/10000], Train Loss: 0.059488, Val Loss: 0.221611
# Epoch [1180/10000], Train Loss: 0.048562, Val Loss: 0.233533
# Epoch [1190/10000], Train Loss: 0.045300, Val Loss: 0.225337
# Epoch [1200/10000], Train Loss: 0.052508, Val Loss: 0.235291
# Epoch [1210/10000], Train Loss: 0.040411, Val Loss: 0.226188
# Epoch [1220/10000], Train Loss: 0.016699, Val Loss: 0.222744
# Epoch [1230/10000], Train Loss: 0.025073, Val Loss: 0.221524
# Epoch [1240/10000], Train Loss: 0.023346, Val Loss: 0.214035
# Epoch [1250/10000], Train Loss: 0.023674, Val Loss: 0.233294
# Epoch [1260/10000], Train Loss: 0.083649, Val Loss: 0.237826
# Epoch [1270/10000], Train Loss: 0.040047, Val Loss: 0.223836
# Epoch [1280/10000], Train Loss: 0.017972, Val Loss: 0.223812
# Epoch [1290/10000], Train Loss: 0.013771, Val Loss: 0.208025
# Epoch [1300/10000], Train Loss: 0.009175, Val Loss: 0.211843
# Epoch [1310/10000], Train Loss: 0.013305, Val Loss: 0.213122
# Epoch [1320/10000], Train Loss: 0.067049, Val Loss: 0.231985
# Epoch [1330/10000], Train Loss: 0.073061, Val Loss: 0.233496
# Epoch [1340/10000], Train Loss: 0.080129, Val Loss: 0.275693
# Epoch [1350/10000], Train Loss: 0.062291, Val Loss: 0.273028
# Epoch [1360/10000], Train Loss: 0.041232, Val Loss: 0.221343
# Epoch [1370/10000], Train Loss: 0.022366, Val Loss: 0.226266
# Epoch [1380/10000], Train Loss: 0.023630, Val Loss: 0.244802
# Epoch [1390/10000], Train Loss: 0.022128, Val Loss: 0.234246
# Epoch [1400/10000], Train Loss: 0.068663, Val Loss: 0.252101
# Epoch [1410/10000], Train Loss: 0.071282, Val Loss: 0.233519
# Epoch [1420/10000], Train Loss: 0.021437, Val Loss: 0.222198
# Epoch [1430/10000], Train Loss: 0.035343, Val Loss: 0.241399
# Epoch [1440/10000], Train Loss: 0.050860, Val Loss: 0.221965
# Epoch [1450/10000], Train Loss: 0.036103, Val Loss: 0.231408
# Epoch [1460/10000], Train Loss: 0.047846, Val Loss: 0.231052
# Epoch [1470/10000], Train Loss: 0.019299, Val Loss: 0.227322
# Epoch [1480/10000], Train Loss: 0.042797, Val Loss: 0.240300
# Epoch [1490/10000], Train Loss: 0.024853, Val Loss: 0.225010
# Epoch [1500/10000], Train Loss: 0.037290, Val Loss: 0.220552
# Epoch [1510/10000], Train Loss: 0.069123, Val Loss: 0.228534
# Epoch [1520/10000], Train Loss: 0.060723, Val Loss: 0.233346
# Epoch [1530/10000], Train Loss: 0.068026, Val Loss: 0.239118
# Epoch [1540/10000], Train Loss: 0.039142, Val Loss: 0.241990
# Epoch [1550/10000], Train Loss: 0.015064, Val Loss: 0.221251
# Epoch [1560/10000], Train Loss: 0.019812, Val Loss: 0.222983
# Epoch [1570/10000], Train Loss: 0.012299, Val Loss: 0.225658
# Epoch [1580/10000], Train Loss: 0.016933, Val Loss: 0.220899
# Epoch [1590/10000], Train Loss: 0.040764, Val Loss: 0.222949
# Epoch [1600/10000], Train Loss: 0.069776, Val Loss: 0.222444
# Epoch [1610/10000], Train Loss: 0.053210, Val Loss: 0.210604
# Epoch [1620/10000], Train Loss: 0.042941, Val Loss: 0.203074
# Epoch [1630/10000], Train Loss: 0.014126, Val Loss: 0.213206
# Epoch [1640/10000], Train Loss: 0.015281, Val Loss: 0.225029
# Epoch [1650/10000], Train Loss: 0.012826, Val Loss: 0.210782
# Epoch [1660/10000], Train Loss: 0.018518, Val Loss: 0.225187
# Epoch [1670/10000], Train Loss: 0.025787, Val Loss: 0.228292
# Epoch [1680/10000], Train Loss: 0.009960, Val Loss: 0.225603
# Epoch [1690/10000], Train Loss: 0.019601, Val Loss: 0.225618
# Epoch [1700/10000], Train Loss: 0.050683, Val Loss: 0.231621
# Epoch [1710/10000], Train Loss: 0.064656, Val Loss: 0.237209
# Epoch [1720/10000], Train Loss: 0.039722, Val Loss: 0.242642
# Epoch [1730/10000], Train Loss: 0.023027, Val Loss: 0.237213
# Epoch [1740/10000], Train Loss: 0.015643, Val Loss: 0.227931
# Early stopping triggered at epoch 1742
# Evaluation Metrics:
# MSE: 570438629.6575
# R² (meanLineIntensity): 0.8508
# R² (meanNumPixels15): 0.7835
# Fold 5 Validation MSE: 570438629.6575
# Fold 5 R² scores: ['0.8508', '0.7835']
#
# Cross-validation Results:
# Average MSE: 590145752.8606 ± 50306055.8868
# Average R² (meanLineIntensity): 0.8289 ± 0.0121
# Average R² (meanNumPixels15): 0.7630 ± 0.0118
# ------------------------------
#
# Cross-validation Results:
# Average MSE: 590145752.8606 ± 50306055.8868

# %%
import os
import json
import pickle
import torch
from datetime import datetime

def save_training_results(models, scalers, scalers_y, val_scores, r2_scores_all, input_cols, target_cols):
    # Create Results directory if it doesn't exist
    results_dir = "Results"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
    
    # Create timestamped subdirectory for this training run
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = os.path.join(results_dir, f"run_{timestamp}")
    os.makedirs(run_dir)
    
    # Save models
    models_dir = os.path.join(run_dir, "models")
    os.makedirs(models_dir)
    for i, model in enumerate(models):
        model_path = os.path.join(models_dir, f"model_fold_{i+1}.pt")
        torch.save(model.state_dict(), model_path)
    
    # Save scalers
    scalers_dir = os.path.join(run_dir, "scalers")
    os.makedirs(scalers_dir)
    for i, (scaler, scaler_y) in enumerate(zip(scalers, scalers_y)):
        # Save feature scaler
        scaler_path = os.path.join(scalers_dir, f"feature_scaler_fold_{i+1}.pkl")
        with open(scaler_path, 'wb') as f:
            pickle.dump(scaler, f)
        
        # Save target scaler
        scaler_y_path = os.path.join(scalers_dir, f"target_scaler_fold_{i+1}.pkl")
        with open(scaler_y_path, 'wb') as f:
            pickle.dump(scaler_y, f)
    
    # Save metrics and configuration
    metrics = {
        'input_features': input_cols,
        'target_variables': target_cols,
        'val_scores': val_scores.tolist() if isinstance(val_scores, np.ndarray) else val_scores,
        'r2_scores_all': r2_scores_all.tolist() if isinstance(r2_scores_all, np.ndarray) else r2_scores_all,
        'average_mse': float(np.mean(val_scores)),
        'mse_std': float(np.std(val_scores)),
        'average_r2_by_target': {
            target: {
                'mean': float(np.mean(r2_scores_all[:, i])),
                'std': float(np.std(r2_scores_all[:, i]))
            }
            for i, target in enumerate(target_cols)
        }
    }
    
    metrics_path = os.path.join(run_dir, "metrics.json")
    with open(metrics_path, 'w') as f:
        json.dump(metrics, f, indent=4)
    
    print(f"\nResults saved in: {run_dir}")
    print("Saved contents:")
    print(f"- {len(models)} models")
    print(f"- {len(scalers)} feature scalers and target scalers")
    print("- Evaluation metrics and configuration")

# Call the function to save the results
save_training_results(
    models=models,
    scalers=scalers,
    scalers_y=scalers_y,  
    val_scores=val_scores,
    r2_scores_all=r2_scores_all,
    input_cols=input_cols,
    target_cols=target_cols
)
# Out:
# Results saved in: Results/run_20241116_141947
# Saved contents:
# - 5 models
# - 5 feature scalers and target scalers
# - Evaluation metrics and configuration

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms for each feature
for col in input_cols + target_cols:
    sns.histplot(data[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
import seaborn as sns

sns.pairplot(data[input_cols + target_cols])
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

r2s = []
for fold_no, indices in enumerate(fold_indices):
    
    X_train, X_val = X[indices[0]], X[indices[1]]
    y_train, y_val = y[indices[0]], y[indices[1]]

    lr_model = LinearRegression()
    lr_model.fit(X_train, y_train)
    y_pred = lr_model.predict(X_val)

    mse = mean_squared_error(y_val, y_pred)
    r2 = r2_score(y_val, y_pred, multioutput='raw_values')
    print(f'Fold:  {fold_no}')
    print(f'Linear Regression MSE: {mse:.4f}')
    print(f'Linear Regression R² scores: {r2}')
    r2s.append(r2)

r2s = np.array(r2s)
mean_score = r2s.mean(axis=0)
print(f'Cross-validation mean score {mean_score}')
# Out:
# Fold:  0
# Linear Regression MSE: 1483179941.3625
# Linear Regression R² scores: [0.51605321 0.33456158]
# Fold:  1
# Linear Regression MSE: 1580383735.1186
# Linear Regression R² scores: [0.4909124  0.29025146]
# Fold:  2
# Linear Regression MSE: 1724734847.0748
# Linear Regression R² scores: [0.52527266 0.33800747]
# Fold:  3
# Linear Regression MSE: 1616719471.2695
# Linear Regression R² scores: [0.56038506 0.33322526]
# Fold:  4
# Linear Regression MSE: 1736380389.1435
# Linear Regression R² scores: [0.54586767 0.33200613]
# Cross-validation mean score [0.5276982  0.32561038]

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_val)

mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred, multioutput='raw_values')
print(f'Random Forest MSE: {mse:.4f}')
print(f'Random Forest R² scores: {r2}')
