# %%
import pandas as pd

# Load the saved CSV file
data = pd.read_csv('processed_data.csv')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import torch
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# Define target and input variables
target_cols = ['meanLineIntensity', 'meanNumPixels15']
input_cols = ['Y_Start', 'Wall', 'Overhang', 'Power', 'd_edge', 'd_over', 'd_col', 'd_over_z']
# remove z, lines per layer instead of Y

# Extract features and targets
X = data[input_cols].values
y = data[target_cols].values

# Create a custom Dataset class
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.FloatTensor(X)
        self.y = torch.FloatTensor(y)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# Function to prepare data loaders for a specific fold
def prepare_fold_data(X, y, train_idx, val_idx, batch_size=32):
    # Scale the features
    scaler = MinMaxScaler()
    scaler_y = MinMaxScaler()
    
    if scaler:
        X_train = scaler.fit_transform(X[train_idx])
        X_val = scaler.transform(X[val_idx])
    else:
        X_train = X[train_idx]
        X_val = X[val_idx]
    y_train = scaler_y.fit_transform(y[train_idx])
    y_eval = scaler_y.transform(y[val_idx])
    
    # Create datasets
    train_dataset = CustomDataset(X_train, y_train)
    val_dataset = CustomDataset(X_val, y_eval)
    
    # Create data loaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False
    )
    
    return train_loader, val_loader, scaler, scaler_y

# Set up K-Fold cross-validation
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Store fold indices for later use
fold_indices = []
for train_idx, val_idx in kf.split(X):
    fold_indices.append((train_idx, val_idx))

# %%
import torch.nn as nn
import torch.optim as optim
import tqdm
from tqdm import tqdm
import copy
import matplotlib.pyplot as plt

class ResidualBlock(nn.Module):
    def __init__(self, dim, dropout_rate=0.2):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Linear(dim, dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate),
            nn.Linear(dim, dim),
        )
        self.relu = nn.ReLU()
        
    def forward(self, x):
        residual = x
        out = self.block(x)
        out += residual  # Skip connection
        return self.relu(out)

class MLPRegressor(nn.Module):
    def __init__(self, input_dim=5, hidden_dim=128, num_layers=3, output_dim=2, dropout_rate=0.2):
        super(MLPRegressor, self).__init__()
        
        self.input_layer = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate)
        )
        
        self.residual_layers = nn.ModuleList([
            ResidualBlock(hidden_dim, dropout_rate) 
            for _ in range(num_layers - 1)
        ])
        
        self.output_layer = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        x = self.input_layer(x)
        for layer in self.residual_layers:
            x = layer(x)
        return self.output_layer(x)

def print_model_params(model):
    total_params = 0
    input_params = sum(p.numel() for p in model.input_layer.parameters())
    total_params += input_params
    
    for i, block in enumerate(model.residual_layers):
        block_params = sum(p.numel() for p in block.parameters())
        total_params += block_params
    
    output_params = sum(p.numel() for p in model.output_layer.parameters())
    total_params += output_params
    
    print("-" * 50)
    print(f"Total Parameters: {total_params:,}")

def train_model(model, train_loader, val_loader, num_epochs=1000, patience=50):
    model = model.to(device)
    criterion = nn.L1Loss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

    best_val_loss = float('inf')
    best_model = None
    patience_counter = 0
    
    # Lists to store losses for plotting
    train_losses = []
    val_losses = []
    epochs = []

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * X_batch.size(0)

        train_loss /= len(train_loader.dataset)

        # Validation phase
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)

        val_loss /= len(val_loader.dataset)

        # Store losses for plotting
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        epochs.append(epoch + 1)

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = copy.deepcopy(model)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f'Early stopping triggered at epoch {epoch+1}')
            break

        if (epoch + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.6f}, Val Loss: {val_loss:.6f}')

    return best_model, train_losses, val_losses, epochs

def train_k_fold(X, y, fold_indices, hidden_dim=128, num_layers=3, batch_size=32):
    models = []
    scalers = []
    scalers_y = []
    val_scores = []
    r2_scores_all = []

    for fold, (train_idx, val_idx) in enumerate(fold_indices):
        print(f'\nTraining Fold {fold+1}')

        # Prepare data for this fold
        train_loader, val_loader, scaler, scaler_y = prepare_fold_data(
            X, y, train_idx, val_idx, batch_size
        )

        # Initialize model
        model = MLPRegressor(
            input_dim=X.shape[1],
            hidden_dim=hidden_dim,
            num_layers=num_layers,
            output_dim=y.shape[1]
        )
        
        print_model_params(model)

        # Train model and get loss history
        best_model, train_losses, val_losses, epochs = train_model(
            model,
            train_loader,
            val_loader,
            num_epochs=10000,
            patience=500
        )

        # Plot loss evolution for this fold
        plt.figure(figsize=(10, 6))
        plt.plot(epochs[1:], train_losses[1:], label='Training Loss')
        plt.plot(epochs[1:], val_losses[1:], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title(f'Loss Evolution - Fold {fold+1}')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Store the trained model and scalers
        models.append(best_model)
        scalers.append(scaler)
        scalers_y.append(scaler_y)

        # Calculate validation scores
        mse, r2_scores, predictions, actuals = evaluate_model(best_model, val_loader, scaler_y)
        val_scores.append(mse)
        r2_scores_all.append(r2_scores)
        print(f'Fold {fold+1} Validation MSE: {mse:.4f}')
        print(f'Fold {fold+1} R² scores: {[f"{r2:.4f}" for r2 in r2_scores]}')

    # Calculate and print average metrics
    print("\nCross-validation Results:")
    print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
    r2_scores_all = np.array(r2_scores_all)
    for i, target in enumerate(['meanLineIntensity', 'meanNumPixels15']):
        mean_r2 = np.mean(r2_scores_all[:, i])
        std_r2 = np.std(r2_scores_all[:, i])
        print(f"Average R² ({target}): {mean_r2:.4f} ± {std_r2:.4f}")
    
    return models, scalers, scalers_y, val_scores, r2_scores_all

def evaluate_model(model, data_loader, scaler_y):
    model = model.to(device)
    model.eval()
    criterion = nn.MSELoss()
    total_loss = 0.0

    # Lists to store predictions and actual values
    all_predictions = []
    all_actuals = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            outputs = model(X_batch)

            # Move to CPU and convert to numpy
            outputs_np = outputs.cpu().numpy()
            y_batch_np = y_batch.cpu().numpy()

            # Inverse transform
            outputs_inv = scaler_y.inverse_transform(outputs_np)
            y_batch_inv = scaler_y.inverse_transform(y_batch_np)

            # Compute loss in original scale
            loss = criterion(torch.tensor(outputs_inv), torch.tensor(y_batch_inv))
            total_loss += loss.item() * X_batch.size(0)

            all_predictions.append(outputs_inv)
            all_actuals.append(y_batch_inv)

    # Convert lists to numpy arrays
    predictions = np.vstack(all_predictions)
    actuals = np.vstack(all_actuals)

    # Calculate MSE
    mse = total_loss / len(data_loader.dataset)

    # Calculate R2 for each target
    r2_scores = []
    for i in range(actuals.shape[1]):
        ss_res = np.sum((actuals[:, i] - predictions[:, i]) ** 2)
        ss_tot = np.sum((actuals[:, i] - np.mean(actuals[:, i])) ** 2)
        r2 = 1 - (ss_res / ss_tot)
        r2_scores.append(r2)

    # Create plots
    import matplotlib.pyplot as plt

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    target_names = ['meanLineIntensity', 'meanNumPixels15']

    for i, (ax, target) in enumerate(zip(axes, target_names)):
        # Plot predicted vs actual
        ax.scatter(actuals[:, i], predictions[:, i], alpha=0.5)

        # Plot perfect prediction line
        min_val = min(actuals[:, i].min(), predictions[:, i].min())
        max_val = max(actuals[:, i].max(), predictions[:, i].max())
        ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Prediction')

        # Add labels and title
        ax.set_xlabel('Actual Values')
        ax.set_ylabel('Predicted Values')
        ax.set_title(f'{target}\nR² = {r2_scores[i]:.4f}')
        ax.grid(True)
        ax.legend()

    plt.tight_layout()
    plt.show()

    # Print detailed metrics
    print("\nEvaluation Metrics:")
    print(f"MSE: {mse:.4f}")
    for i, target in enumerate(target_names):
        print(f"R² ({target}): {r2_scores[i]:.4f}")

    return mse, r2_scores, predictions, actuals


# Train the models
models, scalers, scalers_y, val_scores, r2_scores_all = train_k_fold(X, y, fold_indices, 
                                                                     hidden_dim=1024, 
                                                                     num_layers=96,
                                                                     batch_size=128)

print('---'*10)
# Print overall results
print("\nCross-validation Results:")
print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
# Out:
# Training Fold 1
# --------------------------------------------------
# Total Parameters: 199,435,266
# Epoch [10/10000], Train Loss: 0.100306, Val Loss: 0.095760
# Epoch [20/10000], Train Loss: 0.100733, Val Loss: 0.094444
# Epoch [30/10000], Train Loss: 0.099190, Val Loss: 0.096988
# Epoch [40/10000], Train Loss: 0.099658, Val Loss: 0.093628
# Epoch [50/10000], Train Loss: 0.095017, Val Loss: 0.094683
# Epoch [60/10000], Train Loss: 0.095691, Val Loss: 0.089051
# Epoch [70/10000], Train Loss: 0.093583, Val Loss: 0.089527
# Epoch [80/10000], Train Loss: 0.093980, Val Loss: 0.091744
# Epoch [90/10000], Train Loss: 0.092306, Val Loss: 0.089985
# Epoch [100/10000], Train Loss: 0.090998, Val Loss: 0.088710
# Epoch [110/10000], Train Loss: 0.091915, Val Loss: 0.088050
# Epoch [120/10000], Train Loss: 0.091616, Val Loss: 0.089653
# Epoch [130/10000], Train Loss: 0.093157, Val Loss: 0.097801
# Epoch [140/10000], Train Loss: 0.090763, Val Loss: 0.086583
# Epoch [150/10000], Train Loss: 0.089688, Val Loss: 0.088994
# Epoch [160/10000], Train Loss: 0.090060, Val Loss: 0.086773
# Epoch [170/10000], Train Loss: 0.088851, Val Loss: 0.084935
# Epoch [180/10000], Train Loss: 0.088096, Val Loss: 0.086922
# Epoch [190/10000], Train Loss: 0.087030, Val Loss: 0.086156
# Epoch [200/10000], Train Loss: 0.086654, Val Loss: 0.088610
# Epoch [210/10000], Train Loss: 0.087143, Val Loss: 0.085108
# Epoch [220/10000], Train Loss: 0.086115, Val Loss: 0.086380
# Epoch [230/10000], Train Loss: 0.089909, Val Loss: 0.085648
# Epoch [240/10000], Train Loss: 0.087933, Val Loss: 0.085764
# Epoch [250/10000], Train Loss: 0.085864, Val Loss: 0.085606
# Epoch [260/10000], Train Loss: 0.085409, Val Loss: 0.085794
# Epoch [270/10000], Train Loss: 0.087012, Val Loss: 0.085864
# Epoch [280/10000], Train Loss: 0.086033, Val Loss: 0.085533
# Epoch [290/10000], Train Loss: 0.085729, Val Loss: 0.086451
# Epoch [300/10000], Train Loss: 0.085395, Val Loss: 0.086378
# Epoch [310/10000], Train Loss: 0.085299, Val Loss: 0.086037
# Epoch [320/10000], Train Loss: 0.086087, Val Loss: 0.085208
# Epoch [330/10000], Train Loss: 0.084563, Val Loss: 0.085517
# Epoch [340/10000], Train Loss: 0.085594, Val Loss: 0.084746
# Epoch [350/10000], Train Loss: 0.086334, Val Loss: 0.084961
# Epoch [360/10000], Train Loss: 0.084563, Val Loss: 0.084609
# Epoch [370/10000], Train Loss: 0.084302, Val Loss: 0.083818
# Epoch [380/10000], Train Loss: 0.085527, Val Loss: 0.086921
# Epoch [390/10000], Train Loss: 0.084542, Val Loss: 0.084496
# Epoch [400/10000], Train Loss: 0.085217, Val Loss: 0.088006
# Epoch [410/10000], Train Loss: 0.085194, Val Loss: 0.087683
# Epoch [420/10000], Train Loss: 0.084807, Val Loss: 0.085009
# Epoch [430/10000], Train Loss: 0.085024, Val Loss: 0.084482
# Epoch [440/10000], Train Loss: 0.084507, Val Loss: 0.084986
# Epoch [450/10000], Train Loss: 0.085234, Val Loss: 0.086880
# Epoch [460/10000], Train Loss: 0.084390, Val Loss: 0.084037
# Epoch [470/10000], Train Loss: 0.087110, Val Loss: 0.084480
# Epoch [480/10000], Train Loss: 0.085609, Val Loss: 0.084218
# Epoch [490/10000], Train Loss: 0.083761, Val Loss: 0.084020
# Epoch [500/10000], Train Loss: 0.084670, Val Loss: 0.083650
# Epoch [510/10000], Train Loss: 0.083399, Val Loss: 0.084036
# Epoch [520/10000], Train Loss: 0.084213, Val Loss: 0.085978
# Epoch [530/10000], Train Loss: 0.083901, Val Loss: 0.083728
# Epoch [540/10000], Train Loss: 0.083285, Val Loss: 0.084031
# Epoch [550/10000], Train Loss: 0.084177, Val Loss: 0.084648
# Epoch [560/10000], Train Loss: 0.083798, Val Loss: 0.087539
# Epoch [570/10000], Train Loss: 0.084987, Val Loss: 0.084255
# Epoch [580/10000], Train Loss: 0.083058, Val Loss: 0.084444
# Epoch [590/10000], Train Loss: 0.084045, Val Loss: 0.084019
# Epoch [600/10000], Train Loss: 0.082308, Val Loss: 0.085711
# Epoch [610/10000], Train Loss: 0.087543, Val Loss: 0.088719
# Epoch [620/10000], Train Loss: 0.082020, Val Loss: 0.085334
# Epoch [630/10000], Train Loss: 0.081746, Val Loss: 0.085316
# Epoch [640/10000], Train Loss: 0.081672, Val Loss: 0.084703
# Epoch [650/10000], Train Loss: 0.083389, Val Loss: 0.084261
# Epoch [660/10000], Train Loss: 0.083871, Val Loss: 0.084486
# Epoch [670/10000], Train Loss: 0.082339, Val Loss: 0.084729
# Epoch [680/10000], Train Loss: 0.082019, Val Loss: 0.083141
# Epoch [690/10000], Train Loss: 0.081892, Val Loss: 0.084375
# Epoch [700/10000], Train Loss: 0.080947, Val Loss: 0.083461
# Epoch [710/10000], Train Loss: 0.081312, Val Loss: 0.083152
# Epoch [720/10000], Train Loss: 0.080029, Val Loss: 0.084416
# Epoch [730/10000], Train Loss: 0.080094, Val Loss: 0.084576
# Epoch [740/10000], Train Loss: 0.080347, Val Loss: 0.084636
# Epoch [750/10000], Train Loss: 0.079618, Val Loss: 0.087070
# Epoch [760/10000], Train Loss: 0.078939, Val Loss: 0.084783
# Epoch [770/10000], Train Loss: 0.079522, Val Loss: 0.084157
# Epoch [780/10000], Train Loss: 0.079186, Val Loss: 0.084176
# Epoch [790/10000], Train Loss: 0.078665, Val Loss: 0.086405
# Epoch [800/10000], Train Loss: 0.078958, Val Loss: 0.085339
# Epoch [810/10000], Train Loss: 0.079536, Val Loss: 0.084969
# Epoch [820/10000], Train Loss: 0.078876, Val Loss: 0.085144
# Epoch [830/10000], Train Loss: 0.081030, Val Loss: 0.086951
# Epoch [840/10000], Train Loss: 0.077647, Val Loss: 0.085727
# Epoch [850/10000], Train Loss: 0.079982, Val Loss: 0.085339
# Epoch [860/10000], Train Loss: 0.077920, Val Loss: 0.085380
# Epoch [870/10000], Train Loss: 0.079426, Val Loss: 0.091481
# Epoch [880/10000], Train Loss: 0.079643, Val Loss: 0.085230
# Epoch [890/10000], Train Loss: 0.079255, Val Loss: 0.085205
# Epoch [900/10000], Train Loss: 0.077792, Val Loss: 0.084580
# Epoch [910/10000], Train Loss: 0.078667, Val Loss: 0.086124
# Epoch [920/10000], Train Loss: 0.078514, Val Loss: 0.086343
# Epoch [930/10000], Train Loss: 0.080052, Val Loss: 0.082997
# Epoch [940/10000], Train Loss: 0.077836, Val Loss: 0.087046
# Epoch [950/10000], Train Loss: 0.078143, Val Loss: 0.086593
# Epoch [960/10000], Train Loss: 0.076993, Val Loss: 0.084698
# Epoch [970/10000], Train Loss: 0.079465, Val Loss: 0.086832
# Epoch [980/10000], Train Loss: 0.079465, Val Loss: 0.085050
# Epoch [990/10000], Train Loss: 0.077724, Val Loss: 0.086179
# Epoch [1000/10000], Train Loss: 0.077058, Val Loss: 0.087576
# Epoch [1010/10000], Train Loss: 0.079415, Val Loss: 0.086062
# Epoch [1020/10000], Train Loss: 0.080671, Val Loss: 0.089295
# Epoch [1030/10000], Train Loss: 0.077799, Val Loss: 0.085869
# Epoch [1040/10000], Train Loss: 0.076953, Val Loss: 0.086171
# Epoch [1050/10000], Train Loss: 0.077236, Val Loss: 0.086468
# Epoch [1060/10000], Train Loss: 0.076927, Val Loss: 0.085907
# Epoch [1070/10000], Train Loss: 0.077552, Val Loss: 0.085494
# Epoch [1080/10000], Train Loss: 0.077579, Val Loss: 0.085307
# Epoch [1090/10000], Train Loss: 0.077926, Val Loss: 0.087513
# Epoch [1100/10000], Train Loss: 0.078094, Val Loss: 0.086198
# Epoch [1110/10000], Train Loss: 0.080514, Val Loss: 0.086000
# Epoch [1120/10000], Train Loss: 0.079228, Val Loss: 0.086096
# Epoch [1130/10000], Train Loss: 0.078370, Val Loss: 0.088541
# Epoch [1140/10000], Train Loss: 0.076355, Val Loss: 0.089682
# Epoch [1150/10000], Train Loss: 0.076546, Val Loss: 0.091526
# Epoch [1160/10000], Train Loss: 0.076416, Val Loss: 0.086100
# Epoch [1170/10000], Train Loss: 0.077366, Val Loss: 0.085107
# Epoch [1180/10000], Train Loss: 0.079010, Val Loss: 0.088015
# Early stopping triggered at epoch 1184
# Evaluation Metrics:
# MSE: 1430295294.9421
# R² (meanLineIntensity): 0.5333
# R² (meanNumPixels15): 0.3983
# Fold 1 Validation MSE: 1430295294.9421
# Fold 1 R² scores: ['0.5333', '0.3983']
#
# Training Fold 2
# --------------------------------------------------
# Total Parameters: 199,435,266
# Epoch [10/10000], Train Loss: 0.097610, Val Loss: 0.096989
# Epoch [20/10000], Train Loss: 0.095758, Val Loss: 0.097294
# Epoch [30/10000], Train Loss: 0.095362, Val Loss: 0.094971
# Epoch [40/10000], Train Loss: 0.095826, Val Loss: 0.091220
# Epoch [50/10000], Train Loss: 0.094492, Val Loss: 0.095110
# Epoch [60/10000], Train Loss: 0.094956, Val Loss: 0.099661
# Epoch [70/10000], Train Loss: 0.092136, Val Loss: 0.091991
# Epoch [80/10000], Train Loss: 0.092639, Val Loss: 0.089414
# Epoch [90/10000], Train Loss: 0.092530, Val Loss: 0.092740
# Epoch [100/10000], Train Loss: 0.090757, Val Loss: 0.089476
# Epoch [110/10000], Train Loss: 0.091451, Val Loss: 0.087480
# Epoch [120/10000], Train Loss: 0.093033, Val Loss: 0.094688
# Epoch [130/10000], Train Loss: 0.092385, Val Loss: 0.091201
# Epoch [140/10000], Train Loss: 0.090370, Val Loss: 0.088240
# Epoch [150/10000], Train Loss: 0.089601, Val Loss: 0.086936
# Epoch [160/10000], Train Loss: 0.090884, Val Loss: 0.087721
# Epoch [170/10000], Train Loss: 0.090501, Val Loss: 0.088005
# Epoch [180/10000], Train Loss: 0.087849, Val Loss: 0.086892
# Epoch [190/10000], Train Loss: 0.089215, Val Loss: 0.089919
# Epoch [200/10000], Train Loss: 0.087248, Val Loss: 0.085741
# Epoch [210/10000], Train Loss: 0.088730, Val Loss: 0.085836
# Epoch [220/10000], Train Loss: 0.087106, Val Loss: 0.083914
# Epoch [230/10000], Train Loss: 0.087170, Val Loss: 0.087471
# Epoch [240/10000], Train Loss: 0.086546, Val Loss: 0.083148
# Epoch [250/10000], Train Loss: 0.089606, Val Loss: 0.088951
# Epoch [260/10000], Train Loss: 0.086478, Val Loss: 0.084882
# Epoch [270/10000], Train Loss: 0.086136, Val Loss: 0.087302
# Epoch [280/10000], Train Loss: 0.086823, Val Loss: 0.084080
# Epoch [290/10000], Train Loss: 0.086036, Val Loss: 0.085004
# Epoch [300/10000], Train Loss: 0.085408, Val Loss: 0.083004
# Epoch [310/10000], Train Loss: 0.088066, Val Loss: 0.085467
# Epoch [320/10000], Train Loss: 0.085738, Val Loss: 0.087670
# Epoch [330/10000], Train Loss: 0.083420, Val Loss: 0.082752
# Epoch [340/10000], Train Loss: 0.085166, Val Loss: 0.084706
# Epoch [350/10000], Train Loss: 0.085051, Val Loss: 0.081851
# Epoch [360/10000], Train Loss: 0.084377, Val Loss: 0.084326
# Epoch [370/10000], Train Loss: 0.082928, Val Loss: 0.082670
# Epoch [380/10000], Train Loss: 0.082483, Val Loss: 0.082707
# Epoch [390/10000], Train Loss: 0.083489, Val Loss: 0.083064
# Epoch [400/10000], Train Loss: 0.082732, Val Loss: 0.083688
# Epoch [410/10000], Train Loss: 0.083326, Val Loss: 0.083777
# Epoch [420/10000], Train Loss: 0.084022, Val Loss: 0.083613
# Epoch [430/10000], Train Loss: 0.083358, Val Loss: 0.084251
# Epoch [440/10000], Train Loss: 0.082345, Val Loss: 0.084721
# Epoch [450/10000], Train Loss: 0.082596, Val Loss: 0.084162
# Epoch [460/10000], Train Loss: 0.081147, Val Loss: 0.081252
# Epoch [470/10000], Train Loss: 0.081417, Val Loss: 0.081291
# Epoch [480/10000], Train Loss: 0.082027, Val Loss: 0.082097
# Epoch [490/10000], Train Loss: 0.081456, Val Loss: 0.083860
# Epoch [500/10000], Train Loss: 0.081403, Val Loss: 0.081869
# Epoch [510/10000], Train Loss: 0.080713, Val Loss: 0.082060
# Epoch [520/10000], Train Loss: 0.079817, Val Loss: 0.080945
# Epoch [530/10000], Train Loss: 0.081026, Val Loss: 0.083301
# Epoch [540/10000], Train Loss: 0.079722, Val Loss: 0.081149
# Epoch [550/10000], Train Loss: 0.081121, Val Loss: 0.082653
# Epoch [560/10000], Train Loss: 0.080304, Val Loss: 0.082690
# Epoch [570/10000], Train Loss: 0.080383, Val Loss: 0.082454
# Epoch [580/10000], Train Loss: 0.080627, Val Loss: 0.081535
# Epoch [590/10000], Train Loss: 0.080602, Val Loss: 0.080745
# Epoch [600/10000], Train Loss: 0.079993, Val Loss: 0.083093
# Epoch [610/10000], Train Loss: 0.079634, Val Loss: 0.081678
# Epoch [620/10000], Train Loss: 0.079909, Val Loss: 0.081766
# Epoch [630/10000], Train Loss: 0.079608, Val Loss: 0.082890
# Epoch [640/10000], Train Loss: 0.080000, Val Loss: 0.081442
# Epoch [650/10000], Train Loss: 0.080195, Val Loss: 0.080981
# Epoch [660/10000], Train Loss: 0.078958, Val Loss: 0.081998
# Epoch [670/10000], Train Loss: 0.081339, Val Loss: 0.081400
# Epoch [680/10000], Train Loss: 0.078927, Val Loss: 0.081056
# Epoch [690/10000], Train Loss: 0.079813, Val Loss: 0.082082
# Epoch [700/10000], Train Loss: 0.079201, Val Loss: 0.082336
# Epoch [710/10000], Train Loss: 0.079576, Val Loss: 0.082659
# Epoch [720/10000], Train Loss: 0.079931, Val Loss: 0.082137
# Epoch [730/10000], Train Loss: 0.079940, Val Loss: 0.081691
# Epoch [740/10000], Train Loss: 0.079878, Val Loss: 0.083426
# Epoch [750/10000], Train Loss: 0.078304, Val Loss: 0.080558
# Epoch [760/10000], Train Loss: 0.078327, Val Loss: 0.082395
# Epoch [770/10000], Train Loss: 0.078508, Val Loss: 0.081701
# Epoch [780/10000], Train Loss: 0.078859, Val Loss: 0.081538
# Epoch [790/10000], Train Loss: 0.079530, Val Loss: 0.080397
# Epoch [800/10000], Train Loss: 0.080265, Val Loss: 0.083070
# Epoch [810/10000], Train Loss: 0.078514, Val Loss: 0.082818
# Epoch [820/10000], Train Loss: 0.078663, Val Loss: 0.081809
# Epoch [830/10000], Train Loss: 0.078963, Val Loss: 0.081399
# Epoch [840/10000], Train Loss: 0.078837, Val Loss: 0.082375
# Epoch [850/10000], Train Loss: 0.078283, Val Loss: 0.080273
# Epoch [860/10000], Train Loss: 0.080319, Val Loss: 0.082537
# Epoch [870/10000], Train Loss: 0.079756, Val Loss: 0.083073
# Epoch [880/10000], Train Loss: 0.078085, Val Loss: 0.082203
# Epoch [890/10000], Train Loss: 0.078939, Val Loss: 0.082903
# Epoch [900/10000], Train Loss: 0.078064, Val Loss: 0.081264
# Epoch [910/10000], Train Loss: 0.078445, Val Loss: 0.081438
# Epoch [920/10000], Train Loss: 0.078485, Val Loss: 0.081226
# Epoch [930/10000], Train Loss: 0.079246, Val Loss: 0.082483
# Epoch [940/10000], Train Loss: 0.078447, Val Loss: 0.081165
# Epoch [950/10000], Train Loss: 0.078104, Val Loss: 0.082973
# Epoch [960/10000], Train Loss: 0.078606, Val Loss: 0.082411
# Epoch [970/10000], Train Loss: 0.078370, Val Loss: 0.082438
# Epoch [980/10000], Train Loss: 0.078153, Val Loss: 0.081257
# Epoch [990/10000], Train Loss: 0.078348, Val Loss: 0.082347
# Epoch [1000/10000], Train Loss: 0.078957, Val Loss: 0.084617
# Epoch [1010/10000], Train Loss: 0.078824, Val Loss: 0.082807
# Epoch [1020/10000], Train Loss: 0.077994, Val Loss: 0.084038
# Epoch [1030/10000], Train Loss: 0.078257, Val Loss: 0.083412
# Epoch [1040/10000], Train Loss: 0.078096, Val Loss: 0.082703
# Epoch [1050/10000], Train Loss: 0.077992, Val Loss: 0.083303
# Epoch [1060/10000], Train Loss: 0.077054, Val Loss: 0.083115
# Epoch [1070/10000], Train Loss: 0.077658, Val Loss: 0.083597
# Epoch [1080/10000], Train Loss: 0.078087, Val Loss: 0.086483
# Epoch [1090/10000], Train Loss: 0.077864, Val Loss: 0.083509
# Epoch [1100/10000], Train Loss: 0.079055, Val Loss: 0.082863
# Epoch [1110/10000], Train Loss: 0.077456, Val Loss: 0.081878
# Epoch [1120/10000], Train Loss: 0.079765, Val Loss: 0.084827
# Epoch [1130/10000], Train Loss: 0.077136, Val Loss: 0.082575
# Epoch [1140/10000], Train Loss: 0.078405, Val Loss: 0.082105
# Epoch [1150/10000], Train Loss: 0.079098, Val Loss: 0.083413
# Epoch [1160/10000], Train Loss: 0.078527, Val Loss: 0.083191
# Epoch [1170/10000], Train Loss: 0.076772, Val Loss: 0.083052
# Epoch [1180/10000], Train Loss: 0.077963, Val Loss: 0.083802
# Epoch [1190/10000], Train Loss: 0.079740, Val Loss: 0.083406
# Epoch [1200/10000], Train Loss: 0.077907, Val Loss: 0.083308
# Epoch [1210/10000], Train Loss: 0.077509, Val Loss: 0.083436
# Epoch [1220/10000], Train Loss: 0.076444, Val Loss: 0.082776
# Epoch [1230/10000], Train Loss: 0.076898, Val Loss: 0.083336
# Epoch [1240/10000], Train Loss: 0.077803, Val Loss: 0.083857
# Epoch [1250/10000], Train Loss: 0.078006, Val Loss: 0.083544
# Epoch [1260/10000], Train Loss: 0.077705, Val Loss: 0.084028
# Epoch [1270/10000], Train Loss: 0.079460, Val Loss: 0.081871
# Epoch [1280/10000], Train Loss: 0.076668, Val Loss: 0.081916
# Epoch [1290/10000], Train Loss: 0.076338, Val Loss: 0.082557
# Epoch [1300/10000], Train Loss: 0.078995, Val Loss: 0.083332
# Epoch [1310/10000], Train Loss: 0.076872, Val Loss: 0.083164
# Epoch [1320/10000], Train Loss: 0.076756, Val Loss: 0.082532
# Epoch [1330/10000], Train Loss: 0.077856, Val Loss: 0.083504
# Epoch [1340/10000], Train Loss: 0.077979, Val Loss: 0.082099
# Epoch [1350/10000], Train Loss: 0.076251, Val Loss: 0.083292
# Epoch [1360/10000], Train Loss: 0.076796, Val Loss: 0.083520
# Epoch [1370/10000], Train Loss: 0.076674, Val Loss: 0.082528
# Epoch [1380/10000], Train Loss: 0.076334, Val Loss: 0.083590
# Epoch [1390/10000], Train Loss: 0.077321, Val Loss: 0.082911
# Epoch [1400/10000], Train Loss: 0.077042, Val Loss: 0.082725
# Epoch [1410/10000], Train Loss: 0.077864, Val Loss: 0.083724
# Epoch [1420/10000], Train Loss: 0.079071, Val Loss: 0.084466
# Epoch [1430/10000], Train Loss: 0.077013, Val Loss: 0.083326
# Epoch [1440/10000], Train Loss: 0.076083, Val Loss: 0.084717
# Epoch [1450/10000], Train Loss: 0.076036, Val Loss: 0.082919
# Epoch [1460/10000], Train Loss: 0.076697, Val Loss: 0.083426
# Epoch [1470/10000], Train Loss: 0.075766, Val Loss: 0.083188
# Epoch [1480/10000], Train Loss: 0.077785, Val Loss: 0.084385
# Epoch [1490/10000], Train Loss: 0.079488, Val Loss: 0.081910
# Epoch [1500/10000], Train Loss: 0.076276, Val Loss: 0.083333
# Epoch [1510/10000], Train Loss: 0.075968, Val Loss: 0.083082
# Epoch [1520/10000], Train Loss: 0.076907, Val Loss: 0.083319
# Epoch [1530/10000], Train Loss: 0.075705, Val Loss: 0.084083
# Epoch [1540/10000], Train Loss: 0.077035, Val Loss: 0.083520
# Epoch [1550/10000], Train Loss: 0.076028, Val Loss: 0.083338
# Epoch [1560/10000], Train Loss: 0.076204, Val Loss: 0.084096
# Epoch [1570/10000], Train Loss: 0.077523, Val Loss: 0.086681
# Epoch [1580/10000], Train Loss: 0.076579, Val Loss: 0.083756
# Epoch [1590/10000], Train Loss: 0.077685, Val Loss: 0.083751
# Epoch [1600/10000], Train Loss: 0.076253, Val Loss: 0.083521
# Epoch [1610/10000], Train Loss: 0.076436, Val Loss: 0.084098
# Epoch [1620/10000], Train Loss: 0.076371, Val Loss: 0.083625
# Epoch [1630/10000], Train Loss: 0.075573, Val Loss: 0.084010
# Epoch [1640/10000], Train Loss: 0.077249, Val Loss: 0.083326
# Epoch [1650/10000], Train Loss: 0.076194, Val Loss: 0.084198
# Epoch [1660/10000], Train Loss: 0.077628, Val Loss: 0.083916
# Epoch [1670/10000], Train Loss: 0.077529, Val Loss: 0.086105
# Epoch [1680/10000], Train Loss: 0.076070, Val Loss: 0.085030
# Epoch [1690/10000], Train Loss: 0.076635, Val Loss: 0.082408
# Epoch [1700/10000], Train Loss: 0.076715, Val Loss: 0.082957
# Epoch [1710/10000], Train Loss: 0.077188, Val Loss: 0.084086
# Epoch [1720/10000], Train Loss: 0.074877, Val Loss: 0.084892
# Epoch [1730/10000], Train Loss: 0.075946, Val Loss: 0.082914
# Epoch [1740/10000], Train Loss: 0.077114, Val Loss: 0.083577
# Epoch [1750/10000], Train Loss: 0.075845, Val Loss: 0.084700
# Epoch [1760/10000], Train Loss: 0.075190, Val Loss: 0.083373
# Early stopping triggered at epoch 1762
# Evaluation Metrics:
# MSE: 1380715376.4848
# R² (meanLineIntensity): 0.5552
# R² (meanNumPixels15): 0.4061
# Fold 2 Validation MSE: 1380715376.4848
# Fold 2 R² scores: ['0.5552', '0.4061']
#
# Training Fold 3
# --------------------------------------------------
# Total Parameters: 199,435,266
# Epoch [10/10000], Train Loss: 0.101221, Val Loss: 0.103868
# Epoch [20/10000], Train Loss: 0.095055, Val Loss: 0.096227
# Epoch [30/10000], Train Loss: 0.096124, Val Loss: 0.098045
# Epoch [40/10000], Train Loss: 0.098207, Val Loss: 0.096958
# Epoch [50/10000], Train Loss: 0.094563, Val Loss: 0.094730
# Epoch [60/10000], Train Loss: 0.091969, Val Loss: 0.092692
# Epoch [70/10000], Train Loss: 0.089675, Val Loss: 0.094292
# Epoch [80/10000], Train Loss: 0.091013, Val Loss: 0.093312
# Epoch [90/10000], Train Loss: 0.090194, Val Loss: 0.091878
# Epoch [100/10000], Train Loss: 0.089333, Val Loss: 0.092965
# Epoch [110/10000], Train Loss: 0.087519, Val Loss: 0.093091
# Epoch [120/10000], Train Loss: 0.088246, Val Loss: 0.092011
# Epoch [130/10000], Train Loss: 0.086915, Val Loss: 0.090902
# Epoch [140/10000], Train Loss: 0.087418, Val Loss: 0.092905
# Epoch [150/10000], Train Loss: 0.087496, Val Loss: 0.095649
# Epoch [160/10000], Train Loss: 0.085945, Val Loss: 0.091992
# Epoch [170/10000], Train Loss: 0.086366, Val Loss: 0.091240
# Epoch [180/10000], Train Loss: 0.085382, Val Loss: 0.091607
# Epoch [190/10000], Train Loss: 0.083967, Val Loss: 0.091155
# Epoch [200/10000], Train Loss: 0.082879, Val Loss: 0.092320
# Epoch [210/10000], Train Loss: 0.083287, Val Loss: 0.092181
# Epoch [220/10000], Train Loss: 0.084505, Val Loss: 0.091232
# Epoch [230/10000], Train Loss: 0.084631, Val Loss: 0.091720
# Epoch [240/10000], Train Loss: 0.083381, Val Loss: 0.091221
# Epoch [250/10000], Train Loss: 0.081817, Val Loss: 0.090040
# Epoch [260/10000], Train Loss: 0.083585, Val Loss: 0.089950
# Epoch [270/10000], Train Loss: 0.082161, Val Loss: 0.090696
# Epoch [280/10000], Train Loss: 0.084298, Val Loss: 0.089111
# Epoch [290/10000], Train Loss: 0.081190, Val Loss: 0.090887
# Epoch [300/10000], Train Loss: 0.081333, Val Loss: 0.090080
# Epoch [310/10000], Train Loss: 0.080989, Val Loss: 0.090345
# Epoch [320/10000], Train Loss: 0.080484, Val Loss: 0.091784
# Epoch [330/10000], Train Loss: 0.080841, Val Loss: 0.089822
# Epoch [340/10000], Train Loss: 0.080235, Val Loss: 0.092452
# Epoch [350/10000], Train Loss: 0.083040, Val Loss: 0.090276
# Epoch [360/10000], Train Loss: 0.080341, Val Loss: 0.090442
# Epoch [370/10000], Train Loss: 0.080576, Val Loss: 0.090714
# Epoch [380/10000], Train Loss: 0.080417, Val Loss: 0.090541
# Epoch [390/10000], Train Loss: 0.081152, Val Loss: 0.088082
# Epoch [400/10000], Train Loss: 0.079231, Val Loss: 0.091318
# Epoch [410/10000], Train Loss: 0.079776, Val Loss: 0.089575
# Epoch [420/10000], Train Loss: 0.080194, Val Loss: 0.088764
# Epoch [430/10000], Train Loss: 0.081483, Val Loss: 0.090372
# Epoch [440/10000], Train Loss: 0.080424, Val Loss: 0.089601
# Epoch [450/10000], Train Loss: 0.079344, Val Loss: 0.090687
# Epoch [460/10000], Train Loss: 0.081245, Val Loss: 0.090338
# Epoch [470/10000], Train Loss: 0.080829, Val Loss: 0.092721
# Epoch [480/10000], Train Loss: 0.079713, Val Loss: 0.090004
# Epoch [490/10000], Train Loss: 0.079975, Val Loss: 0.096169
# Epoch [500/10000], Train Loss: 0.078453, Val Loss: 0.090952
# Epoch [510/10000], Train Loss: 0.082835, Val Loss: 0.090518
# Epoch [520/10000], Train Loss: 0.081939, Val Loss: 0.090826
# Epoch [530/10000], Train Loss: 0.079101, Val Loss: 0.092578
# Epoch [540/10000], Train Loss: 0.078593, Val Loss: 0.091304
# Epoch [550/10000], Train Loss: 0.080129, Val Loss: 0.093145
# Epoch [560/10000], Train Loss: 0.080061, Val Loss: 0.091663
# Epoch [570/10000], Train Loss: 0.078582, Val Loss: 0.091201
# Epoch [580/10000], Train Loss: 0.078613, Val Loss: 0.090318
# Epoch [590/10000], Train Loss: 0.079119, Val Loss: 0.090148
# Epoch [600/10000], Train Loss: 0.080465, Val Loss: 0.090758
# Epoch [610/10000], Train Loss: 0.080947, Val Loss: 0.092192
# Epoch [620/10000], Train Loss: 0.077567, Val Loss: 0.090964
# Epoch [630/10000], Train Loss: 0.078575, Val Loss: 0.091309
# Epoch [640/10000], Train Loss: 0.078121, Val Loss: 0.091117
# Epoch [650/10000], Train Loss: 0.078763, Val Loss: 0.093146
# Epoch [660/10000], Train Loss: 0.079454, Val Loss: 0.090791
# Epoch [670/10000], Train Loss: 0.078579, Val Loss: 0.090166
# Epoch [680/10000], Train Loss: 0.077249, Val Loss: 0.091337
# Epoch [690/10000], Train Loss: 0.077696, Val Loss: 0.090667
# Epoch [700/10000], Train Loss: 0.077461, Val Loss: 0.091919
# Epoch [710/10000], Train Loss: 0.079872, Val Loss: 0.091744
# Epoch [720/10000], Train Loss: 0.076915, Val Loss: 0.093952
# Epoch [730/10000], Train Loss: 0.077308, Val Loss: 0.091901
# Epoch [740/10000], Train Loss: 0.082471, Val Loss: 0.090469
# Epoch [750/10000], Train Loss: 0.076565, Val Loss: 0.089865
# Epoch [760/10000], Train Loss: 0.076912, Val Loss: 0.090293
# Epoch [770/10000], Train Loss: 0.077006, Val Loss: 0.090676
# Epoch [780/10000], Train Loss: 0.081966, Val Loss: 0.090822
# Epoch [790/10000], Train Loss: 0.076474, Val Loss: 0.089308
# Epoch [800/10000], Train Loss: 0.077331, Val Loss: 0.091681
# Epoch [810/10000], Train Loss: 0.077943, Val Loss: 0.096075
# Epoch [820/10000], Train Loss: 0.077111, Val Loss: 0.090768
# Early stopping triggered at epoch 821
# Evaluation Metrics:
# MSE: 1797908685.7901
# R² (meanLineIntensity): 0.5051
# R² (meanNumPixels15): 0.4251
# Fold 3 Validation MSE: 1797908685.7901
# Fold 3 R² scores: ['0.5051', '0.4251']
#
# Training Fold 4
# --------------------------------------------------
# Total Parameters: 199,435,266
# Epoch [10/10000], Train Loss: 0.094414, Val Loss: 0.103017
# Epoch [20/10000], Train Loss: 0.096361, Val Loss: 0.105525
# Epoch [30/10000], Train Loss: 0.093544, Val Loss: 0.098736
# Epoch [40/10000], Train Loss: 0.092049, Val Loss: 0.097577
# Epoch [50/10000], Train Loss: 0.091571, Val Loss: 0.097049
# Epoch [60/10000], Train Loss: 0.092137, Val Loss: 0.095280
# Epoch [70/10000], Train Loss: 0.089616, Val Loss: 0.095779
# Epoch [80/10000], Train Loss: 0.089330, Val Loss: 0.095529
# Epoch [90/10000], Train Loss: 0.088934, Val Loss: 0.095602
# Epoch [100/10000], Train Loss: 0.087950, Val Loss: 0.095605
# Epoch [110/10000], Train Loss: 0.087591, Val Loss: 0.095496
# Epoch [120/10000], Train Loss: 0.089125, Val Loss: 0.096842
# Epoch [130/10000], Train Loss: 0.087210, Val Loss: 0.094902
# Epoch [140/10000], Train Loss: 0.087188, Val Loss: 0.094362
# Epoch [150/10000], Train Loss: 0.085795, Val Loss: 0.094836
# Epoch [160/10000], Train Loss: 0.087477, Val Loss: 0.096495
# Epoch [170/10000], Train Loss: 0.087073, Val Loss: 0.095832
# Epoch [180/10000], Train Loss: 0.088324, Val Loss: 0.094568
# Epoch [190/10000], Train Loss: 0.086343, Val Loss: 0.094805
# Epoch [200/10000], Train Loss: 0.085765, Val Loss: 0.095604
# Epoch [210/10000], Train Loss: 0.086416, Val Loss: 0.094510
# Epoch [220/10000], Train Loss: 0.085796, Val Loss: 0.094347
# Epoch [230/10000], Train Loss: 0.084791, Val Loss: 0.094628
# Epoch [240/10000], Train Loss: 0.085616, Val Loss: 0.094171
# Epoch [250/10000], Train Loss: 0.086366, Val Loss: 0.093204
# Epoch [260/10000], Train Loss: 0.086387, Val Loss: 0.091224
# Epoch [270/10000], Train Loss: 0.084858, Val Loss: 0.093136
# Epoch [280/10000], Train Loss: 0.085742, Val Loss: 0.094656
# Epoch [290/10000], Train Loss: 0.084232, Val Loss: 0.094377
# Epoch [300/10000], Train Loss: 0.084266, Val Loss: 0.093723
# Epoch [310/10000], Train Loss: 0.085698, Val Loss: 0.094059
# Epoch [320/10000], Train Loss: 0.084284, Val Loss: 0.093184
# Epoch [330/10000], Train Loss: 0.085030, Val Loss: 0.095387
# Epoch [340/10000], Train Loss: 0.084251, Val Loss: 0.092353
# Epoch [350/10000], Train Loss: 0.084747, Val Loss: 0.095016
# Epoch [360/10000], Train Loss: 0.085061, Val Loss: 0.094199
# Epoch [370/10000], Train Loss: 0.083893, Val Loss: 0.095350
# Epoch [380/10000], Train Loss: 0.084967, Val Loss: 0.095979
# Epoch [390/10000], Train Loss: 0.084244, Val Loss: 0.092292
# Epoch [400/10000], Train Loss: 0.082722, Val Loss: 0.091773
# Epoch [410/10000], Train Loss: 0.085100, Val Loss: 0.091329
# Epoch [420/10000], Train Loss: 0.081764, Val Loss: 0.090165
# Epoch [430/10000], Train Loss: 0.083696, Val Loss: 0.091009
# Epoch [440/10000], Train Loss: 0.083635, Val Loss: 0.089600
# Epoch [450/10000], Train Loss: 0.085321, Val Loss: 0.090030
# Epoch [460/10000], Train Loss: 0.080908, Val Loss: 0.089318
# Epoch [470/10000], Train Loss: 0.081734, Val Loss: 0.092220
# Epoch [480/10000], Train Loss: 0.080417, Val Loss: 0.088036
# Epoch [490/10000], Train Loss: 0.080144, Val Loss: 0.089739
# Epoch [500/10000], Train Loss: 0.080123, Val Loss: 0.088237
# Epoch [510/10000], Train Loss: 0.080323, Val Loss: 0.087583
# Epoch [520/10000], Train Loss: 0.081341, Val Loss: 0.088202
# Epoch [530/10000], Train Loss: 0.079242, Val Loss: 0.088026
# Epoch [540/10000], Train Loss: 0.080229, Val Loss: 0.088230
# Epoch [550/10000], Train Loss: 0.081586, Val Loss: 0.089140
# Epoch [560/10000], Train Loss: 0.080464, Val Loss: 0.087648
# Epoch [570/10000], Train Loss: 0.079904, Val Loss: 0.089123
# Epoch [580/10000], Train Loss: 0.080379, Val Loss: 0.093422
# Epoch [590/10000], Train Loss: 0.079220, Val Loss: 0.089575
# Epoch [600/10000], Train Loss: 0.079166, Val Loss: 0.090396
# Epoch [610/10000], Train Loss: 0.078762, Val Loss: 0.088397
# Epoch [620/10000], Train Loss: 0.079347, Val Loss: 0.087290
# Epoch [630/10000], Train Loss: 0.078370, Val Loss: 0.088968
# Epoch [640/10000], Train Loss: 0.079679, Val Loss: 0.087975
# Epoch [650/10000], Train Loss: 0.079723, Val Loss: 0.089363
# Epoch [660/10000], Train Loss: 0.078914, Val Loss: 0.088941
# Epoch [670/10000], Train Loss: 0.080493, Val Loss: 0.090229
# Epoch [680/10000], Train Loss: 0.080222, Val Loss: 0.088452
# Epoch [690/10000], Train Loss: 0.078249, Val Loss: 0.087217
# Epoch [700/10000], Train Loss: 0.079970, Val Loss: 0.087013
# Epoch [710/10000], Train Loss: 0.079105, Val Loss: 0.087589
# Epoch [720/10000], Train Loss: 0.078131, Val Loss: 0.090865
# Epoch [730/10000], Train Loss: 0.078255, Val Loss: 0.087725
# Epoch [740/10000], Train Loss: 0.078314, Val Loss: 0.087930
# Epoch [750/10000], Train Loss: 0.077976, Val Loss: 0.086472
# Epoch [760/10000], Train Loss: 0.078818, Val Loss: 0.089873
# Epoch [770/10000], Train Loss: 0.079622, Val Loss: 0.090245
# Epoch [780/10000], Train Loss: 0.079592, Val Loss: 0.088237
# Epoch [790/10000], Train Loss: 0.078940, Val Loss: 0.087306
# Epoch [800/10000], Train Loss: 0.079173, Val Loss: 0.087509
# Epoch [810/10000], Train Loss: 0.078726, Val Loss: 0.092219
# Epoch [820/10000], Train Loss: 0.078071, Val Loss: 0.087594
# Epoch [830/10000], Train Loss: 0.079256, Val Loss: 0.088630
# Epoch [840/10000], Train Loss: 0.078625, Val Loss: 0.087415
# Epoch [850/10000], Train Loss: 0.077837, Val Loss: 0.088449
# Epoch [860/10000], Train Loss: 0.080412, Val Loss: 0.089197
# Epoch [870/10000], Train Loss: 0.078047, Val Loss: 0.087397
# Epoch [880/10000], Train Loss: 0.077782, Val Loss: 0.088567
# Epoch [890/10000], Train Loss: 0.078821, Val Loss: 0.087752
# Epoch [900/10000], Train Loss: 0.077273, Val Loss: 0.087637
# Epoch [910/10000], Train Loss: 0.081474, Val Loss: 0.088223
# Epoch [920/10000], Train Loss: 0.077280, Val Loss: 0.087122
# Epoch [930/10000], Train Loss: 0.079243, Val Loss: 0.087490
# Epoch [940/10000], Train Loss: 0.077465, Val Loss: 0.089309
# Epoch [950/10000], Train Loss: 0.077100, Val Loss: 0.089452
# Epoch [960/10000], Train Loss: 0.078537, Val Loss: 0.088550
# Epoch [970/10000], Train Loss: 0.077832, Val Loss: 0.087480
# Epoch [980/10000], Train Loss: 0.082664, Val Loss: 0.089032
# Epoch [990/10000], Train Loss: 0.077885, Val Loss: 0.088236
# Epoch [1000/10000], Train Loss: 0.077287, Val Loss: 0.087868
# Epoch [1010/10000], Train Loss: 0.079836, Val Loss: 0.088820
# Epoch [1020/10000], Train Loss: 0.077722, Val Loss: 0.088472
# Epoch [1030/10000], Train Loss: 0.077739, Val Loss: 0.089638
# Epoch [1040/10000], Train Loss: 0.077578, Val Loss: 0.088162
# Epoch [1050/10000], Train Loss: 0.077983, Val Loss: 0.088212
# Epoch [1060/10000], Train Loss: 0.078551, Val Loss: 0.089195
# Epoch [1070/10000], Train Loss: 0.077253, Val Loss: 0.089312
# Epoch [1080/10000], Train Loss: 0.078465, Val Loss: 0.089828
# Epoch [1090/10000], Train Loss: 0.078922, Val Loss: 0.088343
# Epoch [1100/10000], Train Loss: 0.077792, Val Loss: 0.089110
# Epoch [1110/10000], Train Loss: 0.077361, Val Loss: 0.088796
# Epoch [1120/10000], Train Loss: 0.077604, Val Loss: 0.089084
# Early stopping triggered at epoch 1122
# Evaluation Metrics:
# MSE: 1795253769.9006
# R² (meanLineIntensity): 0.5118
# R² (meanNumPixels15): 0.4084
# Fold 4 Validation MSE: 1795253769.9006
# Fold 4 R² scores: ['0.5118', '0.4084']
#
# Training Fold 5
# --------------------------------------------------
# Total Parameters: 199,435,266
# Epoch [10/10000], Train Loss: 0.103615, Val Loss: 0.111796
# Epoch [20/10000], Train Loss: 0.100277, Val Loss: 0.099875
# Epoch [30/10000], Train Loss: 0.099859, Val Loss: 0.100329
# Epoch [40/10000], Train Loss: 0.098813, Val Loss: 0.105203
# Epoch [50/10000], Train Loss: 0.101441, Val Loss: 0.101838
# Epoch [60/10000], Train Loss: 0.096781, Val Loss: 0.100814
# Epoch [70/10000], Train Loss: 0.098439, Val Loss: 0.100329
# Epoch [80/10000], Train Loss: 0.096149, Val Loss: 0.098868
# Epoch [90/10000], Train Loss: 0.096675, Val Loss: 0.101148
# Epoch [100/10000], Train Loss: 0.095750, Val Loss: 0.099579
# Epoch [110/10000], Train Loss: 0.096140, Val Loss: 0.103626
# Epoch [120/10000], Train Loss: 0.095301, Val Loss: 0.101523
# Epoch [130/10000], Train Loss: 0.095155, Val Loss: 0.104447
# Epoch [140/10000], Train Loss: 0.094180, Val Loss: 0.098426
# Epoch [150/10000], Train Loss: 0.094705, Val Loss: 0.098910
# Epoch [160/10000], Train Loss: 0.093688, Val Loss: 0.099218
# Epoch [170/10000], Train Loss: 0.094678, Val Loss: 0.102175
# Epoch [180/10000], Train Loss: 0.093234, Val Loss: 0.099255
# Epoch [190/10000], Train Loss: 0.093431, Val Loss: 0.097511
# Epoch [200/10000], Train Loss: 0.093752, Val Loss: 0.099327
# Epoch [210/10000], Train Loss: 0.093469, Val Loss: 0.102251
# Epoch [220/10000], Train Loss: 0.091845, Val Loss: 0.100340
# Epoch [230/10000], Train Loss: 0.089883, Val Loss: 0.099574
# Epoch [240/10000], Train Loss: 0.092638, Val Loss: 0.099525
# Epoch [250/10000], Train Loss: 0.091776, Val Loss: 0.098647
# Epoch [260/10000], Train Loss: 0.089950, Val Loss: 0.097002
# Epoch [270/10000], Train Loss: 0.090647, Val Loss: 0.098636
# Epoch [280/10000], Train Loss: 0.092244, Val Loss: 0.097614
# Epoch [290/10000], Train Loss: 0.090081, Val Loss: 0.099023
# Epoch [300/10000], Train Loss: 0.091011, Val Loss: 0.098022
# Epoch [310/10000], Train Loss: 0.089641, Val Loss: 0.098194
# Epoch [320/10000], Train Loss: 0.089590, Val Loss: 0.095561
# Epoch [330/10000], Train Loss: 0.090317, Val Loss: 0.096941
# Epoch [340/10000], Train Loss: 0.087799, Val Loss: 0.095643
# Epoch [350/10000], Train Loss: 0.087861, Val Loss: 0.096209
# Epoch [360/10000], Train Loss: 0.087534, Val Loss: 0.095497
# Epoch [370/10000], Train Loss: 0.086388, Val Loss: 0.097693
# Epoch [380/10000], Train Loss: 0.088705, Val Loss: 0.097452
# Epoch [390/10000], Train Loss: 0.086833, Val Loss: 0.094918
# Epoch [400/10000], Train Loss: 0.086188, Val Loss: 0.093053
# Epoch [410/10000], Train Loss: 0.086065, Val Loss: 0.094873
# Epoch [420/10000], Train Loss: 0.084904, Val Loss: 0.093377
# Epoch [430/10000], Train Loss: 0.085369, Val Loss: 0.094455
# Epoch [440/10000], Train Loss: 0.085267, Val Loss: 0.096511
# Epoch [450/10000], Train Loss: 0.084559, Val Loss: 0.094040
# Epoch [460/10000], Train Loss: 0.084992, Val Loss: 0.096132
# Epoch [470/10000], Train Loss: 0.086939, Val Loss: 0.094670
# Epoch [480/10000], Train Loss: 0.084979, Val Loss: 0.094788
# Epoch [490/10000], Train Loss: 0.083639, Val Loss: 0.094032
# Epoch [500/10000], Train Loss: 0.085589, Val Loss: 0.092511
# Epoch [510/10000], Train Loss: 0.083358, Val Loss: 0.093618
# Epoch [520/10000], Train Loss: 0.084358, Val Loss: 0.094086
# Epoch [530/10000], Train Loss: 0.083919, Val Loss: 0.092263
# Epoch [540/10000], Train Loss: 0.084061, Val Loss: 0.092281
# Epoch [550/10000], Train Loss: 0.085785, Val Loss: 0.095492
# Epoch [560/10000], Train Loss: 0.083115, Val Loss: 0.092286
# Epoch [570/10000], Train Loss: 0.084100, Val Loss: 0.097300
# Epoch [580/10000], Train Loss: 0.083568, Val Loss: 0.094808
# Epoch [590/10000], Train Loss: 0.084991, Val Loss: 0.093861
# Epoch [600/10000], Train Loss: 0.082544, Val Loss: 0.092713
# Epoch [610/10000], Train Loss: 0.083531, Val Loss: 0.095141
# Epoch [620/10000], Train Loss: 0.083089, Val Loss: 0.091742
# Epoch [630/10000], Train Loss: 0.084519, Val Loss: 0.092924
# Epoch [640/10000], Train Loss: 0.083258, Val Loss: 0.093068
# Epoch [650/10000], Train Loss: 0.083082, Val Loss: 0.096428
# Epoch [660/10000], Train Loss: 0.083233, Val Loss: 0.092191
# Epoch [670/10000], Train Loss: 0.084141, Val Loss: 0.093409
# Epoch [680/10000], Train Loss: 0.082979, Val Loss: 0.093104
# Epoch [690/10000], Train Loss: 0.082268, Val Loss: 0.094274
# Epoch [700/10000], Train Loss: 0.082954, Val Loss: 0.097119
# Epoch [710/10000], Train Loss: 0.082504, Val Loss: 0.093229
# Epoch [720/10000], Train Loss: 0.082429, Val Loss: 0.094699
# Epoch [730/10000], Train Loss: 0.082016, Val Loss: 0.092847
# Epoch [740/10000], Train Loss: 0.083047, Val Loss: 0.092629
# Epoch [750/10000], Train Loss: 0.083939, Val Loss: 0.094125
# Epoch [760/10000], Train Loss: 0.082596, Val Loss: 0.092635
# Epoch [770/10000], Train Loss: 0.081336, Val Loss: 0.092647
# Epoch [780/10000], Train Loss: 0.082606, Val Loss: 0.094493
# Epoch [790/10000], Train Loss: 0.083414, Val Loss: 0.092234
# Epoch [800/10000], Train Loss: 0.082345, Val Loss: 0.093762
# Epoch [810/10000], Train Loss: 0.082499, Val Loss: 0.093621
# Epoch [820/10000], Train Loss: 0.082968, Val Loss: 0.094744
# Epoch [830/10000], Train Loss: 0.081063, Val Loss: 0.093246
# Epoch [840/10000], Train Loss: 0.081373, Val Loss: 0.094596
# Epoch [850/10000], Train Loss: 0.082281, Val Loss: 0.092668
# Epoch [860/10000], Train Loss: 0.082218, Val Loss: 0.093749
# Epoch [870/10000], Train Loss: 0.081885, Val Loss: 0.094352
# Epoch [880/10000], Train Loss: 0.082662, Val Loss: 0.094146
# Epoch [890/10000], Train Loss: 0.081865, Val Loss: 0.095505
# Epoch [900/10000], Train Loss: 0.082243, Val Loss: 0.093766
# Epoch [910/10000], Train Loss: 0.082780, Val Loss: 0.094261
# Epoch [920/10000], Train Loss: 0.080873, Val Loss: 0.092633
# Epoch [930/10000], Train Loss: 0.081085, Val Loss: 0.094964
# Epoch [940/10000], Train Loss: 0.082383, Val Loss: 0.094848
# Epoch [950/10000], Train Loss: 0.082327, Val Loss: 0.093418
# Epoch [960/10000], Train Loss: 0.082559, Val Loss: 0.093799
# Epoch [970/10000], Train Loss: 0.080994, Val Loss: 0.093520
# Epoch [980/10000], Train Loss: 0.081556, Val Loss: 0.094703
# Epoch [990/10000], Train Loss: 0.081222, Val Loss: 0.093623
# Epoch [1000/10000], Train Loss: 0.081467, Val Loss: 0.095449
# Epoch [1010/10000], Train Loss: 0.081939, Val Loss: 0.094428
# Epoch [1020/10000], Train Loss: 0.081938, Val Loss: 0.094208
# Epoch [1030/10000], Train Loss: 0.081722, Val Loss: 0.093842
# Epoch [1040/10000], Train Loss: 0.081869, Val Loss: 0.093901
# Epoch [1050/10000], Train Loss: 0.081557, Val Loss: 0.094452
# Epoch [1060/10000], Train Loss: 0.081364, Val Loss: 0.092952
# Epoch [1070/10000], Train Loss: 0.081548, Val Loss: 0.093778
# Epoch [1080/10000], Train Loss: 0.080570, Val Loss: 0.093890
# Epoch [1090/10000], Train Loss: 0.083348, Val Loss: 0.093250
# Epoch [1100/10000], Train Loss: 0.082765, Val Loss: 0.094484
# Epoch [1110/10000], Train Loss: 0.081026, Val Loss: 0.093675
# Epoch [1120/10000], Train Loss: 0.081628, Val Loss: 0.094054
# Epoch [1130/10000], Train Loss: 0.081634, Val Loss: 0.093342
# Epoch [1140/10000], Train Loss: 0.081664, Val Loss: 0.094264
# Epoch [1150/10000], Train Loss: 0.081518, Val Loss: 0.093253
# Epoch [1160/10000], Train Loss: 0.081907, Val Loss: 0.093491
# Epoch [1170/10000], Train Loss: 0.080552, Val Loss: 0.095373
# Epoch [1180/10000], Train Loss: 0.081446, Val Loss: 0.096398
# Epoch [1190/10000], Train Loss: 0.082734, Val Loss: 0.095033
# Epoch [1200/10000], Train Loss: 0.081065, Val Loss: 0.093894
# Epoch [1210/10000], Train Loss: 0.082289, Val Loss: 0.090775
# Epoch [1220/10000], Train Loss: 0.082630, Val Loss: 0.090960
# Epoch [1230/10000], Train Loss: 0.080708, Val Loss: 0.093597
# Epoch [1240/10000], Train Loss: 0.081789, Val Loss: 0.093841
# Epoch [1250/10000], Train Loss: 0.080648, Val Loss: 0.093953
# Epoch [1260/10000], Train Loss: 0.081341, Val Loss: 0.094393
# Epoch [1270/10000], Train Loss: 0.080867, Val Loss: 0.094521
# Epoch [1280/10000], Train Loss: 0.081734, Val Loss: 0.093960
# Epoch [1290/10000], Train Loss: 0.080694, Val Loss: 0.093485
# Epoch [1300/10000], Train Loss: 0.081033, Val Loss: 0.094218
# Epoch [1310/10000], Train Loss: 0.080013, Val Loss: 0.095674
# Epoch [1320/10000], Train Loss: 0.083934, Val Loss: 0.099586
# Epoch [1330/10000], Train Loss: 0.079895, Val Loss: 0.095322
# Epoch [1340/10000], Train Loss: 0.081655, Val Loss: 0.093572
# Epoch [1350/10000], Train Loss: 0.079590, Val Loss: 0.095151
# Epoch [1360/10000], Train Loss: 0.081013, Val Loss: 0.095334
# Epoch [1370/10000], Train Loss: 0.081640, Val Loss: 0.094237
# Epoch [1380/10000], Train Loss: 0.080750, Val Loss: 0.094547
# Epoch [1390/10000], Train Loss: 0.080251, Val Loss: 0.095069
# Epoch [1400/10000], Train Loss: 0.080850, Val Loss: 0.096893
# Epoch [1410/10000], Train Loss: 0.080636, Val Loss: 0.093172
# Epoch [1420/10000], Train Loss: 0.079360, Val Loss: 0.095157
# Epoch [1430/10000], Train Loss: 0.080054, Val Loss: 0.093315
# Epoch [1440/10000], Train Loss: 0.079579, Val Loss: 0.095154
# Epoch [1450/10000], Train Loss: 0.082840, Val Loss: 0.094619
# Epoch [1460/10000], Train Loss: 0.080713, Val Loss: 0.094777
# Epoch [1470/10000], Train Loss: 0.082713, Val Loss: 0.093518
# Epoch [1480/10000], Train Loss: 0.080959, Val Loss: 0.094737
# Epoch [1490/10000], Train Loss: 0.081053, Val Loss: 0.093684
# Epoch [1500/10000], Train Loss: 0.080895, Val Loss: 0.094950
# Epoch [1510/10000], Train Loss: 0.080872, Val Loss: 0.096137
# Epoch [1520/10000], Train Loss: 0.079583, Val Loss: 0.095373
# Epoch [1530/10000], Train Loss: 0.080923, Val Loss: 0.094413
# Epoch [1540/10000], Train Loss: 0.080455, Val Loss: 0.094411
# Epoch [1550/10000], Train Loss: 0.082151, Val Loss: 0.095669
# Epoch [1560/10000], Train Loss: 0.081384, Val Loss: 0.094618
# Epoch [1570/10000], Train Loss: 0.080837, Val Loss: 0.097483
# Epoch [1580/10000], Train Loss: 0.080806, Val Loss: 0.097953
# Epoch [1590/10000], Train Loss: 0.080187, Val Loss: 0.094132
# Epoch [1600/10000], Train Loss: 0.080131, Val Loss: 0.093888
# Epoch [1610/10000], Train Loss: 0.081399, Val Loss: 0.094775
# Epoch [1620/10000], Train Loss: 0.080164, Val Loss: 0.094756
# Epoch [1630/10000], Train Loss: 0.080742, Val Loss: 0.093407
# Epoch [1640/10000], Train Loss: 0.080634, Val Loss: 0.093706
# Epoch [1650/10000], Train Loss: 0.080876, Val Loss: 0.094369
# Epoch [1660/10000], Train Loss: 0.083006, Val Loss: 0.093308
# Epoch [1670/10000], Train Loss: 0.080744, Val Loss: 0.094034
# Epoch [1680/10000], Train Loss: 0.083809, Val Loss: 0.095343
# Epoch [1690/10000], Train Loss: 0.082218, Val Loss: 0.094889
# Epoch [1700/10000], Train Loss: 0.083053, Val Loss: 0.098169
# Early stopping triggered at epoch 1710
# Evaluation Metrics:
# MSE: 1773703286.8066
# R² (meanLineIntensity): 0.5361
# R² (meanNumPixels15): 0.4389
# Fold 5 Validation MSE: 1773703286.8066
# Fold 5 R² scores: ['0.5361', '0.4389']
#
# Cross-validation Results:
# Average MSE: 1635575282.7848 ± 188691358.4252
# Average R² (meanLineIntensity): 0.5283 ± 0.0180
# Average R² (meanNumPixels15): 0.4153 ± 0.0147
# ------------------------------
#
# Cross-validation Results:
# Average MSE: 1635575282.7848 ± 188691358.4252

# %%
import os
import json
import pickle
import torch
from datetime import datetime

def save_training_results(models, scalers, scalers_y, val_scores, r2_scores_all, input_cols, target_cols):
    # Create Results directory if it doesn't exist
    results_dir = "Results"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
    
    # Create timestamped subdirectory for this training run
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = os.path.join(results_dir, f"run_{timestamp}")
    os.makedirs(run_dir)
    
    # Save models
    models_dir = os.path.join(run_dir, "models")
    os.makedirs(models_dir)
    for i, model in enumerate(models):
        model_path = os.path.join(models_dir, f"model_fold_{i+1}.pt")
        torch.save(model.state_dict(), model_path)
    
    # Save scalers
    scalers_dir = os.path.join(run_dir, "scalers")
    os.makedirs(scalers_dir)
    for i, (scaler, scaler_y) in enumerate(zip(scalers, scalers_y)):
        # Save feature scaler
        scaler_path = os.path.join(scalers_dir, f"feature_scaler_fold_{i+1}.pkl")
        with open(scaler_path, 'wb') as f:
            pickle.dump(scaler, f)
        
        # Save target scaler
        scaler_y_path = os.path.join(scalers_dir, f"target_scaler_fold_{i+1}.pkl")
        with open(scaler_y_path, 'wb') as f:
            pickle.dump(scaler_y, f)
    
    # Save metrics and configuration
    metrics = {
        'input_features': input_cols,
        'target_variables': target_cols,
        'val_scores': val_scores.tolist() if isinstance(val_scores, np.ndarray) else val_scores,
        'r2_scores_all': r2_scores_all.tolist() if isinstance(r2_scores_all, np.ndarray) else r2_scores_all,
        'average_mse': float(np.mean(val_scores)),
        'mse_std': float(np.std(val_scores)),
        'average_r2_by_target': {
            target: {
                'mean': float(np.mean(r2_scores_all[:, i])),
                'std': float(np.std(r2_scores_all[:, i]))
            }
            for i, target in enumerate(target_cols)
        }
    }
    
    metrics_path = os.path.join(run_dir, "metrics.json")
    with open(metrics_path, 'w') as f:
        json.dump(metrics, f, indent=4)
    
    print(f"\nResults saved in: {run_dir}")
    print("Saved contents:")
    print(f"- {len(models)} models")
    print(f"- {len(scalers)} feature scalers and target scalers")
    print("- Evaluation metrics and configuration")

# Call the function to save the results
save_training_results(
    models=models,
    scalers=scalers,
    scalers_y=scalers_y,  
    val_scores=val_scores,
    r2_scores_all=r2_scores_all,
    input_cols=input_cols,
    target_cols=target_cols
)
# Out:
# Results saved in: Results/run_20241115_181639
# Saved contents:
# - 5 models
# - 5 feature scalers and target scalers
# - Evaluation metrics and configuration

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms for each feature
for col in input_cols + target_cols:
    sns.histplot(data[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
import seaborn as sns

sns.pairplot(data[input_cols + target_cols])
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

r2s = []
for fold_no, indices in enumerate(fold_indices):
    
    X_train, X_val = X[indices[0]], X[indices[1]]
    y_train, y_val = y[indices[0]], y[indices[1]]

    lr_model = LinearRegression()
    lr_model.fit(X_train, y_train)
    y_pred = lr_model.predict(X_val)

    mse = mean_squared_error(y_val, y_pred)
    r2 = r2_score(y_val, y_pred, multioutput='raw_values')
    print(f'Fold:  {fold_no}')
    print(f'Linear Regression MSE: {mse:.4f}')
    print(f'Linear Regression R² scores: {r2}')
    r2s.append(r2)

r2s = np.array(r2s)
mean_score = r2s.mean(axis=0)
print(f'Cross-validation mean score {mean_score}')

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X[train_idx])
X_val = scaler.transform(X[val_idx])

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(X_val[:, 1])
plt.plot(X_val[:, 2])
plt.plot(X_val[:, 3])
plt.plot(X_val[:, 4])

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_val)

mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred, multioutput='raw_values')
print(f'Random Forest MSE: {mse:.4f}')
print(f'Random Forest R² scores: {r2}')
