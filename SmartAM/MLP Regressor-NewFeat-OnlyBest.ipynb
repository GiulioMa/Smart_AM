# %%
import pandas as pd

# Load the saved CSV file
data = pd.read_csv('processed_data.csv')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import torch
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Define target and input variables
target_cols = ['meanLineIntensity', 'meanNumPixels15']
input_cols = ['Z', 'd_edge_left', 'd_edge_right', 'NoLines', 'd_over_left'] 

# Extract features and targets
X = data[input_cols].values
y = data[target_cols].values

# Create a custom Dataset class
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.FloatTensor(X)
        self.y = torch.FloatTensor(y)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# Function to prepare data loaders for a specific fold
def prepare_fold_data(X, y, train_idx, val_idx, batch_size=32):
    # StandardScaler for features
    scaler = StandardScaler()
    scaler_y = StandardScaler()  
    
    # Scale features
    X_train = scaler.fit_transform(X[train_idx])
    X_val = scaler.transform(X[val_idx])
    
    # Scale targets
    y_train = scaler_y.fit_transform(y[train_idx])
    y_val = scaler_y.transform(y[val_idx])
    
    # Create datasets
    train_dataset = CustomDataset(X_train, y_train)
    val_dataset = CustomDataset(X_val, y_val)
    
    # Create data loaders 
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False
    )
    
    return train_loader, val_loader, scaler, scaler_y

# Set up K-Fold cross-validation
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Store fold indices for later use
fold_indices = []
for train_idx, val_idx in kf.split(X):
    fold_indices.append((train_idx, val_idx))

# %%
import torch.nn as nn
import torch.optim as optim
import tqdm
from tqdm import tqdm
import copy
import matplotlib.pyplot as plt

class ResidualBlock(nn.Module):
    def __init__(self, dim, dropout_rate=0.2):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Linear(dim, dim),
            #nn.BatchNorm1d(dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate),
            nn.Linear(dim, dim),
            #nn.BatchNorm1d(dim)
        )
        self.relu = nn.ReLU()
        
    def forward(self, x):
        residual = x
        out = self.block(x)
        out += residual  # Skip connection
        return self.relu(out)

class MLPRegressor(nn.Module):
    def __init__(self, input_dim=5, hidden_dim=128, num_layers=3, output_dim=2, dropout_rate=0.2):
        super(MLPRegressor, self).__init__()
        
        self.input_layer = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            #nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate)
        )
        
        self.residual_layers = nn.ModuleList([
            ResidualBlock(hidden_dim, dropout_rate) 
            for _ in range(num_layers - 1)
        ])
        
        self.output_layer = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        x = self.input_layer(x)
        for layer in self.residual_layers:
            x = layer(x)
        return self.output_layer(x)

def print_model_params(model):
    total_params = 0
    input_params = sum(p.numel() for p in model.input_layer.parameters())
    total_params += input_params
    
    for i, block in enumerate(model.residual_layers):
        block_params = sum(p.numel() for p in block.parameters())
        total_params += block_params
    
    output_params = sum(p.numel() for p in model.output_layer.parameters())
    total_params += output_params
    
    print("-" * 50)
    print(f"Total Parameters: {total_params:,}")

def train_model(model, train_loader, val_loader, num_epochs=1000, patience=50):
    model = model.to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.00001)

    best_val_loss = float('inf')
    best_model = None
    patience_counter = 0
    
    # Lists to store losses for plotting
    train_losses = []
    val_losses = []
    epochs = []

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * X_batch.size(0)

        train_loss /= len(train_loader.dataset)

        # Validation phase
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)

        val_loss /= len(val_loader.dataset)

        # Store losses for plotting
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        epochs.append(epoch + 1)

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = copy.deepcopy(model)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f'Early stopping triggered at epoch {epoch+1}')
            break

        if (epoch + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.6f}, Val Loss: {val_loss:.6f}')

    return best_model, train_losses, val_losses, epochs

def train_k_fold(X, y, fold_indices, hidden_dim=128, num_layers=3, batch_size=32):
    models = []
    scalers = []
    scalers_y = []
    val_scores = []
    r2_scores_all = []

    for fold, (train_idx, val_idx) in enumerate(fold_indices):
        print(f'\nTraining Fold {fold+1}')

        # Prepare data for this fold
        train_loader, val_loader, scaler, scaler_y = prepare_fold_data(
            X, y, train_idx, val_idx, batch_size
        )

        # Initialize model
        model = MLPRegressor(
            input_dim=X.shape[1],
            hidden_dim=hidden_dim,
            num_layers=num_layers,
            output_dim=y.shape[1]
        )
        
        print_model_params(model)

        # Train model and get loss history
        best_model, train_losses, val_losses, epochs = train_model(
            model,
            train_loader,
            val_loader,
            num_epochs=10000,
            patience=500
        )

        # Plot loss evolution for this fold
        plt.figure(figsize=(10, 6))
        plt.plot(epochs[1:], train_losses[1:], label='Training Loss')
        plt.plot(epochs[1:], val_losses[1:], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title(f'Loss Evolution - Fold {fold+1}')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Store the trained model and scalers
        models.append(best_model)
        scalers.append(scaler)
        scalers_y.append(scaler_y)

        # Calculate validation scores
        mse, r2_scores, predictions, actuals = evaluate_model(best_model, val_loader, scaler_y)
        val_scores.append(mse)
        r2_scores_all.append(r2_scores)
        print(f'Fold {fold+1} Validation MSE: {mse:.4f}')
        print(f'Fold {fold+1} R² scores: {[f"{r2:.4f}" for r2 in r2_scores]}')

    # Calculate and print average metrics
    print("\nCross-validation Results:")
    print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
    r2_scores_all = np.array(r2_scores_all)
    for i, target in enumerate(['meanLineIntensity', 'meanNumPixels15']):
        mean_r2 = np.mean(r2_scores_all[:, i])
        std_r2 = np.std(r2_scores_all[:, i])
        print(f"Average R² ({target}): {mean_r2:.4f} ± {std_r2:.4f}")
    
    return models, scalers, scalers_y, val_scores, r2_scores_all

def evaluate_model(model, data_loader, scaler_y):
    model = model.to(device)
    model.eval()
    criterion = nn.MSELoss()
    total_loss = 0.0

    # Lists to store predictions and actual values
    all_predictions = []
    all_actuals = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            outputs = model(X_batch)

            # Move to CPU and convert to numpy
            outputs_np = outputs.cpu().numpy()
            y_batch_np = y_batch.cpu().numpy()

            # Inverse transform
            outputs_inv = scaler_y.inverse_transform(outputs_np)
            y_batch_inv = scaler_y.inverse_transform(y_batch_np)

            # Compute loss in original scale
            loss = criterion(torch.tensor(outputs_inv), torch.tensor(y_batch_inv))
            total_loss += loss.item() * X_batch.size(0)

            all_predictions.append(outputs_inv)
            all_actuals.append(y_batch_inv)

    # Convert lists to numpy arrays
    predictions = np.vstack(all_predictions)
    actuals = np.vstack(all_actuals)

    # Calculate MSE
    mse = total_loss / len(data_loader.dataset)

    # Calculate R2 for each target
    r2_scores = []
    for i in range(actuals.shape[1]):
        ss_res = np.sum((actuals[:, i] - predictions[:, i]) ** 2)
        ss_tot = np.sum((actuals[:, i] - np.mean(actuals[:, i])) ** 2)
        r2 = 1 - (ss_res / ss_tot)
        r2_scores.append(r2)

    # Create plots
    import matplotlib.pyplot as plt

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    target_names = ['meanLineIntensity', 'meanNumPixels15']

    for i, (ax, target) in enumerate(zip(axes, target_names)):
        # Plot predicted vs actual
        ax.scatter(actuals[:, i], predictions[:, i], alpha=0.5)

        # Plot perfect prediction line
        min_val = min(actuals[:, i].min(), predictions[:, i].min())
        max_val = max(actuals[:, i].max(), predictions[:, i].max())
        ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Prediction')

        # Add labels and title
        ax.set_xlabel('Actual Values')
        ax.set_ylabel('Predicted Values')
        ax.set_title(f'{target}\nR² = {r2_scores[i]:.4f}')
        ax.grid(True)
        ax.legend()

    plt.tight_layout()
    plt.show()

    # Print detailed metrics
    print("\nEvaluation Metrics:")
    print(f"MSE: {mse:.4f}")
    for i, target in enumerate(target_names):
        print(f"R² ({target}): {r2_scores[i]:.4f}")

    return mse, r2_scores, predictions, actuals


# Train the models
models, scalers, scalers_y, val_scores, r2_scores_all = train_k_fold(X, y, fold_indices, 
                                                                     hidden_dim=1024, 
                                                                     num_layers=128,
                                                                     batch_size=128)

print('---'*10)
# Print overall results
print("\nCross-validation Results:")
print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
# Out:
# Training Fold 1
# --------------------------------------------------
# Total Parameters: 266,606,594
# Epoch [10/10000], Train Loss: 0.330472, Val Loss: 0.368814
# Epoch [20/10000], Train Loss: 0.268836, Val Loss: 0.290824
# Epoch [30/10000], Train Loss: 0.235230, Val Loss: 0.378089
# Epoch [40/10000], Train Loss: 0.225854, Val Loss: 0.241322
# Epoch [50/10000], Train Loss: 0.243165, Val Loss: 0.354227
# Epoch [60/10000], Train Loss: 0.182933, Val Loss: 0.219687
# Epoch [70/10000], Train Loss: 0.197430, Val Loss: 0.228171
# Epoch [80/10000], Train Loss: 0.183253, Val Loss: 0.246879
# Epoch [90/10000], Train Loss: 0.178180, Val Loss: 0.246124
# Epoch [100/10000], Train Loss: 0.146881, Val Loss: 0.237309
# Epoch [110/10000], Train Loss: 0.152180, Val Loss: 0.235962
# Epoch [120/10000], Train Loss: 0.190311, Val Loss: 0.207200
# Epoch [130/10000], Train Loss: 0.160353, Val Loss: 0.207254
# Epoch [140/10000], Train Loss: 0.139036, Val Loss: 0.179232
# Epoch [150/10000], Train Loss: 0.137132, Val Loss: 0.182675
# Epoch [160/10000], Train Loss: 0.187158, Val Loss: 0.240854
# Epoch [170/10000], Train Loss: 0.133469, Val Loss: 0.205855
# Epoch [180/10000], Train Loss: 0.110402, Val Loss: 0.172296
# Epoch [190/10000], Train Loss: 0.133044, Val Loss: 0.185205
# Epoch [200/10000], Train Loss: 0.131995, Val Loss: 0.205946
# Epoch [210/10000], Train Loss: 0.095039, Val Loss: 0.194569
# Epoch [220/10000], Train Loss: 0.115100, Val Loss: 0.197696
# Epoch [230/10000], Train Loss: 0.134290, Val Loss: 0.209496
# Epoch [240/10000], Train Loss: 0.125010, Val Loss: 0.186133
# Epoch [250/10000], Train Loss: 0.127961, Val Loss: 0.291200
# Epoch [260/10000], Train Loss: 0.158873, Val Loss: 0.218465
# Epoch [270/10000], Train Loss: 0.151132, Val Loss: 0.201403
# Epoch [280/10000], Train Loss: 0.092154, Val Loss: 0.210646
# Epoch [290/10000], Train Loss: 0.110752, Val Loss: 0.191497
# Epoch [300/10000], Train Loss: 0.089517, Val Loss: 0.181143
# Epoch [310/10000], Train Loss: 0.096445, Val Loss: 0.199892
# Epoch [320/10000], Train Loss: 0.101045, Val Loss: 0.222185
# Epoch [330/10000], Train Loss: 0.081420, Val Loss: 0.189221
# Epoch [340/10000], Train Loss: 0.088410, Val Loss: 0.204226
# Epoch [350/10000], Train Loss: 0.099309, Val Loss: 0.193805
# Epoch [360/10000], Train Loss: 0.088871, Val Loss: 0.179281
# Epoch [370/10000], Train Loss: 0.094406, Val Loss: 0.217201
# Epoch [380/10000], Train Loss: 0.096040, Val Loss: 0.209861
# Epoch [390/10000], Train Loss: 0.120083, Val Loss: 0.343862
# Epoch [400/10000], Train Loss: 0.094671, Val Loss: 0.225386
# Epoch [410/10000], Train Loss: 0.071156, Val Loss: 0.201203
# Epoch [420/10000], Train Loss: 0.097724, Val Loss: 0.227223
# Epoch [430/10000], Train Loss: 0.060496, Val Loss: 0.186511
# Epoch [440/10000], Train Loss: 0.116998, Val Loss: 0.179245
# Epoch [450/10000], Train Loss: 0.095630, Val Loss: 0.191418
# Epoch [460/10000], Train Loss: 0.070383, Val Loss: 0.198106
# Epoch [470/10000], Train Loss: 0.083555, Val Loss: 0.197714
# Epoch [480/10000], Train Loss: 0.082519, Val Loss: 0.208930
# Epoch [490/10000], Train Loss: 0.063780, Val Loss: 0.203215
# Epoch [500/10000], Train Loss: 0.064753, Val Loss: 0.206585
# Epoch [510/10000], Train Loss: 0.060866, Val Loss: 0.209438
# Epoch [520/10000], Train Loss: 0.072210, Val Loss: 0.234677
# Epoch [530/10000], Train Loss: 0.063336, Val Loss: 0.200979
# Epoch [540/10000], Train Loss: 0.072588, Val Loss: 0.197103
# Epoch [550/10000], Train Loss: 0.095472, Val Loss: 0.193168
# Epoch [560/10000], Train Loss: 0.073320, Val Loss: 0.206218
# Epoch [570/10000], Train Loss: 0.063861, Val Loss: 0.187146
# Epoch [580/10000], Train Loss: 0.071742, Val Loss: 0.210538
# Epoch [590/10000], Train Loss: 0.079249, Val Loss: 0.236146
# Epoch [600/10000], Train Loss: 0.080136, Val Loss: 0.209461
# Epoch [610/10000], Train Loss: 0.039784, Val Loss: 0.207669
# Epoch [620/10000], Train Loss: 0.053151, Val Loss: 0.209023
# Epoch [630/10000], Train Loss: 0.095377, Val Loss: 0.208683
# Epoch [640/10000], Train Loss: 0.061486, Val Loss: 0.201494
# Epoch [650/10000], Train Loss: 0.057389, Val Loss: 0.209219
# Epoch [660/10000], Train Loss: 0.129509, Val Loss: 0.212541
# Epoch [670/10000], Train Loss: 0.091621, Val Loss: 0.242443
# Epoch [680/10000], Train Loss: 0.055675, Val Loss: 0.197246
# Epoch [690/10000], Train Loss: 0.046435, Val Loss: 0.190595
# Epoch [700/10000], Train Loss: 0.032209, Val Loss: 0.188020
# Epoch [710/10000], Train Loss: 0.062501, Val Loss: 0.211843
# Epoch [720/10000], Train Loss: 0.085109, Val Loss: 0.226535
# Epoch [730/10000], Train Loss: 0.038938, Val Loss: 0.210054
# Epoch [740/10000], Train Loss: 0.040594, Val Loss: 0.196904
# Epoch [750/10000], Train Loss: 0.075793, Val Loss: 0.216679
# Epoch [760/10000], Train Loss: 0.041897, Val Loss: 0.206807
# Epoch [770/10000], Train Loss: 0.035114, Val Loss: 0.213309
# Epoch [780/10000], Train Loss: 0.030074, Val Loss: 0.205155
# Epoch [790/10000], Train Loss: 0.086788, Val Loss: 0.236994
# Epoch [800/10000], Train Loss: 0.044287, Val Loss: 0.189054
# Epoch [810/10000], Train Loss: 0.047909, Val Loss: 0.184128
# Epoch [820/10000], Train Loss: 0.035019, Val Loss: 0.198896
# Epoch [830/10000], Train Loss: 0.078741, Val Loss: 0.244476
# Epoch [840/10000], Train Loss: 0.040510, Val Loss: 0.218148
# Epoch [850/10000], Train Loss: 0.046556, Val Loss: 0.216405
# Epoch [860/10000], Train Loss: 0.122471, Val Loss: 0.247684
# Epoch [870/10000], Train Loss: 0.055025, Val Loss: 0.197993
# Epoch [880/10000], Train Loss: 0.026916, Val Loss: 0.193578
# Epoch [890/10000], Train Loss: 0.049746, Val Loss: 0.200413
# Epoch [900/10000], Train Loss: 0.043016, Val Loss: 0.180772
# Epoch [910/10000], Train Loss: 0.037993, Val Loss: 0.191161
# Epoch [920/10000], Train Loss: 0.035606, Val Loss: 0.201862
# Epoch [930/10000], Train Loss: 0.023205, Val Loss: 0.186415
# Early stopping triggered at epoch 937
# Evaluation Metrics:
# MSE: 494620024.9477
# R² (meanLineIntensity): 0.8386
# R² (meanNumPixels15): 0.7853
# Fold 1 Validation MSE: 494620024.9477
# Fold 1 R² scores: ['0.8386', '0.7853']
#
# Training Fold 2
# --------------------------------------------------
# Total Parameters: 266,606,594
# Epoch [10/10000], Train Loss: 0.343279, Val Loss: 0.369195
# Epoch [20/10000], Train Loss: 0.257288, Val Loss: 0.288070
# Epoch [30/10000], Train Loss: 0.221468, Val Loss: 0.249800
# Epoch [40/10000], Train Loss: 0.188286, Val Loss: 0.233584
# Epoch [50/10000], Train Loss: 0.176243, Val Loss: 0.238424
# Epoch [60/10000], Train Loss: 0.167643, Val Loss: 0.247740
# Epoch [70/10000], Train Loss: 0.158217, Val Loss: 0.225269
# Epoch [80/10000], Train Loss: 0.169024, Val Loss: 0.264367
# Epoch [90/10000], Train Loss: 0.173490, Val Loss: 0.242828
# Epoch [100/10000], Train Loss: 0.158940, Val Loss: 0.247008
# Epoch [110/10000], Train Loss: 0.167328, Val Loss: 0.247938
# Epoch [120/10000], Train Loss: 0.160362, Val Loss: 0.246238
# Epoch [130/10000], Train Loss: 0.133121, Val Loss: 0.208743
# Epoch [140/10000], Train Loss: 0.130813, Val Loss: 0.196896
# Epoch [150/10000], Train Loss: 0.119773, Val Loss: 0.218883
# Epoch [160/10000], Train Loss: 0.132337, Val Loss: 0.226569
# Epoch [170/10000], Train Loss: 0.127206, Val Loss: 0.213439
# Epoch [180/10000], Train Loss: 0.139515, Val Loss: 0.235680
# Epoch [190/10000], Train Loss: 0.107005, Val Loss: 0.223486
# Epoch [200/10000], Train Loss: 0.161142, Val Loss: 0.235172
# Epoch [210/10000], Train Loss: 0.100805, Val Loss: 0.216845
# Epoch [220/10000], Train Loss: 0.110828, Val Loss: 0.214948
# Epoch [230/10000], Train Loss: 0.105584, Val Loss: 0.225972
# Epoch [240/10000], Train Loss: 0.102753, Val Loss: 0.201472
# Epoch [250/10000], Train Loss: 0.095762, Val Loss: 0.189814
# Epoch [260/10000], Train Loss: 0.111913, Val Loss: 0.226058
# Epoch [270/10000], Train Loss: 0.084893, Val Loss: 0.216368
# Epoch [280/10000], Train Loss: 0.115943, Val Loss: 0.240811
# Epoch [290/10000], Train Loss: 0.094213, Val Loss: 0.209327
# Epoch [300/10000], Train Loss: 0.090599, Val Loss: 0.212333
# Epoch [310/10000], Train Loss: 0.096660, Val Loss: 0.198300
# Epoch [320/10000], Train Loss: 0.075037, Val Loss: 0.224446
# Epoch [330/10000], Train Loss: 0.080779, Val Loss: 0.227674
# Epoch [340/10000], Train Loss: 0.104691, Val Loss: 0.221284
# Epoch [350/10000], Train Loss: 0.125099, Val Loss: 0.208095
# Epoch [360/10000], Train Loss: 0.091805, Val Loss: 0.202533
# Epoch [370/10000], Train Loss: 0.068048, Val Loss: 0.183316
# Epoch [380/10000], Train Loss: 0.072785, Val Loss: 0.192293
# Epoch [390/10000], Train Loss: 0.056601, Val Loss: 0.189661
# Epoch [400/10000], Train Loss: 0.068821, Val Loss: 0.212543
# Epoch [410/10000], Train Loss: 0.090962, Val Loss: 0.201531
# Epoch [420/10000], Train Loss: 0.060093, Val Loss: 0.209393
# Epoch [430/10000], Train Loss: 0.066781, Val Loss: 0.194906
# Epoch [440/10000], Train Loss: 0.078681, Val Loss: 0.192147
# Epoch [450/10000], Train Loss: 0.077125, Val Loss: 0.204575
# Epoch [460/10000], Train Loss: 0.079707, Val Loss: 0.219449
# Epoch [470/10000], Train Loss: 0.076686, Val Loss: 0.221412
# Epoch [480/10000], Train Loss: 0.100679, Val Loss: 0.225086
# Epoch [490/10000], Train Loss: 0.089527, Val Loss: 0.198759
# Epoch [500/10000], Train Loss: 0.055330, Val Loss: 0.194589
# Epoch [510/10000], Train Loss: 0.078738, Val Loss: 0.226967
# Epoch [520/10000], Train Loss: 0.074496, Val Loss: 0.219344
# Epoch [530/10000], Train Loss: 0.077322, Val Loss: 0.209104
# Epoch [540/10000], Train Loss: 0.050993, Val Loss: 0.192263
# Epoch [550/10000], Train Loss: 0.089188, Val Loss: 0.209843
# Epoch [560/10000], Train Loss: 0.063365, Val Loss: 0.231609
# Epoch [570/10000], Train Loss: 0.042509, Val Loss: 0.202805
# Epoch [580/10000], Train Loss: 0.050758, Val Loss: 0.195202
# Epoch [590/10000], Train Loss: 0.050132, Val Loss: 0.220076
# Epoch [600/10000], Train Loss: 0.056428, Val Loss: 0.211877
# Epoch [610/10000], Train Loss: 0.035197, Val Loss: 0.201910
# Epoch [620/10000], Train Loss: 0.041446, Val Loss: 0.235953
# Epoch [630/10000], Train Loss: 0.030619, Val Loss: 0.198764
# Epoch [640/10000], Train Loss: 0.070460, Val Loss: 0.195485
# Epoch [650/10000], Train Loss: 0.053849, Val Loss: 0.206619
# Epoch [660/10000], Train Loss: 0.144548, Val Loss: 0.227009
# Epoch [670/10000], Train Loss: 0.056793, Val Loss: 0.202675
# Epoch [680/10000], Train Loss: 0.073256, Val Loss: 0.201340
# Epoch [690/10000], Train Loss: 0.066658, Val Loss: 0.197256
# Epoch [700/10000], Train Loss: 0.034510, Val Loss: 0.218721
# Epoch [710/10000], Train Loss: 0.040968, Val Loss: 0.199666
# Epoch [720/10000], Train Loss: 0.022041, Val Loss: 0.197841
# Epoch [730/10000], Train Loss: 0.020438, Val Loss: 0.204325
# Epoch [740/10000], Train Loss: 0.036105, Val Loss: 0.190365
# Epoch [750/10000], Train Loss: 0.043963, Val Loss: 0.189081
# Epoch [760/10000], Train Loss: 0.070234, Val Loss: 0.228852
# Epoch [770/10000], Train Loss: 0.082957, Val Loss: 0.242274
# Epoch [780/10000], Train Loss: 0.073615, Val Loss: 0.236668
# Epoch [790/10000], Train Loss: 0.066852, Val Loss: 0.205566
# Epoch [800/10000], Train Loss: 0.067595, Val Loss: 0.195669
# Epoch [810/10000], Train Loss: 0.090211, Val Loss: 0.177194
# Epoch [820/10000], Train Loss: 0.044546, Val Loss: 0.187837
# Epoch [830/10000], Train Loss: 0.041379, Val Loss: 0.194762
# Epoch [840/10000], Train Loss: 0.022480, Val Loss: 0.197091
# Epoch [850/10000], Train Loss: 0.044069, Val Loss: 0.209456
# Epoch [860/10000], Train Loss: 0.073767, Val Loss: 0.217223
# Epoch [870/10000], Train Loss: 0.055420, Val Loss: 0.199266
# Epoch [880/10000], Train Loss: 0.057410, Val Loss: 0.206025
# Epoch [890/10000], Train Loss: 0.031544, Val Loss: 0.201566
# Epoch [900/10000], Train Loss: 0.063355, Val Loss: 0.215307
# Epoch [910/10000], Train Loss: 0.038716, Val Loss: 0.194520
# Epoch [920/10000], Train Loss: 0.016859, Val Loss: 0.186265
# Epoch [930/10000], Train Loss: 0.016147, Val Loss: 0.194757
# Epoch [940/10000], Train Loss: 0.030389, Val Loss: 0.203824
# Epoch [950/10000], Train Loss: 0.045918, Val Loss: 0.215919
# Epoch [960/10000], Train Loss: 0.040649, Val Loss: 0.206346
# Epoch [970/10000], Train Loss: 0.021571, Val Loss: 0.200701
# Epoch [980/10000], Train Loss: 0.020988, Val Loss: 0.189521
# Epoch [990/10000], Train Loss: 0.016644, Val Loss: 0.192609
# Epoch [1000/10000], Train Loss: 0.024907, Val Loss: 0.186193
# Epoch [1010/10000], Train Loss: 0.020202, Val Loss: 0.185064
# Epoch [1020/10000], Train Loss: 0.024354, Val Loss: 0.191845
# Epoch [1030/10000], Train Loss: 0.047326, Val Loss: 0.192082
# Epoch [1040/10000], Train Loss: 0.085616, Val Loss: 0.207120
# Epoch [1050/10000], Train Loss: 0.063393, Val Loss: 0.207111
# Epoch [1060/10000], Train Loss: 0.097775, Val Loss: 0.214487
# Epoch [1070/10000], Train Loss: 0.089214, Val Loss: 0.220350
# Epoch [1080/10000], Train Loss: 0.051936, Val Loss: 0.200686
# Epoch [1090/10000], Train Loss: 0.030453, Val Loss: 0.183730
# Epoch [1100/10000], Train Loss: 0.043104, Val Loss: 0.196030
# Epoch [1110/10000], Train Loss: 0.026670, Val Loss: 0.193911
# Epoch [1120/10000], Train Loss: 0.011959, Val Loss: 0.193363
# Epoch [1130/10000], Train Loss: 0.018269, Val Loss: 0.193474
# Epoch [1140/10000], Train Loss: 0.040960, Val Loss: 0.230579
# Epoch [1150/10000], Train Loss: 0.111120, Val Loss: 0.217478
# Epoch [1160/10000], Train Loss: 0.022077, Val Loss: 0.199508
# Epoch [1170/10000], Train Loss: 0.017614, Val Loss: 0.197650
# Epoch [1180/10000], Train Loss: 0.017459, Val Loss: 0.204140
# Epoch [1190/10000], Train Loss: 0.011384, Val Loss: 0.188145
# Epoch [1200/10000], Train Loss: 0.023811, Val Loss: 0.218109
# Epoch [1210/10000], Train Loss: 0.022945, Val Loss: 0.202780
# Epoch [1220/10000], Train Loss: 0.021463, Val Loss: 0.212888
# Epoch [1230/10000], Train Loss: 0.022016, Val Loss: 0.204216
# Epoch [1240/10000], Train Loss: 0.100954, Val Loss: 0.209171
# Epoch [1250/10000], Train Loss: 0.070630, Val Loss: 0.217556
# Epoch [1260/10000], Train Loss: 0.034306, Val Loss: 0.213488
# Epoch [1270/10000], Train Loss: 0.023361, Val Loss: 0.184841
# Epoch [1280/10000], Train Loss: 0.015027, Val Loss: 0.185245
# Epoch [1290/10000], Train Loss: 0.010959, Val Loss: 0.184967
# Epoch [1300/10000], Train Loss: 0.057578, Val Loss: 0.199340
# Epoch [1310/10000], Train Loss: 0.023287, Val Loss: 0.179117
# Epoch [1320/10000], Train Loss: 0.052048, Val Loss: 0.193475
# Epoch [1330/10000], Train Loss: 0.065079, Val Loss: 0.219028
# Epoch [1340/10000], Train Loss: 0.024004, Val Loss: 0.190578
# Epoch [1350/10000], Train Loss: 0.040612, Val Loss: 0.212120
# Epoch [1360/10000], Train Loss: 0.040813, Val Loss: 0.186752
# Epoch [1370/10000], Train Loss: 0.020780, Val Loss: 0.178904
# Epoch [1380/10000], Train Loss: 0.020912, Val Loss: 0.187078
# Epoch [1390/10000], Train Loss: 0.012282, Val Loss: 0.187710
# Epoch [1400/10000], Train Loss: 0.019527, Val Loss: 0.181632
# Epoch [1410/10000], Train Loss: 0.073976, Val Loss: 0.197183
# Epoch [1420/10000], Train Loss: 0.044996, Val Loss: 0.217887
# Epoch [1430/10000], Train Loss: 0.022229, Val Loss: 0.203030
# Epoch [1440/10000], Train Loss: 0.015719, Val Loss: 0.193361
# Epoch [1450/10000], Train Loss: 0.007745, Val Loss: 0.194691
# Epoch [1460/10000], Train Loss: 0.016276, Val Loss: 0.200667
# Epoch [1470/10000], Train Loss: 0.019001, Val Loss: 0.193952
# Epoch [1480/10000], Train Loss: 0.024960, Val Loss: 0.201596
# Epoch [1490/10000], Train Loss: 0.069345, Val Loss: 0.230073
# Epoch [1500/10000], Train Loss: 0.055490, Val Loss: 0.204197
# Epoch [1510/10000], Train Loss: 0.038115, Val Loss: 0.199315
# Epoch [1520/10000], Train Loss: 0.046260, Val Loss: 0.206528
# Epoch [1530/10000], Train Loss: 0.079953, Val Loss: 0.197751
# Epoch [1540/10000], Train Loss: 0.024845, Val Loss: 0.199905
# Epoch [1550/10000], Train Loss: 0.016966, Val Loss: 0.196235
# Epoch [1560/10000], Train Loss: 0.008289, Val Loss: 0.202647
# Epoch [1570/10000], Train Loss: 0.012393, Val Loss: 0.200976
# Epoch [1580/10000], Train Loss: 0.011820, Val Loss: 0.204594
# Epoch [1590/10000], Train Loss: 0.013207, Val Loss: 0.194513
# Epoch [1600/10000], Train Loss: 0.088348, Val Loss: 0.234314
# Epoch [1610/10000], Train Loss: 0.049816, Val Loss: 0.200537
# Epoch [1620/10000], Train Loss: 0.016506, Val Loss: 0.195894
# Epoch [1630/10000], Train Loss: 0.030260, Val Loss: 0.215996
# Epoch [1640/10000], Train Loss: 0.008196, Val Loss: 0.197248
# Epoch [1650/10000], Train Loss: 0.010629, Val Loss: 0.197903
# Epoch [1660/10000], Train Loss: 0.020511, Val Loss: 0.196434
# Epoch [1670/10000], Train Loss: 0.010774, Val Loss: 0.202895
# Epoch [1680/10000], Train Loss: 0.050043, Val Loss: 0.219007
# Epoch [1690/10000], Train Loss: 0.070376, Val Loss: 0.225907
# Epoch [1700/10000], Train Loss: 0.052134, Val Loss: 0.183203
# Epoch [1710/10000], Train Loss: 0.019780, Val Loss: 0.194571
# Epoch [1720/10000], Train Loss: 0.013463, Val Loss: 0.206788
# Epoch [1730/10000], Train Loss: 0.012406, Val Loss: 0.203311
# Epoch [1740/10000], Train Loss: 0.018530, Val Loss: 0.202484
# Epoch [1750/10000], Train Loss: 0.021195, Val Loss: 0.211367
# Early stopping triggered at epoch 1754
# Evaluation Metrics:
# MSE: 508672309.0689
# R² (meanLineIntensity): 0.8361
# R² (meanNumPixels15): 0.7666
# Fold 2 Validation MSE: 508672309.0689
# Fold 2 R² scores: ['0.8361', '0.7666']
#
# Training Fold 3
# --------------------------------------------------
# Total Parameters: 266,606,594
# Epoch [10/10000], Train Loss: 0.364685, Val Loss: 0.420170
# Epoch [20/10000], Train Loss: 0.268031, Val Loss: 0.352950
# Epoch [30/10000], Train Loss: 0.237240, Val Loss: 0.325165
# Epoch [40/10000], Train Loss: 0.192323, Val Loss: 0.347291
# Epoch [50/10000], Train Loss: 0.220137, Val Loss: 0.288935
# Epoch [60/10000], Train Loss: 0.177261, Val Loss: 0.289192
# Epoch [70/10000], Train Loss: 0.197176, Val Loss: 0.321965
# Epoch [80/10000], Train Loss: 0.159271, Val Loss: 0.287536
# Epoch [90/10000], Train Loss: 0.162201, Val Loss: 0.303526
# Epoch [100/10000], Train Loss: 0.204100, Val Loss: 0.334193
# Epoch [110/10000], Train Loss: 0.161999, Val Loss: 0.273600
# Epoch [120/10000], Train Loss: 0.135956, Val Loss: 0.295975
# Epoch [130/10000], Train Loss: 0.122756, Val Loss: 0.289295
# Epoch [140/10000], Train Loss: 0.140631, Val Loss: 0.273511
# Epoch [150/10000], Train Loss: 0.140909, Val Loss: 0.293171
# Epoch [160/10000], Train Loss: 0.119026, Val Loss: 0.263234
# Epoch [170/10000], Train Loss: 0.155496, Val Loss: 0.309814
# Epoch [180/10000], Train Loss: 0.121970, Val Loss: 0.280453
# Epoch [190/10000], Train Loss: 0.117483, Val Loss: 0.285966
# Epoch [200/10000], Train Loss: 0.102447, Val Loss: 0.269683
# Epoch [210/10000], Train Loss: 0.090830, Val Loss: 0.268150
# Epoch [220/10000], Train Loss: 0.087949, Val Loss: 0.279365
# Epoch [230/10000], Train Loss: 0.119183, Val Loss: 0.249378
# Epoch [240/10000], Train Loss: 0.096655, Val Loss: 0.273715
# Epoch [250/10000], Train Loss: 0.102237, Val Loss: 0.273009
# Epoch [260/10000], Train Loss: 0.095815, Val Loss: 0.270696
# Epoch [270/10000], Train Loss: 0.109110, Val Loss: 0.280759
# Epoch [280/10000], Train Loss: 0.098399, Val Loss: 0.288081
# Epoch [290/10000], Train Loss: 0.086626, Val Loss: 0.270427
# Epoch [300/10000], Train Loss: 0.087121, Val Loss: 0.261994
# Epoch [310/10000], Train Loss: 0.100993, Val Loss: 0.263794
# Epoch [320/10000], Train Loss: 0.084388, Val Loss: 0.276282
# Epoch [330/10000], Train Loss: 0.070761, Val Loss: 0.273250
# Epoch [340/10000], Train Loss: 0.106104, Val Loss: 0.309607
# Epoch [350/10000], Train Loss: 0.085144, Val Loss: 0.304044
# Epoch [360/10000], Train Loss: 0.074289, Val Loss: 0.272545
# Epoch [370/10000], Train Loss: 0.079765, Val Loss: 0.274843
# Epoch [380/10000], Train Loss: 0.087218, Val Loss: 0.277299
# Epoch [390/10000], Train Loss: 0.055755, Val Loss: 0.278647
# Epoch [400/10000], Train Loss: 0.079698, Val Loss: 0.285560
# Epoch [410/10000], Train Loss: 0.085100, Val Loss: 0.284463
# Epoch [420/10000], Train Loss: 0.060158, Val Loss: 0.255119
# Epoch [430/10000], Train Loss: 0.061891, Val Loss: 0.251625
# Epoch [440/10000], Train Loss: 0.081991, Val Loss: 0.258289
# Epoch [450/10000], Train Loss: 0.099083, Val Loss: 0.289636
# Epoch [460/10000], Train Loss: 0.075129, Val Loss: 0.282737
# Epoch [470/10000], Train Loss: 0.070073, Val Loss: 0.280147
# Epoch [480/10000], Train Loss: 0.062405, Val Loss: 0.277715
# Epoch [490/10000], Train Loss: 0.107465, Val Loss: 0.253831
# Epoch [500/10000], Train Loss: 0.083006, Val Loss: 0.267997
# Epoch [510/10000], Train Loss: 0.091679, Val Loss: 0.251148
# Epoch [520/10000], Train Loss: 0.097802, Val Loss: 0.360949
# Epoch [530/10000], Train Loss: 0.070723, Val Loss: 0.286184
# Epoch [540/10000], Train Loss: 0.045193, Val Loss: 0.285723
# Epoch [550/10000], Train Loss: 0.033493, Val Loss: 0.252950
# Epoch [560/10000], Train Loss: 0.052799, Val Loss: 0.260827
# Epoch [570/10000], Train Loss: 0.069622, Val Loss: 0.268893
# Epoch [580/10000], Train Loss: 0.044845, Val Loss: 0.268305
# Epoch [590/10000], Train Loss: 0.044663, Val Loss: 0.273756
# Epoch [600/10000], Train Loss: 0.060088, Val Loss: 0.268429
# Epoch [610/10000], Train Loss: 0.085874, Val Loss: 0.266892
# Epoch [620/10000], Train Loss: 0.045783, Val Loss: 0.266011
# Epoch [630/10000], Train Loss: 0.069692, Val Loss: 0.317249
# Epoch [640/10000], Train Loss: 0.053843, Val Loss: 0.249209
# Epoch [650/10000], Train Loss: 0.089366, Val Loss: 0.245610
# Epoch [660/10000], Train Loss: 0.039856, Val Loss: 0.249149
# Epoch [670/10000], Train Loss: 0.044950, Val Loss: 0.239109
# Epoch [680/10000], Train Loss: 0.035099, Val Loss: 0.270116
# Epoch [690/10000], Train Loss: 0.035327, Val Loss: 0.262514
# Epoch [700/10000], Train Loss: 0.058805, Val Loss: 0.246962
# Epoch [710/10000], Train Loss: 0.043533, Val Loss: 0.260983
# Epoch [720/10000], Train Loss: 0.047196, Val Loss: 0.258706
# Epoch [730/10000], Train Loss: 0.051701, Val Loss: 0.264906
# Epoch [740/10000], Train Loss: 0.054078, Val Loss: 0.267535
# Epoch [750/10000], Train Loss: 0.046873, Val Loss: 0.268827
# Epoch [760/10000], Train Loss: 0.028281, Val Loss: 0.253704
# Epoch [770/10000], Train Loss: 0.032809, Val Loss: 0.268286
# Epoch [780/10000], Train Loss: 0.021733, Val Loss: 0.258377
# Epoch [790/10000], Train Loss: 0.022042, Val Loss: 0.254305
# Epoch [800/10000], Train Loss: 0.021953, Val Loss: 0.261594
# Epoch [810/10000], Train Loss: 0.013827, Val Loss: 0.267137
# Epoch [820/10000], Train Loss: 0.024078, Val Loss: 0.264837
# Epoch [830/10000], Train Loss: 0.139795, Val Loss: 0.264518
# Epoch [840/10000], Train Loss: 0.103681, Val Loss: 0.266545
# Epoch [850/10000], Train Loss: 0.034796, Val Loss: 0.266220
# Epoch [860/10000], Train Loss: 0.034807, Val Loss: 0.260132
# Epoch [870/10000], Train Loss: 0.031338, Val Loss: 0.262825
# Epoch [880/10000], Train Loss: 0.044042, Val Loss: 0.273772
# Epoch [890/10000], Train Loss: 0.069124, Val Loss: 0.279105
# Epoch [900/10000], Train Loss: 0.097986, Val Loss: 0.282220
# Epoch [910/10000], Train Loss: 0.066887, Val Loss: 0.278882
# Epoch [920/10000], Train Loss: 0.059181, Val Loss: 0.281322
# Epoch [930/10000], Train Loss: 0.020507, Val Loss: 0.277355
# Epoch [940/10000], Train Loss: 0.013795, Val Loss: 0.279132
# Epoch [950/10000], Train Loss: 0.016710, Val Loss: 0.261810
# Epoch [960/10000], Train Loss: 0.027305, Val Loss: 0.254642
# Epoch [970/10000], Train Loss: 0.047425, Val Loss: 0.268096
# Epoch [980/10000], Train Loss: 0.027198, Val Loss: 0.267211
# Epoch [990/10000], Train Loss: 0.058220, Val Loss: 0.278371
# Epoch [1000/10000], Train Loss: 0.061621, Val Loss: 0.287721
# Epoch [1010/10000], Train Loss: 0.022430, Val Loss: 0.273924
# Epoch [1020/10000], Train Loss: 0.038531, Val Loss: 0.263310
# Epoch [1030/10000], Train Loss: 0.013899, Val Loss: 0.269804
# Epoch [1040/10000], Train Loss: 0.023180, Val Loss: 0.266099
# Early stopping triggered at epoch 1048
# Evaluation Metrics:
# MSE: 665622418.2099
# R² (meanLineIntensity): 0.8168
# R² (meanNumPixels15): 0.7304
# Fold 3 Validation MSE: 665622418.2099
# Fold 3 R² scores: ['0.8168', '0.7304']
#
# Training Fold 4
# --------------------------------------------------
# Total Parameters: 266,606,594
# Epoch [10/10000], Train Loss: 0.374597, Val Loss: 0.424579
# Epoch [20/10000], Train Loss: 0.297563, Val Loss: 0.347041
# Epoch [30/10000], Train Loss: 0.237538, Val Loss: 0.362609
# Epoch [40/10000], Train Loss: 0.219443, Val Loss: 0.323248
# Epoch [50/10000], Train Loss: 0.201956, Val Loss: 0.301916
# Epoch [60/10000], Train Loss: 0.190989, Val Loss: 0.263052
# Epoch [70/10000], Train Loss: 0.183871, Val Loss: 0.278061
# Epoch [80/10000], Train Loss: 0.162896, Val Loss: 0.367040
# Epoch [90/10000], Train Loss: 0.149566, Val Loss: 0.224280
# Epoch [100/10000], Train Loss: 0.161082, Val Loss: 0.267964
# Epoch [110/10000], Train Loss: 0.167909, Val Loss: 0.269254
# Epoch [120/10000], Train Loss: 0.139589, Val Loss: 0.245159
# Epoch [130/10000], Train Loss: 0.129000, Val Loss: 0.247042
# Epoch [140/10000], Train Loss: 0.165993, Val Loss: 0.248963
# Epoch [150/10000], Train Loss: 0.141246, Val Loss: 0.270466
# Epoch [160/10000], Train Loss: 0.122935, Val Loss: 0.241412
# Epoch [170/10000], Train Loss: 0.122911, Val Loss: 0.228094
# Epoch [180/10000], Train Loss: 0.153942, Val Loss: 0.262405
# Epoch [190/10000], Train Loss: 0.116109, Val Loss: 0.219156
# Epoch [200/10000], Train Loss: 0.109939, Val Loss: 0.221007
# Epoch [210/10000], Train Loss: 0.111239, Val Loss: 0.211276
# Epoch [220/10000], Train Loss: 0.091723, Val Loss: 0.219875
# Epoch [230/10000], Train Loss: 0.158449, Val Loss: 0.268775
# Epoch [240/10000], Train Loss: 0.117410, Val Loss: 0.244777
# Epoch [250/10000], Train Loss: 0.095258, Val Loss: 0.202113
# Epoch [260/10000], Train Loss: 0.157436, Val Loss: 0.238184
# Epoch [270/10000], Train Loss: 0.105748, Val Loss: 0.215272
# Epoch [280/10000], Train Loss: 0.081627, Val Loss: 0.198069
# Epoch [290/10000], Train Loss: 0.073891, Val Loss: 0.218035
# Epoch [300/10000], Train Loss: 0.112332, Val Loss: 0.249543
# Epoch [310/10000], Train Loss: 0.091665, Val Loss: 0.236188
# Epoch [320/10000], Train Loss: 0.084764, Val Loss: 0.221706
# Epoch [330/10000], Train Loss: 0.159683, Val Loss: 0.217244
# Epoch [340/10000], Train Loss: 0.094503, Val Loss: 0.230085
# Epoch [350/10000], Train Loss: 0.097488, Val Loss: 0.233555
# Epoch [360/10000], Train Loss: 0.084520, Val Loss: 0.218852
# Epoch [370/10000], Train Loss: 0.066823, Val Loss: 0.213639
# Epoch [380/10000], Train Loss: 0.089025, Val Loss: 0.224281
# Epoch [390/10000], Train Loss: 0.103533, Val Loss: 0.231393
# Epoch [400/10000], Train Loss: 0.066116, Val Loss: 0.211369
# Epoch [410/10000], Train Loss: 0.071348, Val Loss: 0.228599
# Epoch [420/10000], Train Loss: 0.063369, Val Loss: 0.219894
# Epoch [430/10000], Train Loss: 0.079673, Val Loss: 0.242615
# Epoch [440/10000], Train Loss: 0.067319, Val Loss: 0.224640
# Epoch [450/10000], Train Loss: 0.093434, Val Loss: 0.229840
# Epoch [460/10000], Train Loss: 0.062962, Val Loss: 0.238308
# Epoch [470/10000], Train Loss: 0.067224, Val Loss: 0.222226
# Epoch [480/10000], Train Loss: 0.092516, Val Loss: 0.238506
# Epoch [490/10000], Train Loss: 0.059626, Val Loss: 0.216825
# Epoch [500/10000], Train Loss: 0.101676, Val Loss: 0.216419
# Epoch [510/10000], Train Loss: 0.076490, Val Loss: 0.212006
# Epoch [520/10000], Train Loss: 0.068375, Val Loss: 0.228430
# Epoch [530/10000], Train Loss: 0.064948, Val Loss: 0.241607
# Epoch [540/10000], Train Loss: 0.123914, Val Loss: 0.212934
# Epoch [550/10000], Train Loss: 0.075173, Val Loss: 0.244136
# Epoch [560/10000], Train Loss: 0.053238, Val Loss: 0.216076
# Epoch [570/10000], Train Loss: 0.066094, Val Loss: 0.228384
# Epoch [580/10000], Train Loss: 0.039987, Val Loss: 0.216401
# Epoch [590/10000], Train Loss: 0.035204, Val Loss: 0.226030
# Epoch [600/10000], Train Loss: 0.047032, Val Loss: 0.227010
# Epoch [610/10000], Train Loss: 0.058798, Val Loss: 0.229772
# Epoch [620/10000], Train Loss: 0.072469, Val Loss: 0.224092
# Epoch [630/10000], Train Loss: 0.056116, Val Loss: 0.228487
# Epoch [640/10000], Train Loss: 0.029573, Val Loss: 0.237566
# Epoch [650/10000], Train Loss: 0.045470, Val Loss: 0.241901
# Epoch [660/10000], Train Loss: 0.137928, Val Loss: 0.247949
# Epoch [670/10000], Train Loss: 0.053338, Val Loss: 0.224825
# Epoch [680/10000], Train Loss: 0.066283, Val Loss: 0.221231
# Epoch [690/10000], Train Loss: 0.053865, Val Loss: 0.245889
# Epoch [700/10000], Train Loss: 0.044719, Val Loss: 0.218654
# Epoch [710/10000], Train Loss: 0.049464, Val Loss: 0.230773
# Epoch [720/10000], Train Loss: 0.087856, Val Loss: 0.253273
# Epoch [730/10000], Train Loss: 0.087229, Val Loss: 0.211569
# Epoch [740/10000], Train Loss: 0.090403, Val Loss: 0.217200
# Epoch [750/10000], Train Loss: 0.047190, Val Loss: 0.230236
# Epoch [760/10000], Train Loss: 0.033117, Val Loss: 0.224169
# Epoch [770/10000], Train Loss: 0.072626, Val Loss: 0.225144
# Early stopping triggered at epoch 780
# Evaluation Metrics:
# MSE: 569409406.9392
# R² (meanLineIntensity): 0.8452
# R² (meanNumPixels15): 0.7754
# Fold 4 Validation MSE: 569409406.9392
# Fold 4 R² scores: ['0.8452', '0.7754']
#
# Training Fold 5
# --------------------------------------------------
# Total Parameters: 266,606,594
# Epoch [10/10000], Train Loss: 0.357421, Val Loss: 0.400279
# Epoch [20/10000], Train Loss: 0.288613, Val Loss: 0.321073
# Epoch [30/10000], Train Loss: 0.254802, Val Loss: 0.293791
# Epoch [40/10000], Train Loss: 0.242754, Val Loss: 0.331859
# Epoch [50/10000], Train Loss: 0.185522, Val Loss: 0.273085
# Epoch [60/10000], Train Loss: 0.200102, Val Loss: 0.274102
# Epoch [70/10000], Train Loss: 0.168738, Val Loss: 0.283875
# Epoch [80/10000], Train Loss: 0.181148, Val Loss: 0.266411
# Epoch [90/10000], Train Loss: 0.164676, Val Loss: 0.268872
# Epoch [100/10000], Train Loss: 0.156903, Val Loss: 0.241595
# Epoch [110/10000], Train Loss: 0.164800, Val Loss: 0.244914
# Epoch [120/10000], Train Loss: 0.167836, Val Loss: 0.264733
# Epoch [130/10000], Train Loss: 0.145415, Val Loss: 0.242017
# Epoch [140/10000], Train Loss: 0.160255, Val Loss: 0.249885
# Epoch [150/10000], Train Loss: 0.126248, Val Loss: 0.260671
# Epoch [160/10000], Train Loss: 0.132271, Val Loss: 0.242338
# Epoch [170/10000], Train Loss: 0.143345, Val Loss: 0.289507
# Epoch [180/10000], Train Loss: 0.133467, Val Loss: 0.274919
# Epoch [190/10000], Train Loss: 0.136691, Val Loss: 0.248584
# Epoch [200/10000], Train Loss: 0.114860, Val Loss: 0.244921
# Epoch [210/10000], Train Loss: 0.119323, Val Loss: 0.232847
# Epoch [220/10000], Train Loss: 0.122445, Val Loss: 0.252906
# Epoch [230/10000], Train Loss: 0.108688, Val Loss: 0.243924
# Epoch [240/10000], Train Loss: 0.129375, Val Loss: 0.252106
# Epoch [250/10000], Train Loss: 0.147952, Val Loss: 0.277778
# Epoch [260/10000], Train Loss: 0.125190, Val Loss: 0.243096
# Epoch [270/10000], Train Loss: 0.085121, Val Loss: 0.239317
# Epoch [280/10000], Train Loss: 0.097605, Val Loss: 0.239847
# Epoch [290/10000], Train Loss: 0.101484, Val Loss: 0.273627
# Epoch [300/10000], Train Loss: 0.097441, Val Loss: 0.237271
# Epoch [310/10000], Train Loss: 0.107478, Val Loss: 0.225620
# Epoch [320/10000], Train Loss: 0.099185, Val Loss: 0.217442
# Epoch [330/10000], Train Loss: 0.097168, Val Loss: 0.271084
# Epoch [340/10000], Train Loss: 0.141839, Val Loss: 0.250243
# Epoch [350/10000], Train Loss: 0.081291, Val Loss: 0.240744
# Epoch [360/10000], Train Loss: 0.090833, Val Loss: 0.225064
# Epoch [370/10000], Train Loss: 0.092660, Val Loss: 0.237348
# Epoch [380/10000], Train Loss: 0.077369, Val Loss: 0.231074
# Epoch [390/10000], Train Loss: 0.079322, Val Loss: 0.230717
# Epoch [400/10000], Train Loss: 0.072639, Val Loss: 0.239745
# Epoch [410/10000], Train Loss: 0.087440, Val Loss: 0.265866
# Epoch [420/10000], Train Loss: 0.073053, Val Loss: 0.247897
# Epoch [430/10000], Train Loss: 0.084723, Val Loss: 0.247506
# Epoch [440/10000], Train Loss: 0.133108, Val Loss: 0.275677
# Epoch [450/10000], Train Loss: 0.080393, Val Loss: 0.254787
# Epoch [460/10000], Train Loss: 0.089281, Val Loss: 0.261683
# Epoch [470/10000], Train Loss: 0.099179, Val Loss: 0.253113
# Epoch [480/10000], Train Loss: 0.076019, Val Loss: 0.214361
# Epoch [490/10000], Train Loss: 0.068796, Val Loss: 0.253870
# Epoch [500/10000], Train Loss: 0.063253, Val Loss: 0.221442
# Epoch [510/10000], Train Loss: 0.059178, Val Loss: 0.256059
# Epoch [520/10000], Train Loss: 0.074931, Val Loss: 0.266595
# Epoch [530/10000], Train Loss: 0.101120, Val Loss: 0.264679
# Epoch [540/10000], Train Loss: 0.086215, Val Loss: 0.232079
# Epoch [550/10000], Train Loss: 0.074256, Val Loss: 0.216777
# Epoch [560/10000], Train Loss: 0.135972, Val Loss: 0.279766
# Epoch [570/10000], Train Loss: 0.077623, Val Loss: 0.243984
# Epoch [580/10000], Train Loss: 0.062953, Val Loss: 0.243820
# Epoch [590/10000], Train Loss: 0.061782, Val Loss: 0.246777
# Epoch [600/10000], Train Loss: 0.063429, Val Loss: 0.245760
# Epoch [610/10000], Train Loss: 0.078169, Val Loss: 0.248361
# Epoch [620/10000], Train Loss: 0.083295, Val Loss: 0.263426
# Epoch [630/10000], Train Loss: 0.058652, Val Loss: 0.242116
# Epoch [640/10000], Train Loss: 0.066516, Val Loss: 0.255691
# Epoch [650/10000], Train Loss: 0.112133, Val Loss: 0.269715
# Epoch [660/10000], Train Loss: 0.102529, Val Loss: 0.230045
# Epoch [670/10000], Train Loss: 0.073408, Val Loss: 0.268169
# Epoch [680/10000], Train Loss: 0.046931, Val Loss: 0.253644
# Epoch [690/10000], Train Loss: 0.055394, Val Loss: 0.250145
# Epoch [700/10000], Train Loss: 0.052321, Val Loss: 0.232048
# Epoch [710/10000], Train Loss: 0.028567, Val Loss: 0.219881
# Epoch [720/10000], Train Loss: 0.070136, Val Loss: 0.239493
# Epoch [730/10000], Train Loss: 0.062383, Val Loss: 0.254529
# Epoch [740/10000], Train Loss: 0.031644, Val Loss: 0.251896
# Epoch [750/10000], Train Loss: 0.064521, Val Loss: 0.294915
# Epoch [760/10000], Train Loss: 0.043621, Val Loss: 0.262688
# Epoch [770/10000], Train Loss: 0.047299, Val Loss: 0.234345
# Epoch [780/10000], Train Loss: 0.094987, Val Loss: 0.279893
# Epoch [790/10000], Train Loss: 0.063126, Val Loss: 0.250748
# Epoch [800/10000], Train Loss: 0.059466, Val Loss: 0.241075
# Epoch [810/10000], Train Loss: 0.035493, Val Loss: 0.258132
# Epoch [820/10000], Train Loss: 0.030199, Val Loss: 0.251655
# Epoch [830/10000], Train Loss: 0.073423, Val Loss: 0.226352
# Epoch [840/10000], Train Loss: 0.036471, Val Loss: 0.255300
# Epoch [850/10000], Train Loss: 0.036300, Val Loss: 0.237695
# Epoch [860/10000], Train Loss: 0.084841, Val Loss: 0.273896
# Epoch [870/10000], Train Loss: 0.059346, Val Loss: 0.266221
# Epoch [880/10000], Train Loss: 0.105421, Val Loss: 0.254924
# Early stopping triggered at epoch 881
# Evaluation Metrics:
# MSE: 600750264.5746
# R² (meanLineIntensity): 0.8429
# R² (meanNumPixels15): 0.7693
# Fold 5 Validation MSE: 600750264.5746
# Fold 5 R² scores: ['0.8429', '0.7693']
#
# Cross-validation Results:
# Average MSE: 567814884.7481 ± 62464273.1590
# Average R² (meanLineIntensity): 0.8359 ± 0.0101
# Average R² (meanNumPixels15): 0.7654 ± 0.0186
# ------------------------------
#
# Cross-validation Results:
# Average MSE: 567814884.7481 ± 62464273.1590

# %%
import os
import json
import pickle
import torch
from datetime import datetime

def save_training_results(models, scalers, scalers_y, val_scores, r2_scores_all, input_cols, target_cols):
    # Create Results directory if it doesn't exist
    results_dir = "Results"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
    
    # Create timestamped subdirectory for this training run
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = os.path.join(results_dir, f"run_{timestamp}")
    os.makedirs(run_dir)
    
    # Save models
    models_dir = os.path.join(run_dir, "models")
    os.makedirs(models_dir)
    for i, model in enumerate(models):
        model_path = os.path.join(models_dir, f"model_fold_{i+1}.pt")
        torch.save(model.state_dict(), model_path)
    
    # Save scalers
    scalers_dir = os.path.join(run_dir, "scalers")
    os.makedirs(scalers_dir)
    for i, (scaler, scaler_y) in enumerate(zip(scalers, scalers_y)):
        # Save feature scaler
        scaler_path = os.path.join(scalers_dir, f"feature_scaler_fold_{i+1}.pkl")
        with open(scaler_path, 'wb') as f:
            pickle.dump(scaler, f)
        
        # Save target scaler
        scaler_y_path = os.path.join(scalers_dir, f"target_scaler_fold_{i+1}.pkl")
        with open(scaler_y_path, 'wb') as f:
            pickle.dump(scaler_y, f)
    
    # Save metrics and configuration
    metrics = {
        'input_features': input_cols,
        'target_variables': target_cols,
        'val_scores': val_scores.tolist() if isinstance(val_scores, np.ndarray) else val_scores,
        'r2_scores_all': r2_scores_all.tolist() if isinstance(r2_scores_all, np.ndarray) else r2_scores_all,
        'average_mse': float(np.mean(val_scores)),
        'mse_std': float(np.std(val_scores)),
        'average_r2_by_target': {
            target: {
                'mean': float(np.mean(r2_scores_all[:, i])),
                'std': float(np.std(r2_scores_all[:, i]))
            }
            for i, target in enumerate(target_cols)
        }
    }
    
    metrics_path = os.path.join(run_dir, "metrics.json")
    with open(metrics_path, 'w') as f:
        json.dump(metrics, f, indent=4)
    
    print(f"\nResults saved in: {run_dir}")
    print("Saved contents:")
    print(f"- {len(models)} models")
    print(f"- {len(scalers)} feature scalers and target scalers")
    print("- Evaluation metrics and configuration")

# Call the function to save the results
save_training_results(
    models=models,
    scalers=scalers,
    scalers_y=scalers_y,  
    val_scores=val_scores,
    r2_scores_all=r2_scores_all,
    input_cols=input_cols,
    target_cols=target_cols
)
# Out:
# Results saved in: Results/run_20241118_114750
# Saved contents:
# - 5 models
# - 5 feature scalers and target scalers
# - Evaluation metrics and configuration

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms for each feature
for col in input_cols + target_cols:
    sns.histplot(data[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
import seaborn as sns

sns.pairplot(data[input_cols + target_cols])
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

r2s = []
for fold_no, indices in enumerate(fold_indices):
    
    X_train, X_val = X[indices[0]], X[indices[1]]
    y_train, y_val = y[indices[0]], y[indices[1]]

    lr_model = LinearRegression()
    lr_model.fit(X_train, y_train)
    y_pred = lr_model.predict(X_val)

    mse = mean_squared_error(y_val, y_pred)
    r2 = r2_score(y_val, y_pred, multioutput='raw_values')
    print(f'Fold:  {fold_no}')
    print(f'Linear Regression MSE: {mse:.4f}')
    print(f'Linear Regression R² scores: {r2}')
    r2s.append(r2)

r2s = np.array(r2s)
mean_score = r2s.mean(axis=0)
print(f'Cross-validation mean score {mean_score}')
# Out:
# Fold:  0
# Linear Regression MSE: 1517265336.1435
# Linear Regression R² scores: [0.50493267 0.31038152]
# Fold:  1
# Linear Regression MSE: 1674725009.4159
# Linear Regression R² scores: [0.46052306 0.2421029 ]
# Fold:  2
# Linear Regression MSE: 1788748953.9105
# Linear Regression R² scores: [0.50765321 0.31165992]
# Fold:  3
# Linear Regression MSE: 1667596721.9200
# Linear Regression R² scores: [0.5465519  0.30141716]
# Fold:  4
# Linear Regression MSE: 1742148453.7266
# Linear Regression R² scores: [0.54435967 0.32484261]
# Cross-validation mean score [0.5128041  0.29808082]

# %%
from sklearn.ensemble import RandomForestRegressor

r2s = []
for fold_no, indices in enumerate(fold_indices):
    
    X_train, X_val = X[indices[0]], X[indices[1]]
    y_train, y_val = y[indices[0]], y[indices[1]]
    rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
    rf_model.fit(X_train, y_train)
    y_pred = rf_model.predict(X_val)

    mse = mean_squared_error(y_val, y_pred)
    r2 = r2_score(y_val, y_pred, multioutput='raw_values')
    print(f'Fold:  {fold_no}')
    print(f'Random Forest MSE: {mse:.4f}')
    print(f'Random Forest R² scores: {r2}')
    r2s.append(r2)
    
    #plot predictions
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    target_names = ['meanLineIntensity', 'meanNumPixels15']

    for i, (ax, target) in enumerate(zip(axes, target_names)):
        # Plot predicted vs actual
        ax.scatter(y_val[:, i], y_pred[:, i], alpha=0.5)

        # Plot perfect prediction line
        min_val = min(y_val[:, i].min(), y_pred[:, i].min())
        max_val = max(y_val[:, i].max(), y_pred[:, i].max())
        ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Prediction')

        # Add labels and title
        ax.set_xlabel('Actual Values')
        ax.set_ylabel('Predicted Values')
        ax.set_title(f'{target}\nR² = {r2[i]:.4f}')
        ax.grid(True)
        ax.legend()

    plt.tight_layout()
    plt.show()


r2s = np.array(r2s)
mean_score = r2s.mean(axis=0)
print(f'Cross-validation mean score {mean_score}')
# Out:
# Fold:  0
# Random Forest MSE: 455124564.9925
# Random Forest R² scores: [0.85149754 0.79474304]
# Fold:  1
# Random Forest MSE: 498089766.6446
# Random Forest R² scores: [0.83955101 0.77458291]
# Fold:  2
# Random Forest MSE: 587661507.0319
# Random Forest R² scores: [0.83824824 0.77398236]
# Fold:  3
# Random Forest MSE: 553431335.4034
# Random Forest R² scores: [0.84951131 0.77858343]
# Fold:  4
# Random Forest MSE: 523663947.1507
# Random Forest R² scores: [0.8630399  0.80879328]
# Cross-validation mean score [0.8483696  0.78613701]

# %%
from sklearn.ensemble import RandomForestRegressor

r2s = []
for fold_no, indices in enumerate(fold_indices):
    
    X_train, X_val = X[indices[0]], X[indices[1]]
    y_train, y_val = y[indices[0]], y[indices[1]]
    rf_model = RandomForestRegressor(n_estimators=1000, random_state=42)
    rf_model.fit(X_train, y_train)
    y_pred = rf_model.predict(X_val)

    mse = mean_squared_error(y_val, y_pred)
    r2 = r2_score(y_val, y_pred, multioutput='raw_values')
    print(f'Fold:  {fold_no}')
    print(f'Random Forest MSE: {mse:.4f}')
    print(f'Random Forest R² scores: {r2}')
    r2s.append(r2)

r2s = np.array(r2s)
mean_score = r2s.mean(axis=0)
print(f'Cross-validation mean score {mean_score}')
# Out:
# Fold:  0
# Random Forest MSE: 449637491.7220
# Random Forest R² scores: [0.85328827 0.79457061]
# Fold:  1
# Random Forest MSE: 495080872.6302
# Random Forest R² scores: [0.84052054 0.77373305]
# Fold:  2
# Random Forest MSE: 582096341.6828
# Random Forest R² scores: [0.8397803  0.77396937]
# Fold:  3
# Random Forest MSE: 548298460.0026
# Random Forest R² scores: [0.85090694 0.78145464]
# Fold:  4
# Random Forest MSE: 505860300.0987
# Random Forest R² scores: [0.86769637 0.81471858]
# Cross-validation mean score [0.85043848 0.78768925]
