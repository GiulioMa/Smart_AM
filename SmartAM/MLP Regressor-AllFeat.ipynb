# %%
import pandas as pd

# Load the saved CSV file
data = pd.read_csv('processed_data.csv')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import torch
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# Define target and input variables
target_cols = ['Median_meltLength', 'meanNumPixels15']
input_cols = ['Z', 'Y_Start', 'Wall', 'Overhang', 'Power', 'd_edge', 'd_over', 'd_col', 'd_over_z']

# Extract features and targets
X = data[input_cols].values
y = data[target_cols].values

# Create a custom Dataset class
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.FloatTensor(X)
        self.y = torch.FloatTensor(y)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# Function to prepare data loaders for a specific fold
def prepare_fold_data(X, y, train_idx, val_idx, batch_size=32):
    # Scale the features
    scaler = MinMaxScaler()
    scaler_y = MinMaxScaler()
    
    if scaler:
        X_train = scaler.fit_transform(X[train_idx])
        X_val = scaler.transform(X[val_idx])
    else:
        X_train = X[train_idx]
        X_val = X[val_idx]
    y_train = scaler_y.fit_transform(y[train_idx])
    y_eval = scaler_y.transform(y[val_idx])
    
    # Create datasets
    train_dataset = CustomDataset(X_train, y_train)
    val_dataset = CustomDataset(X_val, y_eval)
    
    # Create data loaders
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False
    )
    
    return train_loader, val_loader, scaler, scaler_y

# Set up K-Fold cross-validation
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Store fold indices for later use
fold_indices = []
for train_idx, val_idx in kf.split(X):
    fold_indices.append((train_idx, val_idx))

# %%
import torch.nn as nn
import torch.optim as optim
import tqdm
from tqdm import tqdm
import copy
import matplotlib.pyplot as plt

class ResidualBlock(nn.Module):
    def __init__(self, dim, dropout_rate=0.2):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Linear(dim, dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate),
            nn.Linear(dim, dim),
        )
        self.relu = nn.ReLU()
        
    def forward(self, x):
        residual = x
        out = self.block(x)
        out += residual  # Skip connection
        return self.relu(out)

class MLPRegressor(nn.Module):
    def __init__(self, input_dim=5, hidden_dim=128, num_layers=3, output_dim=2, dropout_rate=0.2):
        super(MLPRegressor, self).__init__()
        
        self.input_layer = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate)
        )
        
        self.residual_layers = nn.ModuleList([
            ResidualBlock(hidden_dim, dropout_rate) 
            for _ in range(num_layers - 1)
        ])
        
        self.output_layer = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        x = self.input_layer(x)
        for layer in self.residual_layers:
            x = layer(x)
        return self.output_layer(x)

def print_model_params(model):
    total_params = 0
    input_params = sum(p.numel() for p in model.input_layer.parameters())
    total_params += input_params
    
    for i, block in enumerate(model.residual_layers):
        block_params = sum(p.numel() for p in block.parameters())
        total_params += block_params
    
    output_params = sum(p.numel() for p in model.output_layer.parameters())
    total_params += output_params
    
    print("-" * 50)
    print(f"Total Parameters: {total_params:,}")

def train_model(model, train_loader, val_loader, num_epochs=1000, patience=50):
    model = model.to(device)
    criterion = nn.L1Loss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)

    best_val_loss = float('inf')
    best_model = None
    patience_counter = 0
    
    # Lists to store losses for plotting
    train_losses = []
    val_losses = []
    epochs = []

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * X_batch.size(0)

        train_loss /= len(train_loader.dataset)

        # Validation phase
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)

        val_loss /= len(val_loader.dataset)

        # Store losses for plotting
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        epochs.append(epoch + 1)

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = copy.deepcopy(model)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f'Early stopping triggered at epoch {epoch+1}')
            break

        if (epoch + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.6f}, Val Loss: {val_loss:.6f}')

    return best_model, train_losses, val_losses, epochs

def train_k_fold(X, y, fold_indices, hidden_dim=128, num_layers=3, batch_size=32):
    models = []
    scalers = []
    scalers_y = []
    val_scores = []
    r2_scores_all = []

    for fold, (train_idx, val_idx) in enumerate(fold_indices):
        print(f'\nTraining Fold {fold+1}')

        # Prepare data for this fold
        train_loader, val_loader, scaler, scaler_y = prepare_fold_data(
            X, y, train_idx, val_idx, batch_size
        )

        # Initialize model
        model = MLPRegressor(
            input_dim=X.shape[1],
            hidden_dim=hidden_dim,
            num_layers=num_layers,
            output_dim=y.shape[1]
        )
        
        print_model_params(model)

        # Train model and get loss history
        best_model, train_losses, val_losses, epochs = train_model(
            model,
            train_loader,
            val_loader,
            num_epochs=10000,
            patience=500
        )

        # Plot loss evolution for this fold
        plt.figure(figsize=(10, 6))
        plt.plot(epochs[1:], train_losses[1:], label='Training Loss')
        plt.plot(epochs[1:], val_losses[1:], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title(f'Loss Evolution - Fold {fold+1}')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Store the trained model and scalers
        models.append(best_model)
        scalers.append(scaler)
        scalers_y.append(scaler_y)

        # Calculate validation scores
        mse, r2_scores, predictions, actuals = evaluate_model(best_model, val_loader, scaler_y)
        val_scores.append(mse)
        r2_scores_all.append(r2_scores)
        print(f'Fold {fold+1} Validation MSE: {mse:.4f}')
        print(f'Fold {fold+1} R² scores: {[f"{r2:.4f}" for r2 in r2_scores]}')

    # Calculate and print average metrics
    print("\nCross-validation Results:")
    print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
    r2_scores_all = np.array(r2_scores_all)
    for i, target in enumerate(['Median_meltLength', 'meanNumPixels15']):
        mean_r2 = np.mean(r2_scores_all[:, i])
        std_r2 = np.std(r2_scores_all[:, i])
        print(f"Average R² ({target}): {mean_r2:.4f} ± {std_r2:.4f}")
    
    return models, scalers, scalers_y, val_scores, r2_scores_all

def evaluate_model(model, data_loader, scaler_y):
    model = model.to(device)
    model.eval()
    criterion = nn.MSELoss()
    total_loss = 0.0

    # Lists to store predictions and actual values
    all_predictions = []
    all_actuals = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            outputs = model(X_batch)

            # Move to CPU and convert to numpy
            outputs_np = outputs.cpu().numpy()
            y_batch_np = y_batch.cpu().numpy()

            # Inverse transform
            outputs_inv = scaler_y.inverse_transform(outputs_np)
            y_batch_inv = scaler_y.inverse_transform(y_batch_np)

            # Compute loss in original scale
            loss = criterion(torch.tensor(outputs_inv), torch.tensor(y_batch_inv))
            total_loss += loss.item() * X_batch.size(0)

            all_predictions.append(outputs_inv)
            all_actuals.append(y_batch_inv)

    # Convert lists to numpy arrays
    predictions = np.vstack(all_predictions)
    actuals = np.vstack(all_actuals)

    # Calculate MSE
    mse = total_loss / len(data_loader.dataset)

    # Calculate R2 for each target
    r2_scores = []
    for i in range(actuals.shape[1]):
        ss_res = np.sum((actuals[:, i] - predictions[:, i]) ** 2)
        ss_tot = np.sum((actuals[:, i] - np.mean(actuals[:, i])) ** 2)
        r2 = 1 - (ss_res / ss_tot)
        r2_scores.append(r2)

    # Create plots
    import matplotlib.pyplot as plt

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    target_names = ['Median_meltLength', 'meanNumPixels15']

    for i, (ax, target) in enumerate(zip(axes, target_names)):
        # Plot predicted vs actual
        ax.scatter(actuals[:, i], predictions[:, i], alpha=0.5)

        # Plot perfect prediction line
        min_val = min(actuals[:, i].min(), predictions[:, i].min())
        max_val = max(actuals[:, i].max(), predictions[:, i].max())
        ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Prediction')

        # Add labels and title
        ax.set_xlabel('Actual Values')
        ax.set_ylabel('Predicted Values')
        ax.set_title(f'{target}\nR² = {r2_scores[i]:.4f}')
        ax.grid(True)
        ax.legend()

    plt.tight_layout()
    plt.show()

    # Print detailed metrics
    print("\nEvaluation Metrics:")
    print(f"MSE: {mse:.4f}")
    for i, target in enumerate(target_names):
        print(f"R² ({target}): {r2_scores[i]:.4f}")

    return mse, r2_scores, predictions, actuals


# Train the models
models, scalers, scalers_y, val_scores, r2_scores_all = train_k_fold(X, y, fold_indices, 
                                                                     hidden_dim=1024, 
                                                                     num_layers=96,
                                                                     batch_size=128)

print('---'*10)
# Print overall results
print("\nCross-validation Results:")
print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
# Out:
# Training Fold 1
# --------------------------------------------------
# Total Parameters: 199,436,290
# Epoch [10/10000], Train Loss: 0.080223, Val Loss: 0.079701
# Epoch [20/10000], Train Loss: 0.079286, Val Loss: 0.079122
# Epoch [30/10000], Train Loss: 0.077088, Val Loss: 0.079081
# Epoch [40/10000], Train Loss: 0.076257, Val Loss: 0.074979
# Epoch [50/10000], Train Loss: 0.069086, Val Loss: 0.070337
# Epoch [60/10000], Train Loss: 0.069840, Val Loss: 0.077113
# Epoch [70/10000], Train Loss: 0.065363, Val Loss: 0.066668
# Epoch [80/10000], Train Loss: 0.065146, Val Loss: 0.064423
# Epoch [90/10000], Train Loss: 0.062882, Val Loss: 0.065488
# Epoch [100/10000], Train Loss: 0.062626, Val Loss: 0.063921
# Epoch [110/10000], Train Loss: 0.063075, Val Loss: 0.064464
# Epoch [120/10000], Train Loss: 0.059873, Val Loss: 0.063662
# Epoch [130/10000], Train Loss: 0.061649, Val Loss: 0.064102
# Epoch [140/10000], Train Loss: 0.056239, Val Loss: 0.061074
# Epoch [150/10000], Train Loss: 0.057070, Val Loss: 0.059026
# Epoch [160/10000], Train Loss: 0.059371, Val Loss: 0.062158
# Epoch [170/10000], Train Loss: 0.054122, Val Loss: 0.059943
# Epoch [180/10000], Train Loss: 0.052286, Val Loss: 0.060304
# Epoch [190/10000], Train Loss: 0.051547, Val Loss: 0.059189
# Epoch [200/10000], Train Loss: 0.050583, Val Loss: 0.059576
# Epoch [210/10000], Train Loss: 0.052000, Val Loss: 0.057759
# Epoch [220/10000], Train Loss: 0.050766, Val Loss: 0.056907
# Epoch [230/10000], Train Loss: 0.048733, Val Loss: 0.056112
# Epoch [240/10000], Train Loss: 0.046420, Val Loss: 0.057094
# Epoch [250/10000], Train Loss: 0.046190, Val Loss: 0.055110
# Epoch [260/10000], Train Loss: 0.046430, Val Loss: 0.055921
# Epoch [270/10000], Train Loss: 0.045014, Val Loss: 0.056092
# Epoch [280/10000], Train Loss: 0.045222, Val Loss: 0.054204
# Epoch [290/10000], Train Loss: 0.042762, Val Loss: 0.054050
# Epoch [300/10000], Train Loss: 0.044687, Val Loss: 0.057986
# Epoch [310/10000], Train Loss: 0.040876, Val Loss: 0.053118
# Epoch [320/10000], Train Loss: 0.041211, Val Loss: 0.052630
# Epoch [330/10000], Train Loss: 0.039015, Val Loss: 0.052679
# Epoch [340/10000], Train Loss: 0.040419, Val Loss: 0.052506
# Epoch [350/10000], Train Loss: 0.037680, Val Loss: 0.053325
# Epoch [360/10000], Train Loss: 0.038166, Val Loss: 0.051921
# Epoch [370/10000], Train Loss: 0.037887, Val Loss: 0.053901
# Epoch [380/10000], Train Loss: 0.039210, Val Loss: 0.052785
# Epoch [390/10000], Train Loss: 0.036276, Val Loss: 0.053408
# Epoch [400/10000], Train Loss: 0.034590, Val Loss: 0.050979
# Epoch [410/10000], Train Loss: 0.036801, Val Loss: 0.054124
# Epoch [420/10000], Train Loss: 0.035312, Val Loss: 0.051063
# Epoch [430/10000], Train Loss: 0.034753, Val Loss: 0.049960
# Epoch [440/10000], Train Loss: 0.034050, Val Loss: 0.052016
# Epoch [450/10000], Train Loss: 0.033493, Val Loss: 0.051433
# Epoch [460/10000], Train Loss: 0.035095, Val Loss: 0.050390
# Epoch [470/10000], Train Loss: 0.032633, Val Loss: 0.051616
# Epoch [480/10000], Train Loss: 0.031662, Val Loss: 0.051565
# Epoch [490/10000], Train Loss: 0.031826, Val Loss: 0.052309
# Epoch [500/10000], Train Loss: 0.030625, Val Loss: 0.050943
# Epoch [510/10000], Train Loss: 0.032369, Val Loss: 0.052083
# Epoch [520/10000], Train Loss: 0.030225, Val Loss: 0.051716
# Epoch [530/10000], Train Loss: 0.031716, Val Loss: 0.051084
# Epoch [540/10000], Train Loss: 0.028868, Val Loss: 0.053186
# Epoch [550/10000], Train Loss: 0.031132, Val Loss: 0.050919
# Epoch [560/10000], Train Loss: 0.028848, Val Loss: 0.052123
# Epoch [570/10000], Train Loss: 0.028667, Val Loss: 0.051106
# Epoch [580/10000], Train Loss: 0.028668, Val Loss: 0.052966
# Epoch [590/10000], Train Loss: 0.029497, Val Loss: 0.051601
# Epoch [600/10000], Train Loss: 0.028446, Val Loss: 0.052663
# Epoch [610/10000], Train Loss: 0.030645, Val Loss: 0.050722
# Epoch [620/10000], Train Loss: 0.027974, Val Loss: 0.052518
# Epoch [630/10000], Train Loss: 0.029065, Val Loss: 0.053905
# Epoch [640/10000], Train Loss: 0.029587, Val Loss: 0.051517
# Epoch [650/10000], Train Loss: 0.029692, Val Loss: 0.052414
# Epoch [660/10000], Train Loss: 0.026399, Val Loss: 0.051162
# Epoch [670/10000], Train Loss: 0.029651, Val Loss: 0.054225
# Epoch [680/10000], Train Loss: 0.025893, Val Loss: 0.050231
# Epoch [690/10000], Train Loss: 0.026231, Val Loss: 0.052027
# Epoch [700/10000], Train Loss: 0.029843, Val Loss: 0.051666
# Epoch [710/10000], Train Loss: 0.024287, Val Loss: 0.050395
# Epoch [720/10000], Train Loss: 0.026909, Val Loss: 0.052972
# Epoch [730/10000], Train Loss: 0.028296, Val Loss: 0.052062
# Epoch [740/10000], Train Loss: 0.025461, Val Loss: 0.052681
# Epoch [750/10000], Train Loss: 0.024458, Val Loss: 0.050643
# Epoch [760/10000], Train Loss: 0.024378, Val Loss: 0.050739
# Epoch [770/10000], Train Loss: 0.024472, Val Loss: 0.050998
# Epoch [780/10000], Train Loss: 0.028890, Val Loss: 0.050362
# Epoch [790/10000], Train Loss: 0.024829, Val Loss: 0.051711
# Epoch [800/10000], Train Loss: 0.024009, Val Loss: 0.049814
# Epoch [810/10000], Train Loss: 0.022316, Val Loss: 0.051741
# Epoch [820/10000], Train Loss: 0.024019, Val Loss: 0.052770
# Epoch [830/10000], Train Loss: 0.022642, Val Loss: 0.052060
# Epoch [840/10000], Train Loss: 0.024329, Val Loss: 0.052996
# Epoch [850/10000], Train Loss: 0.022479, Val Loss: 0.051137
# Epoch [860/10000], Train Loss: 0.025538, Val Loss: 0.051932
# Epoch [870/10000], Train Loss: 0.025582, Val Loss: 0.053011
# Epoch [880/10000], Train Loss: 0.022702, Val Loss: 0.052307
# Epoch [890/10000], Train Loss: 0.025073, Val Loss: 0.051443
# Epoch [900/10000], Train Loss: 0.022050, Val Loss: 0.054136
# Epoch [910/10000], Train Loss: 0.023845, Val Loss: 0.051834
# Epoch [920/10000], Train Loss: 0.023022, Val Loss: 0.051135
# Epoch [930/10000], Train Loss: 0.022629, Val Loss: 0.052595
# Epoch [940/10000], Train Loss: 0.020717, Val Loss: 0.050886
# Epoch [950/10000], Train Loss: 0.020573, Val Loss: 0.050308
# Epoch [960/10000], Train Loss: 0.020151, Val Loss: 0.052003
# Epoch [970/10000], Train Loss: 0.021799, Val Loss: 0.050974
# Epoch [980/10000], Train Loss: 0.021213, Val Loss: 0.052259
# Epoch [990/10000], Train Loss: 0.023019, Val Loss: 0.053484
# Epoch [1000/10000], Train Loss: 0.021931, Val Loss: 0.053136
# Epoch [1010/10000], Train Loss: 0.019660, Val Loss: 0.051019
# Epoch [1020/10000], Train Loss: 0.019950, Val Loss: 0.051948
# Epoch [1030/10000], Train Loss: 0.025692, Val Loss: 0.054731
# Epoch [1040/10000], Train Loss: 0.024811, Val Loss: 0.051160
# Epoch [1050/10000], Train Loss: 0.021700, Val Loss: 0.051856
# Epoch [1060/10000], Train Loss: 0.019144, Val Loss: 0.050962
# Epoch [1070/10000], Train Loss: 0.018108, Val Loss: 0.051837
# Epoch [1080/10000], Train Loss: 0.019258, Val Loss: 0.052612
# Epoch [1090/10000], Train Loss: 0.018824, Val Loss: 0.051908
# Epoch [1100/10000], Train Loss: 0.018459, Val Loss: 0.052003
# Epoch [1110/10000], Train Loss: 0.021094, Val Loss: 0.051164
# Early stopping triggered at epoch 1116
# Evaluation Metrics:
# MSE: 108395.3260
# R² (Median_meltLength): 0.6782
# R² (meanNumPixels15): 0.7341
# Fold 1 Validation MSE: 108395.3260
# Fold 1 R² scores: ['0.6782', '0.7341']
#
# Training Fold 2
# --------------------------------------------------
# Total Parameters: 199,436,290
# Epoch [10/10000], Train Loss: 0.083232, Val Loss: 0.078881
# Epoch [20/10000], Train Loss: 0.080979, Val Loss: 0.079713
# Epoch [30/10000], Train Loss: 0.078569, Val Loss: 0.076504
# Epoch [40/10000], Train Loss: 0.076482, Val Loss: 0.070859
# Epoch [50/10000], Train Loss: 0.072758, Val Loss: 0.071135
# Epoch [60/10000], Train Loss: 0.073657, Val Loss: 0.067963
# Epoch [70/10000], Train Loss: 0.067441, Val Loss: 0.063705
# Epoch [80/10000], Train Loss: 0.071561, Val Loss: 0.062507
# Epoch [90/10000], Train Loss: 0.072537, Val Loss: 0.068874
# Epoch [100/10000], Train Loss: 0.066874, Val Loss: 0.065385
# Epoch [110/10000], Train Loss: 0.065905, Val Loss: 0.062535
# Epoch [120/10000], Train Loss: 0.065869, Val Loss: 0.067695
# Epoch [130/10000], Train Loss: 0.066175, Val Loss: 0.064679
# Epoch [140/10000], Train Loss: 0.064718, Val Loss: 0.063868
# Epoch [150/10000], Train Loss: 0.063193, Val Loss: 0.061772
# Epoch [160/10000], Train Loss: 0.064728, Val Loss: 0.069320
# Epoch [170/10000], Train Loss: 0.060381, Val Loss: 0.060832
# Epoch [180/10000], Train Loss: 0.071590, Val Loss: 0.067430
# Epoch [190/10000], Train Loss: 0.067338, Val Loss: 0.065691
# Epoch [200/10000], Train Loss: 0.064760, Val Loss: 0.060895
# Epoch [210/10000], Train Loss: 0.066058, Val Loss: 0.064893
# Epoch [220/10000], Train Loss: 0.066224, Val Loss: 0.063331
# Epoch [230/10000], Train Loss: 0.067768, Val Loss: 0.065996
# Epoch [240/10000], Train Loss: 0.066528, Val Loss: 0.068005
# Epoch [250/10000], Train Loss: 0.064663, Val Loss: 0.062229
# Epoch [260/10000], Train Loss: 0.063569, Val Loss: 0.060323
# Epoch [270/10000], Train Loss: 0.075690, Val Loss: 0.074691
# Epoch [280/10000], Train Loss: 0.070142, Val Loss: 0.066177
# Epoch [290/10000], Train Loss: 0.064470, Val Loss: 0.062663
# Epoch [300/10000], Train Loss: 0.065734, Val Loss: 0.061363
# Epoch [310/10000], Train Loss: 0.064608, Val Loss: 0.062881
# Epoch [320/10000], Train Loss: 0.070062, Val Loss: 0.066637
# Epoch [330/10000], Train Loss: 0.063228, Val Loss: 0.061852
# Epoch [340/10000], Train Loss: 0.063762, Val Loss: 0.062358
# Epoch [350/10000], Train Loss: 0.061821, Val Loss: 0.060788
# Epoch [360/10000], Train Loss: 0.063786, Val Loss: 0.060712
# Epoch [370/10000], Train Loss: 0.060410, Val Loss: 0.059966
# Epoch [380/10000], Train Loss: 0.060318, Val Loss: 0.058876
# Epoch [390/10000], Train Loss: 0.061602, Val Loss: 0.062063
# Epoch [400/10000], Train Loss: 0.061612, Val Loss: 0.058753
# Epoch [410/10000], Train Loss: 0.060963, Val Loss: 0.061531
# Epoch [420/10000], Train Loss: 0.064433, Val Loss: 0.062261
# Epoch [430/10000], Train Loss: 0.058040, Val Loss: 0.059940
# Epoch [440/10000], Train Loss: 0.058241, Val Loss: 0.062882
# Epoch [450/10000], Train Loss: 0.058858, Val Loss: 0.058530
# Epoch [460/10000], Train Loss: 0.056703, Val Loss: 0.057778
# Epoch [470/10000], Train Loss: 0.061198, Val Loss: 0.060626
# Epoch [480/10000], Train Loss: 0.071747, Val Loss: 0.068657
# Epoch [490/10000], Train Loss: 0.071204, Val Loss: 0.065630
# Epoch [500/10000], Train Loss: 0.062702, Val Loss: 0.057636
# Epoch [510/10000], Train Loss: 0.057038, Val Loss: 0.056127
# Epoch [520/10000], Train Loss: 0.056603, Val Loss: 0.057036
# Epoch [530/10000], Train Loss: 0.054462, Val Loss: 0.060016
# Epoch [540/10000], Train Loss: 0.054416, Val Loss: 0.055881
# Epoch [550/10000], Train Loss: 0.051495, Val Loss: 0.053438
# Epoch [560/10000], Train Loss: 0.052907, Val Loss: 0.056592
# Epoch [570/10000], Train Loss: 0.051273, Val Loss: 0.052956
# Epoch [580/10000], Train Loss: 0.051893, Val Loss: 0.053528
# Epoch [590/10000], Train Loss: 0.049102, Val Loss: 0.055650
# Epoch [600/10000], Train Loss: 0.048762, Val Loss: 0.053117
# Epoch [610/10000], Train Loss: 0.048921, Val Loss: 0.054732
# Epoch [620/10000], Train Loss: 0.047411, Val Loss: 0.053848
# Epoch [630/10000], Train Loss: 0.046522, Val Loss: 0.053099
# Epoch [640/10000], Train Loss: 0.049034, Val Loss: 0.054092
# Epoch [650/10000], Train Loss: 0.046675, Val Loss: 0.053847
# Epoch [660/10000], Train Loss: 0.045648, Val Loss: 0.053675
# Epoch [670/10000], Train Loss: 0.045323, Val Loss: 0.056195
# Epoch [680/10000], Train Loss: 0.047665, Val Loss: 0.053981
# Epoch [690/10000], Train Loss: 0.043110, Val Loss: 0.057905
# Epoch [700/10000], Train Loss: 0.043227, Val Loss: 0.053771
# Epoch [710/10000], Train Loss: 0.044950, Val Loss: 0.055279
# Epoch [720/10000], Train Loss: 0.040746, Val Loss: 0.054063
# Epoch [730/10000], Train Loss: 0.040322, Val Loss: 0.054039
# Epoch [740/10000], Train Loss: 0.043068, Val Loss: 0.056024
# Epoch [750/10000], Train Loss: 0.038903, Val Loss: 0.056507
# Epoch [760/10000], Train Loss: 0.038882, Val Loss: 0.052620
# Epoch [770/10000], Train Loss: 0.037872, Val Loss: 0.053265
# Epoch [780/10000], Train Loss: 0.039769, Val Loss: 0.055657
# Epoch [790/10000], Train Loss: 0.036895, Val Loss: 0.054195
# Epoch [800/10000], Train Loss: 0.037674, Val Loss: 0.053156
# Epoch [810/10000], Train Loss: 0.036132, Val Loss: 0.053359
# Epoch [820/10000], Train Loss: 0.035217, Val Loss: 0.052548
# Epoch [830/10000], Train Loss: 0.035280, Val Loss: 0.052544
# Epoch [840/10000], Train Loss: 0.035600, Val Loss: 0.054442
# Epoch [850/10000], Train Loss: 0.037281, Val Loss: 0.055400
# Epoch [860/10000], Train Loss: 0.034070, Val Loss: 0.053003
# Epoch [870/10000], Train Loss: 0.032012, Val Loss: 0.051537
# Epoch [880/10000], Train Loss: 0.034456, Val Loss: 0.051593
# Epoch [890/10000], Train Loss: 0.035741, Val Loss: 0.052661
# Epoch [900/10000], Train Loss: 0.036583, Val Loss: 0.053735
# Epoch [910/10000], Train Loss: 0.033172, Val Loss: 0.053305
# Epoch [920/10000], Train Loss: 0.032946, Val Loss: 0.053998
# Epoch [930/10000], Train Loss: 0.032943, Val Loss: 0.054147
# Epoch [940/10000], Train Loss: 0.032121, Val Loss: 0.054392
# Epoch [950/10000], Train Loss: 0.032974, Val Loss: 0.054176
# Epoch [960/10000], Train Loss: 0.032499, Val Loss: 0.054458
# Epoch [970/10000], Train Loss: 0.031003, Val Loss: 0.054065
# Epoch [980/10000], Train Loss: 0.031776, Val Loss: 0.052977
# Epoch [990/10000], Train Loss: 0.032751, Val Loss: 0.052758
# Epoch [1000/10000], Train Loss: 0.031990, Val Loss: 0.052634
# Epoch [1010/10000], Train Loss: 0.032119, Val Loss: 0.056191
# Epoch [1020/10000], Train Loss: 0.031022, Val Loss: 0.051829
# Epoch [1030/10000], Train Loss: 0.029746, Val Loss: 0.053485
# Epoch [1040/10000], Train Loss: 0.032381, Val Loss: 0.052119
# Epoch [1050/10000], Train Loss: 0.030807, Val Loss: 0.052367
# Epoch [1060/10000], Train Loss: 0.029554, Val Loss: 0.052849
# Epoch [1070/10000], Train Loss: 0.031879, Val Loss: 0.053398
# Epoch [1080/10000], Train Loss: 0.029855, Val Loss: 0.052504
# Epoch [1090/10000], Train Loss: 0.029296, Val Loss: 0.053007
# Epoch [1100/10000], Train Loss: 0.030655, Val Loss: 0.055288
# Epoch [1110/10000], Train Loss: 0.030289, Val Loss: 0.052946
# Epoch [1120/10000], Train Loss: 0.027324, Val Loss: 0.051714
# Epoch [1130/10000], Train Loss: 0.028431, Val Loss: 0.053521
# Epoch [1140/10000], Train Loss: 0.032368, Val Loss: 0.055883
# Epoch [1150/10000], Train Loss: 0.028020, Val Loss: 0.052585
# Epoch [1160/10000], Train Loss: 0.030515, Val Loss: 0.053607
# Epoch [1170/10000], Train Loss: 0.031503, Val Loss: 0.051902
# Epoch [1180/10000], Train Loss: 0.028099, Val Loss: 0.053124
# Epoch [1190/10000], Train Loss: 0.026733, Val Loss: 0.054716
# Epoch [1200/10000], Train Loss: 0.028063, Val Loss: 0.054985
# Epoch [1210/10000], Train Loss: 0.029061, Val Loss: 0.054411
# Epoch [1220/10000], Train Loss: 0.029828, Val Loss: 0.057391
# Epoch [1230/10000], Train Loss: 0.029653, Val Loss: 0.055590
# Epoch [1240/10000], Train Loss: 0.028277, Val Loss: 0.053304
# Epoch [1250/10000], Train Loss: 0.026770, Val Loss: 0.051304
# Epoch [1260/10000], Train Loss: 0.026932, Val Loss: 0.053439
# Epoch [1270/10000], Train Loss: 0.027823, Val Loss: 0.054636
# Epoch [1280/10000], Train Loss: 0.030305, Val Loss: 0.053942
# Epoch [1290/10000], Train Loss: 0.027655, Val Loss: 0.055103
# Epoch [1300/10000], Train Loss: 0.025800, Val Loss: 0.053820
# Epoch [1310/10000], Train Loss: 0.028460, Val Loss: 0.054025
# Early stopping triggered at epoch 1317
# Evaluation Metrics:
# MSE: 111140.4417
# R² (Median_meltLength): 0.5194
# R² (meanNumPixels15): 0.7166
# Fold 2 Validation MSE: 111140.4417
# Fold 2 R² scores: ['0.5194', '0.7166']
#
# Training Fold 3
# --------------------------------------------------
# Total Parameters: 199,436,290
# Epoch [10/10000], Train Loss: 0.085592, Val Loss: 0.084376
# Epoch [20/10000], Train Loss: 0.092767, Val Loss: 0.083440
# Epoch [30/10000], Train Loss: 0.076016, Val Loss: 0.078677
# Epoch [40/10000], Train Loss: 0.073237, Val Loss: 0.078034
# Epoch [50/10000], Train Loss: 0.071698, Val Loss: 0.077410
# Epoch [60/10000], Train Loss: 0.072920, Val Loss: 0.076627
# Epoch [70/10000], Train Loss: 0.068849, Val Loss: 0.073295
# Epoch [80/10000], Train Loss: 0.065048, Val Loss: 0.068226
# Epoch [90/10000], Train Loss: 0.070078, Val Loss: 0.077230
# Epoch [100/10000], Train Loss: 0.063238, Val Loss: 0.066215
# Epoch [110/10000], Train Loss: 0.063739, Val Loss: 0.067726
# Epoch [120/10000], Train Loss: 0.061374, Val Loss: 0.066136
# Epoch [130/10000], Train Loss: 0.063295, Val Loss: 0.068758
# Epoch [140/10000], Train Loss: 0.061107, Val Loss: 0.070869
# Epoch [150/10000], Train Loss: 0.059040, Val Loss: 0.064413
# Epoch [160/10000], Train Loss: 0.059666, Val Loss: 0.068612
# Epoch [170/10000], Train Loss: 0.058149, Val Loss: 0.064428
# Epoch [180/10000], Train Loss: 0.056182, Val Loss: 0.062345
# Epoch [190/10000], Train Loss: 0.053130, Val Loss: 0.062901
# Epoch [200/10000], Train Loss: 0.052754, Val Loss: 0.063307
# Epoch [210/10000], Train Loss: 0.051632, Val Loss: 0.065542
# Epoch [220/10000], Train Loss: 0.052281, Val Loss: 0.061016
# Epoch [230/10000], Train Loss: 0.052307, Val Loss: 0.064842
# Epoch [240/10000], Train Loss: 0.049942, Val Loss: 0.067770
# Epoch [250/10000], Train Loss: 0.054352, Val Loss: 0.061382
# Epoch [260/10000], Train Loss: 0.049342, Val Loss: 0.059129
# Epoch [270/10000], Train Loss: 0.048443, Val Loss: 0.058246
# Epoch [280/10000], Train Loss: 0.047937, Val Loss: 0.058627
# Epoch [290/10000], Train Loss: 0.049535, Val Loss: 0.066921
# Epoch [300/10000], Train Loss: 0.047096, Val Loss: 0.059279
# Epoch [310/10000], Train Loss: 0.045749, Val Loss: 0.057963
# Epoch [320/10000], Train Loss: 0.045704, Val Loss: 0.058147
# Epoch [330/10000], Train Loss: 0.044385, Val Loss: 0.061158
# Epoch [340/10000], Train Loss: 0.043984, Val Loss: 0.055661
# Epoch [350/10000], Train Loss: 0.044378, Val Loss: 0.057147
# Epoch [360/10000], Train Loss: 0.044557, Val Loss: 0.055839
# Epoch [370/10000], Train Loss: 0.043615, Val Loss: 0.058057
# Epoch [380/10000], Train Loss: 0.043480, Val Loss: 0.056941
# Epoch [390/10000], Train Loss: 0.042252, Val Loss: 0.055012
# Epoch [400/10000], Train Loss: 0.042354, Val Loss: 0.057134
# Epoch [410/10000], Train Loss: 0.041861, Val Loss: 0.055980
# Epoch [420/10000], Train Loss: 0.041213, Val Loss: 0.059735
# Epoch [430/10000], Train Loss: 0.039280, Val Loss: 0.056405
# Epoch [440/10000], Train Loss: 0.039145, Val Loss: 0.054585
# Epoch [450/10000], Train Loss: 0.041191, Val Loss: 0.055535
# Epoch [460/10000], Train Loss: 0.038561, Val Loss: 0.054757
# Epoch [470/10000], Train Loss: 0.037653, Val Loss: 0.053584
# Epoch [480/10000], Train Loss: 0.038519, Val Loss: 0.055293
# Epoch [490/10000], Train Loss: 0.038518, Val Loss: 0.056030
# Epoch [500/10000], Train Loss: 0.038602, Val Loss: 0.054470
# Epoch [510/10000], Train Loss: 0.039089, Val Loss: 0.055883
# Epoch [520/10000], Train Loss: 0.038128, Val Loss: 0.056201
# Epoch [530/10000], Train Loss: 0.038683, Val Loss: 0.054386
# Epoch [540/10000], Train Loss: 0.037114, Val Loss: 0.054755
# Epoch [550/10000], Train Loss: 0.039332, Val Loss: 0.055746
# Epoch [560/10000], Train Loss: 0.036627, Val Loss: 0.056434
# Epoch [570/10000], Train Loss: 0.034794, Val Loss: 0.055195
# Epoch [580/10000], Train Loss: 0.036484, Val Loss: 0.054402
# Epoch [590/10000], Train Loss: 0.033914, Val Loss: 0.056331
# Epoch [600/10000], Train Loss: 0.035400, Val Loss: 0.055476
# Epoch [610/10000], Train Loss: 0.035737, Val Loss: 0.055583
# Epoch [620/10000], Train Loss: 0.035344, Val Loss: 0.057637
# Epoch [630/10000], Train Loss: 0.032726, Val Loss: 0.056813
# Epoch [640/10000], Train Loss: 0.031307, Val Loss: 0.057526
# Epoch [650/10000], Train Loss: 0.033534, Val Loss: 0.055747
# Epoch [660/10000], Train Loss: 0.032286, Val Loss: 0.056346
# Epoch [670/10000], Train Loss: 0.031693, Val Loss: 0.055850
# Epoch [680/10000], Train Loss: 0.032690, Val Loss: 0.058247
# Epoch [690/10000], Train Loss: 0.032796, Val Loss: 0.056465
# Epoch [700/10000], Train Loss: 0.032037, Val Loss: 0.056242
# Epoch [710/10000], Train Loss: 0.030679, Val Loss: 0.056427
# Epoch [720/10000], Train Loss: 0.032691, Val Loss: 0.054987
# Epoch [730/10000], Train Loss: 0.030980, Val Loss: 0.057018
# Epoch [740/10000], Train Loss: 0.032527, Val Loss: 0.056956
# Epoch [750/10000], Train Loss: 0.029768, Val Loss: 0.058183
# Epoch [760/10000], Train Loss: 0.030362, Val Loss: 0.056847
# Epoch [770/10000], Train Loss: 0.029335, Val Loss: 0.056365
# Epoch [780/10000], Train Loss: 0.031686, Val Loss: 0.056972
# Epoch [790/10000], Train Loss: 0.029873, Val Loss: 0.054817
# Epoch [800/10000], Train Loss: 0.028430, Val Loss: 0.054151
# Epoch [810/10000], Train Loss: 0.030319, Val Loss: 0.057462
# Epoch [820/10000], Train Loss: 0.030109, Val Loss: 0.056591
# Epoch [830/10000], Train Loss: 0.028599, Val Loss: 0.056882
# Epoch [840/10000], Train Loss: 0.028737, Val Loss: 0.056277
# Epoch [850/10000], Train Loss: 0.027866, Val Loss: 0.056625
# Epoch [860/10000], Train Loss: 0.026858, Val Loss: 0.056181
# Epoch [870/10000], Train Loss: 0.028793, Val Loss: 0.055910
# Epoch [880/10000], Train Loss: 0.027511, Val Loss: 0.057458
# Epoch [890/10000], Train Loss: 0.028211, Val Loss: 0.056377
# Epoch [900/10000], Train Loss: 0.027557, Val Loss: 0.057766
# Epoch [910/10000], Train Loss: 0.027635, Val Loss: 0.058721
# Epoch [920/10000], Train Loss: 0.024418, Val Loss: 0.056643
# Epoch [930/10000], Train Loss: 0.028176, Val Loss: 0.058482
# Epoch [940/10000], Train Loss: 0.026481, Val Loss: 0.055796
# Epoch [950/10000], Train Loss: 0.027185, Val Loss: 0.057483
# Epoch [960/10000], Train Loss: 0.027429, Val Loss: 0.057583
# Early stopping triggered at epoch 965
# Evaluation Metrics:
# MSE: 109483.2647
# R² (Median_meltLength): 0.5947
# R² (meanNumPixels15): 0.7508
# Fold 3 Validation MSE: 109483.2647
# Fold 3 R² scores: ['0.5947', '0.7508']
#
# Training Fold 4
# --------------------------------------------------
# Total Parameters: 199,436,290
# Epoch [10/10000], Train Loss: 0.097283, Val Loss: 0.100086
# Epoch [20/10000], Train Loss: 0.097378, Val Loss: 0.100847
# Epoch [30/10000], Train Loss: 0.097198, Val Loss: 0.100709
# Epoch [40/10000], Train Loss: 0.097587, Val Loss: 0.100123
# Epoch [50/10000], Train Loss: 0.097089, Val Loss: 0.101443
# Epoch [60/10000], Train Loss: 0.097595, Val Loss: 0.100390
# Epoch [70/10000], Train Loss: 0.097327, Val Loss: 0.100489
# Epoch [80/10000], Train Loss: 0.097207, Val Loss: 0.100125
# Epoch [90/10000], Train Loss: 0.097495, Val Loss: 0.101489
# Epoch [100/10000], Train Loss: 0.097113, Val Loss: 0.100029
# Epoch [110/10000], Train Loss: 0.097291, Val Loss: 0.100271
# Epoch [120/10000], Train Loss: 0.097081, Val Loss: 0.100576
# Epoch [130/10000], Train Loss: 0.097040, Val Loss: 0.100717
# Epoch [140/10000], Train Loss: 0.096952, Val Loss: 0.100572
# Epoch [150/10000], Train Loss: 0.097223, Val Loss: 0.100016
# Epoch [160/10000], Train Loss: 0.097085, Val Loss: 0.100286
# Epoch [170/10000], Train Loss: 0.097135, Val Loss: 0.100254
# Epoch [180/10000], Train Loss: 0.083931, Val Loss: 0.086350
# Epoch [190/10000], Train Loss: 0.082867, Val Loss: 0.085911
# Epoch [200/10000], Train Loss: 0.078374, Val Loss: 0.081003
# Epoch [210/10000], Train Loss: 0.075026, Val Loss: 0.077703
# Epoch [220/10000], Train Loss: 0.072527, Val Loss: 0.076198
# Epoch [230/10000], Train Loss: 0.069952, Val Loss: 0.075872
# Epoch [240/10000], Train Loss: 0.071921, Val Loss: 0.074759
# Epoch [250/10000], Train Loss: 0.068978, Val Loss: 0.074575
# Epoch [260/10000], Train Loss: 0.067960, Val Loss: 0.072116
# Epoch [270/10000], Train Loss: 0.068067, Val Loss: 0.073097
# Epoch [280/10000], Train Loss: 0.066984, Val Loss: 0.072952
# Epoch [290/10000], Train Loss: 0.067881, Val Loss: 0.076647
# Epoch [300/10000], Train Loss: 0.066267, Val Loss: 0.071540
# Epoch [310/10000], Train Loss: 0.067708, Val Loss: 0.073385
# Epoch [320/10000], Train Loss: 0.063208, Val Loss: 0.070014
# Epoch [330/10000], Train Loss: 0.064906, Val Loss: 0.068080
# Epoch [340/10000], Train Loss: 0.065457, Val Loss: 0.070513
# Epoch [350/10000], Train Loss: 0.064923, Val Loss: 0.073199
# Epoch [360/10000], Train Loss: 0.063143, Val Loss: 0.071109
# Epoch [370/10000], Train Loss: 0.060271, Val Loss: 0.067820
# Epoch [380/10000], Train Loss: 0.059992, Val Loss: 0.069069
# Epoch [390/10000], Train Loss: 0.059542, Val Loss: 0.069310
# Epoch [400/10000], Train Loss: 0.064746, Val Loss: 0.071178
# Epoch [410/10000], Train Loss: 0.059987, Val Loss: 0.068503
# Epoch [420/10000], Train Loss: 0.057118, Val Loss: 0.068078
# Epoch [430/10000], Train Loss: 0.057715, Val Loss: 0.066596
# Epoch [440/10000], Train Loss: 0.056938, Val Loss: 0.067205
# Epoch [450/10000], Train Loss: 0.056156, Val Loss: 0.066503
# Epoch [460/10000], Train Loss: 0.055819, Val Loss: 0.067163
# Epoch [470/10000], Train Loss: 0.064946, Val Loss: 0.069825
# Epoch [480/10000], Train Loss: 0.057327, Val Loss: 0.066058
# Epoch [490/10000], Train Loss: 0.054768, Val Loss: 0.068592
# Epoch [500/10000], Train Loss: 0.054371, Val Loss: 0.065650
# Epoch [510/10000], Train Loss: 0.052997, Val Loss: 0.062842
# Epoch [520/10000], Train Loss: 0.054055, Val Loss: 0.063768
# Epoch [530/10000], Train Loss: 0.053139, Val Loss: 0.064546
# Epoch [540/10000], Train Loss: 0.051500, Val Loss: 0.063716
# Epoch [550/10000], Train Loss: 0.051660, Val Loss: 0.063916
# Epoch [560/10000], Train Loss: 0.051876, Val Loss: 0.066545
# Epoch [570/10000], Train Loss: 0.052018, Val Loss: 0.063372
# Epoch [580/10000], Train Loss: 0.050142, Val Loss: 0.062694
# Epoch [590/10000], Train Loss: 0.049734, Val Loss: 0.064218
# Epoch [600/10000], Train Loss: 0.050033, Val Loss: 0.063164
# Epoch [610/10000], Train Loss: 0.051433, Val Loss: 0.063849
# Epoch [620/10000], Train Loss: 0.049559, Val Loss: 0.063786
# Epoch [630/10000], Train Loss: 0.052339, Val Loss: 0.064679
# Epoch [640/10000], Train Loss: 0.049477, Val Loss: 0.062938
# Epoch [650/10000], Train Loss: 0.050618, Val Loss: 0.061734
# Epoch [660/10000], Train Loss: 0.050301, Val Loss: 0.061944
# Epoch [670/10000], Train Loss: 0.048423, Val Loss: 0.061636
# Epoch [680/10000], Train Loss: 0.048775, Val Loss: 0.062256
# Epoch [690/10000], Train Loss: 0.048435, Val Loss: 0.063959
# Epoch [700/10000], Train Loss: 0.049544, Val Loss: 0.062503
# Epoch [710/10000], Train Loss: 0.051273, Val Loss: 0.061880
# Epoch [720/10000], Train Loss: 0.047544, Val Loss: 0.061113
# Epoch [730/10000], Train Loss: 0.047683, Val Loss: 0.064035
# Epoch [740/10000], Train Loss: 0.046949, Val Loss: 0.061743
# Epoch [750/10000], Train Loss: 0.046440, Val Loss: 0.061924
# Epoch [760/10000], Train Loss: 0.046471, Val Loss: 0.060985
# Epoch [770/10000], Train Loss: 0.045263, Val Loss: 0.062529
# Epoch [780/10000], Train Loss: 0.046427, Val Loss: 0.063207
# Epoch [790/10000], Train Loss: 0.054951, Val Loss: 0.064063
# Epoch [800/10000], Train Loss: 0.052117, Val Loss: 0.067353
# Epoch [810/10000], Train Loss: 0.046985, Val Loss: 0.062670
# Epoch [820/10000], Train Loss: 0.045406, Val Loss: 0.061249
# Epoch [830/10000], Train Loss: 0.045703, Val Loss: 0.063198
# Epoch [840/10000], Train Loss: 0.047081, Val Loss: 0.061889
# Epoch [850/10000], Train Loss: 0.047044, Val Loss: 0.063253
# Epoch [860/10000], Train Loss: 0.045420, Val Loss: 0.060498
# Epoch [870/10000], Train Loss: 0.046870, Val Loss: 0.061927
# Epoch [880/10000], Train Loss: 0.044891, Val Loss: 0.061333
# Epoch [890/10000], Train Loss: 0.044953, Val Loss: 0.060649
# Epoch [900/10000], Train Loss: 0.044172, Val Loss: 0.061079
# Epoch [910/10000], Train Loss: 0.044222, Val Loss: 0.062966
# Epoch [920/10000], Train Loss: 0.046574, Val Loss: 0.062290
# Epoch [930/10000], Train Loss: 0.045023, Val Loss: 0.059164
# Epoch [940/10000], Train Loss: 0.044266, Val Loss: 0.060268
# Epoch [950/10000], Train Loss: 0.043074, Val Loss: 0.060648
# Epoch [960/10000], Train Loss: 0.042713, Val Loss: 0.060401
# Epoch [970/10000], Train Loss: 0.044998, Val Loss: 0.059696
# Epoch [980/10000], Train Loss: 0.046561, Val Loss: 0.062153
# Epoch [990/10000], Train Loss: 0.043734, Val Loss: 0.061592
# Epoch [1000/10000], Train Loss: 0.043388, Val Loss: 0.061616
# Epoch [1010/10000], Train Loss: 0.043213, Val Loss: 0.062890
# Epoch [1020/10000], Train Loss: 0.043945, Val Loss: 0.059623
# Epoch [1030/10000], Train Loss: 0.043583, Val Loss: 0.059105
# Epoch [1040/10000], Train Loss: 0.041447, Val Loss: 0.060209
# Epoch [1050/10000], Train Loss: 0.042137, Val Loss: 0.060908
# Epoch [1060/10000], Train Loss: 0.043565, Val Loss: 0.059699
# Epoch [1070/10000], Train Loss: 0.041374, Val Loss: 0.059997
# Epoch [1080/10000], Train Loss: 0.042378, Val Loss: 0.059843
# Epoch [1090/10000], Train Loss: 0.040786, Val Loss: 0.059553
# Epoch [1100/10000], Train Loss: 0.045047, Val Loss: 0.060587
# Epoch [1110/10000], Train Loss: 0.040473, Val Loss: 0.058838
# Epoch [1120/10000], Train Loss: 0.041890, Val Loss: 0.060654
# Epoch [1130/10000], Train Loss: 0.042626, Val Loss: 0.058955
# Epoch [1140/10000], Train Loss: 0.046204, Val Loss: 0.062814
# Epoch [1150/10000], Train Loss: 0.041500, Val Loss: 0.059848
# Epoch [1160/10000], Train Loss: 0.040093, Val Loss: 0.061491
# Epoch [1170/10000], Train Loss: 0.044091, Val Loss: 0.059327
# Epoch [1180/10000], Train Loss: 0.040443, Val Loss: 0.058127
# Epoch [1190/10000], Train Loss: 0.042392, Val Loss: 0.059098
# Epoch [1200/10000], Train Loss: 0.040860, Val Loss: 0.058466
# Epoch [1210/10000], Train Loss: 0.043136, Val Loss: 0.061616
# Epoch [1220/10000], Train Loss: 0.042180, Val Loss: 0.060167
# Epoch [1230/10000], Train Loss: 0.040034, Val Loss: 0.058324
# Epoch [1240/10000], Train Loss: 0.043650, Val Loss: 0.060233
# Epoch [1250/10000], Train Loss: 0.047727, Val Loss: 0.059422
# Epoch [1260/10000], Train Loss: 0.042268, Val Loss: 0.058445
# Epoch [1270/10000], Train Loss: 0.043196, Val Loss: 0.069553
# Epoch [1280/10000], Train Loss: 0.042012, Val Loss: 0.063206
# Epoch [1290/10000], Train Loss: 0.051045, Val Loss: 0.060569
# Epoch [1300/10000], Train Loss: 0.045332, Val Loss: 0.058888
# Epoch [1310/10000], Train Loss: 0.044780, Val Loss: 0.061448
# Epoch [1320/10000], Train Loss: 0.043762, Val Loss: 0.059464
# Epoch [1330/10000], Train Loss: 0.044462, Val Loss: 0.060936
# Epoch [1340/10000], Train Loss: 0.041884, Val Loss: 0.057068
# Epoch [1350/10000], Train Loss: 0.040090, Val Loss: 0.058850
# Epoch [1360/10000], Train Loss: 0.040688, Val Loss: 0.056781
# Epoch [1370/10000], Train Loss: 0.039482, Val Loss: 0.055599
# Epoch [1380/10000], Train Loss: 0.040343, Val Loss: 0.059418
# Epoch [1390/10000], Train Loss: 0.038989, Val Loss: 0.056049
# Epoch [1400/10000], Train Loss: 0.052582, Val Loss: 0.062480
# Epoch [1410/10000], Train Loss: 0.041711, Val Loss: 0.057715
# Epoch [1420/10000], Train Loss: 0.041758, Val Loss: 0.056612
# Epoch [1430/10000], Train Loss: 0.036884, Val Loss: 0.055838
# Epoch [1440/10000], Train Loss: 0.040183, Val Loss: 0.056754
# Epoch [1450/10000], Train Loss: 0.039609, Val Loss: 0.065515
# Epoch [1460/10000], Train Loss: 0.038702, Val Loss: 0.056334
# Epoch [1470/10000], Train Loss: 0.035860, Val Loss: 0.055867
# Epoch [1480/10000], Train Loss: 0.038076, Val Loss: 0.055851
# Epoch [1490/10000], Train Loss: 0.036710, Val Loss: 0.056698
# Epoch [1500/10000], Train Loss: 0.035261, Val Loss: 0.055236
# Epoch [1510/10000], Train Loss: 0.033508, Val Loss: 0.054364
# Epoch [1520/10000], Train Loss: 0.035375, Val Loss: 0.054565
# Epoch [1530/10000], Train Loss: 0.034611, Val Loss: 0.054143
# Epoch [1540/10000], Train Loss: 0.034405, Val Loss: 0.053844
# Epoch [1550/10000], Train Loss: 0.035984, Val Loss: 0.055283
# Epoch [1560/10000], Train Loss: 0.032154, Val Loss: 0.053863
# Epoch [1570/10000], Train Loss: 0.036276, Val Loss: 0.055837
# Epoch [1580/10000], Train Loss: 0.034241, Val Loss: 0.053161
# Epoch [1590/10000], Train Loss: 0.036532, Val Loss: 0.055705
# Epoch [1600/10000], Train Loss: 0.036254, Val Loss: 0.055573
# Epoch [1610/10000], Train Loss: 0.032971, Val Loss: 0.053788
# Epoch [1620/10000], Train Loss: 0.037608, Val Loss: 0.055853
# Epoch [1630/10000], Train Loss: 0.034747, Val Loss: 0.054707
# Epoch [1640/10000], Train Loss: 0.034243, Val Loss: 0.054441
# Epoch [1650/10000], Train Loss: 0.033283, Val Loss: 0.054029
# Epoch [1660/10000], Train Loss: 0.033976, Val Loss: 0.054864
# Epoch [1670/10000], Train Loss: 0.034661, Val Loss: 0.054539
# Epoch [1680/10000], Train Loss: 0.035249, Val Loss: 0.055248
# Epoch [1690/10000], Train Loss: 0.031223, Val Loss: 0.054047
# Epoch [1700/10000], Train Loss: 0.033048, Val Loss: 0.055448
# Epoch [1710/10000], Train Loss: 0.032503, Val Loss: 0.054774
# Epoch [1720/10000], Train Loss: 0.030757, Val Loss: 0.053010
# Epoch [1730/10000], Train Loss: 0.032797, Val Loss: 0.057284
# Epoch [1740/10000], Train Loss: 0.032991, Val Loss: 0.055489
# Epoch [1750/10000], Train Loss: 0.034975, Val Loss: 0.057407
# Epoch [1760/10000], Train Loss: 0.029942, Val Loss: 0.054975
# Epoch [1770/10000], Train Loss: 0.033414, Val Loss: 0.054753
# Epoch [1780/10000], Train Loss: 0.032291, Val Loss: 0.056127
# Epoch [1790/10000], Train Loss: 0.029249, Val Loss: 0.053512
# Epoch [1800/10000], Train Loss: 0.039463, Val Loss: 0.060936
# Epoch [1810/10000], Train Loss: 0.030583, Val Loss: 0.054657
# Epoch [1820/10000], Train Loss: 0.031468, Val Loss: 0.054888
# Epoch [1830/10000], Train Loss: 0.033495, Val Loss: 0.055894
# Epoch [1840/10000], Train Loss: 0.031091, Val Loss: 0.054003
# Epoch [1850/10000], Train Loss: 0.033048, Val Loss: 0.055979
# Epoch [1860/10000], Train Loss: 0.030779, Val Loss: 0.054519
# Epoch [1870/10000], Train Loss: 0.032621, Val Loss: 0.054345
# Epoch [1880/10000], Train Loss: 0.030461, Val Loss: 0.055209
# Epoch [1890/10000], Train Loss: 0.031275, Val Loss: 0.057375
# Epoch [1900/10000], Train Loss: 0.034637, Val Loss: 0.056441
# Epoch [1910/10000], Train Loss: 0.033287, Val Loss: 0.056365
# Epoch [1920/10000], Train Loss: 0.032596, Val Loss: 0.054054
# Epoch [1930/10000], Train Loss: 0.031253, Val Loss: 0.054517
# Epoch [1940/10000], Train Loss: 0.033279, Val Loss: 0.055579
# Epoch [1950/10000], Train Loss: 0.027599, Val Loss: 0.053830
# Epoch [1960/10000], Train Loss: 0.031093, Val Loss: 0.056811
# Epoch [1970/10000], Train Loss: 0.034823, Val Loss: 0.054787
# Epoch [1980/10000], Train Loss: 0.028928, Val Loss: 0.055366
# Epoch [1990/10000], Train Loss: 0.032983, Val Loss: 0.055250
# Epoch [2000/10000], Train Loss: 0.035769, Val Loss: 0.054807
# Epoch [2010/10000], Train Loss: 0.031017, Val Loss: 0.054061
# Epoch [2020/10000], Train Loss: 0.028932, Val Loss: 0.055206
# Epoch [2030/10000], Train Loss: 0.029528, Val Loss: 0.054244
# Epoch [2040/10000], Train Loss: 0.030907, Val Loss: 0.054046
# Epoch [2050/10000], Train Loss: 0.033297, Val Loss: 0.056360
# Epoch [2060/10000], Train Loss: 0.031443, Val Loss: 0.055002
# Epoch [2070/10000], Train Loss: 0.030591, Val Loss: 0.054832
# Early stopping triggered at epoch 2079
# Evaluation Metrics:
# MSE: 120289.9069
# R² (Median_meltLength): 0.6380
# R² (meanNumPixels15): 0.7233
# Fold 4 Validation MSE: 120289.9069
# Fold 4 R² scores: ['0.6380', '0.7233']
#
# Training Fold 5
# --------------------------------------------------
# Total Parameters: 199,436,290
# Epoch [10/10000], Train Loss: 0.080141, Val Loss: 0.081357
# Epoch [20/10000], Train Loss: 0.077984, Val Loss: 0.076799
# Epoch [30/10000], Train Loss: 0.078251, Val Loss: 0.077094
# Epoch [40/10000], Train Loss: 0.074686, Val Loss: 0.073496
# Epoch [50/10000], Train Loss: 0.072936, Val Loss: 0.070001
# Epoch [60/10000], Train Loss: 0.071334, Val Loss: 0.077306
# Epoch [70/10000], Train Loss: 0.069870, Val Loss: 0.072197
# Epoch [80/10000], Train Loss: 0.070098, Val Loss: 0.067331
# Epoch [90/10000], Train Loss: 0.064122, Val Loss: 0.065310
# Epoch [100/10000], Train Loss: 0.064668, Val Loss: 0.069352
# Epoch [110/10000], Train Loss: 0.063354, Val Loss: 0.068620
# Epoch [120/10000], Train Loss: 0.063460, Val Loss: 0.065568
# Epoch [130/10000], Train Loss: 0.066665, Val Loss: 0.064908
# Epoch [140/10000], Train Loss: 0.063630, Val Loss: 0.066050
# Epoch [150/10000], Train Loss: 0.059239, Val Loss: 0.060699
# Epoch [160/10000], Train Loss: 0.059520, Val Loss: 0.061413
# Epoch [170/10000], Train Loss: 0.060393, Val Loss: 0.065278
# Epoch [180/10000], Train Loss: 0.056864, Val Loss: 0.058709
# Epoch [190/10000], Train Loss: 0.059821, Val Loss: 0.074458
# Epoch [200/10000], Train Loss: 0.057103, Val Loss: 0.059328
# Epoch [210/10000], Train Loss: 0.056102, Val Loss: 0.060468
# Epoch [220/10000], Train Loss: 0.054913, Val Loss: 0.057034
# Epoch [230/10000], Train Loss: 0.058007, Val Loss: 0.060961
# Epoch [240/10000], Train Loss: 0.054221, Val Loss: 0.057338
# Epoch [250/10000], Train Loss: 0.054184, Val Loss: 0.057593
# Epoch [260/10000], Train Loss: 0.054384, Val Loss: 0.059224
# Epoch [270/10000], Train Loss: 0.055525, Val Loss: 0.056906
# Epoch [280/10000], Train Loss: 0.051683, Val Loss: 0.056342
# Epoch [290/10000], Train Loss: 0.050299, Val Loss: 0.054618
# Epoch [300/10000], Train Loss: 0.050985, Val Loss: 0.053614
# Epoch [310/10000], Train Loss: 0.051380, Val Loss: 0.055082
# Epoch [320/10000], Train Loss: 0.047223, Val Loss: 0.055557
# Epoch [330/10000], Train Loss: 0.046151, Val Loss: 0.052614
# Epoch [340/10000], Train Loss: 0.046381, Val Loss: 0.053816
# Epoch [350/10000], Train Loss: 0.047833, Val Loss: 0.055885
# Epoch [360/10000], Train Loss: 0.046987, Val Loss: 0.053122
# Epoch [370/10000], Train Loss: 0.043362, Val Loss: 0.050567
# Epoch [380/10000], Train Loss: 0.042846, Val Loss: 0.054351
# Epoch [390/10000], Train Loss: 0.043348, Val Loss: 0.053047
# Epoch [400/10000], Train Loss: 0.042874, Val Loss: 0.053999
# Epoch [410/10000], Train Loss: 0.043287, Val Loss: 0.049941
# Epoch [420/10000], Train Loss: 0.041666, Val Loss: 0.055507
# Epoch [430/10000], Train Loss: 0.044911, Val Loss: 0.055094
# Epoch [440/10000], Train Loss: 0.040991, Val Loss: 0.049551
# Epoch [450/10000], Train Loss: 0.040343, Val Loss: 0.050066
# Epoch [460/10000], Train Loss: 0.040038, Val Loss: 0.051089
# Epoch [470/10000], Train Loss: 0.042155, Val Loss: 0.049975
# Epoch [480/10000], Train Loss: 0.038660, Val Loss: 0.048989
# Epoch [490/10000], Train Loss: 0.037207, Val Loss: 0.049985
# Epoch [500/10000], Train Loss: 0.038222, Val Loss: 0.053162
# Epoch [510/10000], Train Loss: 0.038217, Val Loss: 0.051692
# Epoch [520/10000], Train Loss: 0.037217, Val Loss: 0.050241
# Epoch [530/10000], Train Loss: 0.038029, Val Loss: 0.049506
# Epoch [540/10000], Train Loss: 0.035117, Val Loss: 0.050621
# Epoch [550/10000], Train Loss: 0.038577, Val Loss: 0.050621
# Epoch [560/10000], Train Loss: 0.037130, Val Loss: 0.050835
# Epoch [570/10000], Train Loss: 0.036393, Val Loss: 0.051228
# Epoch [580/10000], Train Loss: 0.034591, Val Loss: 0.049873
# Epoch [590/10000], Train Loss: 0.034543, Val Loss: 0.049691
# Epoch [600/10000], Train Loss: 0.033757, Val Loss: 0.050042
# Epoch [610/10000], Train Loss: 0.035039, Val Loss: 0.052365
# Epoch [620/10000], Train Loss: 0.032597, Val Loss: 0.051300
# Epoch [630/10000], Train Loss: 0.033123, Val Loss: 0.049503
# Epoch [640/10000], Train Loss: 0.032044, Val Loss: 0.051910
# Epoch [650/10000], Train Loss: 0.034474, Val Loss: 0.051971
# Epoch [660/10000], Train Loss: 0.032928, Val Loss: 0.051995
# Epoch [670/10000], Train Loss: 0.032266, Val Loss: 0.049405
# Epoch [680/10000], Train Loss: 0.030842, Val Loss: 0.051584
# Epoch [690/10000], Train Loss: 0.032709, Val Loss: 0.052540
# Epoch [700/10000], Train Loss: 0.031283, Val Loss: 0.049042
# Epoch [710/10000], Train Loss: 0.030283, Val Loss: 0.050990
# Epoch [720/10000], Train Loss: 0.029540, Val Loss: 0.050436
# Epoch [730/10000], Train Loss: 0.029624, Val Loss: 0.050022
# Epoch [740/10000], Train Loss: 0.030422, Val Loss: 0.051431
# Epoch [750/10000], Train Loss: 0.031037, Val Loss: 0.050667
# Epoch [760/10000], Train Loss: 0.031444, Val Loss: 0.051307
# Epoch [770/10000], Train Loss: 0.028530, Val Loss: 0.049197
# Epoch [780/10000], Train Loss: 0.030793, Val Loss: 0.049879
# Epoch [790/10000], Train Loss: 0.028317, Val Loss: 0.048932
# Epoch [800/10000], Train Loss: 0.029591, Val Loss: 0.049247
# Epoch [810/10000], Train Loss: 0.029514, Val Loss: 0.050564
# Epoch [820/10000], Train Loss: 0.028824, Val Loss: 0.050688
# Epoch [830/10000], Train Loss: 0.030767, Val Loss: 0.049926
# Epoch [840/10000], Train Loss: 0.027143, Val Loss: 0.049175
# Epoch [850/10000], Train Loss: 0.027645, Val Loss: 0.049182
# Epoch [860/10000], Train Loss: 0.026648, Val Loss: 0.049629
# Epoch [870/10000], Train Loss: 0.029922, Val Loss: 0.052001
# Epoch [880/10000], Train Loss: 0.028650, Val Loss: 0.047839
# Epoch [890/10000], Train Loss: 0.026879, Val Loss: 0.047519
# Epoch [900/10000], Train Loss: 0.025850, Val Loss: 0.048809
# Epoch [910/10000], Train Loss: 0.028354, Val Loss: 0.049823
# Epoch [920/10000], Train Loss: 0.025958, Val Loss: 0.048022
# Epoch [930/10000], Train Loss: 0.026192, Val Loss: 0.047192
# Epoch [940/10000], Train Loss: 0.026516, Val Loss: 0.049634
# Epoch [950/10000], Train Loss: 0.027016, Val Loss: 0.048705
# Epoch [960/10000], Train Loss: 0.025042, Val Loss: 0.048937
# Epoch [970/10000], Train Loss: 0.024313, Val Loss: 0.049095
# Epoch [980/10000], Train Loss: 0.025081, Val Loss: 0.049343
# Epoch [990/10000], Train Loss: 0.025073, Val Loss: 0.049921
# Epoch [1000/10000], Train Loss: 0.023539, Val Loss: 0.048320
# Epoch [1010/10000], Train Loss: 0.028042, Val Loss: 0.051993
# Epoch [1020/10000], Train Loss: 0.025610, Val Loss: 0.050533
# Epoch [1030/10000], Train Loss: 0.023532, Val Loss: 0.049460
# Epoch [1040/10000], Train Loss: 0.027573, Val Loss: 0.053485
# Epoch [1050/10000], Train Loss: 0.025633, Val Loss: 0.048592
# Epoch [1060/10000], Train Loss: 0.026474, Val Loss: 0.050161
# Epoch [1070/10000], Train Loss: 0.024903, Val Loss: 0.049172
# Epoch [1080/10000], Train Loss: 0.027422, Val Loss: 0.050438
# Epoch [1090/10000], Train Loss: 0.030757, Val Loss: 0.053770
# Epoch [1100/10000], Train Loss: 0.024841, Val Loss: 0.048240
# Epoch [1110/10000], Train Loss: 0.023340, Val Loss: 0.049617
# Epoch [1120/10000], Train Loss: 0.026751, Val Loss: 0.049111
# Epoch [1130/10000], Train Loss: 0.023358, Val Loss: 0.049130
# Epoch [1140/10000], Train Loss: 0.027967, Val Loss: 0.049144
# Epoch [1150/10000], Train Loss: 0.022983, Val Loss: 0.050269
# Epoch [1160/10000], Train Loss: 0.023495, Val Loss: 0.048616
# Epoch [1170/10000], Train Loss: 0.023849, Val Loss: 0.049619
# Epoch [1180/10000], Train Loss: 0.023536, Val Loss: 0.050333
# Epoch [1190/10000], Train Loss: 0.022358, Val Loss: 0.048521
# Epoch [1200/10000], Train Loss: 0.026694, Val Loss: 0.053145
# Epoch [1210/10000], Train Loss: 0.023741, Val Loss: 0.049532
# Epoch [1220/10000], Train Loss: 0.022553, Val Loss: 0.048955
# Epoch [1230/10000], Train Loss: 0.025904, Val Loss: 0.050417
# Epoch [1240/10000], Train Loss: 0.032935, Val Loss: 0.049921
# Epoch [1250/10000], Train Loss: 0.023336, Val Loss: 0.051062
# Epoch [1260/10000], Train Loss: 0.025635, Val Loss: 0.049138
# Epoch [1270/10000], Train Loss: 0.023883, Val Loss: 0.048387
# Epoch [1280/10000], Train Loss: 0.024395, Val Loss: 0.049757
# Epoch [1290/10000], Train Loss: 0.025463, Val Loss: 0.052302
# Epoch [1300/10000], Train Loss: 0.025384, Val Loss: 0.049269
# Epoch [1310/10000], Train Loss: 0.026257, Val Loss: 0.050094
# Epoch [1320/10000], Train Loss: 0.027802, Val Loss: 0.053990
# Epoch [1330/10000], Train Loss: 0.023490, Val Loss: 0.049880
# Epoch [1340/10000], Train Loss: 0.021983, Val Loss: 0.049023
# Epoch [1350/10000], Train Loss: 0.022956, Val Loss: 0.051214
# Epoch [1360/10000], Train Loss: 0.021422, Val Loss: 0.049015
# Epoch [1370/10000], Train Loss: 0.024821, Val Loss: 0.051160
# Epoch [1380/10000], Train Loss: 0.024933, Val Loss: 0.050954
# Epoch [1390/10000], Train Loss: 0.028879, Val Loss: 0.050381
# Epoch [1400/10000], Train Loss: 0.025083, Val Loss: 0.050264
# Epoch [1410/10000], Train Loss: 0.024659, Val Loss: 0.050095
# Epoch [1420/10000], Train Loss: 0.023293, Val Loss: 0.050739
# Epoch [1430/10000], Train Loss: 0.021831, Val Loss: 0.049204
# Epoch [1440/10000], Train Loss: 0.023414, Val Loss: 0.049882
# Epoch [1450/10000], Train Loss: 0.023316, Val Loss: 0.049981
# Epoch [1460/10000], Train Loss: 0.022552, Val Loss: 0.050421
# Early stopping triggered at epoch 1467
# Evaluation Metrics:
# MSE: 99554.0635
# R² (Median_meltLength): 0.6903
# R² (meanNumPixels15): 0.7794
# Fold 5 Validation MSE: 99554.0635
# Fold 5 R² scores: ['0.6903', '0.7794']
#
# Cross-validation Results:
# Average MSE: 109772.6005 ± 6616.4012
# Average R² (Median_meltLength): 0.6241 ± 0.0622
# Average R² (meanNumPixels15): 0.7409 ± 0.0225
# ------------------------------
#
# Cross-validation Results:
# Average MSE: 109772.6005 ± 6616.4012

# %%
import os
import json
import pickle
import torch
from datetime import datetime

def save_training_results(models, scalers, scalers_y, val_scores, r2_scores_all, input_cols, target_cols):
    # Create Results directory if it doesn't exist
    results_dir = "Results"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
    
    # Create timestamped subdirectory for this training run
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = os.path.join(results_dir, f"run_{timestamp}")
    os.makedirs(run_dir)
    
    # Save models
    models_dir = os.path.join(run_dir, "models")
    os.makedirs(models_dir)
    for i, model in enumerate(models):
        model_path = os.path.join(models_dir, f"model_fold_{i+1}.pt")
        torch.save(model.state_dict(), model_path)
    
    # Save scalers
    scalers_dir = os.path.join(run_dir, "scalers")
    os.makedirs(scalers_dir)
    for i, (scaler, scaler_y) in enumerate(zip(scalers, scalers_y)):
        # Save feature scaler
        scaler_path = os.path.join(scalers_dir, f"feature_scaler_fold_{i+1}.pkl")
        with open(scaler_path, 'wb') as f:
            pickle.dump(scaler, f)
        
        # Save target scaler
        scaler_y_path = os.path.join(scalers_dir, f"target_scaler_fold_{i+1}.pkl")
        with open(scaler_y_path, 'wb') as f:
            pickle.dump(scaler_y, f)
    
    # Save metrics and configuration
    metrics = {
        'input_features': input_cols,
        'target_variables': target_cols,
        'val_scores': val_scores.tolist() if isinstance(val_scores, np.ndarray) else val_scores,
        'r2_scores_all': r2_scores_all.tolist() if isinstance(r2_scores_all, np.ndarray) else r2_scores_all,
        'average_mse': float(np.mean(val_scores)),
        'mse_std': float(np.std(val_scores)),
        'average_r2_by_target': {
            target: {
                'mean': float(np.mean(r2_scores_all[:, i])),
                'std': float(np.std(r2_scores_all[:, i]))
            }
            for i, target in enumerate(target_cols)
        }
    }
    
    metrics_path = os.path.join(run_dir, "metrics.json")
    with open(metrics_path, 'w') as f:
        json.dump(metrics, f, indent=4)
    
    print(f"\nResults saved in: {run_dir}")
    print("Saved contents:")
    print(f"- {len(models)} models")
    print(f"- {len(scalers)} feature scalers and target scalers")
    print("- Evaluation metrics and configuration")

# Call the function to save the results
save_training_results(
    models=models,
    scalers=scalers,
    scalers_y=scalers_y,  
    val_scores=val_scores,
    r2_scores_all=r2_scores_all,
    input_cols=input_cols,
    target_cols=target_cols
)
# Out:
# Results saved in: Results/run_20241115_001257
# Saved contents:
# - 5 models
# - 5 feature scalers and target scalers
# - Evaluation metrics and configuration

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms for each feature
for col in input_cols + target_cols:
    sns.histplot(data[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
import seaborn as sns

sns.pairplot(data[input_cols + target_cols])
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

r2s = []
for fold_no, indices in enumerate(fold_indices):
    
    X_train, X_val = X[indices[0]], X[indices[1]]
    y_train, y_val = y[indices[0]], y[indices[1]]

    lr_model = LinearRegression()
    lr_model.fit(X_train, y_train)
    y_pred = lr_model.predict(X_val)

    mse = mean_squared_error(y_val, y_pred)
    r2 = r2_score(y_val, y_pred, multioutput='raw_values')
    print(f'Fold:  {fold_no}')
    print(f'Linear Regression MSE: {mse:.4f}')
    print(f'Linear Regression R² scores: {r2}')
    r2s.append(r2)

r2s = np.array(r2s)
mean_score = r2s.mean(axis=0)
print(f'Cross-validation mean score {mean_score}')
# Out:
# Fold:  0
# Linear Regression MSE: 291726.9578
# Linear Regression R² scores: [0.1820264  0.28443274]
# Fold:  1
# Linear Regression MSE: 301515.3669
# Linear Regression R² scores: [0.14040448 0.23107319]
# Fold:  2
# Linear Regression MSE: 318117.6827
# Linear Regression R² scores: [0.11821145 0.27604734]
# Fold:  3
# Linear Regression MSE: 316811.5704
# Linear Regression R² scores: [0.20865499 0.27136192]
# Fold:  4
# Linear Regression MSE: 317752.1562
# Linear Regression R² scores: [0.09844954 0.29590548]
# Cross-validation mean score [0.14954937 0.27176413]

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X[train_idx])
X_val = scaler.transform(X[val_idx])

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(X_val[:, 1])
plt.plot(X_val[:, 2])
plt.plot(X_val[:, 3])
plt.plot(X_val[:, 4])

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_val)

mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred, multioutput='raw_values')
print(f'Random Forest MSE: {mse:.4f}')
print(f'Random Forest R² scores: {r2}')
# Out:
# Random Forest MSE: 97530.1821
# Random Forest R² scores: [0.73296871 0.78388648]
