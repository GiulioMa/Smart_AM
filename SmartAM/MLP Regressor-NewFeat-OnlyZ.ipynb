# %%
import pandas as pd

# Load the saved CSV file
data = pd.read_csv('processed_data.csv')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import torch
from torch.utils.data import Dataset, DataLoader

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# Define target and input variables
target_cols = ['meanLineIntensity', 'meanNumPixels15']
input_cols = ['Z'] #, 'Wall', 'Overhang', 'NoLines', 'Power', 
                   #'d_edge_right', 'd_edge_left', 'd_over_left', 
                   #'d_over_right', 'd_col', 'd_over_z']

# Extract features and targets
X = data[input_cols].values
y = data[target_cols].values

# Create a custom Dataset class
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.FloatTensor(X)
        self.y = torch.FloatTensor(y)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# Function to prepare data loaders for a specific fold
def prepare_fold_data(X, y, train_idx, val_idx, batch_size=32):
    # Always use StandardScaler for features
    scaler = StandardScaler()
    scaler_y = StandardScaler()  
    
    # Scale features
    X_train = scaler.fit_transform(X[train_idx])
    X_val = scaler.transform(X[val_idx])
    
    # Scale targets
    y_train = scaler_y.fit_transform(y[train_idx])
    y_val = scaler_y.transform(y[val_idx])
    
    # Create datasets
    train_dataset = CustomDataset(X_train, y_train)
    val_dataset = CustomDataset(X_val, y_val)
    
    # Create data loaders with larger batch size
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True
    )
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False
    )
    
    return train_loader, val_loader, scaler, scaler_y

# Set up K-Fold cross-validation
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

# Store fold indices for later use
fold_indices = []
for train_idx, val_idx in kf.split(X):
    fold_indices.append((train_idx, val_idx))

# %%
import torch.nn as nn
import torch.optim as optim
import tqdm
from tqdm import tqdm
import copy
import matplotlib.pyplot as plt

class ResidualBlock(nn.Module):
    def __init__(self, dim, dropout_rate=0.2):
        super(ResidualBlock, self).__init__()
        self.block = nn.Sequential(
            nn.Linear(dim, dim),
            #nn.BatchNorm1d(dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate),
            nn.Linear(dim, dim),
            #nn.BatchNorm1d(dim)
        )
        self.relu = nn.ReLU()
        
    def forward(self, x):
        residual = x
        out = self.block(x)
        out += residual  # Skip connection
        return self.relu(out)

class MLPRegressor(nn.Module):
    def __init__(self, input_dim=5, hidden_dim=128, num_layers=3, output_dim=2, dropout_rate=0.2):
        super(MLPRegressor, self).__init__()
        
        self.input_layer = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            #nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            #nn.Dropout(dropout_rate)
        )
        
        self.residual_layers = nn.ModuleList([
            ResidualBlock(hidden_dim, dropout_rate) 
            for _ in range(num_layers - 1)
        ])
        
        self.output_layer = nn.Linear(hidden_dim, output_dim)
        
    def forward(self, x):
        x = self.input_layer(x)
        for layer in self.residual_layers:
            x = layer(x)
        return self.output_layer(x)

def print_model_params(model):
    total_params = 0
    input_params = sum(p.numel() for p in model.input_layer.parameters())
    total_params += input_params
    
    for i, block in enumerate(model.residual_layers):
        block_params = sum(p.numel() for p in block.parameters())
        total_params += block_params
    
    output_params = sum(p.numel() for p in model.output_layer.parameters())
    total_params += output_params
    
    print("-" * 50)
    print(f"Total Parameters: {total_params:,}")

def train_model(model, train_loader, val_loader, num_epochs=1000, patience=50):
    model = model.to(device)
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=0.00001)

    best_val_loss = float('inf')
    best_model = None
    patience_counter = 0
    
    # Lists to store losses for plotting
    train_losses = []
    val_losses = []
    epochs = []

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * X_batch.size(0)

        train_loss /= len(train_loader.dataset)

        # Validation phase
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                X_batch, y_batch = X_batch.to(device), y_batch.to(device)
                outputs = model(X_batch)
                loss = criterion(outputs, y_batch)
                val_loss += loss.item() * X_batch.size(0)

        val_loss /= len(val_loader.dataset)

        # Store losses for plotting
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        epochs.append(epoch + 1)

        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model = copy.deepcopy(model)
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f'Early stopping triggered at epoch {epoch+1}')
            break

        if (epoch + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.6f}, Val Loss: {val_loss:.6f}')

    return best_model, train_losses, val_losses, epochs

def train_k_fold(X, y, fold_indices, hidden_dim=128, num_layers=3, batch_size=32):
    models = []
    scalers = []
    scalers_y = []
    val_scores = []
    r2_scores_all = []

    for fold, (train_idx, val_idx) in enumerate(fold_indices):
        print(f'\nTraining Fold {fold+1}')

        # Prepare data for this fold
        train_loader, val_loader, scaler, scaler_y = prepare_fold_data(
            X, y, train_idx, val_idx, batch_size
        )

        # Initialize model
        model = MLPRegressor(
            input_dim=X.shape[1],
            hidden_dim=hidden_dim,
            num_layers=num_layers,
            output_dim=y.shape[1]
        )
        
        print_model_params(model)

        # Train model and get loss history
        best_model, train_losses, val_losses, epochs = train_model(
            model,
            train_loader,
            val_loader,
            num_epochs=10000,
            patience=500
        )

        # Plot loss evolution for this fold
        plt.figure(figsize=(10, 6))
        plt.plot(epochs[1:], train_losses[1:], label='Training Loss')
        plt.plot(epochs[1:], val_losses[1:], label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title(f'Loss Evolution - Fold {fold+1}')
        plt.legend()
        plt.grid(True)
        plt.show()

        # Store the trained model and scalers
        models.append(best_model)
        scalers.append(scaler)
        scalers_y.append(scaler_y)

        # Calculate validation scores
        mse, r2_scores, predictions, actuals = evaluate_model(best_model, val_loader, scaler_y)
        val_scores.append(mse)
        r2_scores_all.append(r2_scores)
        print(f'Fold {fold+1} Validation MSE: {mse:.4f}')
        print(f'Fold {fold+1} R² scores: {[f"{r2:.4f}" for r2 in r2_scores]}')

    # Calculate and print average metrics
    print("\nCross-validation Results:")
    print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
    r2_scores_all = np.array(r2_scores_all)
    for i, target in enumerate(['meanLineIntensity', 'meanNumPixels15']):
        mean_r2 = np.mean(r2_scores_all[:, i])
        std_r2 = np.std(r2_scores_all[:, i])
        print(f"Average R² ({target}): {mean_r2:.4f} ± {std_r2:.4f}")
    
    return models, scalers, scalers_y, val_scores, r2_scores_all

def evaluate_model(model, data_loader, scaler_y):
    model = model.to(device)
    model.eval()
    criterion = nn.MSELoss()
    total_loss = 0.0

    # Lists to store predictions and actual values
    all_predictions = []
    all_actuals = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            outputs = model(X_batch)

            # Move to CPU and convert to numpy
            outputs_np = outputs.cpu().numpy()
            y_batch_np = y_batch.cpu().numpy()

            # Inverse transform
            outputs_inv = scaler_y.inverse_transform(outputs_np)
            y_batch_inv = scaler_y.inverse_transform(y_batch_np)

            # Compute loss in original scale
            loss = criterion(torch.tensor(outputs_inv), torch.tensor(y_batch_inv))
            total_loss += loss.item() * X_batch.size(0)

            all_predictions.append(outputs_inv)
            all_actuals.append(y_batch_inv)

    # Convert lists to numpy arrays
    predictions = np.vstack(all_predictions)
    actuals = np.vstack(all_actuals)

    # Calculate MSE
    mse = total_loss / len(data_loader.dataset)

    # Calculate R2 for each target
    r2_scores = []
    for i in range(actuals.shape[1]):
        ss_res = np.sum((actuals[:, i] - predictions[:, i]) ** 2)
        ss_tot = np.sum((actuals[:, i] - np.mean(actuals[:, i])) ** 2)
        r2 = 1 - (ss_res / ss_tot)
        r2_scores.append(r2)

    # Create plots
    import matplotlib.pyplot as plt

    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    target_names = ['meanLineIntensity', 'meanNumPixels15']

    for i, (ax, target) in enumerate(zip(axes, target_names)):
        # Plot predicted vs actual
        ax.scatter(actuals[:, i], predictions[:, i], alpha=0.5)

        # Plot perfect prediction line
        min_val = min(actuals[:, i].min(), predictions[:, i].min())
        max_val = max(actuals[:, i].max(), predictions[:, i].max())
        ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Prediction')

        # Add labels and title
        ax.set_xlabel('Actual Values')
        ax.set_ylabel('Predicted Values')
        ax.set_title(f'{target}\nR² = {r2_scores[i]:.4f}')
        ax.grid(True)
        ax.legend()

    plt.tight_layout()
    plt.show()

    # Print detailed metrics
    print("\nEvaluation Metrics:")
    print(f"MSE: {mse:.4f}")
    for i, target in enumerate(target_names):
        print(f"R² ({target}): {r2_scores[i]:.4f}")

    return mse, r2_scores, predictions, actuals


# Train the models
models, scalers, scalers_y, val_scores, r2_scores_all = train_k_fold(X, y, fold_indices, 
                                                                     hidden_dim=1024, 
                                                                     num_layers=128,
                                                                     batch_size=128)

print('---'*10)
# Print overall results
print("\nCross-validation Results:")
print(f"Average MSE: {np.mean(val_scores):.4f} ± {np.std(val_scores):.4f}")
# Out:
# Training Fold 1
# --------------------------------------------------
# Total Parameters: 266,602,498
# Epoch [10/10000], Train Loss: 0.416150, Val Loss: 0.348943
# Epoch [20/10000], Train Loss: 0.411224, Val Loss: 0.364852
# Epoch [30/10000], Train Loss: 0.414792, Val Loss: 0.378874
# Epoch [40/10000], Train Loss: 0.378940, Val Loss: 0.349283
# Epoch [50/10000], Train Loss: 0.395972, Val Loss: 0.306305
# Epoch [60/10000], Train Loss: 0.379829, Val Loss: 0.312511
# Epoch [70/10000], Train Loss: 0.382312, Val Loss: 0.297792
# Epoch [80/10000], Train Loss: 0.398782, Val Loss: 0.331319
# Epoch [90/10000], Train Loss: 0.370055, Val Loss: 0.291502
# Epoch [100/10000], Train Loss: 0.368918, Val Loss: 0.290881
# Epoch [110/10000], Train Loss: 0.359186, Val Loss: 0.305035
# Epoch [120/10000], Train Loss: 0.356251, Val Loss: 0.301500
# Epoch [130/10000], Train Loss: 0.358410, Val Loss: 0.316159
# Epoch [140/10000], Train Loss: 0.356163, Val Loss: 0.327816
# Epoch [150/10000], Train Loss: 0.366459, Val Loss: 0.315333
# Epoch [160/10000], Train Loss: 0.367334, Val Loss: 0.327405
# Epoch [170/10000], Train Loss: 0.356615, Val Loss: 0.300516
# Epoch [180/10000], Train Loss: 0.355602, Val Loss: 0.298265
# Epoch [190/10000], Train Loss: 0.352533, Val Loss: 0.289800
# Epoch [200/10000], Train Loss: 0.357136, Val Loss: 0.300851
# Epoch [210/10000], Train Loss: 0.352608, Val Loss: 0.307341
# Epoch [220/10000], Train Loss: 0.349345, Val Loss: 0.289143
# Epoch [230/10000], Train Loss: 0.363000, Val Loss: 0.301487
# Epoch [240/10000], Train Loss: 0.362516, Val Loss: 0.295645
# Epoch [250/10000], Train Loss: 0.351889, Val Loss: 0.299815
# Epoch [260/10000], Train Loss: 0.353015, Val Loss: 0.286357
# Epoch [270/10000], Train Loss: 0.350564, Val Loss: 0.285225
# Epoch [280/10000], Train Loss: 0.346264, Val Loss: 0.285366
# Epoch [290/10000], Train Loss: 0.347513, Val Loss: 0.297240
# Epoch [300/10000], Train Loss: 0.353333, Val Loss: 0.300177
# Epoch [310/10000], Train Loss: 0.373296, Val Loss: 0.319462
# Epoch [320/10000], Train Loss: 0.344681, Val Loss: 0.286677
# Epoch [330/10000], Train Loss: 0.355939, Val Loss: 0.305681
# Epoch [340/10000], Train Loss: 0.345434, Val Loss: 0.295400
# Epoch [350/10000], Train Loss: 0.352615, Val Loss: 0.300255
# Epoch [360/10000], Train Loss: 0.346162, Val Loss: 0.283058
# Epoch [370/10000], Train Loss: 0.347625, Val Loss: 0.292888
# Epoch [380/10000], Train Loss: 0.359603, Val Loss: 0.289645
# Epoch [390/10000], Train Loss: 0.362185, Val Loss: 0.323809
# Epoch [400/10000], Train Loss: 0.349066, Val Loss: 0.284129
# Epoch [410/10000], Train Loss: 0.358365, Val Loss: 0.307080
# Epoch [420/10000], Train Loss: 0.348969, Val Loss: 0.291054
# Epoch [430/10000], Train Loss: 0.349492, Val Loss: 0.306668
# Epoch [440/10000], Train Loss: 0.349821, Val Loss: 0.283036
# Epoch [450/10000], Train Loss: 0.358367, Val Loss: 0.293391
# Epoch [460/10000], Train Loss: 0.355879, Val Loss: 0.288831
# Epoch [470/10000], Train Loss: 0.355250, Val Loss: 0.290814
# Epoch [480/10000], Train Loss: 0.348858, Val Loss: 0.288239
# Epoch [490/10000], Train Loss: 0.351669, Val Loss: 0.329329
# Epoch [500/10000], Train Loss: 0.348556, Val Loss: 0.285710
# Epoch [510/10000], Train Loss: 0.348768, Val Loss: 0.298232
# Epoch [520/10000], Train Loss: 0.345453, Val Loss: 0.288908
# Epoch [530/10000], Train Loss: 0.353822, Val Loss: 0.285999
# Epoch [540/10000], Train Loss: 0.361822, Val Loss: 0.284556
# Epoch [550/10000], Train Loss: 0.352807, Val Loss: 0.290152
# Epoch [560/10000], Train Loss: 0.355632, Val Loss: 0.284686
# Epoch [570/10000], Train Loss: 0.343277, Val Loss: 0.285442
# Epoch [580/10000], Train Loss: 0.368871, Val Loss: 0.301043
# Epoch [590/10000], Train Loss: 0.386418, Val Loss: 0.316216
# Epoch [600/10000], Train Loss: 0.346404, Val Loss: 0.284695
# Epoch [610/10000], Train Loss: 0.344089, Val Loss: 0.284627
# Epoch [620/10000], Train Loss: 0.347780, Val Loss: 0.288737
# Epoch [630/10000], Train Loss: 0.341116, Val Loss: 0.285864
# Epoch [640/10000], Train Loss: 0.342561, Val Loss: 0.286160
# Epoch [650/10000], Train Loss: 0.345800, Val Loss: 0.284516
# Epoch [660/10000], Train Loss: 0.341416, Val Loss: 0.284978
# Epoch [670/10000], Train Loss: 0.358673, Val Loss: 0.291271
# Epoch [680/10000], Train Loss: 0.370516, Val Loss: 0.296040
# Epoch [690/10000], Train Loss: 0.343307, Val Loss: 0.282724
# Epoch [700/10000], Train Loss: 0.344616, Val Loss: 0.286062
# Epoch [710/10000], Train Loss: 0.355886, Val Loss: 0.298078
# Epoch [720/10000], Train Loss: 0.373583, Val Loss: 0.310963
# Epoch [730/10000], Train Loss: 0.344238, Val Loss: 0.287304
# Epoch [740/10000], Train Loss: 0.347457, Val Loss: 0.287013
# Epoch [750/10000], Train Loss: 0.347536, Val Loss: 0.286676
# Epoch [760/10000], Train Loss: 0.345316, Val Loss: 0.286337
# Epoch [770/10000], Train Loss: 0.342340, Val Loss: 0.287117
# Epoch [780/10000], Train Loss: 0.341088, Val Loss: 0.287847
# Early stopping triggered at epoch 783
# Evaluation Metrics:
# MSE: 839791660.2534
# R² (meanLineIntensity): 0.7260
# R² (meanNumPixels15): 0.6568
# Fold 1 Validation MSE: 839791660.2534
# Fold 1 R² scores: ['0.7260', '0.6568']
#
# Training Fold 2
# --------------------------------------------------
# Total Parameters: 266,602,498
# Epoch [10/10000], Train Loss: 0.384682, Val Loss: 0.373147
# Epoch [20/10000], Train Loss: 0.388805, Val Loss: 0.377049
# Epoch [30/10000], Train Loss: 0.385538, Val Loss: 0.423408
# Epoch [40/10000], Train Loss: 0.377175, Val Loss: 0.409005
# Epoch [50/10000], Train Loss: 0.351030, Val Loss: 0.342350
# Epoch [60/10000], Train Loss: 0.356501, Val Loss: 0.383337
# Epoch [70/10000], Train Loss: 0.350679, Val Loss: 0.338128
# Epoch [80/10000], Train Loss: 0.361286, Val Loss: 0.320055
# Epoch [90/10000], Train Loss: 0.345063, Val Loss: 0.313692
# Epoch [100/10000], Train Loss: 0.365924, Val Loss: 0.362107
# Epoch [110/10000], Train Loss: 0.347980, Val Loss: 0.327579
# Epoch [120/10000], Train Loss: 0.359794, Val Loss: 0.337307
# Epoch [130/10000], Train Loss: 0.346717, Val Loss: 0.336436
# Epoch [140/10000], Train Loss: 0.358103, Val Loss: 0.321520
# Epoch [150/10000], Train Loss: 0.346737, Val Loss: 0.320028
# Epoch [160/10000], Train Loss: 0.349976, Val Loss: 0.329396
# Epoch [170/10000], Train Loss: 0.359792, Val Loss: 0.324300
# Epoch [180/10000], Train Loss: 0.344960, Val Loss: 0.330259
# Epoch [190/10000], Train Loss: 0.343508, Val Loss: 0.367583
# Epoch [200/10000], Train Loss: 0.360717, Val Loss: 0.326761
# Epoch [210/10000], Train Loss: 0.337755, Val Loss: 0.316285
# Epoch [220/10000], Train Loss: 0.354109, Val Loss: 0.325801
# Epoch [230/10000], Train Loss: 0.348198, Val Loss: 0.354490
# Epoch [240/10000], Train Loss: 0.349524, Val Loss: 0.342081
# Epoch [250/10000], Train Loss: 0.342330, Val Loss: 0.319372
# Epoch [260/10000], Train Loss: 0.340145, Val Loss: 0.325759
# Epoch [270/10000], Train Loss: 0.341678, Val Loss: 0.335838
# Epoch [280/10000], Train Loss: 0.349041, Val Loss: 0.319543
# Epoch [290/10000], Train Loss: 0.343189, Val Loss: 0.325081
# Epoch [300/10000], Train Loss: 0.352493, Val Loss: 0.324035
# Epoch [310/10000], Train Loss: 0.337739, Val Loss: 0.322606
# Epoch [320/10000], Train Loss: 0.347597, Val Loss: 0.313135
# Epoch [330/10000], Train Loss: 0.364592, Val Loss: 0.344212
# Epoch [340/10000], Train Loss: 0.344397, Val Loss: 0.334740
# Epoch [350/10000], Train Loss: 0.340908, Val Loss: 0.320379
# Epoch [360/10000], Train Loss: 0.352250, Val Loss: 0.328149
# Epoch [370/10000], Train Loss: 0.347438, Val Loss: 0.326549
# Epoch [380/10000], Train Loss: 0.338080, Val Loss: 0.312420
# Epoch [390/10000], Train Loss: 0.337919, Val Loss: 0.312648
# Epoch [400/10000], Train Loss: 0.344889, Val Loss: 0.311164
# Epoch [410/10000], Train Loss: 0.340171, Val Loss: 0.313737
# Epoch [420/10000], Train Loss: 0.338134, Val Loss: 0.314157
# Epoch [430/10000], Train Loss: 0.338212, Val Loss: 0.318847
# Epoch [440/10000], Train Loss: 0.336867, Val Loss: 0.332002
# Epoch [450/10000], Train Loss: 0.337115, Val Loss: 0.309462
# Epoch [460/10000], Train Loss: 0.353265, Val Loss: 0.349980
# Epoch [470/10000], Train Loss: 0.338710, Val Loss: 0.325617
# Epoch [480/10000], Train Loss: 0.348981, Val Loss: 0.307562
# Epoch [490/10000], Train Loss: 0.341801, Val Loss: 0.318115
# Epoch [500/10000], Train Loss: 0.342559, Val Loss: 0.309667
# Epoch [510/10000], Train Loss: 0.337423, Val Loss: 0.332796
# Epoch [520/10000], Train Loss: 0.341929, Val Loss: 0.335556
# Epoch [530/10000], Train Loss: 0.342160, Val Loss: 0.313969
# Epoch [540/10000], Train Loss: 0.334772, Val Loss: 0.320693
# Epoch [550/10000], Train Loss: 0.339778, Val Loss: 0.314545
# Epoch [560/10000], Train Loss: 0.340640, Val Loss: 0.332136
# Epoch [570/10000], Train Loss: 0.342525, Val Loss: 0.315263
# Epoch [580/10000], Train Loss: 0.342267, Val Loss: 0.322258
# Epoch [590/10000], Train Loss: 0.342353, Val Loss: 0.312890
# Epoch [600/10000], Train Loss: 0.334552, Val Loss: 0.317612
# Epoch [610/10000], Train Loss: 0.334707, Val Loss: 0.313871
# Epoch [620/10000], Train Loss: 0.335764, Val Loss: 0.307107
# Epoch [630/10000], Train Loss: 0.352192, Val Loss: 0.332028
# Epoch [640/10000], Train Loss: 0.351040, Val Loss: 0.340849
# Epoch [650/10000], Train Loss: 0.356837, Val Loss: 0.334613
# Epoch [660/10000], Train Loss: 0.343891, Val Loss: 0.324765
# Epoch [670/10000], Train Loss: 0.342792, Val Loss: 0.319551
# Epoch [680/10000], Train Loss: 0.340625, Val Loss: 0.306898
# Epoch [690/10000], Train Loss: 0.336330, Val Loss: 0.310901
# Epoch [700/10000], Train Loss: 0.338757, Val Loss: 0.321775
# Epoch [710/10000], Train Loss: 0.334441, Val Loss: 0.313413
# Epoch [720/10000], Train Loss: 0.355874, Val Loss: 0.321645
# Epoch [730/10000], Train Loss: 0.351462, Val Loss: 0.336201
# Epoch [740/10000], Train Loss: 0.336735, Val Loss: 0.317603
# Epoch [750/10000], Train Loss: 0.363644, Val Loss: 0.334719
# Epoch [760/10000], Train Loss: 0.338971, Val Loss: 0.321427
# Epoch [770/10000], Train Loss: 0.334452, Val Loss: 0.314097
# Epoch [780/10000], Train Loss: 0.337526, Val Loss: 0.317169
# Epoch [790/10000], Train Loss: 0.357474, Val Loss: 0.337770
# Epoch [800/10000], Train Loss: 0.350842, Val Loss: 0.347838
# Epoch [810/10000], Train Loss: 0.343278, Val Loss: 0.335100
# Epoch [820/10000], Train Loss: 0.388045, Val Loss: 0.343254
# Epoch [830/10000], Train Loss: 0.338782, Val Loss: 0.333100
# Epoch [840/10000], Train Loss: 0.336413, Val Loss: 0.324488
# Epoch [850/10000], Train Loss: 0.338915, Val Loss: 0.319593
# Epoch [860/10000], Train Loss: 0.353147, Val Loss: 0.347657
# Epoch [870/10000], Train Loss: 0.341648, Val Loss: 0.327145
# Epoch [880/10000], Train Loss: 0.335634, Val Loss: 0.309672
# Epoch [890/10000], Train Loss: 0.336691, Val Loss: 0.309918
# Epoch [900/10000], Train Loss: 0.336113, Val Loss: 0.308695
# Epoch [910/10000], Train Loss: 0.331391, Val Loss: 0.310827
# Epoch [920/10000], Train Loss: 0.333515, Val Loss: 0.316443
# Epoch [930/10000], Train Loss: 0.333330, Val Loss: 0.312578
# Epoch [940/10000], Train Loss: 0.335491, Val Loss: 0.319771
# Epoch [950/10000], Train Loss: 0.333087, Val Loss: 0.314608
# Epoch [960/10000], Train Loss: 0.349224, Val Loss: 0.336012
# Epoch [970/10000], Train Loss: 0.345915, Val Loss: 0.334763
# Epoch [980/10000], Train Loss: 0.336905, Val Loss: 0.311913
# Epoch [990/10000], Train Loss: 0.340673, Val Loss: 0.313335
# Epoch [1000/10000], Train Loss: 0.333491, Val Loss: 0.313359
# Epoch [1010/10000], Train Loss: 0.332938, Val Loss: 0.311026
# Epoch [1020/10000], Train Loss: 0.333797, Val Loss: 0.313042
# Epoch [1030/10000], Train Loss: 0.331894, Val Loss: 0.317958
# Epoch [1040/10000], Train Loss: 0.332738, Val Loss: 0.311955
# Epoch [1050/10000], Train Loss: 0.362571, Val Loss: 0.339675
# Epoch [1060/10000], Train Loss: 0.334499, Val Loss: 0.316786
# Epoch [1070/10000], Train Loss: 0.340901, Val Loss: 0.334503
# Epoch [1080/10000], Train Loss: 0.334247, Val Loss: 0.316058
# Epoch [1090/10000], Train Loss: 0.334967, Val Loss: 0.307973
# Epoch [1100/10000], Train Loss: 0.332690, Val Loss: 0.309269
# Epoch [1110/10000], Train Loss: 0.331633, Val Loss: 0.311988
# Epoch [1120/10000], Train Loss: 0.336765, Val Loss: 0.313015
# Epoch [1130/10000], Train Loss: 0.331121, Val Loss: 0.312080
# Epoch [1140/10000], Train Loss: 0.331475, Val Loss: 0.310835
# Epoch [1150/10000], Train Loss: 0.332867, Val Loss: 0.312206
# Epoch [1160/10000], Train Loss: 0.330741, Val Loss: 0.311670
# Epoch [1170/10000], Train Loss: 0.334200, Val Loss: 0.311826
# Epoch [1180/10000], Train Loss: 0.343630, Val Loss: 0.322534
# Epoch [1190/10000], Train Loss: 0.342565, Val Loss: 0.316557
# Epoch [1200/10000], Train Loss: 0.341460, Val Loss: 0.308856
# Epoch [1210/10000], Train Loss: 0.335498, Val Loss: 0.317352
# Epoch [1220/10000], Train Loss: 0.333498, Val Loss: 0.312358
# Epoch [1230/10000], Train Loss: 0.332911, Val Loss: 0.309509
# Epoch [1240/10000], Train Loss: 0.331413, Val Loss: 0.314223
# Epoch [1250/10000], Train Loss: 0.332196, Val Loss: 0.308885
# Epoch [1260/10000], Train Loss: 0.330550, Val Loss: 0.312538
# Epoch [1270/10000], Train Loss: 0.330605, Val Loss: 0.314656
# Epoch [1280/10000], Train Loss: 0.331390, Val Loss: 0.309622
# Epoch [1290/10000], Train Loss: 0.331885, Val Loss: 0.310007
# Epoch [1300/10000], Train Loss: 0.331518, Val Loss: 0.312870
# Epoch [1310/10000], Train Loss: 0.331251, Val Loss: 0.310766
# Epoch [1320/10000], Train Loss: 0.342368, Val Loss: 0.314011
# Epoch [1330/10000], Train Loss: 0.361457, Val Loss: 0.372662
# Epoch [1340/10000], Train Loss: 0.344762, Val Loss: 0.353491
# Epoch [1350/10000], Train Loss: 0.334880, Val Loss: 0.316929
# Epoch [1360/10000], Train Loss: 0.343873, Val Loss: 0.317318
# Epoch [1370/10000], Train Loss: 0.363051, Val Loss: 0.338538
# Epoch [1380/10000], Train Loss: 0.336106, Val Loss: 0.313695
# Epoch [1390/10000], Train Loss: 0.335582, Val Loss: 0.311275
# Epoch [1400/10000], Train Loss: 0.331783, Val Loss: 0.312900
# Epoch [1410/10000], Train Loss: 0.331878, Val Loss: 0.313629
# Epoch [1420/10000], Train Loss: 0.332382, Val Loss: 0.309305
# Epoch [1430/10000], Train Loss: 0.336535, Val Loss: 0.314921
# Epoch [1440/10000], Train Loss: 0.330937, Val Loss: 0.311734
# Epoch [1450/10000], Train Loss: 0.330407, Val Loss: 0.310084
# Early stopping triggered at epoch 1456
# Evaluation Metrics:
# MSE: 906509392.3967
# R² (meanLineIntensity): 0.7080
# R² (meanNumPixels15): 0.6115
# Fold 2 Validation MSE: 906509392.3967
# Fold 2 R² scores: ['0.7080', '0.6115']
#
# Training Fold 3
# --------------------------------------------------
# Total Parameters: 266,602,498
# Epoch [10/10000], Train Loss: 0.392347, Val Loss: 0.428318
# Epoch [20/10000], Train Loss: 0.367795, Val Loss: 0.421387
# Epoch [30/10000], Train Loss: 0.374287, Val Loss: 0.401829
# Epoch [40/10000], Train Loss: 0.363950, Val Loss: 0.438714
# Epoch [50/10000], Train Loss: 0.364251, Val Loss: 0.409662
# Epoch [60/10000], Train Loss: 0.366675, Val Loss: 0.414401
# Epoch [70/10000], Train Loss: 0.354175, Val Loss: 0.406706
# Epoch [80/10000], Train Loss: 0.348160, Val Loss: 0.397689
# Epoch [90/10000], Train Loss: 0.343595, Val Loss: 0.398281
# Epoch [100/10000], Train Loss: 0.344875, Val Loss: 0.392624
# Epoch [110/10000], Train Loss: 0.344311, Val Loss: 0.415710
# Epoch [120/10000], Train Loss: 0.334607, Val Loss: 0.397352
# Epoch [130/10000], Train Loss: 0.344453, Val Loss: 0.405209
# Epoch [140/10000], Train Loss: 0.336184, Val Loss: 0.393372
# Epoch [150/10000], Train Loss: 0.360644, Val Loss: 0.445306
# Epoch [160/10000], Train Loss: 0.354672, Val Loss: 0.395816
# Epoch [170/10000], Train Loss: 0.345360, Val Loss: 0.409329
# Epoch [180/10000], Train Loss: 0.343362, Val Loss: 0.408270
# Epoch [190/10000], Train Loss: 0.348225, Val Loss: 0.426496
# Epoch [200/10000], Train Loss: 0.339520, Val Loss: 0.387097
# Epoch [210/10000], Train Loss: 0.337970, Val Loss: 0.384702
# Epoch [220/10000], Train Loss: 0.342578, Val Loss: 0.410524
# Epoch [230/10000], Train Loss: 0.342250, Val Loss: 0.397963
# Epoch [240/10000], Train Loss: 0.340751, Val Loss: 0.410045
# Epoch [250/10000], Train Loss: 0.333582, Val Loss: 0.388554
# Epoch [260/10000], Train Loss: 0.334262, Val Loss: 0.388855
# Epoch [270/10000], Train Loss: 0.335406, Val Loss: 0.401763
# Epoch [280/10000], Train Loss: 0.349908, Val Loss: 0.389355
# Epoch [290/10000], Train Loss: 0.343350, Val Loss: 0.393192
# Epoch [300/10000], Train Loss: 0.346079, Val Loss: 0.412500
# Epoch [310/10000], Train Loss: 0.375839, Val Loss: 0.394328
# Epoch [320/10000], Train Loss: 0.347305, Val Loss: 0.410665
# Epoch [330/10000], Train Loss: 0.347520, Val Loss: 0.405649
# Epoch [340/10000], Train Loss: 0.374499, Val Loss: 0.450504
# Epoch [350/10000], Train Loss: 0.342107, Val Loss: 0.386315
# Epoch [360/10000], Train Loss: 0.350112, Val Loss: 0.394077
# Epoch [370/10000], Train Loss: 0.333352, Val Loss: 0.384309
# Epoch [380/10000], Train Loss: 0.344823, Val Loss: 0.407694
# Epoch [390/10000], Train Loss: 0.338989, Val Loss: 0.386874
# Epoch [400/10000], Train Loss: 0.333186, Val Loss: 0.390889
# Epoch [410/10000], Train Loss: 0.332919, Val Loss: 0.393210
# Epoch [420/10000], Train Loss: 0.339627, Val Loss: 0.397297
# Epoch [430/10000], Train Loss: 0.330341, Val Loss: 0.384110
# Epoch [440/10000], Train Loss: 0.345793, Val Loss: 0.420876
# Epoch [450/10000], Train Loss: 0.331939, Val Loss: 0.394194
# Epoch [460/10000], Train Loss: 0.332493, Val Loss: 0.390239
# Epoch [470/10000], Train Loss: 0.327428, Val Loss: 0.386843
# Epoch [480/10000], Train Loss: 0.329582, Val Loss: 0.394577
# Epoch [490/10000], Train Loss: 0.331031, Val Loss: 0.384080
# Epoch [500/10000], Train Loss: 0.329526, Val Loss: 0.406223
# Epoch [510/10000], Train Loss: 0.329956, Val Loss: 0.389147
# Epoch [520/10000], Train Loss: 0.331900, Val Loss: 0.388274
# Epoch [530/10000], Train Loss: 0.340930, Val Loss: 0.383999
# Epoch [540/10000], Train Loss: 0.331477, Val Loss: 0.392401
# Epoch [550/10000], Train Loss: 0.332942, Val Loss: 0.386447
# Epoch [560/10000], Train Loss: 0.390392, Val Loss: 0.440629
# Epoch [570/10000], Train Loss: 0.350680, Val Loss: 0.399332
# Epoch [580/10000], Train Loss: 0.333025, Val Loss: 0.391569
# Epoch [590/10000], Train Loss: 0.342735, Val Loss: 0.392611
# Epoch [600/10000], Train Loss: 0.336223, Val Loss: 0.387255
# Epoch [610/10000], Train Loss: 0.335719, Val Loss: 0.387396
# Epoch [620/10000], Train Loss: 0.360807, Val Loss: 0.438473
# Epoch [630/10000], Train Loss: 0.333296, Val Loss: 0.389983
# Epoch [640/10000], Train Loss: 0.337840, Val Loss: 0.387385
# Epoch [650/10000], Train Loss: 0.330213, Val Loss: 0.389214
# Epoch [660/10000], Train Loss: 0.328669, Val Loss: 0.384140
# Epoch [670/10000], Train Loss: 0.332353, Val Loss: 0.386775
# Epoch [680/10000], Train Loss: 0.333277, Val Loss: 0.405431
# Epoch [690/10000], Train Loss: 0.333202, Val Loss: 0.393489
# Epoch [700/10000], Train Loss: 0.343206, Val Loss: 0.402674
# Epoch [710/10000], Train Loss: 0.329698, Val Loss: 0.393051
# Epoch [720/10000], Train Loss: 0.335384, Val Loss: 0.410749
# Epoch [730/10000], Train Loss: 0.331139, Val Loss: 0.382726
# Epoch [740/10000], Train Loss: 0.330368, Val Loss: 0.390237
# Epoch [750/10000], Train Loss: 0.335983, Val Loss: 0.392178
# Epoch [760/10000], Train Loss: 0.327575, Val Loss: 0.381940
# Epoch [770/10000], Train Loss: 0.330469, Val Loss: 0.384698
# Epoch [780/10000], Train Loss: 0.327908, Val Loss: 0.387548
# Epoch [790/10000], Train Loss: 0.372041, Val Loss: 0.406462
# Epoch [800/10000], Train Loss: 0.331204, Val Loss: 0.381835
# Epoch [810/10000], Train Loss: 0.352694, Val Loss: 0.378395
# Epoch [820/10000], Train Loss: 0.329660, Val Loss: 0.381333
# Epoch [830/10000], Train Loss: 0.334294, Val Loss: 0.389627
# Epoch [840/10000], Train Loss: 0.331049, Val Loss: 0.409594
# Epoch [850/10000], Train Loss: 0.329204, Val Loss: 0.388137
# Epoch [860/10000], Train Loss: 0.329728, Val Loss: 0.385690
# Epoch [870/10000], Train Loss: 0.329258, Val Loss: 0.392717
# Epoch [880/10000], Train Loss: 0.335190, Val Loss: 0.389110
# Epoch [890/10000], Train Loss: 0.327223, Val Loss: 0.387905
# Epoch [900/10000], Train Loss: 0.338456, Val Loss: 0.413576
# Epoch [910/10000], Train Loss: 0.332529, Val Loss: 0.416538
# Epoch [920/10000], Train Loss: 0.329346, Val Loss: 0.387122
# Epoch [930/10000], Train Loss: 0.331821, Val Loss: 0.388335
# Epoch [940/10000], Train Loss: 0.333963, Val Loss: 0.390641
# Epoch [950/10000], Train Loss: 0.326680, Val Loss: 0.381535
# Epoch [960/10000], Train Loss: 0.327047, Val Loss: 0.386216
# Epoch [970/10000], Train Loss: 0.330305, Val Loss: 0.387403
# Early stopping triggered at epoch 976
# Evaluation Metrics:
# MSE: 1154083293.3481
# R² (meanLineIntensity): 0.6823
# R² (meanNumPixels15): 0.5949
# Fold 3 Validation MSE: 1154083293.3481
# Fold 3 R² scores: ['0.6823', '0.5949']
#
# Training Fold 4
# --------------------------------------------------
# Total Parameters: 266,602,498
# Epoch [10/10000], Train Loss: 0.409866, Val Loss: 0.447130
# Epoch [20/10000], Train Loss: 0.401363, Val Loss: 0.417831
# Epoch [30/10000], Train Loss: 0.385859, Val Loss: 0.417630
# Epoch [40/10000], Train Loss: 0.404644, Val Loss: 0.488519
# Epoch [50/10000], Train Loss: 0.371516, Val Loss: 0.414716
# Epoch [60/10000], Train Loss: 0.367965, Val Loss: 0.393460
# Epoch [70/10000], Train Loss: 0.367669, Val Loss: 0.405497
# Epoch [80/10000], Train Loss: 0.347343, Val Loss: 0.390177
# Epoch [90/10000], Train Loss: 0.364185, Val Loss: 0.372435
# Epoch [100/10000], Train Loss: 0.357145, Val Loss: 0.401133
# Epoch [110/10000], Train Loss: 0.366389, Val Loss: 0.386269
# Epoch [120/10000], Train Loss: 0.355677, Val Loss: 0.397287
# Epoch [130/10000], Train Loss: 0.348274, Val Loss: 0.384219
# Epoch [140/10000], Train Loss: 0.366543, Val Loss: 0.389494
# Epoch [150/10000], Train Loss: 0.359748, Val Loss: 0.407385
# Epoch [160/10000], Train Loss: 0.340039, Val Loss: 0.380936
# Epoch [170/10000], Train Loss: 0.343947, Val Loss: 0.416745
# Epoch [180/10000], Train Loss: 0.346710, Val Loss: 0.373856
# Epoch [190/10000], Train Loss: 0.348367, Val Loss: 0.378290
# Epoch [200/10000], Train Loss: 0.345118, Val Loss: 0.378809
# Epoch [210/10000], Train Loss: 0.340803, Val Loss: 0.380624
# Epoch [220/10000], Train Loss: 0.353060, Val Loss: 0.386403
# Epoch [230/10000], Train Loss: 0.349552, Val Loss: 0.380445
# Epoch [240/10000], Train Loss: 0.343079, Val Loss: 0.404270
# Epoch [250/10000], Train Loss: 0.348998, Val Loss: 0.389813
# Epoch [260/10000], Train Loss: 0.345909, Val Loss: 0.386918
# Epoch [270/10000], Train Loss: 0.340087, Val Loss: 0.382472
# Epoch [280/10000], Train Loss: 0.335184, Val Loss: 0.380768
# Epoch [290/10000], Train Loss: 0.361011, Val Loss: 0.369433
# Epoch [300/10000], Train Loss: 0.336131, Val Loss: 0.385440
# Epoch [310/10000], Train Loss: 0.344594, Val Loss: 0.383491
# Epoch [320/10000], Train Loss: 0.355792, Val Loss: 0.399997
# Epoch [330/10000], Train Loss: 0.348117, Val Loss: 0.383020
# Epoch [340/10000], Train Loss: 0.357642, Val Loss: 0.380871
# Epoch [350/10000], Train Loss: 0.339523, Val Loss: 0.374129
# Epoch [360/10000], Train Loss: 0.345379, Val Loss: 0.381688
# Epoch [370/10000], Train Loss: 0.346532, Val Loss: 0.424013
# Epoch [380/10000], Train Loss: 0.339963, Val Loss: 0.373694
# Epoch [390/10000], Train Loss: 0.341187, Val Loss: 0.365687
# Epoch [400/10000], Train Loss: 0.336940, Val Loss: 0.373647
# Epoch [410/10000], Train Loss: 0.345735, Val Loss: 0.378268
# Epoch [420/10000], Train Loss: 0.365649, Val Loss: 0.386606
# Epoch [430/10000], Train Loss: 0.337039, Val Loss: 0.383152
# Epoch [440/10000], Train Loss: 0.333728, Val Loss: 0.386590
# Epoch [450/10000], Train Loss: 0.363403, Val Loss: 0.382879
# Epoch [460/10000], Train Loss: 0.341328, Val Loss: 0.372046
# Epoch [470/10000], Train Loss: 0.350270, Val Loss: 0.380637
# Epoch [480/10000], Train Loss: 0.343675, Val Loss: 0.389270
# Epoch [490/10000], Train Loss: 0.352991, Val Loss: 0.377036
# Epoch [500/10000], Train Loss: 0.348604, Val Loss: 0.384926
# Epoch [510/10000], Train Loss: 0.349632, Val Loss: 0.392124
# Epoch [520/10000], Train Loss: 0.336462, Val Loss: 0.377095
# Epoch [530/10000], Train Loss: 0.339569, Val Loss: 0.382490
# Epoch [540/10000], Train Loss: 0.334985, Val Loss: 0.375364
# Epoch [550/10000], Train Loss: 0.332878, Val Loss: 0.389079
# Epoch [560/10000], Train Loss: 0.336111, Val Loss: 0.374246
# Epoch [570/10000], Train Loss: 0.337890, Val Loss: 0.374990
# Epoch [580/10000], Train Loss: 0.333424, Val Loss: 0.376492
# Epoch [590/10000], Train Loss: 0.334542, Val Loss: 0.377384
# Epoch [600/10000], Train Loss: 0.338634, Val Loss: 0.381499
# Epoch [610/10000], Train Loss: 0.382040, Val Loss: 0.379743
# Epoch [620/10000], Train Loss: 0.354105, Val Loss: 0.392527
# Epoch [630/10000], Train Loss: 0.334527, Val Loss: 0.373368
# Epoch [640/10000], Train Loss: 0.341044, Val Loss: 0.379879
# Epoch [650/10000], Train Loss: 0.330440, Val Loss: 0.380772
# Epoch [660/10000], Train Loss: 0.353805, Val Loss: 0.513753
# Epoch [670/10000], Train Loss: 0.337301, Val Loss: 0.399664
# Epoch [680/10000], Train Loss: 0.349829, Val Loss: 0.374515
# Epoch [690/10000], Train Loss: 0.331967, Val Loss: 0.370950
# Epoch [700/10000], Train Loss: 0.335817, Val Loss: 0.379974
# Epoch [710/10000], Train Loss: 0.332522, Val Loss: 0.378227
# Epoch [720/10000], Train Loss: 0.330527, Val Loss: 0.371765
# Epoch [730/10000], Train Loss: 0.330708, Val Loss: 0.374142
# Epoch [740/10000], Train Loss: 0.342402, Val Loss: 0.382118
# Epoch [750/10000], Train Loss: 0.333270, Val Loss: 0.378419
# Epoch [760/10000], Train Loss: 0.334297, Val Loss: 0.374353
# Epoch [770/10000], Train Loss: 0.345114, Val Loss: 0.377145
# Epoch [780/10000], Train Loss: 0.345907, Val Loss: 0.373029
# Epoch [790/10000], Train Loss: 0.339785, Val Loss: 0.380705
# Epoch [800/10000], Train Loss: 0.347967, Val Loss: 0.370517
# Epoch [810/10000], Train Loss: 0.357369, Val Loss: 0.375618
# Epoch [820/10000], Train Loss: 0.344062, Val Loss: 0.384907
# Epoch [830/10000], Train Loss: 0.336500, Val Loss: 0.375647
# Epoch [840/10000], Train Loss: 0.332043, Val Loss: 0.382480
# Epoch [850/10000], Train Loss: 0.331842, Val Loss: 0.372140
# Epoch [860/10000], Train Loss: 0.329883, Val Loss: 0.375369
# Epoch [870/10000], Train Loss: 0.331598, Val Loss: 0.376249
# Epoch [880/10000], Train Loss: 0.329776, Val Loss: 0.392398
# Epoch [890/10000], Train Loss: 0.333889, Val Loss: 0.380361
# Epoch [900/10000], Train Loss: 0.328901, Val Loss: 0.375481
# Epoch [910/10000], Train Loss: 0.329124, Val Loss: 0.374451
# Epoch [920/10000], Train Loss: 0.329700, Val Loss: 0.377366
# Epoch [930/10000], Train Loss: 0.402124, Val Loss: 0.397930
# Epoch [940/10000], Train Loss: 0.393291, Val Loss: 0.396471
# Epoch [950/10000], Train Loss: 0.353825, Val Loss: 0.376766
# Early stopping triggered at epoch 953
# Evaluation Metrics:
# MSE: 1046480391.4254
# R² (meanLineIntensity): 0.7154
# R² (meanNumPixels15): 0.5983
# Fold 4 Validation MSE: 1046480391.4254
# Fold 4 R² scores: ['0.7154', '0.5983']
#
# Training Fold 5
# --------------------------------------------------
# Total Parameters: 266,602,498
# Epoch [10/10000], Train Loss: 0.399911, Val Loss: 0.414922
# Epoch [20/10000], Train Loss: 0.375987, Val Loss: 0.414539
# Epoch [30/10000], Train Loss: 0.383534, Val Loss: 0.440621
# Epoch [40/10000], Train Loss: 0.379858, Val Loss: 0.414020
# Epoch [50/10000], Train Loss: 0.363739, Val Loss: 0.402572
# Epoch [60/10000], Train Loss: 0.388654, Val Loss: 0.397211
# Epoch [70/10000], Train Loss: 0.354611, Val Loss: 0.403258
# Epoch [80/10000], Train Loss: 0.368022, Val Loss: 0.417879
# Epoch [90/10000], Train Loss: 0.353224, Val Loss: 0.398386
# Epoch [100/10000], Train Loss: 0.394448, Val Loss: 0.423675
# Epoch [110/10000], Train Loss: 0.386906, Val Loss: 0.446688
# Epoch [120/10000], Train Loss: 0.389671, Val Loss: 0.392313
# Epoch [130/10000], Train Loss: 0.365788, Val Loss: 0.387464
# Epoch [140/10000], Train Loss: 0.349256, Val Loss: 0.437559
# Epoch [150/10000], Train Loss: 0.346140, Val Loss: 0.405132
# Epoch [160/10000], Train Loss: 0.356958, Val Loss: 0.391430
# Epoch [170/10000], Train Loss: 0.349650, Val Loss: 0.394139
# Epoch [180/10000], Train Loss: 0.346383, Val Loss: 0.388832
# Epoch [190/10000], Train Loss: 0.344767, Val Loss: 0.394508
# Epoch [200/10000], Train Loss: 0.339809, Val Loss: 0.388391
# Epoch [210/10000], Train Loss: 0.348527, Val Loss: 0.385156
# Epoch [220/10000], Train Loss: 0.351293, Val Loss: 0.392500
# Epoch [230/10000], Train Loss: 0.350878, Val Loss: 0.415866
# Epoch [240/10000], Train Loss: 0.364666, Val Loss: 0.396972
# Epoch [250/10000], Train Loss: 0.350518, Val Loss: 0.422622
# Epoch [260/10000], Train Loss: 0.351559, Val Loss: 0.399159
# Epoch [270/10000], Train Loss: 0.349240, Val Loss: 0.391512
# Epoch [280/10000], Train Loss: 0.345757, Val Loss: 0.383945
# Epoch [290/10000], Train Loss: 0.341247, Val Loss: 0.391382
# Epoch [300/10000], Train Loss: 0.347468, Val Loss: 0.399269
# Epoch [310/10000], Train Loss: 0.338188, Val Loss: 0.383309
# Epoch [320/10000], Train Loss: 0.347917, Val Loss: 0.386238
# Epoch [330/10000], Train Loss: 0.339463, Val Loss: 0.393877
# Epoch [340/10000], Train Loss: 0.336117, Val Loss: 0.394708
# Epoch [350/10000], Train Loss: 0.343310, Val Loss: 0.389742
# Epoch [360/10000], Train Loss: 0.343892, Val Loss: 0.391537
# Epoch [370/10000], Train Loss: 0.348459, Val Loss: 0.391143
# Epoch [380/10000], Train Loss: 0.340817, Val Loss: 0.387786
# Epoch [390/10000], Train Loss: 0.338028, Val Loss: 0.400487
# Epoch [400/10000], Train Loss: 0.354777, Val Loss: 0.394197
# Epoch [410/10000], Train Loss: 0.339916, Val Loss: 0.379512
# Epoch [420/10000], Train Loss: 0.377063, Val Loss: 0.441466
# Epoch [430/10000], Train Loss: 0.373394, Val Loss: 0.394108
# Epoch [440/10000], Train Loss: 0.342341, Val Loss: 0.384165
# Epoch [450/10000], Train Loss: 0.375612, Val Loss: 0.421592
# Epoch [460/10000], Train Loss: 0.344261, Val Loss: 0.412533
# Epoch [470/10000], Train Loss: 0.339095, Val Loss: 0.389150
# Epoch [480/10000], Train Loss: 0.362583, Val Loss: 0.414334
# Epoch [490/10000], Train Loss: 0.338132, Val Loss: 0.390559
# Epoch [500/10000], Train Loss: 0.345032, Val Loss: 0.373097
# Epoch [510/10000], Train Loss: 0.338214, Val Loss: 0.394279
# Epoch [520/10000], Train Loss: 0.337628, Val Loss: 0.388857
# Epoch [530/10000], Train Loss: 0.338954, Val Loss: 0.393974
# Epoch [540/10000], Train Loss: 0.334035, Val Loss: 0.387274
# Epoch [550/10000], Train Loss: 0.336078, Val Loss: 0.393142
# Epoch [560/10000], Train Loss: 0.338547, Val Loss: 0.398930
# Epoch [570/10000], Train Loss: 0.339419, Val Loss: 0.400059
# Epoch [580/10000], Train Loss: 0.345256, Val Loss: 0.395436
# Epoch [590/10000], Train Loss: 0.345423, Val Loss: 0.394984
# Epoch [600/10000], Train Loss: 0.348852, Val Loss: 0.410120
# Epoch [610/10000], Train Loss: 0.345407, Val Loss: 0.382056
# Epoch [620/10000], Train Loss: 0.334433, Val Loss: 0.383827
# Epoch [630/10000], Train Loss: 0.337742, Val Loss: 0.400282
# Epoch [640/10000], Train Loss: 0.338730, Val Loss: 0.378763
# Epoch [650/10000], Train Loss: 0.338119, Val Loss: 0.401039
# Epoch [660/10000], Train Loss: 0.372301, Val Loss: 0.389594
# Epoch [670/10000], Train Loss: 0.363904, Val Loss: 0.390544
# Epoch [680/10000], Train Loss: 0.354733, Val Loss: 0.394613
# Epoch [690/10000], Train Loss: 0.341255, Val Loss: 0.385663
# Epoch [700/10000], Train Loss: 0.340021, Val Loss: 0.385234
# Epoch [710/10000], Train Loss: 0.347028, Val Loss: 0.394554
# Epoch [720/10000], Train Loss: 0.340482, Val Loss: 0.387717
# Epoch [730/10000], Train Loss: 0.336890, Val Loss: 0.389600
# Epoch [740/10000], Train Loss: 0.336009, Val Loss: 0.381725
# Epoch [750/10000], Train Loss: 0.337783, Val Loss: 0.393782
# Epoch [760/10000], Train Loss: 0.335083, Val Loss: 0.386169
# Epoch [770/10000], Train Loss: 0.333952, Val Loss: 0.390469
# Epoch [780/10000], Train Loss: 0.336871, Val Loss: 0.380221
# Epoch [790/10000], Train Loss: 0.334083, Val Loss: 0.385556
# Epoch [800/10000], Train Loss: 0.334559, Val Loss: 0.384795
# Epoch [810/10000], Train Loss: 0.336025, Val Loss: 0.390565
# Epoch [820/10000], Train Loss: 0.332746, Val Loss: 0.384476
# Epoch [830/10000], Train Loss: 0.334678, Val Loss: 0.384960
# Epoch [840/10000], Train Loss: 0.334617, Val Loss: 0.385936
# Epoch [850/10000], Train Loss: 0.365013, Val Loss: 0.407093
# Epoch [860/10000], Train Loss: 0.343565, Val Loss: 0.425340
# Epoch [870/10000], Train Loss: 0.335933, Val Loss: 0.384705
# Epoch [880/10000], Train Loss: 0.339490, Val Loss: 0.384561
# Epoch [890/10000], Train Loss: 0.340389, Val Loss: 0.390173
# Epoch [900/10000], Train Loss: 0.382070, Val Loss: 0.391573
# Epoch [910/10000], Train Loss: 0.338113, Val Loss: 0.386533
# Epoch [920/10000], Train Loss: 0.337890, Val Loss: 0.394123
# Epoch [930/10000], Train Loss: 0.337868, Val Loss: 0.387196
# Epoch [940/10000], Train Loss: 0.336055, Val Loss: 0.388550
# Epoch [950/10000], Train Loss: 0.335449, Val Loss: 0.386634
# Epoch [960/10000], Train Loss: 0.366163, Val Loss: 0.397428
# Epoch [970/10000], Train Loss: 0.350753, Val Loss: 0.388963
# Epoch [980/10000], Train Loss: 0.360841, Val Loss: 0.390051
# Epoch [990/10000], Train Loss: 0.339932, Val Loss: 0.382316
# Early stopping triggered at epoch 1000
# Evaluation Metrics:
# MSE: 1090738986.4309
# R² (meanLineIntensity): 0.7147
# R² (meanNumPixels15): 0.6077
# Fold 5 Validation MSE: 1090738986.4309
# Fold 5 R² scores: ['0.7147', '0.6077']
#
# Cross-validation Results:
# Average MSE: 1007520744.7709 ± 116841815.7676
# Average R² (meanLineIntensity): 0.7093 ± 0.0147
# Average R² (meanNumPixels15): 0.6138 ± 0.0223
# ------------------------------
#
# Cross-validation Results:
# Average MSE: 1007520744.7709 ± 116841815.7676

# %%
import os
import json
import pickle
import torch
from datetime import datetime

def save_training_results(models, scalers, scalers_y, val_scores, r2_scores_all, input_cols, target_cols):
    # Create Results directory if it doesn't exist
    results_dir = "Results"
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
    
    # Create timestamped subdirectory for this training run
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    run_dir = os.path.join(results_dir, f"run_{timestamp}")
    os.makedirs(run_dir)
    
    # Save models
    models_dir = os.path.join(run_dir, "models")
    os.makedirs(models_dir)
    for i, model in enumerate(models):
        model_path = os.path.join(models_dir, f"model_fold_{i+1}.pt")
        torch.save(model.state_dict(), model_path)
    
    # Save scalers
    scalers_dir = os.path.join(run_dir, "scalers")
    os.makedirs(scalers_dir)
    for i, (scaler, scaler_y) in enumerate(zip(scalers, scalers_y)):
        # Save feature scaler
        scaler_path = os.path.join(scalers_dir, f"feature_scaler_fold_{i+1}.pkl")
        with open(scaler_path, 'wb') as f:
            pickle.dump(scaler, f)
        
        # Save target scaler
        scaler_y_path = os.path.join(scalers_dir, f"target_scaler_fold_{i+1}.pkl")
        with open(scaler_y_path, 'wb') as f:
            pickle.dump(scaler_y, f)
    
    # Save metrics and configuration
    metrics = {
        'input_features': input_cols,
        'target_variables': target_cols,
        'val_scores': val_scores.tolist() if isinstance(val_scores, np.ndarray) else val_scores,
        'r2_scores_all': r2_scores_all.tolist() if isinstance(r2_scores_all, np.ndarray) else r2_scores_all,
        'average_mse': float(np.mean(val_scores)),
        'mse_std': float(np.std(val_scores)),
        'average_r2_by_target': {
            target: {
                'mean': float(np.mean(r2_scores_all[:, i])),
                'std': float(np.std(r2_scores_all[:, i]))
            }
            for i, target in enumerate(target_cols)
        }
    }
    
    metrics_path = os.path.join(run_dir, "metrics.json")
    with open(metrics_path, 'w') as f:
        json.dump(metrics, f, indent=4)
    
    print(f"\nResults saved in: {run_dir}")
    print("Saved contents:")
    print(f"- {len(models)} models")
    print(f"- {len(scalers)} feature scalers and target scalers")
    print("- Evaluation metrics and configuration")

# Call the function to save the results
save_training_results(
    models=models,
    scalers=scalers,
    scalers_y=scalers_y,  
    val_scores=val_scores,
    r2_scores_all=r2_scores_all,
    input_cols=input_cols,
    target_cols=target_cols
)
# Out:
# Results saved in: Results/run_20241118_114105
# Saved contents:
# - 5 models
# - 5 feature scalers and target scalers
# - Evaluation metrics and configuration

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms for each feature
for col in input_cols + target_cols:
    sns.histplot(data[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
import seaborn as sns

sns.pairplot(data[input_cols + target_cols])
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

r2s = []
for fold_no, indices in enumerate(fold_indices):
    
    X_train, X_val = X[indices[0]], X[indices[1]]
    y_train, y_val = y[indices[0]], y[indices[1]]

    lr_model = LinearRegression()
    lr_model.fit(X_train, y_train)
    y_pred = lr_model.predict(X_val)

    mse = mean_squared_error(y_val, y_pred)
    r2 = r2_score(y_val, y_pred, multioutput='raw_values')
    print(f'Fold:  {fold_no}')
    print(f'Linear Regression MSE: {mse:.4f}')
    print(f'Linear Regression R² scores: {r2}')
    r2s.append(r2)

r2s = np.array(r2s)
mean_score = r2s.mean(axis=0)
print(f'Cross-validation mean score {mean_score}')
# Out:
# Fold:  0
# Linear Regression MSE: 2375248061.3263
# Linear Regression R² scores: [0.22496534 0.04676664]
# Fold:  1
# Linear Regression MSE: 2229745704.0687
# Linear Regression R² scores: [0.28172475 0.07185833]
# Fold:  2
# Linear Regression MSE: 2501458926.4102
# Linear Regression R² scores: [0.311476   0.08971802]
# Fold:  3
# Linear Regression MSE: 2298515924.1367
# Linear Regression R² scores: [0.37498489 0.11555767]
# Fold:  4
# Linear Regression MSE: 2608004070.7544
# Linear Regression R² scores: [0.31789411 0.07631435]
# Cross-validation mean score [0.30220902 0.080043  ]

# %%
from sklearn.ensemble import RandomForestRegressor

r2s = []
for fold_no, indices in enumerate(fold_indices):
    
    X_train, X_val = X[indices[0]], X[indices[1]]
    y_train, y_val = y[indices[0]], y[indices[1]]
    rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
    rf_model.fit(X_train, y_train)
    y_pred = rf_model.predict(X_val)

    mse = mean_squared_error(y_val, y_pred)
    r2 = r2_score(y_val, y_pred, multioutput='raw_values')
    print(f'Fold:  {fold_no}')
    print(f'Random Forest MSE: {mse:.4f}')
    print(f'Random Forest R² scores: {r2}')
    r2s.append(r2)
    
    #plot predictions
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    target_names = ['meanLineIntensity', 'meanNumPixels15']

    for i, (ax, target) in enumerate(zip(axes, target_names)):
        # Plot predicted vs actual
        ax.scatter(y_val[:, i], y_pred[:, i], alpha=0.5)

        # Plot perfect prediction line
        min_val = min(y_val[:, i].min(), y_pred[:, i].min())
        max_val = max(y_val[:, i].max(), y_pred[:, i].max())
        ax.plot([min_val, max_val], [min_val, max_val], 'r--', label='Perfect Prediction')

        # Add labels and title
        ax.set_xlabel('Actual Values')
        ax.set_ylabel('Predicted Values')
        ax.set_title(f'{target}\nR² = {r2[i]:.4f}')
        ax.grid(True)
        ax.legend()

    plt.tight_layout()
    plt.show()


r2s = np.array(r2s)
mean_score = r2s.mean(axis=0)
print(f'Cross-validation mean score {mean_score}')
# Out:
# Fold:  0
# Random Forest MSE: 847111606.8362
# Random Forest R² scores: [0.72359172 0.65168681]
# Fold:  1
# Random Forest MSE: 932071826.8150
# Random Forest R² scores: [0.6997503  0.59908325]
# Fold:  2
# Random Forest MSE: 1166365627.9094
# Random Forest R² scores: [0.67895746 0.58878464]
# Fold:  3
# Random Forest MSE: 1102822349.2179
# Random Forest R² scores: [0.70011861 0.58125201]
# Fold:  4
# Random Forest MSE: 1123436201.1280
# Random Forest R² scores: [0.70617396 0.59259051]
# Cross-validation mean score [0.70171841 0.60267944]
